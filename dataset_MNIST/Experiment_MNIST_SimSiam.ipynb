# %% [markdown]
# ## Conifuration

# %%
#import the lib for contrastive learning framework
# !pip install lightly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lightly
#   Downloading lightly-1.2.19-py3-none-any.whl (449 kB)
#      |████████████████████████████████| 449 kB 28.4 MB/s
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.7/dist-packages (from lightly) (4.64.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.21.6)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (57.4.0)
# Collecting lightly-utils~=0.0.0
#   Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.8.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.23.0)
# Collecting hydra-core>=1.0.0
#   Downloading hydra_core-1.2.0-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 63.0 MB/s
# Collecting pytorch-lightning>=1.0.4
#   Downloading pytorch_lightning-1.6.4-py3-none-any.whl (585 kB)
#      |████████████████████████████████| 585 kB 50.7 MB/s
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.7/dist-packages (from lightly) (2022.6.15)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from lightly) (0.12.0+cu113)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.24.3)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.15.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (5.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (21.3)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      |████████████████████████████████| 117 kB 72.7 MB/s
# Collecting omegaconf~=2.2
#   Downloading omegaconf-2.2.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 6.8 MB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from lightly-utils~=0.0.0->lightly) (7.1.2)
# Collecting PyYAML>=5.1.0
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 50.3 MB/s
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (1.11.0+cu113)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2.8.0)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 56.4 MB/s
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (4.1.1)
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.9.1-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 55.1 MB/s
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (3.17.3)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 41.6 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->hydra-core>=1.0.0->lightly) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (3.0.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.3.7)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.1.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.46.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.2.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 69.5 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 66.9 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (21.4.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (2.0.12)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 4.0 MB/s
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=0ec2aef84bbe7f444689f02db546bb3517cfce2f4402714f66988e3db5c7a604
#   Stored in directory: /root/.cache/pip/wheels/8b/8d/53/2af8772d9aec614e3fc65e53d4a993ad73c61daa8bbd85a873
# Successfully built antlr4-python3-runtime
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, PyYAML, fsspec, antlr4-python3-runtime, aiohttp, torchmetrics, pyDeprecate, omegaconf, pytorch-lightning, lightly-utils, hydra-core, lightly
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-6.0 aiohttp-3.8.1 aiosignal-1.2.0 antlr4-python3-runtime-4.9.3 async-timeout-4.0.2 asynctest-0.13.0 frozenlist-1.3.0 fsspec-2022.5.0 hydra-core-1.2.0 lightly-1.2.19 lightly-utils-0.0.2 multidict-6.0.2 omegaconf-2.2.2 pyDeprecate-0.3.2 pytorch-lightning-1.6.4 torchmetrics-0.9.1 yarl-1.7.2

# %%
import lightly
from lightly.models.modules.heads import SimSiamPredictionHead
from lightly.models.modules.heads import SimSiamProjectionHead

from lightly.data import LightlyDataset
from lightly.data import ImageCollateFunction
from lightly.models.modules import BarlowTwinsProjectionHead
from lightly.loss import BarlowTwinsLoss

from lightly.data import LightlyDataset
from lightly.data import SimCLRCollateFunction
from lightly.loss import NTXentLoss
from lightly.loss import NegativeCosineSimilarity
from lightly.models.modules import SimCLRProjectionHead

# %%
import math
import torch
import torch.nn as nn
import torchvision
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from torch.utils.data import Dataset, DataLoader
import torch.optim as torch_optim
import torch.optim.lr_scheduler as lr_scheduler
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
from datetime import datetime

from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from matplotlib import pyplot
import seaborn as sns

from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_mutual_info_score
from sklearn.metrics import silhouette_score
from sklearn import mixture
from sklearn.cluster import DBSCAN
from sklearn.cluster import OPTICS
from sklearn.cluster import AgglomerativeClustering

import tensorboard
from tensorboard import notebook
from torch.utils.tensorboard import SummaryWriter

import matplotlib 
import matplotlib.pyplot as plt
#import plotly.express as px

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons
from sklearn.utils import shuffle

import torchvision.transforms as transforms
import torchvision.datasets as datasets
from sklearn.metrics.pairwise import cosine_similarity

import random
from torch.nn.modules.loss import MSELoss
from sklearn.neighbors import KDTree
#from kmodes.kprototypes import KPrototypes

from scipy.io.arff import loadarff
from sklearn.preprocessing import MinMaxScaler 
from sklearn.datasets import make_classification

# %% [markdown]
# ## Load Dataset MNIST and Check Clustering Result with the Baseline Method Kmeans

# %%
# set the path to the dataset
path_to_data = '/content/drive/MyDrive/Colab_Notebooks/mnist_train.csv'

# %%
data = pd.read_csv(path_to_data)

X_ds = data.copy()
X_ds = X_ds.drop(['label'], axis=1)

y_ds = data.copy()
y_ds = y_ds['label']

# %%
X_ds = X_ds.copy()
X_ds = pd.DataFrame(X_ds).to_numpy()

# %%
#check the clustering result with Kmeans
kmeans_ori = KMeans(n_clusters=10).fit(X_ds)
kmeans_labels_ori = kmeans_ori.labels_

normalized_mutual_info_score(kmeans_labels_ori, y_ds)
# Out:
# 0.4906313683037329

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X_ds)
data_X_tsne = np.vstack((X_tsne.T, y_ds)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ####MixUp

# %%
def mixup(data):
  view = data.copy()
  for i in range(len(view)):
    random_row_index = random.randint(0, len(view)-1)
    view[i] = view[i]*0.7  + view[random_row_index]*0.3
  return view

# %% [markdown]
# ####MixCut

# %%
def mixcut(data):
  data_copy = data.copy()
  view = data.copy()
  mask_len = int(data_copy.shape[1]*0.25)

  for i in range(len(data_copy)):
    random_row_id = random.randint(0, len(data_copy)-1)
    random_column_id = random.randint(0, data_copy.shape[1]-mask_len)
    view[i,random_column_id:(random_column_id+mask_len)] = data_copy[random_row_id,random_column_id:(random_column_id+mask_len)]
  return view

# %% [markdown]
# #### Masking with mean

# %%
def get_random_indices(data, portion_of_mask):
  return np.random.choice(data.shape[1], size=np.floor(data.shape[1]*portion_of_mask).astype(int), replace=False)

# %%
def masking_with_mean(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = column_mu[j]
              
  return view

# %% [markdown]
# ####Masking with random value in domain range

# %%
def masking_with_random(data, portion_of_mask):
  mean = np.mean(data, axis=0)

  column_min = data.min(axis=0).astype(int)
  column_max = data.max(axis=0).astype(int)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = random.randint(column_min[j], column_max[j])
              
  return view

# %% [markdown]
# ####Masking with margin distribution

# %%
def masking_with_margin_distribution(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = np.random.normal(column_mu[j], column_std[j])
              
  return view

# %% [markdown]
# ####Upsampling (SMOTE like)

# %%
#put all data points in kd-tree for fast searching
kdtree = KDTree(X_ds, leaf_size=2)

# %%
#get random point in the k nearest neighbors
def get_idx_random_knn(x,k):
   _, ids = kdtree.query(x.reshape(1, -1), k=k)
   ids = ids.flatten()
   ids = ids[1:-1]
   random_id = np.random.choice(ids, 1)
   return random_id

# %%
#mix up with a random near neighbor 
def mixup_random_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = 0.5*data[i] + 0.5*data[random_neighbor_id]
  return view

# %%
#a random neighbor as augmentation
def random_near_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = data[random_neighbor_id]
  return view

# %% [markdown]
# ##Create Model and Train with Augmented Data

# %%
class MyDataSet(Dataset):
  def __init__(self, view1, view2):
 
    X_view1 = view1.copy()
    X_view2 = view2.copy()
    self.X_view1 = X_view1.copy().astype(np.float32)
    self.X_view2 = X_view2.copy().astype(np.float32)
  
  def __len__(self):
    return len(self.X_view1)
  
  def __getitem__(self, idx):
    return self.X_view1[idx], self.X_view2[idx]

# %%
# define the NN architecture
class convBackbone(nn.Module):
    def __init__(self):
        super(convBackbone, self).__init__()

        #turn on dropout for testing the 'cropping' data augmentation 
        #self.dropout = nn.Dropout(p=0.2)
        
        self.fc1 = nn.Linear(784, 256, bias=False)
        self.bn1 = nn.BatchNorm1d(256)

        self.fc2 = nn.Linear(256, 256, bias=False)
        self.bn2 = nn.BatchNorm1d(256)

        self.fc3 = nn.Linear(256, 256, bias=False)
        self.bn3 = nn.BatchNorm1d(256)


    def forward(self, x):

        #turn on dropout for testing the 'cropping' data augmentation
        #x = self.dropout(x)
        
        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.bn3(self.fc3(x))
                
        return x

# %%
class SimSiam(nn.Module):
    def __init__(self, backbone):
        super().__init__()
        self.backbone = backbone
        self.projection_head = SimSiamProjectionHead(256, 256, 128)
        self.prediction_head = SimSiamPredictionHead(128, 64, 128)

    def forward(self, x):
        f = self.backbone(x)
        z = f.flatten(start_dim=1)
        z = self.projection_head(z)
        p = self.prediction_head(z)
        z = z.detach()
        return f, z, p

backbone = convBackbone()
model = SimSiam(backbone)

# %%
criterion = NegativeCosineSimilarity()
optimizer = torch.optim.SGD(model.parameters(), lr=0.06)

#cosine annealing lr
scheduler = lr_scheduler.CosineAnnealingLR(optimizer,T_max=500, eta_min=0)

# %%
view1 = random_near_neighbor(X_ds, 15)
view2 = random_near_neighbor(X_ds, 15)

#turn on the following to test other augmentations

#view1 = mixup_random_neighbor(X_ds, 15)
#view2 = mixup_random_neighbor(X_ds, 15)

#view1 = mixup(X_ds)
#view2 = mixup(X_ds)

#view1 = mixcut(X_ds)
#view2 = mixcut(X_ds)

#view1 = masking_with_mean(X_ds, 0.4)
#view2 = masking_with_mean(X_ds, 0.4)

#view1 = masking_with_random(X_ds, 0.4)
#view2 = masking_with_random(X_ds, 0.4)

#view1 = masking_with_margin_distribution(X_ds, 0.4)
#view2 = masking_with_margin_distribution(X_ds, 0.4)

train_ds = MyDataSet(view1, view2)
train_dl = DataLoader(train_ds, batch_size=256, shuffle=True)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

for epoch in range(500):
    total_loss = 0
    for x0,x1 in train_dl:
        x0 = x0.to(device)
        x1 = x1.to(device)
        _, z0, p0 = model(x0)
        _, z1, p1 = model(x1)

        loss = 0.5 * (criterion(z0, p1) + criterion(z1, p0))
        total_loss += loss.detach()
        loss.backward()

        optimizer.step()
        optimizer.zero_grad()
        scheduler.step()

    avg_loss = total_loss / len(train_dl)
    print(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
# Out:
# epoch: 00, loss: -0.46580
# epoch: 01, loss: -0.76909
# epoch: 02, loss: -0.78431
# epoch: 03, loss: -0.81879
# epoch: 04, loss: -0.85189
# epoch: 05, loss: -0.86266
# epoch: 06, loss: -0.86527
# epoch: 07, loss: -0.86724
# epoch: 08, loss: -0.87494
# epoch: 09, loss: -0.88208
# epoch: 10, loss: -0.88441
# epoch: 11, loss: -0.88525
# epoch: 12, loss: -0.88940
# epoch: 13, loss: -0.89282
# epoch: 14, loss: -0.89469
# epoch: 15, loss: -0.89473
# epoch: 16, loss: -0.89581
# epoch: 17, loss: -0.89790
# epoch: 18, loss: -0.89827
# epoch: 19, loss: -0.89883
# epoch: 20, loss: -0.89898
# epoch: 21, loss: -0.90008
# epoch: 22, loss: -0.90092
# epoch: 23, loss: -0.90137
# epoch: 24, loss: -0.90143
# epoch: 25, loss: -0.90170
# epoch: 26, loss: -0.90262
# epoch: 27, loss: -0.90285
# epoch: 28, loss: -0.90309
# epoch: 29, loss: -0.90372
# epoch: 30, loss: -0.90484
# epoch: 31, loss: -0.90540
# epoch: 32, loss: -0.90519
# epoch: 33, loss: -0.90529
# epoch: 34, loss: -0.90632
# epoch: 35, loss: -0.90683
# epoch: 36, loss: -0.90746
# epoch: 37, loss: -0.90704
# epoch: 38, loss: -0.90792
# epoch: 39, loss: -0.90847
# epoch: 40, loss: -0.90905
# epoch: 41, loss: -0.90908
# epoch: 42, loss: -0.90884
# epoch: 43, loss: -0.90940
# epoch: 44, loss: -0.90954
# epoch: 45, loss: -0.90994
# epoch: 46, loss: -0.91044
# epoch: 47, loss: -0.91100
# epoch: 48, loss: -0.91183
# epoch: 49, loss: -0.91213
# epoch: 50, loss: -0.91197
# epoch: 51, loss: -0.91306
# epoch: 52, loss: -0.91308
# epoch: 53, loss: -0.91355
# epoch: 54, loss: -0.91392
# epoch: 55, loss: -0.91447
# epoch: 56, loss: -0.91515
# epoch: 57, loss: -0.91554
# epoch: 58, loss: -0.91571
# epoch: 59, loss: -0.91563
# epoch: 60, loss: -0.91650
# epoch: 61, loss: -0.91694
# epoch: 62, loss: -0.91674
# epoch: 63, loss: -0.91682
# epoch: 64, loss: -0.91743
# epoch: 65, loss: -0.91773
# epoch: 66, loss: -0.91795
# epoch: 67, loss: -0.91794
# epoch: 68, loss: -0.91810
# epoch: 69, loss: -0.91862
# epoch: 70, loss: -0.91859
# epoch: 71, loss: -0.91860
# epoch: 72, loss: -0.91844
# epoch: 73, loss: -0.91901
# epoch: 74, loss: -0.91944
# epoch: 75, loss: -0.91929
# epoch: 76, loss: -0.91932
# epoch: 77, loss: -0.91961
# epoch: 78, loss: -0.92020
# epoch: 79, loss: -0.91976
# epoch: 80, loss: -0.92005
# epoch: 81, loss: -0.92032
# epoch: 82, loss: -0.92037
# epoch: 83, loss: -0.92014
# epoch: 84, loss: -0.92008
# epoch: 85, loss: -0.92044
# epoch: 86, loss: -0.92074
# epoch: 87, loss: -0.92084
# epoch: 88, loss: -0.92053
# epoch: 89, loss: -0.92070
# epoch: 90, loss: -0.92114
# epoch: 91, loss: -0.92112
# epoch: 92, loss: -0.92120
# epoch: 93, loss: -0.92079
# epoch: 94, loss: -0.92113
# epoch: 95, loss: -0.92105
# epoch: 96, loss: -0.92115
# epoch: 97, loss: -0.92091
# epoch: 98, loss: -0.92134
# epoch: 99, loss: -0.92161
# epoch: 100, loss: -0.92165
# epoch: 101, loss: -0.92142
# epoch: 102, loss: -0.92155
# epoch: 103, loss: -0.92210
# epoch: 104, loss: -0.92208
# epoch: 105, loss: -0.92199
# epoch: 106, loss: -0.92201
# epoch: 107, loss: -0.92221
# epoch: 108, loss: -0.92220
# epoch: 109, loss: -0.92211
# epoch: 110, loss: -0.92204
# epoch: 111, loss: -0.92171
# epoch: 112, loss: -0.92213
# epoch: 113, loss: -0.92241
# epoch: 114, loss: -0.92230
# epoch: 115, loss: -0.92213
# epoch: 116, loss: -0.92258
# epoch: 117, loss: -0.92309
# epoch: 118, loss: -0.92262
# epoch: 119, loss: -0.92235
# epoch: 120, loss: -0.92272
# epoch: 121, loss: -0.92299
# epoch: 122, loss: -0.92267
# epoch: 123, loss: -0.92270
# epoch: 124, loss: -0.92287
# epoch: 125, loss: -0.92310
# epoch: 126, loss: -0.92299
# epoch: 127, loss: -0.92276
# epoch: 128, loss: -0.92287
# epoch: 129, loss: -0.92327
# epoch: 130, loss: -0.92354
# epoch: 131, loss: -0.92317
# epoch: 132, loss: -0.92332
# epoch: 133, loss: -0.92306
# epoch: 134, loss: -0.92375
# epoch: 135, loss: -0.92324
# epoch: 136, loss: -0.92340
# epoch: 137, loss: -0.92384
# epoch: 138, loss: -0.92373
# epoch: 139, loss: -0.92346
# epoch: 140, loss: -0.92325
# epoch: 141, loss: -0.92350
# epoch: 142, loss: -0.92391
# epoch: 143, loss: -0.92388
# epoch: 144, loss: -0.92360
# epoch: 145, loss: -0.92365
# epoch: 146, loss: -0.92399
# epoch: 147, loss: -0.92394
# epoch: 148, loss: -0.92385
# epoch: 149, loss: -0.92368
# epoch: 150, loss: -0.92366
# epoch: 151, loss: -0.92424
# epoch: 152, loss: -0.92384
# epoch: 153, loss: -0.92364
# epoch: 154, loss: -0.92413
# epoch: 155, loss: -0.92401
# epoch: 156, loss: -0.92405
# epoch: 157, loss: -0.92379
# epoch: 158, loss: -0.92418
# epoch: 159, loss: -0.92401
# epoch: 160, loss: -0.92404
# epoch: 161, loss: -0.92413
# epoch: 162, loss: -0.92416
# epoch: 163, loss: -0.92403
# epoch: 164, loss: -0.92393
# epoch: 165, loss: -0.92404
# epoch: 166, loss: -0.92405
# epoch: 167, loss: -0.92447
# epoch: 168, loss: -0.92446
# epoch: 169, loss: -0.92397
# epoch: 170, loss: -0.92446
# epoch: 171, loss: -0.92424
# epoch: 172, loss: -0.92428
# epoch: 173, loss: -0.92427
# epoch: 174, loss: -0.92413
# epoch: 175, loss: -0.92429
# epoch: 176, loss: -0.92463
# epoch: 177, loss: -0.92393
# epoch: 178, loss: -0.92410
# epoch: 179, loss: -0.92415
# epoch: 180, loss: -0.92444
# epoch: 181, loss: -0.92482
# epoch: 182, loss: -0.92421
# epoch: 183, loss: -0.92461
# epoch: 184, loss: -0.92453
# epoch: 185, loss: -0.92481
# epoch: 186, loss: -0.92468
# epoch: 187, loss: -0.92432
# epoch: 188, loss: -0.92492
# epoch: 189, loss: -0.92476
# epoch: 190, loss: -0.92448
# epoch: 191, loss: -0.92460
# epoch: 192, loss: -0.92435
# epoch: 193, loss: -0.92467
# epoch: 194, loss: -0.92463
# epoch: 195, loss: -0.92467
# epoch: 196, loss: -0.92457
# epoch: 197, loss: -0.92445
# epoch: 198, loss: -0.92456
# epoch: 199, loss: -0.92467
# epoch: 200, loss: -0.92419
# epoch: 201, loss: -0.92424
# epoch: 202, loss: -0.92459
# epoch: 203, loss: -0.92478
# epoch: 204, loss: -0.92462
# epoch: 205, loss: -0.92438
# epoch: 206, loss: -0.92479
# epoch: 207, loss: -0.92455
# epoch: 208, loss: -0.92447
# epoch: 209, loss: -0.92442
# epoch: 210, loss: -0.92439
# epoch: 211, loss: -0.92442
# epoch: 212, loss: -0.92456
# epoch: 213, loss: -0.92437
# epoch: 214, loss: -0.92440
# epoch: 215, loss: -0.92437
# epoch: 216, loss: -0.92441
# epoch: 217, loss: -0.92448
# epoch: 218, loss: -0.92430
# epoch: 219, loss: -0.92432
# epoch: 220, loss: -0.92432
# epoch: 221, loss: -0.92421
# epoch: 222, loss: -0.92450
# epoch: 223, loss: -0.92438
# epoch: 224, loss: -0.92437
# epoch: 225, loss: -0.92453
# epoch: 226, loss: -0.92420
# epoch: 227, loss: -0.92463
# epoch: 228, loss: -0.92449
# epoch: 229, loss: -0.92437
# epoch: 230, loss: -0.92442
# epoch: 231, loss: -0.92487
# epoch: 232, loss: -0.92459
# epoch: 233, loss: -0.92412
# epoch: 234, loss: -0.92430
# epoch: 235, loss: -0.92425
# epoch: 236, loss: -0.92448
# epoch: 237, loss: -0.92435
# epoch: 238, loss: -0.92445
# epoch: 239, loss: -0.92450
# epoch: 240, loss: -0.92430
# epoch: 241, loss: -0.92470
# epoch: 242, loss: -0.92435
# epoch: 243, loss: -0.92440
# epoch: 244, loss: -0.92431
# epoch: 245, loss: -0.92435
# epoch: 246, loss: -0.92446
# epoch: 247, loss: -0.92438
# epoch: 248, loss: -0.92431
# epoch: 249, loss: -0.92456
# epoch: 250, loss: -0.92448
# epoch: 251, loss: -0.92453
# epoch: 252, loss: -0.92449
# epoch: 253, loss: -0.92453
# epoch: 254, loss: -0.92460
# epoch: 255, loss: -0.92427
# epoch: 256, loss: -0.92444
# epoch: 257, loss: -0.92474
# epoch: 258, loss: -0.92434
# epoch: 259, loss: -0.92442
# epoch: 260, loss: -0.92439
# epoch: 261, loss: -0.92474
# epoch: 262, loss: -0.92456
# epoch: 263, loss: -0.92436
# epoch: 264, loss: -0.92436
# epoch: 265, loss: -0.92448
# epoch: 266, loss: -0.92467
# epoch: 267, loss: -0.92444
# epoch: 268, loss: -0.92412
# epoch: 269, loss: -0.92457
# epoch: 270, loss: -0.92483
# epoch: 271, loss: -0.92439
# epoch: 272, loss: -0.92432
# epoch: 273, loss: -0.92454
# epoch: 274, loss: -0.92478
# epoch: 275, loss: -0.92460
# epoch: 276, loss: -0.92437
# epoch: 277, loss: -0.92450
# epoch: 278, loss: -0.92486
# epoch: 279, loss: -0.92474
# epoch: 280, loss: -0.92471
# epoch: 281, loss: -0.92424
# epoch: 282, loss: -0.92484
# epoch: 283, loss: -0.92462
# epoch: 284, loss: -0.92458
# epoch: 285, loss: -0.92467
# epoch: 286, loss: -0.92446
# epoch: 287, loss: -0.92465
# epoch: 288, loss: -0.92438
# epoch: 289, loss: -0.92432
# epoch: 290, loss: -0.92490
# epoch: 291, loss: -0.92460
# epoch: 292, loss: -0.92467
# epoch: 293, loss: -0.92452
# epoch: 294, loss: -0.92409
# epoch: 295, loss: -0.92447
# epoch: 296, loss: -0.92503
# epoch: 297, loss: -0.92458
# epoch: 298, loss: -0.92444
# epoch: 299, loss: -0.92473
# epoch: 300, loss: -0.92456
# epoch: 301, loss: -0.92424
# epoch: 302, loss: -0.92414
# epoch: 303, loss: -0.92441
# epoch: 304, loss: -0.92469
# epoch: 305, loss: -0.92430
# epoch: 306, loss: -0.92433
# epoch: 307, loss: -0.92476
# epoch: 308, loss: -0.92496
# epoch: 309, loss: -0.92444
# epoch: 310, loss: -0.92454
# epoch: 311, loss: -0.92490
# epoch: 312, loss: -0.92486
# epoch: 313, loss: -0.92466
# epoch: 314, loss: -0.92471
# epoch: 315, loss: -0.92479
# epoch: 316, loss: -0.92486
# epoch: 317, loss: -0.92500
# epoch: 318, loss: -0.92453
# epoch: 319, loss: -0.92466
# epoch: 320, loss: -0.92464
# epoch: 321, loss: -0.92465
# epoch: 322, loss: -0.92478
# epoch: 323, loss: -0.92418
# epoch: 324, loss: -0.92470
# epoch: 325, loss: -0.92467
# epoch: 326, loss: -0.92455
# epoch: 327, loss: -0.92452
# epoch: 328, loss: -0.92485
# epoch: 329, loss: -0.92479
# epoch: 330, loss: -0.92470
# epoch: 331, loss: -0.92465
# epoch: 332, loss: -0.92471
# epoch: 333, loss: -0.92468
# epoch: 334, loss: -0.92483
# epoch: 335, loss: -0.92461
# epoch: 336, loss: -0.92455
# epoch: 337, loss: -0.92505
# epoch: 338, loss: -0.92502
# epoch: 339, loss: -0.92469
# epoch: 340, loss: -0.92462
# epoch: 341, loss: -0.92484
# epoch: 342, loss: -0.92529
# epoch: 343, loss: -0.92479
# epoch: 344, loss: -0.92462
# epoch: 345, loss: -0.92472
# epoch: 346, loss: -0.92523
# epoch: 347, loss: -0.92536
# epoch: 348, loss: -0.92492
# epoch: 349, loss: -0.92486
# epoch: 350, loss: -0.92505
# epoch: 351, loss: -0.92532
# epoch: 352, loss: -0.92483
# epoch: 353, loss: -0.92497
# epoch: 354, loss: -0.92520
# epoch: 355, loss: -0.92530
# epoch: 356, loss: -0.92514
# epoch: 357, loss: -0.92475
# epoch: 358, loss: -0.92501
# epoch: 359, loss: -0.92474
# epoch: 360, loss: -0.92494
# epoch: 361, loss: -0.92509
# epoch: 362, loss: -0.92518
# epoch: 363, loss: -0.92498
# epoch: 364, loss: -0.92547
# epoch: 365, loss: -0.92538
# epoch: 366, loss: -0.92488
# epoch: 367, loss: -0.92531
# epoch: 368, loss: -0.92532
# epoch: 369, loss: -0.92548
# epoch: 370, loss: -0.92524
# epoch: 371, loss: -0.92491
# epoch: 372, loss: -0.92543
# epoch: 373, loss: -0.92520
# epoch: 374, loss: -0.92524
# epoch: 375, loss: -0.92541
# epoch: 376, loss: -0.92562
# epoch: 377, loss: -0.92552
# epoch: 378, loss: -0.92524
# epoch: 379, loss: -0.92504
# epoch: 380, loss: -0.92536
# epoch: 381, loss: -0.92536
# epoch: 382, loss: -0.92536
# epoch: 383, loss: -0.92521
# epoch: 384, loss: -0.92579
# epoch: 385, loss: -0.92542
# epoch: 386, loss: -0.92515
# epoch: 387, loss: -0.92518
# epoch: 388, loss: -0.92521
# epoch: 389, loss: -0.92544
# epoch: 390, loss: -0.92518
# epoch: 391, loss: -0.92525
# epoch: 392, loss: -0.92503
# epoch: 393, loss: -0.92531
# epoch: 394, loss: -0.92518
# epoch: 395, loss: -0.92492
# epoch: 396, loss: -0.92541
# epoch: 397, loss: -0.92536
# epoch: 398, loss: -0.92539
# epoch: 399, loss: -0.92509
# epoch: 400, loss: -0.92496
# epoch: 401, loss: -0.92523
# epoch: 402, loss: -0.92502
# epoch: 403, loss: -0.92494
# epoch: 404, loss: -0.92516
# epoch: 405, loss: -0.92510
# epoch: 406, loss: -0.92546
# epoch: 407, loss: -0.92520
# epoch: 408, loss: -0.92477
# epoch: 409, loss: -0.92507
# epoch: 410, loss: -0.92542
# epoch: 411, loss: -0.92511
# epoch: 412, loss: -0.92494
# epoch: 413, loss: -0.92498
# epoch: 414, loss: -0.92540
# epoch: 415, loss: -0.92515
# epoch: 416, loss: -0.92523
# epoch: 417, loss: -0.92531
# epoch: 418, loss: -0.92512
# epoch: 419, loss: -0.92538
# epoch: 420, loss: -0.92534
# epoch: 421, loss: -0.92519
# epoch: 422, loss: -0.92547
# epoch: 423, loss: -0.92549
# epoch: 424, loss: -0.92513
# epoch: 425, loss: -0.92515
# epoch: 426, loss: -0.92503
# epoch: 427, loss: -0.92537
# epoch: 428, loss: -0.92521
# epoch: 429, loss: -0.92511
# epoch: 430, loss: -0.92504
# epoch: 431, loss: -0.92523
# epoch: 432, loss: -0.92532
# epoch: 433, loss: -0.92511
# epoch: 434, loss: -0.92511
# epoch: 435, loss: -0.92534
# epoch: 436, loss: -0.92558
# epoch: 437, loss: -0.92532
# epoch: 438, loss: -0.92521
# epoch: 439, loss: -0.92541
# epoch: 440, loss: -0.92550
# epoch: 441, loss: -0.92530
# epoch: 442, loss: -0.92492
# epoch: 443, loss: -0.92524
# epoch: 444, loss: -0.92522
# epoch: 445, loss: -0.92518
# epoch: 446, loss: -0.92534
# epoch: 447, loss: -0.92521
# epoch: 448, loss: -0.92547
# epoch: 449, loss: -0.92538
# epoch: 450, loss: -0.92477
# epoch: 451, loss: -0.92493
# epoch: 452, loss: -0.92556
# epoch: 453, loss: -0.92573
# epoch: 454, loss: -0.92512
# epoch: 455, loss: -0.92496
# epoch: 456, loss: -0.92539
# epoch: 457, loss: -0.92535
# epoch: 458, loss: -0.92547
# epoch: 459, loss: -0.92501
# epoch: 460, loss: -0.92550
# epoch: 461, loss: -0.92562
# epoch: 462, loss: -0.92548
# epoch: 463, loss: -0.92527
# epoch: 464, loss: -0.92526
# epoch: 465, loss: -0.92503
# epoch: 466, loss: -0.92536
# epoch: 467, loss: -0.92513
# epoch: 468, loss: -0.92516
# epoch: 469, loss: -0.92554
# epoch: 470, loss: -0.92567
# epoch: 471, loss: -0.92556
# epoch: 472, loss: -0.92536
# epoch: 473, loss: -0.92513
# epoch: 474, loss: -0.92551
# epoch: 475, loss: -0.92543
# epoch: 476, loss: -0.92503
# epoch: 477, loss: -0.92536
# epoch: 478, loss: -0.92531
# epoch: 479, loss: -0.92511
# epoch: 480, loss: -0.92526
# epoch: 481, loss: -0.92517
# epoch: 482, loss: -0.92529
# epoch: 483, loss: -0.92547
# epoch: 484, loss: -0.92530
# epoch: 485, loss: -0.92517
# epoch: 486, loss: -0.92528
# epoch: 487, loss: -0.92535
# epoch: 488, loss: -0.92515
# epoch: 489, loss: -0.92517
# epoch: 490, loss: -0.92519
# epoch: 491, loss: -0.92565
# epoch: 492, loss: -0.92549
# epoch: 493, loss: -0.92485
# epoch: 494, loss: -0.92534
# epoch: 495, loss: -0.92549
# epoch: 496, loss: -0.92542
# epoch: 497, loss: -0.92518
# epoch: 498, loss: -0.92538
# epoch: 499, loss: -0.92558

# %% [markdown]
# ##Check the Training Result

# %%
ds_cl= MyDataSet(X_ds, X_ds)
dl_cl = DataLoader(ds_cl, batch_size=256)

# %%
embeddings = []

# disable gradients for faster calculations
model.eval()
with torch.no_grad():
    for dl_cl1, dl_cl2 in dl_cl:

        dl_cl1 = dl_cl1.to(device)
        f, z, p = model(dl_cl1)

        # store the embeddings in lists
        embeddings.append(f)

# concatenate the embeddings, targets and convert to numpy
embeddings = torch.cat(embeddings, dim=0)
embeddings = embeddings.cpu().numpy()

# %%
test = (embeddings - embeddings.mean(axis=0)) / (embeddings.std(axis=0))

# %%
#KMeans in latent space
kmeans_backbone = KMeans(n_clusters=10).fit(test)
kmeans_labels_backbone = kmeans_backbone.labels_

# %%
normalized_mutual_info_score(kmeans_labels_backbone, y_ds)
# Out:
# 0.6789556513348335

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(embeddings)
data_X_tsne = np.vstack((X_tsne.T, y_ds)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
df_tsne.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
#         dim1       dim2    y
# 0 -24.891529  -7.195504  5.0
# 1  33.762180 -23.776377  0.0
# 2  51.349129   4.027562  4.0
# 3 -25.248674 -35.677826  1.0
# 4  16.738806   5.113056  9.0

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()

# %%
#NMI increases from 0.49 to 0.67
