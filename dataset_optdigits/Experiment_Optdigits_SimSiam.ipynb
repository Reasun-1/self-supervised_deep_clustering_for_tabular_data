# %% [markdown]
# ## Conifuration

# %%
#import the lib for contrastive learning framework
# !pip install lightly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lightly in /usr/local/lib/python3.7/dist-packages (1.2.21)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.15.0)
# Requirement already satisfied: pytorch-lightning>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.6.4)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from lightly) (0.12.0+cu113)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.21.6)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.23.0)
# Requirement already satisfied: hydra-core>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.2.0)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (57.4.0)
# Requirement already satisfied: lightly-utils~=0.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (0.0.2)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.7/dist-packages (from lightly) (2022.6.15)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.8.2)
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.7/dist-packages (from lightly) (4.64.0)
# Requirement already satisfied: omegaconf~=2.2 in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (2.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (21.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (4.9.3)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (5.7.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from lightly-utils~=0.0.0->lightly) (7.1.2)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.7/dist-packages (from omegaconf~=2.2->hydra-core>=1.0.0->lightly) (6.0)
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (1.11.0+cu113)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2022.5.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (4.1.1)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2.8.0)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (0.3.2)
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (3.17.3)
# Requirement already satisfied: torchmetrics>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (0.9.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->hydra-core>=1.0.0->lightly) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (3.0.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.35.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.37.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.46.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.3.7)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.1.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (1.7.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (21.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (1.3.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (2.0.12)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (0.13.0)

# %%
import lightly
from lightly.models.modules.heads import SimSiamPredictionHead
from lightly.models.modules.heads import SimSiamProjectionHead

from lightly.data import LightlyDataset
from lightly.data import ImageCollateFunction
from lightly.models.modules import BarlowTwinsProjectionHead
from lightly.loss import BarlowTwinsLoss

from lightly.data import LightlyDataset
from lightly.data import SimCLRCollateFunction
from lightly.loss import NTXentLoss
from lightly.loss import NegativeCosineSimilarity
from lightly.models.modules import SimCLRProjectionHead

# %%
import math
import torch
import torch.nn as nn
import torchvision
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from torch.utils.data import Dataset, DataLoader
import torch.optim as torch_optim
import torch.optim.lr_scheduler as lr_scheduler
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
from datetime import datetime

from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from matplotlib import pyplot
import seaborn as sns

from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_mutual_info_score
from sklearn.metrics import silhouette_score
from sklearn import mixture
from sklearn.cluster import DBSCAN
from sklearn.cluster import OPTICS
from sklearn.cluster import AgglomerativeClustering

import tensorboard
from tensorboard import notebook
from torch.utils.tensorboard import SummaryWriter

import matplotlib 
import matplotlib.pyplot as plt
#import plotly.express as px

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons
from sklearn.utils import shuffle

import torchvision.transforms as transforms
import torchvision.datasets as datasets
from sklearn.metrics.pairwise import cosine_similarity

import random
from torch.nn.modules.loss import MSELoss
from sklearn.neighbors import KDTree
#from kmodes.kprototypes import KPrototypes

from scipy.io.arff import loadarff
from sklearn.preprocessing import MinMaxScaler 
from sklearn.datasets import make_classification

# %% [markdown]
# ## Load Dataset Pendigits and Check Clustering Result with the Baseline Method Kmeans

# %%
# set the path to the dataset
path_to_data = '/content/drive/MyDrive/Colab_Notebooks/optdigits.csv'

# %%
data = pd.read_csv(path_to_data)

X_ds = data.copy()
X_ds = X_ds.drop(['class'], axis=1)
X_ds = pd.DataFrame(X_ds).to_numpy()

y_ds = data.copy()
y_ds = y_ds['class']

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X_ds)
data_X_tsne = np.vstack((X_tsne.T, y_ds)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#check the clustering result with Kmeans
kmeans_ori = KMeans(n_clusters=10).fit(X_ds)
kmeans_labels_ori = kmeans_ori.labels_

normalized_mutual_info_score(kmeans_labels_ori, y_ds)
# Out:
# 0.7570269233767127

# %%
#tsne = TSNE(n_components=2)
#X_tsne = tsne.fit_transform(X_ds)
data_X_tsne = np.vstack((X_tsne.T, kmeans_labels_ori)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ####MixUp

# %%
def mixup(data):
  view = data.copy()
  for i in range(len(view)):
    random_row_index = random.randint(0, len(view)-1)
    view[i] = view[i]*0.5  + view[random_row_index]*0.5
  return view

# %% [markdown]
# ####MixCut

# %%
def mixcut(data):
  data_copy = data.copy()
  view = data.copy()
  mask_len = 100

  for i in range(len(data_copy)):
    random_row_id = random.randint(0, len(data_copy)-1)
    random_column_id = random.randint(0, data_copy.shape[1]-mask_len)
    view[i,random_column_id:(random_column_id+mask_len)] = data_copy[random_row_id,random_column_id:(random_column_id+mask_len)]
  return view

# %% [markdown]
# #### Masking with mean

# %%
def get_random_indices(data, portion_of_mask):
  return np.random.choice(data.shape[1], size=np.floor(data.shape[1]*portion_of_mask).astype(int), replace=False)

# %%
def masking_with_mean(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = column_mu[j]
              
  return view

# %% [markdown]
# ####Masking with random value in domain range

# %%
def masking_with_random(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)
  column_min = np.minimum(data)
  column_max = np.maximum(data)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = random.randint(column_min[j], column_max[j])
              
  return view

# %% [markdown]
# ####Masking with margin distribution

# %%
def masking_with_margin_distribution(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = np.random.normal(column_mu[j], column_std[j])
              
  return view

# %% [markdown]
# ####Upsampling (SMOTE like)

# %%
#put all data points in kd-tree for fast searching
kdtree = KDTree(X_ds, leaf_size=2)

# %%
#get random point in the k nearest neighbors
def get_idx_random_knn(x,k):
   _, ids = kdtree.query(x.reshape(1, -1), k=k)
   ids = ids.flatten()
   ids = ids[1:-1]
   random_id = np.random.choice(ids, 1)
   return random_id

# %%
#mix up with a random near neighbor 
def mixup_random_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = 0.5*data[i] + 0.5*data[random_neighbor_id]
  return view

# %%
#a random neighbor as augmentation
def random_near_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = data[random_neighbor_id]
  return view

# %% [markdown]
# ##Create Model and Train with Augmented Data

# %%
class MyDataSet(Dataset):
  def __init__(self, view1, view2):
 
    X_view1 = view1.copy()
    X_view2 = view2.copy()
    self.X_view1 = X_view1.copy().astype(np.float32)
    self.X_view2 = X_view2.copy().astype(np.float32)
  
  def __len__(self):
    return len(self.X_view1)
  
  def __getitem__(self, idx):
    return self.X_view1[idx], self.X_view2[idx]

# %%
# define the NN architecture
class convBackbone(nn.Module):
    def __init__(self):
        super(convBackbone, self).__init__()

        #turn on dropout for testing the 'cropping' data augmentation 
        #self.dropout = nn.Dropout(p=0.1)
        
        self.fc1 = nn.Linear(64, 64, bias=False)
        self.bn1 = nn.BatchNorm1d(64)

        self.fc2 = nn.Linear(64, 64, bias=False)
        self.bn2 = nn.BatchNorm1d(64)

        self.fc3 = nn.Linear(64, 32, bias=False)
        self.bn3 = nn.BatchNorm1d(32)


    def forward(self, x):

        #turn on dropout for testing the 'cropping' data augmentation 
        #x = self.dropout(x)
        
        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.bn3(self.fc3(x))
                
        return x

# %%
class SimSiam(nn.Module):
    def __init__(self, backbone):
        super().__init__()
        self.backbone = backbone
        self.projection_head = SimSiamProjectionHead(32, 32, 32)
        self.prediction_head = SimSiamPredictionHead(32, 16, 32)

    def forward(self, x):
        f = self.backbone(x)
        z = f.flatten(start_dim=1)
        z = self.projection_head(z)
        p = self.prediction_head(z)
        z = z.detach()
        return f, z, p

backbone = convBackbone()
model = SimSiam(backbone)

# %%
criterion = NegativeCosineSimilarity()
optimizer = torch.optim.SGD(model.parameters(), lr=0.06)

#cosine annealing lr
scheduler = lr_scheduler.CosineAnnealingLR(optimizer,T_max=500, eta_min=0)

# %%
view1 = random_near_neighbor(X_ds, 22)
view2 = random_near_neighbor(X_ds, 18)

#turn on the following to test other augmentations

#view1 = mixup_random_neighbor(X_ds, 15)
#view2 = mixup_random_neighbor(X_ds, 15)

#view1 = mixup(X_ds)
#view2 = mixup(X_ds)

#view1 = mixcut(X_ds)
#view2 = mixcut(X_ds)

#view1 = masking_with_mean(X_ds, 0.4)
#view2 = masking_with_mean(X_ds, 0.4)

#view1 = masking_with_random(X_ds, 0.4)
#view2 = masking_with_random(X_ds, 0.4)

#view1 = masking_with_margin_distribution(X_ds, 0.4)
#view2 = masking_with_margin_distribution(X_ds, 0.4)

train_ds = MyDataSet(view1, view2)
train_dl = DataLoader(train_ds, batch_size=256, shuffle=True)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

for epoch in range(500):
    total_loss = 0
    for x0,x1 in train_dl:
        x0 = x0.to(device)
        x1 = x1.to(device)
        _, z0, p0 = model(x0)
        _, z1, p1 = model(x1)

        loss = 0.5 * (criterion(z0, p1) + criterion(z1, p0))
        total_loss += loss.detach()
        loss.backward()

        optimizer.step()
        optimizer.zero_grad()
        scheduler.step()

    avg_loss = total_loss / len(train_dl)
    print(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
# Out:
# epoch: 00, loss: -0.09934
# epoch: 01, loss: -0.32743
# epoch: 02, loss: -0.51678
# epoch: 03, loss: -0.63135
# epoch: 04, loss: -0.69533
# epoch: 05, loss: -0.73391
# epoch: 06, loss: -0.75853
# epoch: 07, loss: -0.77584
# epoch: 08, loss: -0.78667
# epoch: 09, loss: -0.79577
# epoch: 10, loss: -0.80263
# epoch: 11, loss: -0.80766
# epoch: 12, loss: -0.81249
# epoch: 13, loss: -0.81537
# epoch: 14, loss: -0.81866
# epoch: 15, loss: -0.82240
# epoch: 16, loss: -0.82428
# epoch: 17, loss: -0.82651
# epoch: 18, loss: -0.82848
# epoch: 19, loss: -0.82870
# epoch: 20, loss: -0.82883
# epoch: 21, loss: -0.82955
# epoch: 22, loss: -0.82842
# epoch: 23, loss: -0.82877
# epoch: 24, loss: -0.82938
# epoch: 25, loss: -0.82974
# epoch: 26, loss: -0.83075
# epoch: 27, loss: -0.83123
# epoch: 28, loss: -0.83327
# epoch: 29, loss: -0.83478
# epoch: 30, loss: -0.83762
# epoch: 31, loss: -0.84048
# epoch: 32, loss: -0.84526
# epoch: 33, loss: -0.84845
# epoch: 34, loss: -0.85357
# epoch: 35, loss: -0.85608
# epoch: 36, loss: -0.86018
# epoch: 37, loss: -0.86631
# epoch: 38, loss: -0.86975
# epoch: 39, loss: -0.87463
# epoch: 40, loss: -0.87707
# epoch: 41, loss: -0.87957
# epoch: 42, loss: -0.88337
# epoch: 43, loss: -0.88517
# epoch: 44, loss: -0.88628
# epoch: 45, loss: -0.88792
# epoch: 46, loss: -0.88873
# epoch: 47, loss: -0.89116
# epoch: 48, loss: -0.89495
# epoch: 49, loss: -0.89768
# epoch: 50, loss: -0.89923
# epoch: 51, loss: -0.90204
# epoch: 52, loss: -0.90404
# epoch: 53, loss: -0.90527
# epoch: 54, loss: -0.90701
# epoch: 55, loss: -0.90673
# epoch: 56, loss: -0.90885
# epoch: 57, loss: -0.90923
# epoch: 58, loss: -0.90889
# epoch: 59, loss: -0.90992
# epoch: 60, loss: -0.91011
# epoch: 61, loss: -0.91057
# epoch: 62, loss: -0.90995
# epoch: 63, loss: -0.91140
# epoch: 64, loss: -0.91144
# epoch: 65, loss: -0.91071
# epoch: 66, loss: -0.91105
# epoch: 67, loss: -0.91001
# epoch: 68, loss: -0.91088
# epoch: 69, loss: -0.91081
# epoch: 70, loss: -0.90979
# epoch: 71, loss: -0.91139
# epoch: 72, loss: -0.91130
# epoch: 73, loss: -0.91067
# epoch: 74, loss: -0.91010
# epoch: 75, loss: -0.90946
# epoch: 76, loss: -0.90962
# epoch: 77, loss: -0.90958
# epoch: 78, loss: -0.91028
# epoch: 79, loss: -0.90987
# epoch: 80, loss: -0.90882
# epoch: 81, loss: -0.90852
# epoch: 82, loss: -0.90922
# epoch: 83, loss: -0.90994
# epoch: 84, loss: -0.91038
# epoch: 85, loss: -0.91101
# epoch: 86, loss: -0.91116
# epoch: 87, loss: -0.91396
# epoch: 88, loss: -0.91507
# epoch: 89, loss: -0.91582
# epoch: 90, loss: -0.91674
# epoch: 91, loss: -0.91720
# epoch: 92, loss: -0.91829
# epoch: 93, loss: -0.92013
# epoch: 94, loss: -0.92162
# epoch: 95, loss: -0.92244
# epoch: 96, loss: -0.92430
# epoch: 97, loss: -0.92431
# epoch: 98, loss: -0.92649
# epoch: 99, loss: -0.92739
# epoch: 100, loss: -0.92819
# epoch: 101, loss: -0.92929
# epoch: 102, loss: -0.92893
# epoch: 103, loss: -0.92986
# epoch: 104, loss: -0.92990
# epoch: 105, loss: -0.93065
# epoch: 106, loss: -0.93146
# epoch: 107, loss: -0.93021
# epoch: 108, loss: -0.93220
# epoch: 109, loss: -0.93206
# epoch: 110, loss: -0.93192
# epoch: 111, loss: -0.93215
# epoch: 112, loss: -0.93214
# epoch: 113, loss: -0.93204
# epoch: 114, loss: -0.93286
# epoch: 115, loss: -0.93072
# epoch: 116, loss: -0.93085
# epoch: 117, loss: -0.93152
# epoch: 118, loss: -0.93170
# epoch: 119, loss: -0.93049
# epoch: 120, loss: -0.93224
# epoch: 121, loss: -0.93171
# epoch: 122, loss: -0.93163
# epoch: 123, loss: -0.93099
# epoch: 124, loss: -0.93277
# epoch: 125, loss: -0.93294
# epoch: 126, loss: -0.93317
# epoch: 127, loss: -0.93390
# epoch: 128, loss: -0.93448
# epoch: 129, loss: -0.93397
# epoch: 130, loss: -0.93505
# epoch: 131, loss: -0.93532
# epoch: 132, loss: -0.93631
# epoch: 133, loss: -0.93533
# epoch: 134, loss: -0.93633
# epoch: 135, loss: -0.93795
# epoch: 136, loss: -0.93722
# epoch: 137, loss: -0.93844
# epoch: 138, loss: -0.93877
# epoch: 139, loss: -0.93794
# epoch: 140, loss: -0.93924
# epoch: 141, loss: -0.93860
# epoch: 142, loss: -0.93879
# epoch: 143, loss: -0.93970
# epoch: 144, loss: -0.93853
# epoch: 145, loss: -0.94045
# epoch: 146, loss: -0.93970
# epoch: 147, loss: -0.94035
# epoch: 148, loss: -0.94072
# epoch: 149, loss: -0.93918
# epoch: 150, loss: -0.94060
# epoch: 151, loss: -0.94001
# epoch: 152, loss: -0.94098
# epoch: 153, loss: -0.94058
# epoch: 154, loss: -0.94088
# epoch: 155, loss: -0.94133
# epoch: 156, loss: -0.93975
# epoch: 157, loss: -0.93978
# epoch: 158, loss: -0.94130
# epoch: 159, loss: -0.94102
# epoch: 160, loss: -0.94060
# epoch: 161, loss: -0.94000
# epoch: 162, loss: -0.94083
# epoch: 163, loss: -0.94155
# epoch: 164, loss: -0.94027
# epoch: 165, loss: -0.94104
# epoch: 166, loss: -0.94092
# epoch: 167, loss: -0.94123
# epoch: 168, loss: -0.94089
# epoch: 169, loss: -0.94007
# epoch: 170, loss: -0.94038
# epoch: 171, loss: -0.94050
# epoch: 172, loss: -0.93983
# epoch: 173, loss: -0.94149
# epoch: 174, loss: -0.94149
# epoch: 175, loss: -0.94153
# epoch: 176, loss: -0.94181
# epoch: 177, loss: -0.94188
# epoch: 178, loss: -0.94239
# epoch: 179, loss: -0.94255
# epoch: 180, loss: -0.94258
# epoch: 181, loss: -0.94104
# epoch: 182, loss: -0.94265
# epoch: 183, loss: -0.94367
# epoch: 184, loss: -0.94340
# epoch: 185, loss: -0.94298
# epoch: 186, loss: -0.94289
# epoch: 187, loss: -0.94383
# epoch: 188, loss: -0.94323
# epoch: 189, loss: -0.94521
# epoch: 190, loss: -0.94499
# epoch: 191, loss: -0.94382
# epoch: 192, loss: -0.94373
# epoch: 193, loss: -0.94424
# epoch: 194, loss: -0.94514
# epoch: 195, loss: -0.94527
# epoch: 196, loss: -0.94517
# epoch: 197, loss: -0.94569
# epoch: 198, loss: -0.94493
# epoch: 199, loss: -0.94531
# epoch: 200, loss: -0.94370
# epoch: 201, loss: -0.94504
# epoch: 202, loss: -0.94565
# epoch: 203, loss: -0.94606
# epoch: 204, loss: -0.94505
# epoch: 205, loss: -0.94508
# epoch: 206, loss: -0.94572
# epoch: 207, loss: -0.94538
# epoch: 208, loss: -0.94466
# epoch: 209, loss: -0.94544
# epoch: 210, loss: -0.94531
# epoch: 211, loss: -0.94450
# epoch: 212, loss: -0.94465
# epoch: 213, loss: -0.94436
# epoch: 214, loss: -0.94479
# epoch: 215, loss: -0.94521
# epoch: 216, loss: -0.94573
# epoch: 217, loss: -0.94549
# epoch: 218, loss: -0.94511
# epoch: 219, loss: -0.94615
# epoch: 220, loss: -0.94586
# epoch: 221, loss: -0.94525
# epoch: 222, loss: -0.94594
# epoch: 223, loss: -0.94626
# epoch: 224, loss: -0.94490
# epoch: 225, loss: -0.94645
# epoch: 226, loss: -0.94609
# epoch: 227, loss: -0.94669
# epoch: 228, loss: -0.94604
# epoch: 229, loss: -0.94651
# epoch: 230, loss: -0.94651
# epoch: 231, loss: -0.94781
# epoch: 232, loss: -0.94595
# epoch: 233, loss: -0.94693
# epoch: 234, loss: -0.94819
# epoch: 235, loss: -0.94840
# epoch: 236, loss: -0.94806
# epoch: 237, loss: -0.94897
# epoch: 238, loss: -0.94835
# epoch: 239, loss: -0.94815
# epoch: 240, loss: -0.94840
# epoch: 241, loss: -0.94896
# epoch: 242, loss: -0.94965
# epoch: 243, loss: -0.94920
# epoch: 244, loss: -0.94975
# epoch: 245, loss: -0.94889
# epoch: 246, loss: -0.94936
# epoch: 247, loss: -0.94923
# epoch: 248, loss: -0.94967
# epoch: 249, loss: -0.94988
# epoch: 250, loss: -0.94881
# epoch: 251, loss: -0.94951
# epoch: 252, loss: -0.94978
# epoch: 253, loss: -0.94970
# epoch: 254, loss: -0.94930
# epoch: 255, loss: -0.94899
# epoch: 256, loss: -0.94931
# epoch: 257, loss: -0.95005
# epoch: 258, loss: -0.95004
# epoch: 259, loss: -0.95032
# epoch: 260, loss: -0.95013
# epoch: 261, loss: -0.94925
# epoch: 262, loss: -0.94906
# epoch: 263, loss: -0.94871
# epoch: 264, loss: -0.94956
# epoch: 265, loss: -0.95005
# epoch: 266, loss: -0.94993
# epoch: 267, loss: -0.95091
# epoch: 268, loss: -0.95089
# epoch: 269, loss: -0.95125
# epoch: 270, loss: -0.95068
# epoch: 271, loss: -0.95072
# epoch: 272, loss: -0.95215
# epoch: 273, loss: -0.95071
# epoch: 274, loss: -0.95204
# epoch: 275, loss: -0.95145
# epoch: 276, loss: -0.95132
# epoch: 277, loss: -0.95198
# epoch: 278, loss: -0.95239
# epoch: 279, loss: -0.95277
# epoch: 280, loss: -0.95233
# epoch: 281, loss: -0.95421
# epoch: 282, loss: -0.95385
# epoch: 283, loss: -0.95358
# epoch: 284, loss: -0.95353
# epoch: 285, loss: -0.95357
# epoch: 286, loss: -0.95386
# epoch: 287, loss: -0.95411
# epoch: 288, loss: -0.95389
# epoch: 289, loss: -0.95397
# epoch: 290, loss: -0.95355
# epoch: 291, loss: -0.95479
# epoch: 292, loss: -0.95414
# epoch: 293, loss: -0.95366
# epoch: 294, loss: -0.95483
# epoch: 295, loss: -0.95474
# epoch: 296, loss: -0.95409
# epoch: 297, loss: -0.95506
# epoch: 298, loss: -0.95464
# epoch: 299, loss: -0.95447
# epoch: 300, loss: -0.95448
# epoch: 301, loss: -0.95438
# epoch: 302, loss: -0.95453
# epoch: 303, loss: -0.95521
# epoch: 304, loss: -0.95468
# epoch: 305, loss: -0.95467
# epoch: 306, loss: -0.95428
# epoch: 307, loss: -0.95395
# epoch: 308, loss: -0.95556
# epoch: 309, loss: -0.95501
# epoch: 310, loss: -0.95447
# epoch: 311, loss: -0.95547
# epoch: 312, loss: -0.95564
# epoch: 313, loss: -0.95532
# epoch: 314, loss: -0.95541
# epoch: 315, loss: -0.95597
# epoch: 316, loss: -0.95562
# epoch: 317, loss: -0.95619
# epoch: 318, loss: -0.95596
# epoch: 319, loss: -0.95600
# epoch: 320, loss: -0.95663
# epoch: 321, loss: -0.95647
# epoch: 322, loss: -0.95757
# epoch: 323, loss: -0.95690
# epoch: 324, loss: -0.95781
# epoch: 325, loss: -0.95811
# epoch: 326, loss: -0.95720
# epoch: 327, loss: -0.95742
# epoch: 328, loss: -0.95679
# epoch: 329, loss: -0.95660
# epoch: 330, loss: -0.95714
# epoch: 331, loss: -0.95677
# epoch: 332, loss: -0.95731
# epoch: 333, loss: -0.95774
# epoch: 334, loss: -0.95911
# epoch: 335, loss: -0.95780
# epoch: 336, loss: -0.95808
# epoch: 337, loss: -0.95777
# epoch: 338, loss: -0.95838
# epoch: 339, loss: -0.95886
# epoch: 340, loss: -0.95791
# epoch: 341, loss: -0.95832
# epoch: 342, loss: -0.95731
# epoch: 343, loss: -0.95818
# epoch: 344, loss: -0.95813
# epoch: 345, loss: -0.95816
# epoch: 346, loss: -0.95814
# epoch: 347, loss: -0.95893
# epoch: 348, loss: -0.95778
# epoch: 349, loss: -0.95776
# epoch: 350, loss: -0.95832
# epoch: 351, loss: -0.95876
# epoch: 352, loss: -0.95788
# epoch: 353, loss: -0.95791
# epoch: 354, loss: -0.95908
# epoch: 355, loss: -0.95797
# epoch: 356, loss: -0.95788
# epoch: 357, loss: -0.95904
# epoch: 358, loss: -0.95867
# epoch: 359, loss: -0.95940
# epoch: 360, loss: -0.95914
# epoch: 361, loss: -0.95908
# epoch: 362, loss: -0.95870
# epoch: 363, loss: -0.95856
# epoch: 364, loss: -0.95907
# epoch: 365, loss: -0.95918
# epoch: 366, loss: -0.95879
# epoch: 367, loss: -0.95960
# epoch: 368, loss: -0.95840
# epoch: 369, loss: -0.95917
# epoch: 370, loss: -0.95914
# epoch: 371, loss: -0.95893
# epoch: 372, loss: -0.95994
# epoch: 373, loss: -0.95982
# epoch: 374, loss: -0.95978
# epoch: 375, loss: -0.95998
# epoch: 376, loss: -0.96004
# epoch: 377, loss: -0.95870
# epoch: 378, loss: -0.95935
# epoch: 379, loss: -0.96005
# epoch: 380, loss: -0.96060
# epoch: 381, loss: -0.95998
# epoch: 382, loss: -0.95919
# epoch: 383, loss: -0.95999
# epoch: 384, loss: -0.95989
# epoch: 385, loss: -0.95985
# epoch: 386, loss: -0.96002
# epoch: 387, loss: -0.95876
# epoch: 388, loss: -0.96021
# epoch: 389, loss: -0.95947
# epoch: 390, loss: -0.96012
# epoch: 391, loss: -0.96022
# epoch: 392, loss: -0.95961
# epoch: 393, loss: -0.95961
# epoch: 394, loss: -0.96043
# epoch: 395, loss: -0.96017
# epoch: 396, loss: -0.96025
# epoch: 397, loss: -0.96058
# epoch: 398, loss: -0.95909
# epoch: 399, loss: -0.95972
# epoch: 400, loss: -0.95977
# epoch: 401, loss: -0.95902
# epoch: 402, loss: -0.95963
# epoch: 403, loss: -0.95999
# epoch: 404, loss: -0.95909
# epoch: 405, loss: -0.96020
# epoch: 406, loss: -0.95982
# epoch: 407, loss: -0.95988
# epoch: 408, loss: -0.95925
# epoch: 409, loss: -0.95940
# epoch: 410, loss: -0.95981
# epoch: 411, loss: -0.96042
# epoch: 412, loss: -0.95990
# epoch: 413, loss: -0.96030
# epoch: 414, loss: -0.96047
# epoch: 415, loss: -0.96055
# epoch: 416, loss: -0.95972
# epoch: 417, loss: -0.96091
# epoch: 418, loss: -0.96054
# epoch: 419, loss: -0.96056
# epoch: 420, loss: -0.96056
# epoch: 421, loss: -0.96069
# epoch: 422, loss: -0.96066
# epoch: 423, loss: -0.96018
# epoch: 424, loss: -0.96158
# epoch: 425, loss: -0.96062
# epoch: 426, loss: -0.96086
# epoch: 427, loss: -0.96019
# epoch: 428, loss: -0.96088
# epoch: 429, loss: -0.96081
# epoch: 430, loss: -0.96009
# epoch: 431, loss: -0.96136
# epoch: 432, loss: -0.96088
# epoch: 433, loss: -0.96060
# epoch: 434, loss: -0.96115
# epoch: 435, loss: -0.96033
# epoch: 436, loss: -0.96035
# epoch: 437, loss: -0.96011
# epoch: 438, loss: -0.96113
# epoch: 439, loss: -0.96029
# epoch: 440, loss: -0.96076
# epoch: 441, loss: -0.96050
# epoch: 442, loss: -0.96112
# epoch: 443, loss: -0.96131
# epoch: 444, loss: -0.96042
# epoch: 445, loss: -0.96078
# epoch: 446, loss: -0.96149
# epoch: 447, loss: -0.96067
# epoch: 448, loss: -0.96077
# epoch: 449, loss: -0.96140
# epoch: 450, loss: -0.96140
# epoch: 451, loss: -0.95986
# epoch: 452, loss: -0.96053
# epoch: 453, loss: -0.96138
# epoch: 454, loss: -0.96045
# epoch: 455, loss: -0.96080
# epoch: 456, loss: -0.96026
# epoch: 457, loss: -0.96061
# epoch: 458, loss: -0.96081
# epoch: 459, loss: -0.96134
# epoch: 460, loss: -0.96179
# epoch: 461, loss: -0.96126
# epoch: 462, loss: -0.96082
# epoch: 463, loss: -0.96104
# epoch: 464, loss: -0.96112
# epoch: 465, loss: -0.96113
# epoch: 466, loss: -0.96190
# epoch: 467, loss: -0.96100
# epoch: 468, loss: -0.96140
# epoch: 469, loss: -0.96216
# epoch: 470, loss: -0.96072
# epoch: 471, loss: -0.96262
# epoch: 472, loss: -0.96168
# epoch: 473, loss: -0.96184
# epoch: 474, loss: -0.96128
# epoch: 475, loss: -0.96259
# epoch: 476, loss: -0.96152
# epoch: 477, loss: -0.96205
# epoch: 478, loss: -0.96239
# epoch: 479, loss: -0.96180
# epoch: 480, loss: -0.96136
# epoch: 481, loss: -0.96162
# epoch: 482, loss: -0.96099
# epoch: 483, loss: -0.96231
# epoch: 484, loss: -0.96192
# epoch: 485, loss: -0.96171
# epoch: 486, loss: -0.96217
# epoch: 487, loss: -0.96200
# epoch: 488, loss: -0.96168
# epoch: 489, loss: -0.96209
# epoch: 490, loss: -0.96176
# epoch: 491, loss: -0.96210
# epoch: 492, loss: -0.96116
# epoch: 493, loss: -0.96192
# epoch: 494, loss: -0.96211
# epoch: 495, loss: -0.96231
# epoch: 496, loss: -0.96195
# epoch: 497, loss: -0.96145
# epoch: 498, loss: -0.96120
# epoch: 499, loss: -0.96183

# %% [markdown]
# ##Check the Training Result

# %%
ds_cl= MyDataSet(X_ds, X_ds)
dl_cl = DataLoader(ds_cl, batch_size=256)

# %%
embeddings = []

# disable gradients for faster calculations
model.eval()
with torch.no_grad():
    for dl_cl1, dl_cl2 in dl_cl:

        dl_cl1 = dl_cl1.to(device)
        f, z, p = model(dl_cl1)
        
        # store the embeddings in lists
        embeddings.append(f)

# concatenate the embeddings, targets and convert to numpy
embeddings = torch.cat(embeddings, dim=0)
embeddings = embeddings.cpu().numpy()

# %%
test = (embeddings - embeddings.mean(axis=0)) / (embeddings.std(axis=0))

# %%
#KMeans in latent space
kmeans_backbone = KMeans(n_clusters=10).fit(test)
kmeans_labels_backbone = kmeans_backbone.labels_

# %%
normalized_mutual_info_score(kmeans_labels_backbone, y_ds)
# Out:
# 0.8184048383076259

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(embeddings)
data_X_tsne = np.vstack((X_tsne.T, kmeans_labels_backbone)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#NMI increases from 0.75 to 0.81
