# %% [markdown]
# ## Conifuration

# %%
#import the lib for contrastive learning framework
# !pip install lightly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lightly
#   Downloading lightly-1.2.19-py3-none-any.whl (449 kB)
#      |████████████████████████████████| 449 kB 5.0 MB/s
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.8.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.23.0)
# Collecting hydra-core>=1.0.0
#   Downloading hydra_core-1.2.0-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 80.0 MB/s
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.7/dist-packages (from lightly) (2022.6.15)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.21.6)
# Collecting pytorch-lightning>=1.0.4
#   Downloading pytorch_lightning-1.6.4-py3-none-any.whl (585 kB)
#      |████████████████████████████████| 585 kB 70.7 MB/s
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.15.0)
# Collecting lightly-utils~=0.0.0
#   Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from lightly) (0.12.0+cu113)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (57.4.0)
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.7/dist-packages (from lightly) (4.64.0)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.24.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (21.3)
# Collecting omegaconf~=2.2
#   Downloading omegaconf-2.2.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 10.0 MB/s
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      |████████████████████████████████| 117 kB 60.4 MB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (5.7.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from lightly-utils~=0.0.0->lightly) (7.1.2)
# Collecting PyYAML>=5.1.0
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 49.9 MB/s
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2.8.0)
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (4.1.1)
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (3.17.3)
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.9.1-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 61.8 MB/s
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 95.0 MB/s
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 76.9 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->hydra-core>=1.0.0->lightly) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (2.10)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.35.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.8.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.46.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.3.7)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (21.4.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 61.0 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 63.8 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (2.0.12)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 4.8 MB/s
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=56e5911891803feb2152294abd26dd3c46715a22783d8182254fbb6a11ff19d9
#   Stored in directory: /root/.cache/pip/wheels/8b/8d/53/2af8772d9aec614e3fc65e53d4a993ad73c61daa8bbd85a873
# Successfully built antlr4-python3-runtime
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, PyYAML, fsspec, antlr4-python3-runtime, aiohttp, torchmetrics, pyDeprecate, omegaconf, pytorch-lightning, lightly-utils, hydra-core, lightly
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-6.0 aiohttp-3.8.1 aiosignal-1.2.0 antlr4-python3-runtime-4.9.3 async-timeout-4.0.2 asynctest-0.13.0 frozenlist-1.3.0 fsspec-2022.5.0 hydra-core-1.2.0 lightly-1.2.19 lightly-utils-0.0.2 multidict-6.0.2 omegaconf-2.2.2 pyDeprecate-0.3.2 pytorch-lightning-1.6.4 torchmetrics-0.9.1 yarl-1.7.2

# %%
import lightly
from lightly.models.modules.heads import SimSiamPredictionHead
from lightly.models.modules.heads import SimSiamProjectionHead

from lightly.data import LightlyDataset
from lightly.data import ImageCollateFunction
from lightly.models.modules import BarlowTwinsProjectionHead
from lightly.loss import BarlowTwinsLoss

from lightly.data import LightlyDataset
from lightly.data import SimCLRCollateFunction
from lightly.loss import NTXentLoss
from lightly.loss import NegativeCosineSimilarity
from lightly.models.modules import SimCLRProjectionHead

# %%
import math
import torch
import torch.nn as nn
import torchvision
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from torch.utils.data import Dataset, DataLoader
import torch.optim as torch_optim
import torch.optim.lr_scheduler as lr_scheduler
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
from datetime import datetime

from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from matplotlib import pyplot
import seaborn as sns

from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_mutual_info_score
from sklearn.metrics import silhouette_score
from sklearn import mixture
from sklearn.cluster import DBSCAN
from sklearn.cluster import OPTICS
from sklearn.cluster import AgglomerativeClustering

import tensorboard
from tensorboard import notebook
from torch.utils.tensorboard import SummaryWriter

import matplotlib 
import matplotlib.pyplot as plt
#import plotly.express as px

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons
from sklearn.utils import shuffle

import torchvision.transforms as transforms
import torchvision.datasets as datasets
from sklearn.metrics.pairwise import cosine_similarity

import random
from torch.nn.modules.loss import MSELoss
from sklearn.neighbors import KDTree
#from kmodes.kprototypes import KPrototypes

from scipy.io.arff import loadarff
from sklearn.preprocessing import MinMaxScaler 
from sklearn.datasets import make_classification

# %% [markdown]
# ## Load Dataset Pendigits and Check Clustering Result with the Baseline Method Kmeans

# %%
# set the path to the dataset
path_to_data = '/content/drive/MyDrive/Colab_Notebooks/pendigits.csv'

# %%
data = pd.read_csv(path_to_data)

X_ds = data.copy()
X_ds = X_ds.drop(['class'], axis=1)
X_ds = pd.DataFrame(X_ds).to_numpy()

y_ds = data.copy()
y_ds = y_ds['class']

# %%
#check the clustering result with Kmeans
kmeans_ori = KMeans(n_clusters=10).fit(X_ds)
kmeans_labels_ori = kmeans_ori.labels_

normalized_mutual_info_score(kmeans_labels_ori, y_ds)
# Out:
# 0.6912159965088228

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X_ds)
data_X_tsne = np.vstack((X_tsne.T, y_ds)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ####MixUp

# %%
def mixup(data):
  view = data.copy()
  for i in range(len(view)):
    random_row_index = random.randint(0, len(view)-1)
    view[i] = view[i]*0.5  + view[random_row_index]*0.5
  return view

# %% [markdown]
# ####MixCut

# %%
def mixcut(data):
  data_copy = data.copy()
  view = data.copy()
  mask_len = 100

  for i in range(len(data_copy)):
    random_row_id = random.randint(0, len(data_copy)-1)
    random_column_id = random.randint(0, data_copy.shape[1]-mask_len)
    view[i,random_column_id:(random_column_id+mask_len)] = data_copy[random_row_id,random_column_id:(random_column_id+mask_len)]
  return view

# %% [markdown]
# #### Masking with mean

# %%
def get_random_indices(data, portion_of_mask):
  return np.random.choice(data.shape[1], size=np.floor(data.shape[1]*portion_of_mask).astype(int), replace=False)

# %%
def masking_with_mean(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = column_mu[j]
              
  return view

# %% [markdown]
# ####Masking with random value in domain range

# %%
def masking_with_random(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)
  column_min = np.minimum(data)
  column_max = np.maximum(data)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = random.randint(column_min[j], column_max[j])
              
  return view

# %% [markdown]
# ####Masking with margin distribution

# %%
def masking_with_margin_distribution(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = np.random.normal(column_mu[j], column_std[j])
              
  return view

# %% [markdown]
# ####Upsampling (SMOTE like)

# %%
#put all data points in kd-tree for fast searching
kdtree = KDTree(X_ds, leaf_size=2)

# %%
#get random point in the k nearest neighbors
def get_idx_random_knn(x,k):
   _, ids = kdtree.query(x.reshape(1, -1), k=k)
   ids = ids.flatten()
   ids = ids[1:-1]
   random_id = np.random.choice(ids, 1)
   return random_id

# %%
#mix up with a random near neighbor 
def mixup_random_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = 0.5*data[i] + 0.5*data[random_neighbor_id]
  return view

# %%
#a random neighbor as augmentation
def random_near_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = data[random_neighbor_id]
  return view

# %% [markdown]
# ##Create Model and Train with Augmented Data

# %%
class MyDataSet(Dataset):
  def __init__(self, view1, view2):
 
    X_view1 = view1.copy()
    X_view2 = view2.copy()
    self.X_view1 = X_view1.copy().astype(np.float32)
    self.X_view2 = X_view2.copy().astype(np.float32)
  
  def __len__(self):
    return len(self.X_view1)
  
  def __getitem__(self, idx):
    return self.X_view1[idx], self.X_view2[idx]

# %%
# define the NN architecture
class convBackbone(nn.Module):
    def __init__(self):
        super(convBackbone, self).__init__()

        #turn on dropout for testing the 'cropping' data augmentation 
        #self.dropout = nn.Dropout(p=0.1)
        
        self.fc1 = nn.Linear(16, 16, bias=False)
        self.bn1 = nn.BatchNorm1d(16)

        self.fc2 = nn.Linear(16, 16, bias=False)
        self.bn2 = nn.BatchNorm1d(16)

        self.fc3 = nn.Linear(16, 8, bias=False)
        self.bn3 = nn.BatchNorm1d(8)


    def forward(self, x):

        #turn on dropout for testing the 'cropping' data augmentation 
        #x = self.dropout(x)
        
        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.bn3(self.fc3(x))
                
        return x

# %%
class SimCLR(nn.Module):
    def __init__(self, backbone):
        super().__init__()
        self.backbone = backbone
        self.projection_head = SimCLRProjectionHead(8, 4, 8)

    def forward(self, x):
        x = self.backbone(x).flatten(start_dim=1)
        z = self.projection_head(x)
        return x,z

backbone = convBackbone()
model = SimCLR(backbone)

# %%
criterion = NTXentLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.05, momentum=0.9,weight_decay=1e-4)

#cosine annealing lr
scheduler = lr_scheduler.CosineAnnealingLR(optimizer,T_max=800, eta_min=0)

# %%
view1 = random_near_neighbor(X_ds, 18)
view2 = random_near_neighbor(X_ds, 19)

#turn on the following to test other augmentations

#view1 = mixup_random_neighbor(X_ds, 15)
#view2 = mixup_random_neighbor(X_ds, 15)

#view1 = mixup(X_ds)
#view2 = mixup(X_ds)

#view1 = mixcut(X_ds)
#view2 = mixcut(X_ds)

#view1 = masking_with_mean(X_ds, 0.4)
#view2 = masking_with_mean(X_ds, 0.4)

#view1 = masking_with_random(X_ds, 0.4)
#view2 = masking_with_random(X_ds, 0.4)

#view1 = masking_with_margin_distribution(X_ds, 0.4)
#view2 = masking_with_margin_distribution(X_ds, 0.4)

train_ds = MyDataSet(view1, view2)
train_dl = DataLoader(train_ds, batch_size=256, shuffle=True)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

for epoch in range(800):
    total_loss = 0
    for x0, x1 in train_dl:

        x0 = x0.to(device)
        x1 = x1.to(device)
        z0 = model(x0)
        z1 = model(x1)

        z0 = (z0 - torch.mean(z0,0)) / torch.std(z0,0)
        z1 = (z1 - torch.mean(z1,0)) / torch.std(z1,0)

        loss = criterion(z0, z1)
        total_loss += loss.detach()
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    avg_loss = total_loss / len(train_dl)
    print(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
# Out:
# epoch: 00, loss: 4.85749
# epoch: 01, loss: 4.77320
# epoch: 02, loss: 4.76341
# epoch: 03, loss: 4.75818
# epoch: 04, loss: 4.75325
# epoch: 05, loss: 4.75194
# epoch: 06, loss: 4.75041
# epoch: 07, loss: 4.74909
# epoch: 08, loss: 4.74684
# epoch: 09, loss: 4.74588
# epoch: 10, loss: 4.74400
# epoch: 11, loss: 4.74481
# epoch: 12, loss: 4.74377
# epoch: 13, loss: 4.74298
# epoch: 14, loss: 4.74166
# epoch: 15, loss: 4.74154
# epoch: 16, loss: 4.74095
# epoch: 17, loss: 4.74009
# epoch: 18, loss: 4.74031
# epoch: 19, loss: 4.74055
# epoch: 20, loss: 4.73991
# epoch: 21, loss: 4.73952
# epoch: 22, loss: 4.73806
# epoch: 23, loss: 4.73777
# epoch: 24, loss: 4.73737
# epoch: 25, loss: 4.73710
# epoch: 26, loss: 4.73895
# epoch: 27, loss: 4.73685
# epoch: 28, loss: 4.73702
# epoch: 29, loss: 4.73728
# epoch: 30, loss: 4.73728
# epoch: 31, loss: 4.73618
# epoch: 32, loss: 4.73698
# epoch: 33, loss: 4.73702
# epoch: 34, loss: 4.73565
# epoch: 35, loss: 4.73533
# epoch: 36, loss: 4.73555
# epoch: 37, loss: 4.73531
# epoch: 38, loss: 4.73461
# epoch: 39, loss: 4.73445
# epoch: 40, loss: 4.73436
# epoch: 41, loss: 4.73513
# epoch: 42, loss: 4.73500
# epoch: 43, loss: 4.73467
# epoch: 44, loss: 4.73501
# epoch: 45, loss: 4.73535
# epoch: 46, loss: 4.73426
# epoch: 47, loss: 4.73358
# epoch: 48, loss: 4.73395
# epoch: 49, loss: 4.73357
# epoch: 50, loss: 4.73294
# epoch: 51, loss: 4.73469
# epoch: 52, loss: 4.73406
# epoch: 53, loss: 4.73396
# epoch: 54, loss: 4.73376
# epoch: 55, loss: 4.73344
# epoch: 56, loss: 4.73373
# epoch: 57, loss: 4.73311
# epoch: 58, loss: 4.73334
# epoch: 59, loss: 4.73293
# epoch: 60, loss: 4.73330
# epoch: 61, loss: 4.73308
# epoch: 62, loss: 4.73526
# epoch: 63, loss: 4.73341
# epoch: 64, loss: 4.73213
# epoch: 65, loss: 4.73222
# epoch: 66, loss: 4.73152
# epoch: 67, loss: 4.73245
# epoch: 68, loss: 4.73282
# epoch: 69, loss: 4.73257
# epoch: 70, loss: 4.73228
# epoch: 71, loss: 4.73299
# epoch: 72, loss: 4.73281
# epoch: 73, loss: 4.73274
# epoch: 74, loss: 4.73195
# epoch: 75, loss: 4.73216
# epoch: 76, loss: 4.73171
# epoch: 77, loss: 4.73204
# epoch: 78, loss: 4.73193
# epoch: 79, loss: 4.73318
# epoch: 80, loss: 4.73244
# epoch: 81, loss: 4.73239
# epoch: 82, loss: 4.73132
# epoch: 83, loss: 4.73252
# epoch: 84, loss: 4.73274
# epoch: 85, loss: 4.73119
# epoch: 86, loss: 4.73167
# epoch: 87, loss: 4.73208
# epoch: 88, loss: 4.73134
# epoch: 89, loss: 4.73281
# epoch: 90, loss: 4.73192
# epoch: 91, loss: 4.73172
# epoch: 92, loss: 4.73297
# epoch: 93, loss: 4.73157
# epoch: 94, loss: 4.73154
# epoch: 95, loss: 4.73178
# epoch: 96, loss: 4.73230
# epoch: 97, loss: 4.73134
# epoch: 98, loss: 4.73197
# epoch: 99, loss: 4.73156
# epoch: 100, loss: 4.73231
# epoch: 101, loss: 4.73125
# epoch: 102, loss: 4.73114
# epoch: 103, loss: 4.73171
# epoch: 104, loss: 4.73174
# epoch: 105, loss: 4.73073
# epoch: 106, loss: 4.73178
# epoch: 107, loss: 4.73164
# epoch: 108, loss: 4.73146
# epoch: 109, loss: 4.73144
# epoch: 110, loss: 4.73196
# epoch: 111, loss: 4.73137
# epoch: 112, loss: 4.73102
# epoch: 113, loss: 4.73094
# epoch: 114, loss: 4.73104
# epoch: 115, loss: 4.73175
# epoch: 116, loss: 4.73100
# epoch: 117, loss: 4.73097
# epoch: 118, loss: 4.73139
# epoch: 119, loss: 4.73144
# epoch: 120, loss: 4.73128
# epoch: 121, loss: 4.73137
# epoch: 122, loss: 4.73141
# epoch: 123, loss: 4.73041
# epoch: 124, loss: 4.73066
# epoch: 125, loss: 4.73085
# epoch: 126, loss: 4.73058
# epoch: 127, loss: 4.73186
# epoch: 128, loss: 4.73137
# epoch: 129, loss: 4.73115
# epoch: 130, loss: 4.73038
# epoch: 131, loss: 4.73055
# epoch: 132, loss: 4.73085
# epoch: 133, loss: 4.73061
# epoch: 134, loss: 4.73143
# epoch: 135, loss: 4.73116
# epoch: 136, loss: 4.73058
# epoch: 137, loss: 4.73085
# epoch: 138, loss: 4.73094
# epoch: 139, loss: 4.73044
# epoch: 140, loss: 4.73095
# epoch: 141, loss: 4.73156
# epoch: 142, loss: 4.73099
# epoch: 143, loss: 4.72995
# epoch: 144, loss: 4.73051
# epoch: 145, loss: 4.73140
# epoch: 146, loss: 4.73106
# epoch: 147, loss: 4.73089
# epoch: 148, loss: 4.73103
# epoch: 149, loss: 4.73072
# epoch: 150, loss: 4.73071
# epoch: 151, loss: 4.73064
# epoch: 152, loss: 4.73024
# epoch: 153, loss: 4.73070
# epoch: 154, loss: 4.73048
# epoch: 155, loss: 4.73083
# epoch: 156, loss: 4.73064
# epoch: 157, loss: 4.73112
# epoch: 158, loss: 4.73076
# epoch: 159, loss: 4.72995
# epoch: 160, loss: 4.73031
# epoch: 161, loss: 4.73070
# epoch: 162, loss: 4.73132
# epoch: 163, loss: 4.73255
# epoch: 164, loss: 4.73042
# epoch: 165, loss: 4.73068
# epoch: 166, loss: 4.72996
# epoch: 167, loss: 4.73036
# epoch: 168, loss: 4.73069
# epoch: 169, loss: 4.73072
# epoch: 170, loss: 4.72980
# epoch: 171, loss: 4.73037
# epoch: 172, loss: 4.73195
# epoch: 173, loss: 4.73135
# epoch: 174, loss: 4.73134
# epoch: 175, loss: 4.73106
# epoch: 176, loss: 4.73101
# epoch: 177, loss: 4.73086
# epoch: 178, loss: 4.73069
# epoch: 179, loss: 4.73077
# epoch: 180, loss: 4.73055
# epoch: 181, loss: 4.73063
# epoch: 182, loss: 4.73038
# epoch: 183, loss: 4.73070
# epoch: 184, loss: 4.73169
# epoch: 185, loss: 4.73018
# epoch: 186, loss: 4.73023
# epoch: 187, loss: 4.73056
# epoch: 188, loss: 4.73041
# epoch: 189, loss: 4.73031
# epoch: 190, loss: 4.73036
# epoch: 191, loss: 4.73025
# epoch: 192, loss: 4.73088
# epoch: 193, loss: 4.73040
# epoch: 194, loss: 4.72981
# epoch: 195, loss: 4.73013
# epoch: 196, loss: 4.72952
# epoch: 197, loss: 4.73041
# epoch: 198, loss: 4.73053
# epoch: 199, loss: 4.73112
# epoch: 200, loss: 4.73141
# epoch: 201, loss: 4.73088
# epoch: 202, loss: 4.73063
# epoch: 203, loss: 4.72992
# epoch: 204, loss: 4.73055
# epoch: 205, loss: 4.73053
# epoch: 206, loss: 4.73011
# epoch: 207, loss: 4.73088
# epoch: 208, loss: 4.73053
# epoch: 209, loss: 4.73014
# epoch: 210, loss: 4.73034
# epoch: 211, loss: 4.73039
# epoch: 212, loss: 4.73072
# epoch: 213, loss: 4.72973
# epoch: 214, loss: 4.73015
# epoch: 215, loss: 4.73027
# epoch: 216, loss: 4.72990
# epoch: 217, loss: 4.72966
# epoch: 218, loss: 4.72917
# epoch: 219, loss: 4.73033
# epoch: 220, loss: 4.73037
# epoch: 221, loss: 4.73005
# epoch: 222, loss: 4.72998
# epoch: 223, loss: 4.73061
# epoch: 224, loss: 4.73070
# epoch: 225, loss: 4.73006
# epoch: 226, loss: 4.72995
# epoch: 227, loss: 4.73014
# epoch: 228, loss: 4.72977
# epoch: 229, loss: 4.72989
# epoch: 230, loss: 4.73028
# epoch: 231, loss: 4.73008
# epoch: 232, loss: 4.73037
# epoch: 233, loss: 4.73151
# epoch: 234, loss: 4.73108
# epoch: 235, loss: 4.73048
# epoch: 236, loss: 4.72984
# epoch: 237, loss: 4.72985
# epoch: 238, loss: 4.73062
# epoch: 239, loss: 4.73014
# epoch: 240, loss: 4.73088
# epoch: 241, loss: 4.72949
# epoch: 242, loss: 4.73017
# epoch: 243, loss: 4.72923
# epoch: 244, loss: 4.73046
# epoch: 245, loss: 4.73025
# epoch: 246, loss: 4.73005
# epoch: 247, loss: 4.72983
# epoch: 248, loss: 4.73015
# epoch: 249, loss: 4.72980
# epoch: 250, loss: 4.73060
# epoch: 251, loss: 4.72990
# epoch: 252, loss: 4.73070
# epoch: 253, loss: 4.73040
# epoch: 254, loss: 4.72988
# epoch: 255, loss: 4.72990
# epoch: 256, loss: 4.73006
# epoch: 257, loss: 4.72985
# epoch: 258, loss: 4.73074
# epoch: 259, loss: 4.73012
# epoch: 260, loss: 4.72986
# epoch: 261, loss: 4.73003
# epoch: 262, loss: 4.72908
# epoch: 263, loss: 4.72972
# epoch: 264, loss: 4.72982
# epoch: 265, loss: 4.72984
# epoch: 266, loss: 4.72972
# epoch: 267, loss: 4.73002
# epoch: 268, loss: 4.73070
# epoch: 269, loss: 4.73073
# epoch: 270, loss: 4.73044
# epoch: 271, loss: 4.72966
# epoch: 272, loss: 4.72985
# epoch: 273, loss: 4.72948
# epoch: 274, loss: 4.73117
# epoch: 275, loss: 4.73051
# epoch: 276, loss: 4.73038
# epoch: 277, loss: 4.73105
# epoch: 278, loss: 4.72977
# epoch: 279, loss: 4.73048
# epoch: 280, loss: 4.72996
# epoch: 281, loss: 4.72926
# epoch: 282, loss: 4.73022
# epoch: 283, loss: 4.73081
# epoch: 284, loss: 4.73052
# epoch: 285, loss: 4.72942
# epoch: 286, loss: 4.72974
# epoch: 287, loss: 4.72980
# epoch: 288, loss: 4.73019
# epoch: 289, loss: 4.73115
# epoch: 290, loss: 4.73064
# epoch: 291, loss: 4.72972
# epoch: 292, loss: 4.73015
# epoch: 293, loss: 4.72999
# epoch: 294, loss: 4.72973
# epoch: 295, loss: 4.73023
# epoch: 296, loss: 4.72998
# epoch: 297, loss: 4.73084
# epoch: 298, loss: 4.72931
# epoch: 299, loss: 4.73021
# epoch: 300, loss: 4.73098
# epoch: 301, loss: 4.73048
# epoch: 302, loss: 4.72978
# epoch: 303, loss: 4.73065
# epoch: 304, loss: 4.73047
# epoch: 305, loss: 4.73043
# epoch: 306, loss: 4.73046
# epoch: 307, loss: 4.72963
# epoch: 308, loss: 4.72922
# epoch: 309, loss: 4.72970
# epoch: 310, loss: 4.73052
# epoch: 311, loss: 4.72997
# epoch: 312, loss: 4.73011
# epoch: 313, loss: 4.73050
# epoch: 314, loss: 4.73046
# epoch: 315, loss: 4.72948
# epoch: 316, loss: 4.72988
# epoch: 317, loss: 4.73012
# epoch: 318, loss: 4.73034
# epoch: 319, loss: 4.72969
# epoch: 320, loss: 4.72996
# epoch: 321, loss: 4.73074
# epoch: 322, loss: 4.72942
# epoch: 323, loss: 4.73012
# epoch: 324, loss: 4.72932
# epoch: 325, loss: 4.72963
# epoch: 326, loss: 4.72986
# epoch: 327, loss: 4.72985
# epoch: 328, loss: 4.73028
# epoch: 329, loss: 4.72989
# epoch: 330, loss: 4.72942
# epoch: 331, loss: 4.72953
# epoch: 332, loss: 4.72991
# epoch: 333, loss: 4.72980
# epoch: 334, loss: 4.73006
# epoch: 335, loss: 4.72971
# epoch: 336, loss: 4.72927
# epoch: 337, loss: 4.72983
# epoch: 338, loss: 4.72954
# epoch: 339, loss: 4.72938
# epoch: 340, loss: 4.73016
# epoch: 341, loss: 4.73005
# epoch: 342, loss: 4.72944
# epoch: 343, loss: 4.72947
# epoch: 344, loss: 4.73037
# epoch: 345, loss: 4.73010
# epoch: 346, loss: 4.72950
# epoch: 347, loss: 4.73015
# epoch: 348, loss: 4.72990
# epoch: 349, loss: 4.72994
# epoch: 350, loss: 4.73012
# epoch: 351, loss: 4.73015
# epoch: 352, loss: 4.72938
# epoch: 353, loss: 4.72975
# epoch: 354, loss: 4.73033
# epoch: 355, loss: 4.72984
# epoch: 356, loss: 4.72979
# epoch: 357, loss: 4.72944
# epoch: 358, loss: 4.72884
# epoch: 359, loss: 4.73009
# epoch: 360, loss: 4.73050
# epoch: 361, loss: 4.72984
# epoch: 362, loss: 4.72995
# epoch: 363, loss: 4.73015
# epoch: 364, loss: 4.72964
# epoch: 365, loss: 4.73008
# epoch: 366, loss: 4.73011
# epoch: 367, loss: 4.72998
# epoch: 368, loss: 4.73058
# epoch: 369, loss: 4.72984
# epoch: 370, loss: 4.73028
# epoch: 371, loss: 4.72986
# epoch: 372, loss: 4.73087
# epoch: 373, loss: 4.73036
# epoch: 374, loss: 4.73115
# epoch: 375, loss: 4.72958
# epoch: 376, loss: 4.72933
# epoch: 377, loss: 4.72994
# epoch: 378, loss: 4.73015
# epoch: 379, loss: 4.73005
# epoch: 380, loss: 4.72980
# epoch: 381, loss: 4.72959
# epoch: 382, loss: 4.73028
# epoch: 383, loss: 4.72981
# epoch: 384, loss: 4.73052
# epoch: 385, loss: 4.72984
# epoch: 386, loss: 4.73020
# epoch: 387, loss: 4.73000
# epoch: 388, loss: 4.72989
# epoch: 389, loss: 4.73002
# epoch: 390, loss: 4.73097
# epoch: 391, loss: 4.73050
# epoch: 392, loss: 4.73042
# epoch: 393, loss: 4.73014
# epoch: 394, loss: 4.73035
# epoch: 395, loss: 4.72998
# epoch: 396, loss: 4.72961
# epoch: 397, loss: 4.73002
# epoch: 398, loss: 4.72986
# epoch: 399, loss: 4.72983
# epoch: 400, loss: 4.73012
# epoch: 401, loss: 4.73056
# epoch: 402, loss: 4.73016
# epoch: 403, loss: 4.73085
# epoch: 404, loss: 4.73054
# epoch: 405, loss: 4.72943
# epoch: 406, loss: 4.72968
# epoch: 407, loss: 4.72969
# epoch: 408, loss: 4.73055
# epoch: 409, loss: 4.72991
# epoch: 410, loss: 4.72960
# epoch: 411, loss: 4.72930
# epoch: 412, loss: 4.72962
# epoch: 413, loss: 4.73010
# epoch: 414, loss: 4.72955
# epoch: 415, loss: 4.73020
# epoch: 416, loss: 4.73055
# epoch: 417, loss: 4.72975
# epoch: 418, loss: 4.73001
# epoch: 419, loss: 4.73001
# epoch: 420, loss: 4.72990
# epoch: 421, loss: 4.72899
# epoch: 422, loss: 4.73023
# epoch: 423, loss: 4.73037
# epoch: 424, loss: 4.72996
# epoch: 425, loss: 4.72972
# epoch: 426, loss: 4.73035
# epoch: 427, loss: 4.72880
# epoch: 428, loss: 4.72876
# epoch: 429, loss: 4.73079
# epoch: 430, loss: 4.72939
# epoch: 431, loss: 4.72954
# epoch: 432, loss: 4.72939
# epoch: 433, loss: 4.72962
# epoch: 434, loss: 4.72998
# epoch: 435, loss: 4.72990
# epoch: 436, loss: 4.73030
# epoch: 437, loss: 4.72969
# epoch: 438, loss: 4.72974
# epoch: 439, loss: 4.73023
# epoch: 440, loss: 4.72910
# epoch: 441, loss: 4.73045
# epoch: 442, loss: 4.73065
# epoch: 443, loss: 4.73036
# epoch: 444, loss: 4.73132
# epoch: 445, loss: 4.72964
# epoch: 446, loss: 4.72901
# epoch: 447, loss: 4.73018
# epoch: 448, loss: 4.73021
# epoch: 449, loss: 4.73014
# epoch: 450, loss: 4.72997
# epoch: 451, loss: 4.73118
# epoch: 452, loss: 4.72987
# epoch: 453, loss: 4.73020
# epoch: 454, loss: 4.72994
# epoch: 455, loss: 4.72986
# epoch: 456, loss: 4.72950
# epoch: 457, loss: 4.72991
# epoch: 458, loss: 4.72981
# epoch: 459, loss: 4.72997
# epoch: 460, loss: 4.72957
# epoch: 461, loss: 4.73061
# epoch: 462, loss: 4.72959
# epoch: 463, loss: 4.72906
# epoch: 464, loss: 4.73060
# epoch: 465, loss: 4.73010
# epoch: 466, loss: 4.73033
# epoch: 467, loss: 4.73022
# epoch: 468, loss: 4.73036
# epoch: 469, loss: 4.73017
# epoch: 470, loss: 4.72897
# epoch: 471, loss: 4.72963
# epoch: 472, loss: 4.73032
# epoch: 473, loss: 4.72945
# epoch: 474, loss: 4.72944
# epoch: 475, loss: 4.72952
# epoch: 476, loss: 4.73066
# epoch: 477, loss: 4.72917
# epoch: 478, loss: 4.72968
# epoch: 479, loss: 4.72956
# epoch: 480, loss: 4.73029
# epoch: 481, loss: 4.72985
# epoch: 482, loss: 4.73042
# epoch: 483, loss: 4.72988
# epoch: 484, loss: 4.72927
# epoch: 485, loss: 4.72885
# epoch: 486, loss: 4.72920
# epoch: 487, loss: 4.73101
# epoch: 488, loss: 4.73061
# epoch: 489, loss: 4.73039
# epoch: 490, loss: 4.73081
# epoch: 491, loss: 4.72973
# epoch: 492, loss: 4.72890
# epoch: 493, loss: 4.72876
# epoch: 494, loss: 4.73110
# epoch: 495, loss: 4.72972
# epoch: 496, loss: 4.72937
# epoch: 497, loss: 4.72923
# epoch: 498, loss: 4.72991
# epoch: 499, loss: 4.72952
# epoch: 500, loss: 4.72986
# epoch: 501, loss: 4.73023
# epoch: 502, loss: 4.72922
# epoch: 503, loss: 4.72960
# epoch: 504, loss: 4.72927
# epoch: 505, loss: 4.73061
# epoch: 506, loss: 4.72946
# epoch: 507, loss: 4.73089
# epoch: 508, loss: 4.73054
# epoch: 509, loss: 4.73068
# epoch: 510, loss: 4.72952
# epoch: 511, loss: 4.72981
# epoch: 512, loss: 4.72951
# epoch: 513, loss: 4.72896
# epoch: 514, loss: 4.72912
# epoch: 515, loss: 4.72892
# epoch: 516, loss: 4.72992
# epoch: 517, loss: 4.72966
# epoch: 518, loss: 4.72987
# epoch: 519, loss: 4.72953
# epoch: 520, loss: 4.73026
# epoch: 521, loss: 4.73039
# epoch: 522, loss: 4.72987
# epoch: 523, loss: 4.73009
# epoch: 524, loss: 4.72942
# epoch: 525, loss: 4.72934
# epoch: 526, loss: 4.73099
# epoch: 527, loss: 4.72977
# epoch: 528, loss: 4.72955
# epoch: 529, loss: 4.73068
# epoch: 530, loss: 4.72998
# epoch: 531, loss: 4.72998
# epoch: 532, loss: 4.72963
# epoch: 533, loss: 4.72930
# epoch: 534, loss: 4.72948
# epoch: 535, loss: 4.73034
# epoch: 536, loss: 4.73006
# epoch: 537, loss: 4.73180
# epoch: 538, loss: 4.73008
# epoch: 539, loss: 4.72961
# epoch: 540, loss: 4.73008
# epoch: 541, loss: 4.73000
# epoch: 542, loss: 4.72982
# epoch: 543, loss: 4.73059
# epoch: 544, loss: 4.72970
# epoch: 545, loss: 4.73021
# epoch: 546, loss: 4.72921
# epoch: 547, loss: 4.72966
# epoch: 548, loss: 4.73033
# epoch: 549, loss: 4.72988
# epoch: 550, loss: 4.72953
# epoch: 551, loss: 4.73050
# epoch: 552, loss: 4.72935
# epoch: 553, loss: 4.72962
# epoch: 554, loss: 4.72967
# epoch: 555, loss: 4.73061
# epoch: 556, loss: 4.73036
# epoch: 557, loss: 4.72996
# epoch: 558, loss: 4.73074
# epoch: 559, loss: 4.72933
# epoch: 560, loss: 4.73017
# epoch: 561, loss: 4.72911
# epoch: 562, loss: 4.72926
# epoch: 563, loss: 4.72962
# epoch: 564, loss: 4.72993
# epoch: 565, loss: 4.72993
# epoch: 566, loss: 4.73051
# epoch: 567, loss: 4.72987
# epoch: 568, loss: 4.73063
# epoch: 569, loss: 4.72971
# epoch: 570, loss: 4.73028
# epoch: 571, loss: 4.73112
# epoch: 572, loss: 4.73016
# epoch: 573, loss: 4.72967
# epoch: 574, loss: 4.72960
# epoch: 575, loss: 4.72977
# epoch: 576, loss: 4.72976
# epoch: 577, loss: 4.73014
# epoch: 578, loss: 4.73034
# epoch: 579, loss: 4.72976
# epoch: 580, loss: 4.73040
# epoch: 581, loss: 4.72997
# epoch: 582, loss: 4.72927
# epoch: 583, loss: 4.72992
# epoch: 584, loss: 4.72967
# epoch: 585, loss: 4.72978
# epoch: 586, loss: 4.73005
# epoch: 587, loss: 4.72971
# epoch: 588, loss: 4.72928
# epoch: 589, loss: 4.72983
# epoch: 590, loss: 4.73040
# epoch: 591, loss: 4.72990
# epoch: 592, loss: 4.72918
# epoch: 593, loss: 4.72978
# epoch: 594, loss: 4.73027
# epoch: 595, loss: 4.72948
# epoch: 596, loss: 4.72923
# epoch: 597, loss: 4.72947
# epoch: 598, loss: 4.72894
# epoch: 599, loss: 4.72910
# epoch: 600, loss: 4.72937
# epoch: 601, loss: 4.73027
# epoch: 602, loss: 4.72927
# epoch: 603, loss: 4.72930
# epoch: 604, loss: 4.73028
# epoch: 605, loss: 4.73078
# epoch: 606, loss: 4.72977
# epoch: 607, loss: 4.73005
# epoch: 608, loss: 4.72902
# epoch: 609, loss: 4.72907
# epoch: 610, loss: 4.72957
# epoch: 611, loss: 4.72909
# epoch: 612, loss: 4.73014
# epoch: 613, loss: 4.72968
# epoch: 614, loss: 4.72906
# epoch: 615, loss: 4.72923
# epoch: 616, loss: 4.72982
# epoch: 617, loss: 4.72949
# epoch: 618, loss: 4.72952
# epoch: 619, loss: 4.73007
# epoch: 620, loss: 4.72965
# epoch: 621, loss: 4.72935
# epoch: 622, loss: 4.73008
# epoch: 623, loss: 4.73103
# epoch: 624, loss: 4.73030
# epoch: 625, loss: 4.72899
# epoch: 626, loss: 4.73008
# epoch: 627, loss: 4.73006
# epoch: 628, loss: 4.73043
# epoch: 629, loss: 4.72931
# epoch: 630, loss: 4.72972
# epoch: 631, loss: 4.72975
# epoch: 632, loss: 4.72965
# epoch: 633, loss: 4.72995
# epoch: 634, loss: 4.73013
# epoch: 635, loss: 4.72985
# epoch: 636, loss: 4.72938
# epoch: 637, loss: 4.72916
# epoch: 638, loss: 4.72919
# epoch: 639, loss: 4.72871
# epoch: 640, loss: 4.72960
# epoch: 641, loss: 4.72969
# epoch: 642, loss: 4.72896
# epoch: 643, loss: 4.72932
# epoch: 644, loss: 4.73020
# epoch: 645, loss: 4.72994
# epoch: 646, loss: 4.73027
# epoch: 647, loss: 4.72963
# epoch: 648, loss: 4.72990
# epoch: 649, loss: 4.72964
# epoch: 650, loss: 4.73012
# epoch: 651, loss: 4.72993
# epoch: 652, loss: 4.72981
# epoch: 653, loss: 4.72982
# epoch: 654, loss: 4.72975
# epoch: 655, loss: 4.72995
# epoch: 656, loss: 4.72925
# epoch: 657, loss: 4.72997
# epoch: 658, loss: 4.72986
# epoch: 659, loss: 4.72978
# epoch: 660, loss: 4.73027
# epoch: 661, loss: 4.72953
# epoch: 662, loss: 4.73035
# epoch: 663, loss: 4.72984
# epoch: 664, loss: 4.73003
# epoch: 665, loss: 4.72908
# epoch: 666, loss: 4.73003
# epoch: 667, loss: 4.72972
# epoch: 668, loss: 4.73033
# epoch: 669, loss: 4.72992
# epoch: 670, loss: 4.73011
# epoch: 671, loss: 4.72894
# epoch: 672, loss: 4.72979
# epoch: 673, loss: 4.73009
# epoch: 674, loss: 4.73036
# epoch: 675, loss: 4.72935
# epoch: 676, loss: 4.73062
# epoch: 677, loss: 4.72906
# epoch: 678, loss: 4.73033
# epoch: 679, loss: 4.73003
# epoch: 680, loss: 4.72936
# epoch: 681, loss: 4.73066
# epoch: 682, loss: 4.72951
# epoch: 683, loss: 4.72922
# epoch: 684, loss: 4.73014
# epoch: 685, loss: 4.72962
# epoch: 686, loss: 4.73002
# epoch: 687, loss: 4.72950
# epoch: 688, loss: 4.72951
# epoch: 689, loss: 4.73026
# epoch: 690, loss: 4.72906
# epoch: 691, loss: 4.72911
# epoch: 692, loss: 4.72999
# epoch: 693, loss: 4.73024
# epoch: 694, loss: 4.72958
# epoch: 695, loss: 4.72986
# epoch: 696, loss: 4.72899
# epoch: 697, loss: 4.72966
# epoch: 698, loss: 4.72931
# epoch: 699, loss: 4.72980
# epoch: 700, loss: 4.72899
# epoch: 701, loss: 4.73002
# epoch: 702, loss: 4.72971
# epoch: 703, loss: 4.72945
# epoch: 704, loss: 4.72971
# epoch: 705, loss: 4.72952
# epoch: 706, loss: 4.72996
# epoch: 707, loss: 4.72919
# epoch: 708, loss: 4.72974
# epoch: 709, loss: 4.73001
# epoch: 710, loss: 4.72991
# epoch: 711, loss: 4.72932
# epoch: 712, loss: 4.72964
# epoch: 713, loss: 4.72965
# epoch: 714, loss: 4.72977
# epoch: 715, loss: 4.72940
# epoch: 716, loss: 4.72924
# epoch: 717, loss: 4.72982
# epoch: 718, loss: 4.72947
# epoch: 719, loss: 4.73217
# epoch: 720, loss: 4.72984
# epoch: 721, loss: 4.73011
# epoch: 722, loss: 4.72949
# epoch: 723, loss: 4.72957
# epoch: 724, loss: 4.72936
# epoch: 725, loss: 4.72880
# epoch: 726, loss: 4.73013
# epoch: 727, loss: 4.73039
# epoch: 728, loss: 4.73005
# epoch: 729, loss: 4.72956
# epoch: 730, loss: 4.73081
# epoch: 731, loss: 4.72979
# epoch: 732, loss: 4.72974
# epoch: 733, loss: 4.72945
# epoch: 734, loss: 4.72978
# epoch: 735, loss: 4.72950
# epoch: 736, loss: 4.72904
# epoch: 737, loss: 4.72968
# epoch: 738, loss: 4.72922
# epoch: 739, loss: 4.72932
# epoch: 740, loss: 4.72962
# epoch: 741, loss: 4.72894
# epoch: 742, loss: 4.72959
# epoch: 743, loss: 4.72982
# epoch: 744, loss: 4.72914
# epoch: 745, loss: 4.72982
# epoch: 746, loss: 4.72948
# epoch: 747, loss: 4.72965
# epoch: 748, loss: 4.72979
# epoch: 749, loss: 4.72913
# epoch: 750, loss: 4.72905
# epoch: 751, loss: 4.73016
# epoch: 752, loss: 4.72956
# epoch: 753, loss: 4.72891
# epoch: 754, loss: 4.72939
# epoch: 755, loss: 4.72969
# epoch: 756, loss: 4.73069
# epoch: 757, loss: 4.72919
# epoch: 758, loss: 4.72960
# epoch: 759, loss: 4.72970
# epoch: 760, loss: 4.72996
# epoch: 761, loss: 4.73025
# epoch: 762, loss: 4.73028
# epoch: 763, loss: 4.72993
# epoch: 764, loss: 4.73009
# epoch: 765, loss: 4.72862
# epoch: 766, loss: 4.72993
# epoch: 767, loss: 4.72935
# epoch: 768, loss: 4.72966
# epoch: 769, loss: 4.72940
# epoch: 770, loss: 4.72911
# epoch: 771, loss: 4.72985
# epoch: 772, loss: 4.72973
# epoch: 773, loss: 4.72867
# epoch: 774, loss: 4.72918
# epoch: 775, loss: 4.72964
# epoch: 776, loss: 4.72977
# epoch: 777, loss: 4.72925
# epoch: 778, loss: 4.73008
# epoch: 779, loss: 4.73056
# epoch: 780, loss: 4.72984
# epoch: 781, loss: 4.72942
# epoch: 782, loss: 4.73025
# epoch: 783, loss: 4.72974
# epoch: 784, loss: 4.72928
# epoch: 785, loss: 4.72964
# epoch: 786, loss: 4.73051
# epoch: 787, loss: 4.72994
# epoch: 788, loss: 4.73015
# epoch: 789, loss: 4.72974
# epoch: 790, loss: 4.72953
# epoch: 791, loss: 4.72941
# epoch: 792, loss: 4.73027
# epoch: 793, loss: 4.73083
# epoch: 794, loss: 4.73021
# epoch: 795, loss: 4.73032
# epoch: 796, loss: 4.72970
# epoch: 797, loss: 4.72947
# epoch: 798, loss: 4.72948
# epoch: 799, loss: 4.72953

# %% [markdown]
# ##Check the Training Result

# %%
ds_cl= MyDataSet(X_ds, X_ds)
dl_cl = DataLoader(ds_cl, batch_size=256)

# %%
embeddings = []

# disable gradients for faster calculations
model.eval()
with torch.no_grad():
    for dl_cl1, dl_cl2 in dl_cl:

        dl_cl1 = dl_cl1.to(device)
        x,z = model(dl_cl1)
        
        # store the embeddings in lists
        embeddings.append(x)

# concatenate the embeddings, targets and convert to numpy
embeddings = torch.cat(embeddings, dim=0)
embeddings = embeddings.cpu().numpy()

# %%
test = (embeddings - embeddings.mean(axis=0)) / (embeddings.std(axis=0))

# %%
#KMeans in latent space
kmeans_backbone = KMeans(n_clusters=10).fit(test)
kmeans_labels_backbone = kmeans_backbone.labels_

# %%
normalized_mutual_info_score(kmeans_labels_backbone, y_ds)
# Out:
# 0.7716121977897825

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(embeddings)
data_X_tsne = np.vstack((X_tsne.T, y_ds)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#NMI increases from 0.69 to 0.77
