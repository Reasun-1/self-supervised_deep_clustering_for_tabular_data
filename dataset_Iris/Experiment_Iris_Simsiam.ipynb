# %% [markdown]
# ## Conifuration

# %%
#import the lib for contrastive learning framework
# !pip install lightly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lightly in /usr/local/lib/python3.7/dist-packages (1.2.23)
# Requirement already satisfied: hydra-core>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.2.0)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.23.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from lightly) (0.12.0+cu113)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (57.4.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.8.2)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.24.3)
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.7/dist-packages (from lightly) (4.64.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.21.6)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.7/dist-packages (from lightly) (2022.6.15)
# Requirement already satisfied: pytorch-lightning>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.6.4)
# Requirement already satisfied: lightly-utils~=0.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (0.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (21.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (4.9.3)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (5.7.1)
# Requirement already satisfied: omegaconf~=2.2 in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (2.2.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from lightly-utils~=0.0.0->lightly) (7.1.2)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.7/dist-packages (from omegaconf~=2.2->hydra-core>=1.0.0->lightly) (6.0)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2022.5.0)
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (3.17.3)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (0.3.2)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2.8.0)
# Requirement already satisfied: torchmetrics>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (0.9.2)
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (4.1.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->hydra-core>=1.0.0->lightly) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (3.0.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.3.7)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.46.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.35.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.1.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.0.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.37.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (1.2.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (0.13.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (21.4.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (2.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (6.0.2)

# %%
import lightly
from lightly.models.modules.heads import SimSiamPredictionHead
from lightly.models.modules.heads import SimSiamProjectionHead

from lightly.data import LightlyDataset
from lightly.data import ImageCollateFunction
from lightly.models.modules import BarlowTwinsProjectionHead
from lightly.loss import BarlowTwinsLoss

from lightly.data import LightlyDataset
from lightly.data import SimCLRCollateFunction
from lightly.loss import NTXentLoss
from lightly.loss import NegativeCosineSimilarity
from lightly.models.modules import SimCLRProjectionHead

# %%
import math
import torch
import torch.nn as nn
import torchvision
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from torch.utils.data import Dataset, DataLoader
import torch.optim as torch_optim
import torch.optim.lr_scheduler as lr_scheduler
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
from datetime import datetime

from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from matplotlib import pyplot
import seaborn as sns

from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_mutual_info_score
from sklearn.metrics import silhouette_score
from sklearn import mixture
from sklearn.cluster import DBSCAN
from sklearn.cluster import OPTICS
from sklearn.cluster import AgglomerativeClustering

import tensorboard
from tensorboard import notebook
from torch.utils.tensorboard import SummaryWriter

import matplotlib 
import matplotlib.pyplot as plt
#import plotly.express as px

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons
from sklearn.utils import shuffle

import torchvision.transforms as transforms
import torchvision.datasets as datasets
from sklearn.metrics.pairwise import cosine_similarity

import random
from torch.nn.modules.loss import MSELoss
from sklearn.neighbors import KDTree
#from kmodes.kprototypes import KPrototypes

from scipy.io.arff import loadarff
from sklearn.preprocessing import MinMaxScaler 
from sklearn.datasets import make_classification

# %% [markdown]
# ## Load Dataset Pendigits and Check Clustering Result with the Baseline Method Kmeans

# %%
# set the path to the dataset
path_to_data = '/content/drive/MyDrive/Colab_Notebooks/iris.data'

# %%
data = pd.read_csv(path_to_data)

# %%
X = data.copy()
X = X.drop(['Iris-setosa'], axis=1)
X_ds = pd.DataFrame(X).to_numpy()

Y = data.copy()
Y = Y['Iris-setosa']
Y = LabelEncoder().fit_transform(Y)
y_ds = Y.copy()

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X_ds)
data_X_tsne = np.vstack((X_tsne.T, y_ds)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#check the clustering result with Kmeans
kmeans_ori = KMeans(n_clusters=3).fit(X_ds)
kmeans_labels_ori = kmeans_ori.labels_

normalized_mutual_info_score(kmeans_labels_ori, y_ds)
# Out:
# 0.7565280566037268

# %%
#tsne = TSNE(n_components=2)
#X_tsne = tsne.fit_transform(X_ds)
data_X_tsne = np.vstack((X_tsne.T, kmeans_labels_ori)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ####MixUp

# %%
def mixup(data):
  view = data.copy()
  for i in range(len(view)):
    random_row_index = random.randint(0, len(view)-1)
    view[i] = view[i]*0.5  + view[random_row_index]*0.5
  return view

# %% [markdown]
# ####MixCut

# %%
def mixcut(data):
  data_copy = data.copy()
  view = data.copy()
  mask_len = 100

  for i in range(len(data_copy)):
    random_row_id = random.randint(0, len(data_copy)-1)
    random_column_id = random.randint(0, data_copy.shape[1]-mask_len)
    view[i,random_column_id:(random_column_id+mask_len)] = data_copy[random_row_id,random_column_id:(random_column_id+mask_len)]
  return view

# %% [markdown]
# #### Masking with mean

# %%
def get_random_indices(data, portion_of_mask):
  return np.random.choice(data.shape[1], size=np.floor(data.shape[1]*portion_of_mask).astype(int), replace=False)

# %%
def masking_with_mean(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = column_mu[j]
              
  return view

# %% [markdown]
# ####Masking with random value in domain range

# %%
def masking_with_random(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)
  column_min = np.minimum(data)
  column_max = np.maximum(data)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = random.randint(column_min[j], column_max[j])
              
  return view

# %% [markdown]
# ####Masking with margin distribution

# %%
def masking_with_margin_distribution(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = np.random.normal(column_mu[j], column_std[j])
              
  return view

# %% [markdown]
# ####Upsampling (SMOTE like)

# %%
#put all data points in kd-tree for fast searching
kdtree = KDTree(X_ds, leaf_size=2)

# %%
#get random point in the k nearest neighbors
def get_idx_random_knn(x,k):
   _, ids = kdtree.query(x.reshape(1, -1), k=k)
   ids = ids.flatten()
   ids = ids[1:-1]
   random_id = np.random.choice(ids, 1)
   return random_id

# %%
#mix up with a random near neighbor 
def mixup_random_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = 0.5*data[i] + 0.5*data[random_neighbor_id]
  return view

# %%
#a random neighbor as augmentation
def random_near_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = data[random_neighbor_id]
  return view

# %% [markdown]
# ##Create Model and Train with Augmented Data

# %%
class MyDataSet(Dataset):
  def __init__(self, view1, view2):
 
    X_view1 = view1.copy()
    X_view2 = view2.copy()
    self.X_view1 = X_view1.copy().astype(np.float32)
    self.X_view2 = X_view2.copy().astype(np.float32)
  
  def __len__(self):
    return len(self.X_view1)
  
  def __getitem__(self, idx):
    return self.X_view1[idx], self.X_view2[idx]

# %%
# define the NN architecture
class convBackbone(nn.Module):
    def __init__(self):
        super(convBackbone, self).__init__()

        #turn on dropout for testing the 'cropping' data augmentation 
        #self.dropout = nn.Dropout(p=0.1)
        
        self.fc1 = nn.Linear(4, 4, bias=False)
        self.bn1 = nn.BatchNorm1d(4)

        self.fc2 = nn.Linear(4, 4, bias=False)
        self.bn2 = nn.BatchNorm1d(4)

        self.fc3 = nn.Linear(4, 4, bias=False)
        self.bn3 = nn.BatchNorm1d(4)


    def forward(self, x):

        #turn on dropout for testing the 'cropping' data augmentation 
        #x = self.dropout(x)
        
        #x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.bn3(self.fc3(x))
                
        return x

# %%
class SimSiam(nn.Module):
    def __init__(self, backbone):
        super().__init__()
        self.backbone = backbone
        self.projection_head = SimSiamProjectionHead(4, 4, 4)
        self.prediction_head = SimSiamPredictionHead(4, 4, 4)

    def forward(self, x):
        f = self.backbone(x)
        z = f.flatten(start_dim=1)
        z = self.projection_head(z)
        p = self.prediction_head(z)
        z = z.detach()
        return f, z, p

backbone = convBackbone()
model = SimSiam(backbone)

# %%
criterion = NegativeCosineSimilarity()
optimizer = torch.optim.SGD(model.parameters(), lr=0.06)

#cosine annealing lr
scheduler = lr_scheduler.CosineAnnealingLR(optimizer,T_max=500, eta_min=0)

# %%
view1 = random_near_neighbor(X_ds, 12)
view2 = random_near_neighbor(X_ds, 18)

#turn on the following to test other augmentations

#view1 = mixup_random_neighbor(X_ds, 15)
#view2 = mixup_random_neighbor(X_ds, 15)

#view1 = mixup(X_ds)
#view2 = mixup(X_ds)

#view1 = mixcut(X_ds)
#view2 = mixcut(X_ds)

#view1 = masking_with_mean(X_ds, 0.4)
#view2 = masking_with_mean(X_ds, 0.4)

#view1 = masking_with_random(X_ds, 0.4)
#view2 = masking_with_random(X_ds, 0.4)

#view1 = masking_with_margin_distribution(X_ds, 0.4)
#view2 = masking_with_margin_distribution(X_ds, 0.4)

train_ds = MyDataSet(view1, view2)
train_dl = DataLoader(train_ds, batch_size=256, shuffle=True)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

for epoch in range(500):
    total_loss = 0
    for x0,x1 in train_dl:
        x0 = x0.to(device)
        x1 = x1.to(device)
        _, z0, p0 = model(x0)
        _, z1, p1 = model(x1)

        loss = 0.5 * (criterion(z0, p1) + criterion(z1, p0))
        total_loss += loss.detach()
        loss.backward()

        optimizer.step()
        optimizer.zero_grad()
        scheduler.step()

    avg_loss = total_loss / len(train_dl)
    print(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
# Out:
# epoch: 00, loss: 0.14643
# epoch: 01, loss: 0.14028
# epoch: 02, loss: 0.12310
# epoch: 03, loss: 0.06902
# epoch: 04, loss: 0.00919
# epoch: 05, loss: -0.00645
# epoch: 06, loss: -0.06698
# epoch: 07, loss: -0.05957
# epoch: 08, loss: -0.14842
# epoch: 09, loss: -0.36757
# epoch: 10, loss: -0.51505
# epoch: 11, loss: -0.59047
# epoch: 12, loss: -0.63120
# epoch: 13, loss: -0.66604
# epoch: 14, loss: -0.69672
# epoch: 15, loss: -0.72264
# epoch: 16, loss: -0.74548
# epoch: 17, loss: -0.76487
# epoch: 18, loss: -0.78234
# epoch: 19, loss: -0.79742
# epoch: 20, loss: -0.81057
# epoch: 21, loss: -0.82237
# epoch: 22, loss: -0.83300
# epoch: 23, loss: -0.84162
# epoch: 24, loss: -0.85007
# epoch: 25, loss: -0.85950
# epoch: 26, loss: -0.86597
# epoch: 27, loss: -0.87121
# epoch: 28, loss: -0.87599
# epoch: 29, loss: -0.88095
# epoch: 30, loss: -0.87879
# epoch: 31, loss: -0.89380
# epoch: 32, loss: -0.89475
# epoch: 33, loss: -0.90051
# epoch: 34, loss: -0.90285
# epoch: 35, loss: -0.90589
# epoch: 36, loss: -0.90858
# epoch: 37, loss: -0.91082
# epoch: 38, loss: -0.91302
# epoch: 39, loss: -0.91501
# epoch: 40, loss: -0.91682
# epoch: 41, loss: -0.91863
# epoch: 42, loss: -0.92013
# epoch: 43, loss: -0.92170
# epoch: 44, loss: -0.92311
# epoch: 45, loss: -0.92446
# epoch: 46, loss: -0.92571
# epoch: 47, loss: -0.92790
# epoch: 48, loss: -0.92871
# epoch: 49, loss: -0.92980
# epoch: 50, loss: -0.93077
# epoch: 51, loss: -0.93172
# epoch: 52, loss: -0.93262
# epoch: 53, loss: -0.93295
# epoch: 54, loss: -0.93436
# epoch: 55, loss: -0.93454
# epoch: 56, loss: -0.93584
# epoch: 57, loss: -0.93591
# epoch: 58, loss: -0.93732
# epoch: 59, loss: -0.93783
# epoch: 60, loss: -0.93847
# epoch: 61, loss: -0.93905
# epoch: 62, loss: -0.93958
# epoch: 63, loss: -0.93978
# epoch: 64, loss: -0.94027
# epoch: 65, loss: -0.94071
# epoch: 66, loss: -0.94114
# epoch: 67, loss: -0.94155
# epoch: 68, loss: -0.94194
# epoch: 69, loss: -0.94231
# epoch: 70, loss: -0.94267
# epoch: 71, loss: -0.94301
# epoch: 72, loss: -0.94333
# epoch: 73, loss: -0.94364
# epoch: 74, loss: -0.94394
# epoch: 75, loss: -0.94422
# epoch: 76, loss: -0.94450
# epoch: 77, loss: -0.94537
# epoch: 78, loss: -0.94562
# epoch: 79, loss: -0.94589
# epoch: 80, loss: -0.94614
# epoch: 81, loss: -0.94638
# epoch: 82, loss: -0.94661
# epoch: 83, loss: -0.94683
# epoch: 84, loss: -0.94704
# epoch: 85, loss: -0.94724
# epoch: 86, loss: -0.94743
# epoch: 87, loss: -0.94762
# epoch: 88, loss: -0.94780
# epoch: 89, loss: -0.94801
# epoch: 90, loss: -0.94818
# epoch: 91, loss: -0.94835
# epoch: 92, loss: -0.94850
# epoch: 93, loss: -0.94865
# epoch: 94, loss: -0.94879
# epoch: 95, loss: -0.94893
# epoch: 96, loss: -0.94906
# epoch: 97, loss: -0.94918
# epoch: 98, loss: -0.94929
# epoch: 99, loss: -0.94941
# epoch: 100, loss: -0.94951
# epoch: 101, loss: -0.94961
# epoch: 102, loss: -0.94971
# epoch: 103, loss: -0.94980
# epoch: 104, loss: -0.94988
# epoch: 105, loss: -0.94997
# epoch: 106, loss: -0.95001
# epoch: 107, loss: -0.95007
# epoch: 108, loss: -0.95014
# epoch: 109, loss: -0.95021
# epoch: 110, loss: -0.95027
# epoch: 111, loss: -0.95033
# epoch: 112, loss: -0.95038
# epoch: 113, loss: -0.95039
# epoch: 114, loss: -0.95043
# epoch: 115, loss: -0.95047
# epoch: 116, loss: -0.95055
# epoch: 117, loss: -0.95061
# epoch: 118, loss: -0.95067
# epoch: 119, loss: -0.95071
# epoch: 120, loss: -0.95076
# epoch: 121, loss: -0.95080
# epoch: 122, loss: -0.95083
# epoch: 123, loss: -0.95087
# epoch: 124, loss: -0.95090
# epoch: 125, loss: -0.95092
# epoch: 126, loss: -0.95095
# epoch: 127, loss: -0.95097
# epoch: 128, loss: -0.95099
# epoch: 129, loss: -0.95101
# epoch: 130, loss: -0.95102
# epoch: 131, loss: -0.95104
# epoch: 132, loss: -0.95105
# epoch: 133, loss: -0.95106
# epoch: 134, loss: -0.95107
# epoch: 135, loss: -0.95108
# epoch: 136, loss: -0.95108
# epoch: 137, loss: -0.95109
# epoch: 138, loss: -0.95109
# epoch: 139, loss: -0.95109
# epoch: 140, loss: -0.95109
# epoch: 141, loss: -0.95109
# epoch: 142, loss: -0.95109
# epoch: 143, loss: -0.95109
# epoch: 144, loss: -0.95108
# epoch: 145, loss: -0.95108
# epoch: 146, loss: -0.95107
# epoch: 147, loss: -0.95107
# epoch: 148, loss: -0.95106
# epoch: 149, loss: -0.95105
# epoch: 150, loss: -0.95104
# epoch: 151, loss: -0.95103
# epoch: 152, loss: -0.95102
# epoch: 153, loss: -0.95101
# epoch: 154, loss: -0.95100
# epoch: 155, loss: -0.95099
# epoch: 156, loss: -0.95098
# epoch: 157, loss: -0.95097
# epoch: 158, loss: -0.95096
# epoch: 159, loss: -0.95095
# epoch: 160, loss: -0.95094
# epoch: 161, loss: -0.95092
# epoch: 162, loss: -0.95091
# epoch: 163, loss: -0.95090
# epoch: 164, loss: -0.95088
# epoch: 165, loss: -0.95087
# epoch: 166, loss: -0.95085
# epoch: 167, loss: -0.95123
# epoch: 168, loss: -0.95098
# epoch: 169, loss: -0.95087
# epoch: 170, loss: -0.95083
# epoch: 171, loss: -0.95080
# epoch: 172, loss: -0.95078
# epoch: 173, loss: -0.95115
# epoch: 174, loss: -0.95091
# epoch: 175, loss: -0.95080
# epoch: 176, loss: -0.95075
# epoch: 177, loss: -0.95073
# epoch: 178, loss: -0.95108
# epoch: 179, loss: -0.95084
# epoch: 180, loss: -0.95074
# epoch: 181, loss: -0.95069
# epoch: 182, loss: -0.95102
# epoch: 183, loss: -0.95080
# epoch: 184, loss: -0.95069
# epoch: 185, loss: -0.95062
# epoch: 186, loss: -0.95092
# epoch: 187, loss: -0.95067
# epoch: 188, loss: -0.95055
# epoch: 189, loss: -0.95047
# epoch: 190, loss: -0.95077
# epoch: 191, loss: -0.95053
# epoch: 192, loss: -0.95041
# epoch: 193, loss: -0.95034
# epoch: 194, loss: -0.95062
# epoch: 195, loss: -0.95040
# epoch: 196, loss: -0.95028
# epoch: 197, loss: -0.95054
# epoch: 198, loss: -0.95031
# epoch: 199, loss: -0.95019
# epoch: 200, loss: -0.95046
# epoch: 201, loss: -0.95023
# epoch: 202, loss: -0.95011
# epoch: 203, loss: -0.95036
# epoch: 204, loss: -0.95013
# epoch: 205, loss: -0.95001
# epoch: 206, loss: -0.95026
# epoch: 207, loss: -0.95003
# epoch: 208, loss: -0.94991
# epoch: 209, loss: -0.95016
# epoch: 210, loss: -0.94993
# epoch: 211, loss: -0.94982
# epoch: 212, loss: -0.95006
# epoch: 213, loss: -0.94984
# epoch: 214, loss: -0.94973
# epoch: 215, loss: -0.94997
# epoch: 216, loss: -0.94976
# epoch: 217, loss: -0.94965
# epoch: 218, loss: -0.94988
# epoch: 219, loss: -0.94968
# epoch: 220, loss: -0.94957
# epoch: 221, loss: -0.94980
# epoch: 222, loss: -0.94960
# epoch: 223, loss: -0.94949
# epoch: 224, loss: -0.94972
# epoch: 225, loss: -0.94952
# epoch: 226, loss: -0.94971
# epoch: 227, loss: -0.94950
# epoch: 228, loss: -0.94939
# epoch: 229, loss: -0.94960
# epoch: 230, loss: -0.94942
# epoch: 231, loss: -0.94960
# epoch: 232, loss: -0.94940
# epoch: 233, loss: -0.94929
# epoch: 234, loss: -0.94949
# epoch: 235, loss: -0.94931
# epoch: 236, loss: -0.94949
# epoch: 237, loss: -0.94930
# epoch: 238, loss: -0.94919
# epoch: 239, loss: -0.94939
# epoch: 240, loss: -0.94923
# epoch: 241, loss: -0.94940
# epoch: 242, loss: -0.94921
# epoch: 243, loss: -0.94937
# epoch: 244, loss: -0.94920
# epoch: 245, loss: -0.94909
# epoch: 246, loss: -0.94927
# epoch: 247, loss: -0.94912
# epoch: 248, loss: -0.94927
# epoch: 249, loss: -0.94910
# epoch: 250, loss: -0.94925
# epoch: 251, loss: -0.94908
# epoch: 252, loss: -0.94922
# epoch: 253, loss: -0.94906
# epoch: 254, loss: -0.94896
# epoch: 255, loss: -0.94913
# epoch: 256, loss: -0.94899
# epoch: 257, loss: -0.94913
# epoch: 258, loss: -0.94898
# epoch: 259, loss: -0.94912
# epoch: 260, loss: -0.94896
# epoch: 261, loss: -0.94910
# epoch: 262, loss: -0.94894
# epoch: 263, loss: -0.94908
# epoch: 264, loss: -0.94893
# epoch: 265, loss: -0.94906
# epoch: 266, loss: -0.94892
# epoch: 267, loss: -0.94905
# epoch: 268, loss: -0.94890
# epoch: 269, loss: -0.94903
# epoch: 270, loss: -0.94889
# epoch: 271, loss: -0.94901
# epoch: 272, loss: -0.94887
# epoch: 273, loss: -0.94900
# epoch: 274, loss: -0.94887
# epoch: 275, loss: -0.94898
# epoch: 276, loss: -0.94885
# epoch: 277, loss: -0.94896
# epoch: 278, loss: -0.94883
# epoch: 279, loss: -0.94895
# epoch: 280, loss: -0.94882
# epoch: 281, loss: -0.94893
# epoch: 282, loss: -0.94881
# epoch: 283, loss: -0.94892
# epoch: 284, loss: -0.94880
# epoch: 285, loss: -0.94890
# epoch: 286, loss: -0.94878
# epoch: 287, loss: -0.94889
# epoch: 288, loss: -0.94877
# epoch: 289, loss: -0.94888
# epoch: 290, loss: -0.94877
# epoch: 291, loss: -0.94887
# epoch: 292, loss: -0.94875
# epoch: 293, loss: -0.94885
# epoch: 294, loss: -0.94874
# epoch: 295, loss: -0.94884
# epoch: 296, loss: -0.94874
# epoch: 297, loss: -0.94884
# epoch: 298, loss: -0.94873
# epoch: 299, loss: -0.94882
# epoch: 300, loss: -0.94872
# epoch: 301, loss: -0.94881
# epoch: 302, loss: -0.94871
# epoch: 303, loss: -0.94880
# epoch: 304, loss: -0.94871
# epoch: 305, loss: -0.94880
# epoch: 306, loss: -0.94870
# epoch: 307, loss: -0.94879
# epoch: 308, loss: -0.94869
# epoch: 309, loss: -0.94878
# epoch: 310, loss: -0.94868
# epoch: 311, loss: -0.94877
# epoch: 312, loss: -0.94869
# epoch: 313, loss: -0.94877
# epoch: 314, loss: -0.94868
# epoch: 315, loss: -0.94876
# epoch: 316, loss: -0.94867
# epoch: 317, loss: -0.94875
# epoch: 318, loss: -0.94867
# epoch: 319, loss: -0.94875
# epoch: 320, loss: -0.94866
# epoch: 321, loss: -0.94874
# epoch: 322, loss: -0.94866
# epoch: 323, loss: -0.94873
# epoch: 324, loss: -0.94865
# epoch: 325, loss: -0.94872
# epoch: 326, loss: -0.94866
# epoch: 327, loss: -0.94872
# epoch: 328, loss: -0.94865
# epoch: 329, loss: -0.94872
# epoch: 330, loss: -0.94864
# epoch: 331, loss: -0.94871
# epoch: 332, loss: -0.94876
# epoch: 333, loss: -0.94868
# epoch: 334, loss: -0.94874
# epoch: 335, loss: -0.94867
# epoch: 336, loss: -0.94873
# epoch: 337, loss: -0.94865
# epoch: 338, loss: -0.94871
# epoch: 339, loss: -0.94865
# epoch: 340, loss: -0.94871
# epoch: 341, loss: -0.94864
# epoch: 342, loss: -0.94870
# epoch: 343, loss: -0.94864
# epoch: 344, loss: -0.94869
# epoch: 345, loss: -0.94874
# epoch: 346, loss: -0.94867
# epoch: 347, loss: -0.94872
# epoch: 348, loss: -0.94865
# epoch: 349, loss: -0.94870
# epoch: 350, loss: -0.94865
# epoch: 351, loss: -0.94870
# epoch: 352, loss: -0.94864
# epoch: 353, loss: -0.94869
# epoch: 354, loss: -0.94863
# epoch: 355, loss: -0.94868
# epoch: 356, loss: -0.94872
# epoch: 357, loss: -0.94866
# epoch: 358, loss: -0.94870
# epoch: 359, loss: -0.94865
# epoch: 360, loss: -0.94869
# epoch: 361, loss: -0.94864
# epoch: 362, loss: -0.94868
# epoch: 363, loss: -0.94863
# epoch: 364, loss: -0.94867
# epoch: 365, loss: -0.94870
# epoch: 366, loss: -0.94865
# epoch: 367, loss: -0.94869
# epoch: 368, loss: -0.94865
# epoch: 369, loss: -0.94868
# epoch: 370, loss: -0.94864
# epoch: 371, loss: -0.94867
# epoch: 372, loss: -0.94863
# epoch: 373, loss: -0.94867
# epoch: 374, loss: -0.94869
# epoch: 375, loss: -0.94865
# epoch: 376, loss: -0.94868
# epoch: 377, loss: -0.94864
# epoch: 378, loss: -0.94867
# epoch: 379, loss: -0.94864
# epoch: 380, loss: -0.94867
# epoch: 381, loss: -0.94863
# epoch: 382, loss: -0.94866
# epoch: 383, loss: -0.94868
# epoch: 384, loss: -0.94865
# epoch: 385, loss: -0.94867
# epoch: 386, loss: -0.94864
# epoch: 387, loss: -0.94866
# epoch: 388, loss: -0.94863
# epoch: 389, loss: -0.94866
# epoch: 390, loss: -0.94868
# epoch: 391, loss: -0.94865
# epoch: 392, loss: -0.94867
# epoch: 393, loss: -0.94864
# epoch: 394, loss: -0.94866
# epoch: 395, loss: -0.94863
# epoch: 396, loss: -0.94866
# epoch: 397, loss: -0.94868
# epoch: 398, loss: -0.94865
# epoch: 399, loss: -0.94867
# epoch: 400, loss: -0.94864
# epoch: 401, loss: -0.94866
# epoch: 402, loss: -0.94864
# epoch: 403, loss: -0.94866
# epoch: 404, loss: -0.94863
# epoch: 405, loss: -0.94865
# epoch: 406, loss: -0.94867
# epoch: 407, loss: -0.94864
# epoch: 408, loss: -0.94866
# epoch: 409, loss: -0.94864
# epoch: 410, loss: -0.94865
# epoch: 411, loss: -0.94863
# epoch: 412, loss: -0.94865
# epoch: 413, loss: -0.94866
# epoch: 414, loss: -0.94864
# epoch: 415, loss: -0.94866
# epoch: 416, loss: -0.94864
# epoch: 417, loss: -0.94865
# epoch: 418, loss: -0.94866
# epoch: 419, loss: -0.94864
# epoch: 420, loss: -0.94866
# epoch: 421, loss: -0.94864
# epoch: 422, loss: -0.94865
# epoch: 423, loss: -0.94864
# epoch: 424, loss: -0.94865
# epoch: 425, loss: -0.94863
# epoch: 426, loss: -0.94864
# epoch: 427, loss: -0.94866
# epoch: 428, loss: -0.94864
# epoch: 429, loss: -0.94865
# epoch: 430, loss: -0.94864
# epoch: 431, loss: -0.94865
# epoch: 432, loss: -0.94866
# epoch: 433, loss: -0.94864
# epoch: 434, loss: -0.94865
# epoch: 435, loss: -0.94864
# epoch: 436, loss: -0.94865
# epoch: 437, loss: -0.94864
# epoch: 438, loss: -0.94865
# epoch: 439, loss: -0.94865
# epoch: 440, loss: -0.94864
# epoch: 441, loss: -0.94865
# epoch: 442, loss: -0.94864
# epoch: 443, loss: -0.94865
# epoch: 444, loss: -0.94864
# epoch: 445, loss: -0.94864
# epoch: 446, loss: -0.94865
# epoch: 447, loss: -0.94864
# epoch: 448, loss: -0.94865
# epoch: 449, loss: -0.94864
# epoch: 450, loss: -0.94865
# epoch: 451, loss: -0.94864
# epoch: 452, loss: -0.94864
# epoch: 453, loss: -0.94865
# epoch: 454, loss: -0.94864
# epoch: 455, loss: -0.94865
# epoch: 456, loss: -0.94864
# epoch: 457, loss: -0.94864
# epoch: 458, loss: -0.94864
# epoch: 459, loss: -0.94864
# epoch: 460, loss: -0.94865
# epoch: 461, loss: -0.94864
# epoch: 462, loss: -0.94864
# epoch: 463, loss: -0.94864
# epoch: 464, loss: -0.94864
# epoch: 465, loss: -0.94865
# epoch: 466, loss: -0.94864
# epoch: 467, loss: -0.94864
# epoch: 468, loss: -0.94864
# epoch: 469, loss: -0.94864
# epoch: 470, loss: -0.94864
# epoch: 471, loss: -0.94864
# epoch: 472, loss: -0.94864
# epoch: 473, loss: -0.94864
# epoch: 474, loss: -0.94864
# epoch: 475, loss: -0.94864
# epoch: 476, loss: -0.94864
# epoch: 477, loss: -0.94864
# epoch: 478, loss: -0.94864
# epoch: 479, loss: -0.94864
# epoch: 480, loss: -0.94864
# epoch: 481, loss: -0.94864
# epoch: 482, loss: -0.94864
# epoch: 483, loss: -0.94864
# epoch: 484, loss: -0.94864
# epoch: 485, loss: -0.94864
# epoch: 486, loss: -0.94864
# epoch: 487, loss: -0.94864
# epoch: 488, loss: -0.94864
# epoch: 489, loss: -0.94864
# epoch: 490, loss: -0.94864
# epoch: 491, loss: -0.94864
# epoch: 492, loss: -0.94864
# epoch: 493, loss: -0.94864
# epoch: 494, loss: -0.94864
# epoch: 495, loss: -0.94864
# epoch: 496, loss: -0.94864
# epoch: 497, loss: -0.94864
# epoch: 498, loss: -0.94864
# epoch: 499, loss: -0.94864

# %% [markdown]
# ##Check the Training Result

# %%
ds_cl= MyDataSet(X_ds, X_ds)
dl_cl = DataLoader(ds_cl, batch_size=256)

# %%
embeddings = []

# disable gradients for faster calculations
model.eval()
with torch.no_grad():
    for dl_cl1, dl_cl2 in dl_cl:

        dl_cl1 = dl_cl1.to(device)
        f, z, p = model(dl_cl1)
        
        # store the embeddings in lists
        embeddings.append(f)

# concatenate the embeddings, targets and convert to numpy
embeddings = torch.cat(embeddings, dim=0)
embeddings = embeddings.cpu().numpy()

# %%
test = (embeddings - embeddings.mean(axis=0)) / (embeddings.std(axis=0))

# %%
#KMeans in latent space
kmeans_backbone = KMeans(n_clusters=3).fit(test)
kmeans_labels_backbone = kmeans_backbone.labels_

# %%
normalized_mutual_info_score(kmeans_labels_backbone, y_ds)
# Out:
# 0.9003125046768173

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(embeddings)
data_X_tsne = np.vstack((X_tsne.T, kmeans_labels_backbone)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#NMI increases from 0.75 to 0.90
