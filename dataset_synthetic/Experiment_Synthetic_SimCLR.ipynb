# %% [markdown]
# ## Conifuration

# %%
#import the lib for contrastive learning framework
# !pip install lightly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lightly in /usr/local/lib/python3.7/dist-packages (1.2.20)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (57.4.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.15.0)
# Requirement already satisfied: pytorch-lightning>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.6.4)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.23.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from lightly) (0.12.0+cu113)
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.7/dist-packages (from lightly) (4.64.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.7/dist-packages (from lightly) (2022.6.15)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.8.2)
# Requirement already satisfied: hydra-core>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.2.0)
# Requirement already satisfied: lightly-utils~=0.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (0.0.2)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.21.6)
# Requirement already satisfied: omegaconf~=2.2 in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (2.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (21.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (4.9.3)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (5.7.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from lightly-utils~=0.0.0->lightly) (7.1.2)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.7/dist-packages (from omegaconf~=2.2->hydra-core>=1.0.0->lightly) (6.0)
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (3.17.3)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2022.5.0)
# Requirement already satisfied: torchmetrics>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (0.9.1)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (0.3.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (4.1.1)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2.8.0)
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (1.11.0+cu113)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->hydra-core>=1.0.0->lightly) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (3.0.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.3.7)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.8.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.46.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.35.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (2.0.12)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (21.4.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (1.3.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (0.13.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (1.7.2)

# %%
import lightly
from lightly.models.modules.heads import SimSiamPredictionHead
from lightly.models.modules.heads import SimSiamProjectionHead

from lightly.data import LightlyDataset
from lightly.data import ImageCollateFunction
from lightly.models.modules import BarlowTwinsProjectionHead
from lightly.loss import BarlowTwinsLoss

from lightly.data import LightlyDataset
from lightly.data import SimCLRCollateFunction
from lightly.loss import NTXentLoss
from lightly.loss import NegativeCosineSimilarity
from lightly.models.modules import SimCLRProjectionHead

# %%
import math
import torch
import torch.nn as nn
import torchvision
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from torch.utils.data import Dataset, DataLoader
import torch.optim as torch_optim
import torch.optim.lr_scheduler as lr_scheduler
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
from datetime import datetime

from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from matplotlib import pyplot
import seaborn as sns

from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_mutual_info_score
from sklearn.metrics import silhouette_score
from sklearn import mixture
from sklearn.cluster import DBSCAN
from sklearn.cluster import OPTICS
from sklearn.cluster import AgglomerativeClustering

import tensorboard
from tensorboard import notebook
from torch.utils.tensorboard import SummaryWriter

import matplotlib 
import matplotlib.pyplot as plt
#import plotly.express as px

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons
from sklearn.utils import shuffle

import torchvision.transforms as transforms
import torchvision.datasets as datasets
from sklearn.metrics.pairwise import cosine_similarity

import random
from torch.nn.modules.loss import MSELoss
from sklearn.neighbors import KDTree
#from kmodes.kprototypes import KPrototypes

from scipy.io.arff import loadarff
from sklearn.preprocessing import MinMaxScaler 
from sklearn.datasets import make_classification

# %% [markdown]
# ## Create Synthetic Dataset and Check Clustering Result with the Baseline Method Kmeans

# %%
X, y = make_classification(n_samples=10000, n_features=200, n_redundant=0, n_informative=25, n_clusters_per_class=1, n_classes=3, class_sep=1.5)

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X)
data_X_tsne = np.vstack((X_tsne.T, y)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#check the clustering result with Kmeans
kmeans_ori = KMeans(n_clusters=3).fit(X)
kmeans_labels_ori = kmeans_ori.labels_

normalized_mutual_info_score(kmeans_labels_ori, y)
# Out:
# 0.6977090683508675

# %%
data_X_tsne = np.vstack((X_tsne.T, kmeans_labels_ori)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()

# %% [markdown]
# ## Data Augmentation

# %%
#scale data to prevent gradient vanishing
X_ds = 100*X+250

# %%
X_ds
# Out:
# array([[322.93697012, 195.91098219, 200.69827658, ..., 466.00485682,
#         338.15888646, 205.75457906],
#        [521.06245895, 177.97087343, 387.66136216, ..., 155.63705412,
#         323.87744679, 262.5632628 ],
#        [354.77919891, 186.46570705, 297.94178871, ..., 240.99103592,
#         366.51152826, 272.17325403],
#        ...,
#        [348.1607614 , 213.58373638, 290.71648565, ..., 216.46980351,
#         248.27038011, 235.25377728],
#        [306.03367872, 220.22684775, 250.96604808, ...,  86.02473199,
#         326.78145158, 287.76767001],
#        [287.70008808, 161.61952772, 328.21433671, ..., 345.53008962,
#         150.8820699 , 239.74728396]])

# %% [markdown]
# ####MixUp

# %%
def mixup(data):
  view = data.copy()
  for i in range(len(view)):
    random_row_index = random.randint(0, len(view)-1)
    view[i] = view[i]*0.5  + view[random_row_index]*0.5
  return view

# %% [markdown]
# ####MixCut

# %%
def mixcut(data):
  data_copy = data.copy()
  view = data.copy()
  mask_len = 100

  for i in range(len(data_copy)):
    random_row_id = random.randint(0, len(data_copy)-1)
    random_column_id = random.randint(0, data_copy.shape[1]-mask_len)
    view[i,random_column_id:(random_column_id+mask_len)] = data_copy[random_row_id,random_column_id:(random_column_id+mask_len)]
  return view

# %% [markdown]
# #### Masking with mean

# %%
def get_random_indices(data, portion_of_mask):
  return np.random.choice(data.shape[1], size=np.floor(data.shape[1]*portion_of_mask).astype(int), replace=False)

# %%
def masking_with_mean(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = column_mu[j]
              
  return view

# %% [markdown]
# ####Masking with random value in domain range

# %%
def masking_with_random(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)
  column_min = np.minimum(data)
  column_max = np.maximum(data)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = random.randint(column_min[j], column_max[j])
              
  return view

# %% [markdown]
# ####Masking with margin distribution

# %%
def masking_with_margin_distribution(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = np.random.normal(column_mu[j], column_std[j])
              
  return view

# %% [markdown]
# ####Upsampling (SMOTE like)

# %%
#put all data points in kd-tree for fast searching
kdtree = KDTree(X_ds, leaf_size=2)

# %%
#get random point in the k nearest neighbors
def get_idx_random_knn(x,k):
   _, ids = kdtree.query(x.reshape(1, -1), k=k)
   ids = ids.flatten()
   ids = ids[1:-1]
   random_id = np.random.choice(ids, 1)
   return random_id

# %%
#mix up with a random near neighbor 
def mixup_random_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = 0.5*data[i] + 0.5*data[random_neighbor_id]
  return view

# %%
#a random neighbor as augmentation
def random_near_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = data[random_neighbor_id]
  return view

# %% [markdown]
# ##Create Model and Train with Augmented Data

# %%
class MyDataSet(Dataset):
  def __init__(self, view1, view2):
 
    X_view1 = view1.copy()
    X_view2 = view2.copy()
    self.X_view1 = X_view1.copy().astype(np.float32)
    self.X_view2 = X_view2.copy().astype(np.float32)
  
  def __len__(self):
    return len(self.X_view1)
  
  def __getitem__(self, idx):
    return self.X_view1[idx], self.X_view2[idx]

# %%
# define the NN architecture
class convBackbone(nn.Module):
    def __init__(self):
        super(convBackbone, self).__init__()

        #turn on dropout for testing the 'cropping' data augmentation
        #self.dropout = nn.Dropout(p=0.1)
        
        self.fc1 = nn.Linear(200, 156, bias=False)
        self.bn1 = nn.BatchNorm1d(156)

        self.fc2 = nn.Linear(156, 128, bias=False)
        self.bn2 = nn.BatchNorm1d(128)

        self.fc3 = nn.Linear(128, 128, bias=False)
        self.bn3 = nn.BatchNorm1d(128)


    def forward(self, x):

        #turn on dropout for testing the 'cropping' data augmentation
        #x = self.dropout(x)
        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.bn3(self.fc3(x))
                
        return x

# %%
class SimCLR(nn.Module):
    def __init__(self, backbone):
        super().__init__()
        self.backbone = backbone
        self.projection_head = SimCLRProjectionHead(128, 64, 128)

    def forward(self, x):
        x = self.backbone(x).flatten(start_dim=1)
        z = self.projection_head(x)
        return x,z

backbone = convBackbone()
model = SimCLR(backbone)

# %%
criterion = NTXentLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9,weight_decay=1e-4)

#cosine annealing lr
scheduler = lr_scheduler.CosineAnnealingLR(optimizer,T_max=500, eta_min=0)

# %%
view1 = random_near_neighbor(X_ds, 15)
view2 = random_near_neighbor(X_ds, 15)

#turn on the following to test other augmentations

#view1 = mixup_random_neighbor(X_ds, 15)
#view2 = mixup_random_neighbor(X_ds, 15)

#view1 = mixup(X_ds)
#view2 = mixup(X_ds)

#view1 = mixcut(X_ds)
#view2 = mixcut(X_ds)

#view1 = masking_with_mean(X_ds, 0.4)
#view2 = masking_with_mean(X_ds, 0.4)

#view1 = masking_with_random(X_ds, 0.4)
#view2 = masking_with_random(X_ds, 0.4)

#view1 = masking_with_margin_distribution(X_ds, 0.4)
#view2 = masking_with_margin_distribution(X_ds, 0.4)

train_ds = MyDataSet(view1, view2)
train_dl = DataLoader(train_ds, batch_size=256, shuffle=True)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

for epoch in range(500):
    total_loss = 0
    for x0, x1 in train_dl:

        x0 = x0.to(device)
        x1 = x1.to(device)
        _,z0 = model(x0)
        _,z1 = model(x1)

        z0 = (z0 - torch.mean(z0,0)) / torch.std(z0,0)
        z1 = (z1 - torch.mean(z1,0)) / torch.std(z1,0)

        loss = criterion(z0, z1)
        total_loss += loss.detach()
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    avg_loss = total_loss / len(train_dl)
    print(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
# Out:
# epoch: 00, loss: 5.38429
# epoch: 01, loss: 5.08818
# epoch: 02, loss: 5.04263
# epoch: 03, loss: 5.01220
# epoch: 04, loss: 4.99962
# epoch: 05, loss: 4.98508
# epoch: 06, loss: 4.96715
# epoch: 07, loss: 4.95718
# epoch: 08, loss: 4.95382
# epoch: 09, loss: 4.94435
# epoch: 10, loss: 4.93353
# epoch: 11, loss: 4.93087
# epoch: 12, loss: 4.92110
# epoch: 13, loss: 4.91015
# epoch: 14, loss: 4.90555
# epoch: 15, loss: 4.90048
# epoch: 16, loss: 4.89336
# epoch: 17, loss: 4.88435
# epoch: 18, loss: 4.88023
# epoch: 19, loss: 4.88241
# epoch: 20, loss: 4.87429
# epoch: 21, loss: 4.86470
# epoch: 22, loss: 4.85774
# epoch: 23, loss: 4.85807
# epoch: 24, loss: 4.85529
# epoch: 25, loss: 4.84708
# epoch: 26, loss: 4.84337
# epoch: 27, loss: 4.83651
# epoch: 28, loss: 4.83865
# epoch: 29, loss: 4.83126
# epoch: 30, loss: 4.82602
# epoch: 31, loss: 4.82264
# epoch: 32, loss: 4.82075
# epoch: 33, loss: 4.82155
# epoch: 34, loss: 4.81983
# epoch: 35, loss: 4.81975
# epoch: 36, loss: 4.80620
# epoch: 37, loss: 4.80431
# epoch: 38, loss: 4.80305
# epoch: 39, loss: 4.80223
# epoch: 40, loss: 4.80000
# epoch: 41, loss: 4.79602
# epoch: 42, loss: 4.78903
# epoch: 43, loss: 4.78971
# epoch: 44, loss: 4.79200
# epoch: 45, loss: 4.78568
# epoch: 46, loss: 4.78425
# epoch: 47, loss: 4.77730
# epoch: 48, loss: 4.77530
# epoch: 49, loss: 4.77652
# epoch: 50, loss: 4.77975
# epoch: 51, loss: 4.77647
# epoch: 52, loss: 4.76872
# epoch: 53, loss: 4.76453
# epoch: 54, loss: 4.76088
# epoch: 55, loss: 4.76743
# epoch: 56, loss: 4.75951
# epoch: 57, loss: 4.75633
# epoch: 58, loss: 4.76482
# epoch: 59, loss: 4.75601
# epoch: 60, loss: 4.75048
# epoch: 61, loss: 4.75116
# epoch: 62, loss: 4.74971
# epoch: 63, loss: 4.74817
# epoch: 64, loss: 4.75302
# epoch: 65, loss: 4.74573
# epoch: 66, loss: 4.75137
# epoch: 67, loss: 4.75313
# epoch: 68, loss: 4.74312
# epoch: 69, loss: 4.74820
# epoch: 70, loss: 4.73838
# epoch: 71, loss: 4.73117
# epoch: 72, loss: 4.73813
# epoch: 73, loss: 4.73834
# epoch: 74, loss: 4.74253
# epoch: 75, loss: 4.74769
# epoch: 76, loss: 4.73433
# epoch: 77, loss: 4.73297
# epoch: 78, loss: 4.73058
# epoch: 79, loss: 4.73406
# epoch: 80, loss: 4.73538
# epoch: 81, loss: 4.73354
# epoch: 82, loss: 4.72149
# epoch: 83, loss: 4.72194
# epoch: 84, loss: 4.72100
# epoch: 85, loss: 4.71791
# epoch: 86, loss: 4.72277
# epoch: 87, loss: 4.71598
# epoch: 88, loss: 4.71333
# epoch: 89, loss: 4.71994
# epoch: 90, loss: 4.72783
# epoch: 91, loss: 4.72699
# epoch: 92, loss: 4.71700
# epoch: 93, loss: 4.71789
# epoch: 94, loss: 4.71648
# epoch: 95, loss: 4.71800
# epoch: 96, loss: 4.72971
# epoch: 97, loss: 4.71809
# epoch: 98, loss: 4.70863
# epoch: 99, loss: 4.70852
# epoch: 100, loss: 4.71191
# epoch: 101, loss: 4.70800
# epoch: 102, loss: 4.71131
# epoch: 103, loss: 4.70183
# epoch: 104, loss: 4.70177
# epoch: 105, loss: 4.70033
# epoch: 106, loss: 4.70552
# epoch: 107, loss: 4.70445
# epoch: 108, loss: 4.69377
# epoch: 109, loss: 4.69694
# epoch: 110, loss: 4.69714
# epoch: 111, loss: 4.69419
# epoch: 112, loss: 4.69846
# epoch: 113, loss: 4.70042
# epoch: 114, loss: 4.69941
# epoch: 115, loss: 4.69967
# epoch: 116, loss: 4.69574
# epoch: 117, loss: 4.69775
# epoch: 118, loss: 4.69936
# epoch: 119, loss: 4.69727
# epoch: 120, loss: 4.69772
# epoch: 121, loss: 4.69105
# epoch: 122, loss: 4.69212
# epoch: 123, loss: 4.69129
# epoch: 124, loss: 4.69094
# epoch: 125, loss: 4.69097
# epoch: 126, loss: 4.69452
# epoch: 127, loss: 4.68942
# epoch: 128, loss: 4.69185
# epoch: 129, loss: 4.69141
# epoch: 130, loss: 4.69211
# epoch: 131, loss: 4.69319
# epoch: 132, loss: 4.69130
# epoch: 133, loss: 4.69302
# epoch: 134, loss: 4.68664
# epoch: 135, loss: 4.69388
# epoch: 136, loss: 4.69854
# epoch: 137, loss: 4.68834
# epoch: 138, loss: 4.68772
# epoch: 139, loss: 4.68603
# epoch: 140, loss: 4.68601
# epoch: 141, loss: 4.68673
# epoch: 142, loss: 4.69841
# epoch: 143, loss: 4.69474
# epoch: 144, loss: 4.68632
# epoch: 145, loss: 4.68336
# epoch: 146, loss: 4.67751
# epoch: 147, loss: 4.67782
# epoch: 148, loss: 4.67947
# epoch: 149, loss: 4.67694
# epoch: 150, loss: 4.67257
# epoch: 151, loss: 4.67374
# epoch: 152, loss: 4.67847
# epoch: 153, loss: 4.67961
# epoch: 154, loss: 4.68051
# epoch: 155, loss: 4.69693
# epoch: 156, loss: 4.68330
# epoch: 157, loss: 4.68435
# epoch: 158, loss: 4.67699
# epoch: 159, loss: 4.67259
# epoch: 160, loss: 4.67091
# epoch: 161, loss: 4.66943
# epoch: 162, loss: 4.67896
# epoch: 163, loss: 4.68280
# epoch: 164, loss: 4.67563
# epoch: 165, loss: 4.67436
# epoch: 166, loss: 4.67821
# epoch: 167, loss: 4.67086
# epoch: 168, loss: 4.67204
# epoch: 169, loss: 4.67132
# epoch: 170, loss: 4.67027
# epoch: 171, loss: 4.66780
# epoch: 172, loss: 4.66726
# epoch: 173, loss: 4.66260
# epoch: 174, loss: 4.66457
# epoch: 175, loss: 4.67286
# epoch: 176, loss: 4.66425
# epoch: 177, loss: 4.67007
# epoch: 178, loss: 4.66821
# epoch: 179, loss: 4.66926
# epoch: 180, loss: 4.67228
# epoch: 181, loss: 4.67529
# epoch: 182, loss: 4.66873
# epoch: 183, loss: 4.67195
# epoch: 184, loss: 4.67034
# epoch: 185, loss: 4.67493
# epoch: 186, loss: 4.67312
# epoch: 187, loss: 4.67078
# epoch: 188, loss: 4.66655
# epoch: 189, loss: 4.66169
# epoch: 190, loss: 4.65911
# epoch: 191, loss: 4.66500
# epoch: 192, loss: 4.66837
# epoch: 193, loss: 4.66424
# epoch: 194, loss: 4.66059
# epoch: 195, loss: 4.66401
# epoch: 196, loss: 4.65778
# epoch: 197, loss: 4.65614
# epoch: 198, loss: 4.65613
# epoch: 199, loss: 4.65972
# epoch: 200, loss: 4.65815
# epoch: 201, loss: 4.66300
# epoch: 202, loss: 4.66190
# epoch: 203, loss: 4.65628
# epoch: 204, loss: 4.66105
# epoch: 205, loss: 4.66368
# epoch: 206, loss: 4.67005
# epoch: 207, loss: 4.65890
# epoch: 208, loss: 4.65426
# epoch: 209, loss: 4.65933
# epoch: 210, loss: 4.65859
# epoch: 211, loss: 4.65389
# epoch: 212, loss: 4.65481
# epoch: 213, loss: 4.65266
# epoch: 214, loss: 4.65936
# epoch: 215, loss: 4.65995
# epoch: 216, loss: 4.65225
# epoch: 217, loss: 4.65714
# epoch: 218, loss: 4.65136
# epoch: 219, loss: 4.65137
# epoch: 220, loss: 4.65380
# epoch: 221, loss: 4.65256
# epoch: 222, loss: 4.64925
# epoch: 223, loss: 4.65590
# epoch: 224, loss: 4.65520
# epoch: 225, loss: 4.65949
# epoch: 226, loss: 4.66187
# epoch: 227, loss: 4.65796
# epoch: 228, loss: 4.65037
# epoch: 229, loss: 4.65184
# epoch: 230, loss: 4.64866
# epoch: 231, loss: 4.65241
# epoch: 232, loss: 4.64980
# epoch: 233, loss: 4.64742
# epoch: 234, loss: 4.65187
# epoch: 235, loss: 4.64967
# epoch: 236, loss: 4.65153
# epoch: 237, loss: 4.65274
# epoch: 238, loss: 4.65666
# epoch: 239, loss: 4.64985
# epoch: 240, loss: 4.65605
# epoch: 241, loss: 4.66192
# epoch: 242, loss: 4.65952
# epoch: 243, loss: 4.65289
# epoch: 244, loss: 4.65066
# epoch: 245, loss: 4.64539
# epoch: 246, loss: 4.64787
# epoch: 247, loss: 4.65617
# epoch: 248, loss: 4.64945
# epoch: 249, loss: 4.64591
# epoch: 250, loss: 4.64549
# epoch: 251, loss: 4.64914
# epoch: 252, loss: 4.65417
# epoch: 253, loss: 4.65782
# epoch: 254, loss: 4.65071
# epoch: 255, loss: 4.64537
# epoch: 256, loss: 4.64114
# epoch: 257, loss: 4.64946
# epoch: 258, loss: 4.65452
# epoch: 259, loss: 4.65333
# epoch: 260, loss: 4.65064
# epoch: 261, loss: 4.64801
# epoch: 262, loss: 4.64460
# epoch: 263, loss: 4.65234
# epoch: 264, loss: 4.65325
# epoch: 265, loss: 4.65197
# epoch: 266, loss: 4.65234
# epoch: 267, loss: 4.65115
# epoch: 268, loss: 4.64630
# epoch: 269, loss: 4.64410
# epoch: 270, loss: 4.64836
# epoch: 271, loss: 4.65452
# epoch: 272, loss: 4.64976
# epoch: 273, loss: 4.64236
# epoch: 274, loss: 4.64621
# epoch: 275, loss: 4.64744
# epoch: 276, loss: 4.64572
# epoch: 277, loss: 4.64940
# epoch: 278, loss: 4.64422
# epoch: 279, loss: 4.64354
# epoch: 280, loss: 4.64726
# epoch: 281, loss: 4.64206
# epoch: 282, loss: 4.64356
# epoch: 283, loss: 4.64358
# epoch: 284, loss: 4.64063
# epoch: 285, loss: 4.64058
# epoch: 286, loss: 4.64649
# epoch: 287, loss: 4.64161
# epoch: 288, loss: 4.64377
# epoch: 289, loss: 4.64633
# epoch: 290, loss: 4.65294
# epoch: 291, loss: 4.64399
# epoch: 292, loss: 4.64204
# epoch: 293, loss: 4.64366
# epoch: 294, loss: 4.64697
# epoch: 295, loss: 4.65014
# epoch: 296, loss: 4.64114
# epoch: 297, loss: 4.64343
# epoch: 298, loss: 4.64589
# epoch: 299, loss: 4.64675
# epoch: 300, loss: 4.64357
# epoch: 301, loss: 4.63686
# epoch: 302, loss: 4.63607
# epoch: 303, loss: 4.63721
# epoch: 304, loss: 4.64297
# epoch: 305, loss: 4.63851
# epoch: 306, loss: 4.63890
# epoch: 307, loss: 4.63667
# epoch: 308, loss: 4.64093
# epoch: 309, loss: 4.64365
# epoch: 310, loss: 4.63869
# epoch: 311, loss: 4.64312
# epoch: 312, loss: 4.63904
# epoch: 313, loss: 4.63123
# epoch: 314, loss: 4.63239
# epoch: 315, loss: 4.63529
# epoch: 316, loss: 4.63758
# epoch: 317, loss: 4.64073
# epoch: 318, loss: 4.63690
# epoch: 319, loss: 4.63887
# epoch: 320, loss: 4.63189
# epoch: 321, loss: 4.63986
# epoch: 322, loss: 4.63301
# epoch: 323, loss: 4.63372
# epoch: 324, loss: 4.63882
# epoch: 325, loss: 4.63874
# epoch: 326, loss: 4.63591
# epoch: 327, loss: 4.64288
# epoch: 328, loss: 4.64423
# epoch: 329, loss: 4.65081
# epoch: 330, loss: 4.64516
# epoch: 331, loss: 4.63945
# epoch: 332, loss: 4.63955
# epoch: 333, loss: 4.63910
# epoch: 334, loss: 4.63379
# epoch: 335, loss: 4.63750
# epoch: 336, loss: 4.64186
# epoch: 337, loss: 4.63263
# epoch: 338, loss: 4.63497
# epoch: 339, loss: 4.64147
# epoch: 340, loss: 4.63408
# epoch: 341, loss: 4.63742
# epoch: 342, loss: 4.63675
# epoch: 343, loss: 4.63337
# epoch: 344, loss: 4.63746
# epoch: 345, loss: 4.63404
# epoch: 346, loss: 4.63507
# epoch: 347, loss: 4.63219
# epoch: 348, loss: 4.62999
# epoch: 349, loss: 4.63016
# epoch: 350, loss: 4.63704
# epoch: 351, loss: 4.64197
# epoch: 352, loss: 4.64558
# epoch: 353, loss: 4.64798
# epoch: 354, loss: 4.63971
# epoch: 355, loss: 4.63686
# epoch: 356, loss: 4.63459
# epoch: 357, loss: 4.63846
# epoch: 358, loss: 4.63326
# epoch: 359, loss: 4.63339
# epoch: 360, loss: 4.62951
# epoch: 361, loss: 4.62495
# epoch: 362, loss: 4.62556
# epoch: 363, loss: 4.62971
# epoch: 364, loss: 4.63718
# epoch: 365, loss: 4.63786
# epoch: 366, loss: 4.63425
# epoch: 367, loss: 4.62885
# epoch: 368, loss: 4.63067
# epoch: 369, loss: 4.63880
# epoch: 370, loss: 4.63450
# epoch: 371, loss: 4.63199
# epoch: 372, loss: 4.63041
# epoch: 373, loss: 4.63468
# epoch: 374, loss: 4.63871
# epoch: 375, loss: 4.63264
# epoch: 376, loss: 4.62801
# epoch: 377, loss: 4.62631
# epoch: 378, loss: 4.62671
# epoch: 379, loss: 4.62889
# epoch: 380, loss: 4.62581
# epoch: 381, loss: 4.62864
# epoch: 382, loss: 4.63995
# epoch: 383, loss: 4.65019
# epoch: 384, loss: 4.63938
# epoch: 385, loss: 4.64335
# epoch: 386, loss: 4.63240
# epoch: 387, loss: 4.63393
# epoch: 388, loss: 4.63019
# epoch: 389, loss: 4.63104
# epoch: 390, loss: 4.62985
# epoch: 391, loss: 4.63077
# epoch: 392, loss: 4.62764
# epoch: 393, loss: 4.63175
# epoch: 394, loss: 4.63156
# epoch: 395, loss: 4.63354
# epoch: 396, loss: 4.62988
# epoch: 397, loss: 4.63199
# epoch: 398, loss: 4.64033
# epoch: 399, loss: 4.63244
# epoch: 400, loss: 4.62690
# epoch: 401, loss: 4.62276
# epoch: 402, loss: 4.62723
# epoch: 403, loss: 4.62209
# epoch: 404, loss: 4.62545
# epoch: 405, loss: 4.62817
# epoch: 406, loss: 4.62599
# epoch: 407, loss: 4.62881
# epoch: 408, loss: 4.62482
# epoch: 409, loss: 4.62397
# epoch: 410, loss: 4.62567
# epoch: 411, loss: 4.62144
# epoch: 412, loss: 4.62654
# epoch: 413, loss: 4.62249
# epoch: 414, loss: 4.63215
# epoch: 415, loss: 4.63089
# epoch: 416, loss: 4.63070
# epoch: 417, loss: 4.62966
# epoch: 418, loss: 4.62988
# epoch: 419, loss: 4.63000
# epoch: 420, loss: 4.62855
# epoch: 421, loss: 4.62283
# epoch: 422, loss: 4.62191
# epoch: 423, loss: 4.62035
# epoch: 424, loss: 4.62416
# epoch: 425, loss: 4.62473
# epoch: 426, loss: 4.62631
# epoch: 427, loss: 4.62467
# epoch: 428, loss: 4.62334
# epoch: 429, loss: 4.62469
# epoch: 430, loss: 4.62368
# epoch: 431, loss: 4.62617
# epoch: 432, loss: 4.62204
# epoch: 433, loss: 4.62194
# epoch: 434, loss: 4.62432
# epoch: 435, loss: 4.62140
# epoch: 436, loss: 4.62076
# epoch: 437, loss: 4.62226
# epoch: 438, loss: 4.62001
# epoch: 439, loss: 4.62105
# epoch: 440, loss: 4.62620
# epoch: 441, loss: 4.62648
# epoch: 442, loss: 4.62308
# epoch: 443, loss: 4.62908
# epoch: 444, loss: 4.62968
# epoch: 445, loss: 4.62486
# epoch: 446, loss: 4.62357
# epoch: 447, loss: 4.61903
# epoch: 448, loss: 4.62274
# epoch: 449, loss: 4.62388
# epoch: 450, loss: 4.62408
# epoch: 451, loss: 4.62548
# epoch: 452, loss: 4.62841
# epoch: 453, loss: 4.62125
# epoch: 454, loss: 4.62282
# epoch: 455, loss: 4.62195
# epoch: 456, loss: 4.62102
# epoch: 457, loss: 4.62259
# epoch: 458, loss: 4.62514
# epoch: 459, loss: 4.62035
# epoch: 460, loss: 4.62241
# epoch: 461, loss: 4.62056
# epoch: 462, loss: 4.62692
# epoch: 463, loss: 4.62713
# epoch: 464, loss: 4.62817
# epoch: 465, loss: 4.62972
# epoch: 466, loss: 4.62239
# epoch: 467, loss: 4.62206
# epoch: 468, loss: 4.62187
# epoch: 469, loss: 4.61695
# epoch: 470, loss: 4.62267
# epoch: 471, loss: 4.62040
# epoch: 472, loss: 4.62181
# epoch: 473, loss: 4.62172
# epoch: 474, loss: 4.62437
# epoch: 475, loss: 4.62508
# epoch: 476, loss: 4.62561
# epoch: 477, loss: 4.62022
# epoch: 478, loss: 4.62389
# epoch: 479, loss: 4.62227
# epoch: 480, loss: 4.62079
# epoch: 481, loss: 4.61789
# epoch: 482, loss: 4.62815
# epoch: 483, loss: 4.62229
# epoch: 484, loss: 4.62547
# epoch: 485, loss: 4.61733
# epoch: 486, loss: 4.61809
# epoch: 487, loss: 4.62261
# epoch: 488, loss: 4.63283
# epoch: 489, loss: 4.61858
# epoch: 490, loss: 4.61560
# epoch: 491, loss: 4.62148
# epoch: 492, loss: 4.62366
# epoch: 493, loss: 4.61828
# epoch: 494, loss: 4.62201
# epoch: 495, loss: 4.62719
# epoch: 496, loss: 4.62500
# epoch: 497, loss: 4.62249
# epoch: 498, loss: 4.62767
# epoch: 499, loss: 4.61634

# %% [markdown]
# ##Check the Training Result

# %%
ds_cl= MyDataSet(X_ds, X_ds)
dl_cl = DataLoader(ds_cl, batch_size=256)

# %%
embeddings = []

# disable gradients for faster calculations
model.eval()
with torch.no_grad():
    for dl_cl1, dl_cl2 in dl_cl:

        #dl_cl1 = (dl_cl1 - torch.mean(dl_cl1,0))/torch.std(dl_cl1,0)

        # move images to the gpu
        dl_cl1 = dl_cl1.to(device)

        # embed the images with the pre-trained backbone
        #y = model.backbone(images).flatten(start_dim=1)
        x,_ = model(dl_cl1)
        # store the embeddings in lists
        embeddings.append(x)

# concatenate the embeddings, targets and convert to numpy
embeddings = torch.cat(embeddings, dim=0)
embeddings = embeddings.cpu().numpy()

# %%
test = (embeddings - embeddings.mean(axis=0)) / (embeddings.std(axis=0))

# %%
#KMeans in latent space
kmeans_backbone = KMeans(n_clusters=3).fit(test)
kmeans_labels_backbone = kmeans_backbone.labels_

# %%
normalized_mutual_info_score(kmeans_labels_backbone, y)
# Out:
# 0.8588699635529649

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(test)
data_X_tsne = np.vstack((X_tsne.T, kmeans_labels_backbone)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#NMI increases from 0.69 to 0.85
