# %% [markdown]
# ## Conifuration

# %%
#import the lib for contrastive learning framework
# !pip install lightly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lightly
#   Downloading lightly-1.2.23-py3-none-any.whl (459 kB)
#      |████████████████████████████████| 459 kB 4.1 MB/s
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (57.4.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.15.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from lightly) (0.12.0+cu113)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.8.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.23.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.21.6)
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.7/dist-packages (from lightly) (4.64.0)
# Collecting hydra-core>=1.0.0
#   Downloading hydra_core-1.2.0-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 46.7 MB/s
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.24.3)
# Collecting lightly-utils~=0.0.0
#   Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Collecting pytorch-lightning>=1.0.4
#   Downloading pytorch_lightning-1.6.4-py3-none-any.whl (585 kB)
#      |████████████████████████████████| 585 kB 42.0 MB/s
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.7/dist-packages (from lightly) (2022.6.15)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (21.3)
# Collecting omegaconf~=2.2
#   Downloading omegaconf-2.2.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 6.9 MB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (5.7.1)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      |████████████████████████████████| 117 kB 57.1 MB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from lightly-utils~=0.0.0->lightly) (7.1.2)
# Collecting PyYAML>=5.1.0
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 35.3 MB/s
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (4.1.1)
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (3.17.3)
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.9.2-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 40.0 MB/s
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (1.11.0+cu113)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2.8.0)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 42.6 MB/s
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 9.3 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->hydra-core>=1.0.0->lightly) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (2.10)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.6)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.46.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.3.7)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.1.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.2.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 39.6 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (2.1.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (21.4.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.0 MB/s
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 16.2 MB/s
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=c510eae39532cd15afc06fc2cbf96d508054a5f8109d21361e994763ae499f3a
#   Stored in directory: /root/.cache/pip/wheels/8b/8d/53/2af8772d9aec614e3fc65e53d4a993ad73c61daa8bbd85a873
# Successfully built antlr4-python3-runtime
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, PyYAML, fsspec, antlr4-python3-runtime, aiohttp, torchmetrics, pyDeprecate, omegaconf, pytorch-lightning, lightly-utils, hydra-core, lightly
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-6.0 aiohttp-3.8.1 aiosignal-1.2.0 antlr4-python3-runtime-4.9.3 async-timeout-4.0.2 asynctest-0.13.0 frozenlist-1.3.0 fsspec-2022.5.0 hydra-core-1.2.0 lightly-1.2.23 lightly-utils-0.0.2 multidict-6.0.2 omegaconf-2.2.2 pyDeprecate-0.3.2 pytorch-lightning-1.6.4 torchmetrics-0.9.2 yarl-1.7.2

# %%
import lightly
from lightly.models.modules.heads import SimSiamPredictionHead
from lightly.models.modules.heads import SimSiamProjectionHead

from lightly.data import LightlyDataset
from lightly.data import ImageCollateFunction
from lightly.models.modules import BarlowTwinsProjectionHead
from lightly.loss import BarlowTwinsLoss

from lightly.data import LightlyDataset
from lightly.data import SimCLRCollateFunction
from lightly.loss import NTXentLoss
from lightly.loss import NegativeCosineSimilarity
from lightly.models.modules import SimCLRProjectionHead

# %%
import math
import torch
import torch.nn as nn
import torchvision
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from torch.utils.data import Dataset, DataLoader
import torch.optim as torch_optim
import torch.optim.lr_scheduler as lr_scheduler
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
from datetime import datetime

from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from matplotlib import pyplot
import seaborn as sns

from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_mutual_info_score
from sklearn.metrics import silhouette_score
from sklearn import mixture
from sklearn.cluster import DBSCAN
from sklearn.cluster import OPTICS
from sklearn.cluster import AgglomerativeClustering

import tensorboard
from tensorboard import notebook
from torch.utils.tensorboard import SummaryWriter

import matplotlib 
import matplotlib.pyplot as plt
#import plotly.express as px

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons
from sklearn.utils import shuffle

import torchvision.transforms as transforms
import torchvision.datasets as datasets
from sklearn.metrics.pairwise import cosine_similarity

import random
from torch.nn.modules.loss import MSELoss
from sklearn.neighbors import KDTree
#from kmodes.kprototypes import KPrototypes

from scipy.io.arff import loadarff
from sklearn.preprocessing import MinMaxScaler 
from sklearn.datasets import make_classification

# %% [markdown]
# ## Load Dataset Pendigits and Check Clustering Result with the Baseline Method Kmeans

# %%
# set the path to the dataset
path_to_data = '/content/drive/MyDrive/Colab_Notebooks/usps.arff'

# %%
raw_data = loadarff(path_to_data)
data = pd.DataFrame(raw_data[0])

# %%
X_ds = data.copy()
X_ds = X_ds.drop(['int0'], axis=1)
X_ds = pd.DataFrame(X_ds).to_numpy()

y_ds = data.copy()
y_ds = y_ds['int0']

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X_ds)
data_X_tsne = np.vstack((X_tsne.T, y_ds)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#check the clustering result with Kmeans
kmeans_ori = KMeans(n_clusters=10).fit(X_ds)
kmeans_labels_ori = kmeans_ori.labels_

normalized_mutual_info_score(kmeans_labels_ori, y_ds)
# Out:
# 0.6136288135352246

# %%
#tsne = TSNE(n_components=2)
#X_tsne = tsne.fit_transform(X_ds)
data_X_tsne = np.vstack((X_tsne.T, kmeans_labels_ori)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ####MixUp

# %%
def mixup(data):
  view = data.copy()
  for i in range(len(view)):
    random_row_index = random.randint(0, len(view)-1)
    view[i] = view[i]*0.5  + view[random_row_index]*0.5
  return view

# %% [markdown]
# ####MixCut

# %%
def mixcut(data):
  data_copy = data.copy()
  view = data.copy()
  mask_len = 100

  for i in range(len(data_copy)):
    random_row_id = random.randint(0, len(data_copy)-1)
    random_column_id = random.randint(0, data_copy.shape[1]-mask_len)
    view[i,random_column_id:(random_column_id+mask_len)] = data_copy[random_row_id,random_column_id:(random_column_id+mask_len)]
  return view

# %% [markdown]
# #### Masking with mean

# %%
def get_random_indices(data, portion_of_mask):
  return np.random.choice(data.shape[1], size=np.floor(data.shape[1]*portion_of_mask).astype(int), replace=False)

# %%
def masking_with_mean(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = column_mu[j]
              
  return view

# %% [markdown]
# ####Masking with random value in domain range

# %%
def masking_with_random(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)
  column_min = np.minimum(data)
  column_max = np.maximum(data)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = random.randint(column_min[j], column_max[j])
              
  return view

# %% [markdown]
# ####Masking with margin distribution

# %%
def masking_with_margin_distribution(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = np.random.normal(column_mu[j], column_std[j])
              
  return view

# %% [markdown]
# ####Upsampling (SMOTE like)

# %%
#put all data points in kd-tree for fast searching
kdtree = KDTree(X_ds, leaf_size=2)

# %%
#get random point in the k nearest neighbors
def get_idx_random_knn(x,k):
   _, ids = kdtree.query(x.reshape(1, -1), k=k)
   ids = ids.flatten()
   ids = ids[1:-1]
   random_id = np.random.choice(ids, 1)
   return random_id

# %%
#mix up with a random near neighbor 
def mixup_random_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = 0.5*data[i] + 0.5*data[random_neighbor_id]
  return view

# %%
#a random neighbor as augmentation
def random_near_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = data[random_neighbor_id]
  return view

# %% [markdown]
# ##Create Model and Train with Augmented Data

# %%
class MyDataSet(Dataset):
  def __init__(self, view1, view2):
 
    X_view1 = view1.copy()
    X_view2 = view2.copy()
    self.X_view1 = X_view1.copy().astype(np.float32)
    self.X_view2 = X_view2.copy().astype(np.float32)
  
  def __len__(self):
    return len(self.X_view1)
  
  def __getitem__(self, idx):
    return self.X_view1[idx], self.X_view2[idx]

# %%
# define the NN architecture
class convBackbone(nn.Module):
    def __init__(self):
        super(convBackbone, self).__init__()

        #turn on dropout for testing the 'cropping' data augmentation 
        #self.dropout = nn.Dropout(p=0.1)
        
        self.fc1 = nn.Linear(256, 256, bias=False)
        self.bn1 = nn.BatchNorm1d(256)

        self.fc2 = nn.Linear(256, 256, bias=False)
        self.bn2 = nn.BatchNorm1d(256)

        self.fc3 = nn.Linear(256, 128, bias=False)
        self.bn3 = nn.BatchNorm1d(128)


    def forward(self, x):

        #turn on dropout for testing the 'cropping' data augmentation 
        #x = self.dropout(x)
        
        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.bn3(self.fc3(x))
                
        return x

# %%
class SimSiam(nn.Module):
    def __init__(self, backbone):
        super().__init__()
        self.backbone = backbone
        self.projection_head = SimSiamProjectionHead(128, 128, 128)
        self.prediction_head = SimSiamPredictionHead(128, 64, 128)

    def forward(self, x):
        f = self.backbone(x)
        z = f.flatten(start_dim=1)
        z = self.projection_head(z)
        p = self.prediction_head(z)
        z = z.detach()
        return f, z, p

backbone = convBackbone()
model = SimSiam(backbone)

# %%
criterion = NegativeCosineSimilarity()
optimizer = torch.optim.SGD(model.parameters(), lr=0.06)

#cosine annealing lr
scheduler = lr_scheduler.CosineAnnealingLR(optimizer,T_max=500, eta_min=0)

# %%
view1 = random_near_neighbor(X_ds, 22)
view2 = random_near_neighbor(X_ds, 18)

#turn on the following to test other augmentations

#view1 = mixup_random_neighbor(X_ds, 15)
#view2 = mixup_random_neighbor(X_ds, 15)

#view1 = mixup(X_ds)
#view2 = mixup(X_ds)

#view1 = mixcut(X_ds)
#view2 = mixcut(X_ds)

#view1 = masking_with_mean(X_ds, 0.4)
#view2 = masking_with_mean(X_ds, 0.4)

#view1 = masking_with_random(X_ds, 0.4)
#view2 = masking_with_random(X_ds, 0.4)

#view1 = masking_with_margin_distribution(X_ds, 0.4)
#view2 = masking_with_margin_distribution(X_ds, 0.4)

train_ds = MyDataSet(view1, view2)
train_dl = DataLoader(train_ds, batch_size=256, shuffle=True)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

for epoch in range(500):
    total_loss = 0
    for x0,x1 in train_dl:
        x0 = x0.to(device)
        x1 = x1.to(device)
        _, z0, p0 = model(x0)
        _, z1, p1 = model(x1)

        loss = 0.5 * (criterion(z0, p1) + criterion(z1, p0))
        total_loss += loss.detach()
        loss.backward()

        optimizer.step()
        optimizer.zero_grad()
        scheduler.step()

    avg_loss = total_loss / len(train_dl)
    print(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
# Out:
# epoch: 00, loss: -0.16534
# epoch: 01, loss: -0.41184
# epoch: 02, loss: -0.58222
# epoch: 03, loss: -0.68694
# epoch: 04, loss: -0.74602
# epoch: 05, loss: -0.78049
# epoch: 06, loss: -0.80283
# epoch: 07, loss: -0.81708
# epoch: 08, loss: -0.82665
# epoch: 09, loss: -0.83184
# epoch: 10, loss: -0.83618
# epoch: 11, loss: -0.83739
# epoch: 12, loss: -0.83811
# epoch: 13, loss: -0.83850
# epoch: 14, loss: -0.83812
# epoch: 15, loss: -0.83805
# epoch: 16, loss: -0.84051
# epoch: 17, loss: -0.84267
# epoch: 18, loss: -0.84619
# epoch: 19, loss: -0.85200
# epoch: 20, loss: -0.85913
# epoch: 21, loss: -0.86518
# epoch: 22, loss: -0.87159
# epoch: 23, loss: -0.87879
# epoch: 24, loss: -0.88320
# epoch: 25, loss: -0.88881
# epoch: 26, loss: -0.89306
# epoch: 27, loss: -0.89558
# epoch: 28, loss: -0.89958
# epoch: 29, loss: -0.90139
# epoch: 30, loss: -0.90289
# epoch: 31, loss: -0.90468
# epoch: 32, loss: -0.90607
# epoch: 33, loss: -0.90695
# epoch: 34, loss: -0.90663
# epoch: 35, loss: -0.90862
# epoch: 36, loss: -0.90906
# epoch: 37, loss: -0.90942
# epoch: 38, loss: -0.90896
# epoch: 39, loss: -0.90835
# epoch: 40, loss: -0.90941
# epoch: 41, loss: -0.90879
# epoch: 42, loss: -0.90909
# epoch: 43, loss: -0.90875
# epoch: 44, loss: -0.90904
# epoch: 45, loss: -0.90929
# epoch: 46, loss: -0.90925
# epoch: 47, loss: -0.91035
# epoch: 48, loss: -0.90975
# epoch: 49, loss: -0.91159
# epoch: 50, loss: -0.91274
# epoch: 51, loss: -0.91261
# epoch: 52, loss: -0.91378
# epoch: 53, loss: -0.91413
# epoch: 54, loss: -0.91601
# epoch: 55, loss: -0.91545
# epoch: 56, loss: -0.91659
# epoch: 57, loss: -0.91799
# epoch: 58, loss: -0.91770
# epoch: 59, loss: -0.91837
# epoch: 60, loss: -0.91799
# epoch: 61, loss: -0.91922
# epoch: 62, loss: -0.91824
# epoch: 63, loss: -0.91958
# epoch: 64, loss: -0.91987
# epoch: 65, loss: -0.91996
# epoch: 66, loss: -0.92054
# epoch: 67, loss: -0.92023
# epoch: 68, loss: -0.91962
# epoch: 69, loss: -0.92011
# epoch: 70, loss: -0.91901
# epoch: 71, loss: -0.91993
# epoch: 72, loss: -0.91964
# epoch: 73, loss: -0.91984
# epoch: 74, loss: -0.91996
# epoch: 75, loss: -0.92019
# epoch: 76, loss: -0.91979
# epoch: 77, loss: -0.92074
# epoch: 78, loss: -0.92082
# epoch: 79, loss: -0.92127
# epoch: 80, loss: -0.92155
# epoch: 81, loss: -0.92183
# epoch: 82, loss: -0.92273
# epoch: 83, loss: -0.92269
# epoch: 84, loss: -0.92332
# epoch: 85, loss: -0.92352
# epoch: 86, loss: -0.92463
# epoch: 87, loss: -0.92462
# epoch: 88, loss: -0.92467
# epoch: 89, loss: -0.92515
# epoch: 90, loss: -0.92511
# epoch: 91, loss: -0.92510
# epoch: 92, loss: -0.92512
# epoch: 93, loss: -0.92502
# epoch: 94, loss: -0.92471
# epoch: 95, loss: -0.92567
# epoch: 96, loss: -0.92556
# epoch: 97, loss: -0.92499
# epoch: 98, loss: -0.92525
# epoch: 99, loss: -0.92455
# epoch: 100, loss: -0.92533
# epoch: 101, loss: -0.92532
# epoch: 102, loss: -0.92550
# epoch: 103, loss: -0.92577
# epoch: 104, loss: -0.92578
# epoch: 105, loss: -0.92591
# epoch: 106, loss: -0.92587
# epoch: 107, loss: -0.92631
# epoch: 108, loss: -0.92754
# epoch: 109, loss: -0.92695
# epoch: 110, loss: -0.92616
# epoch: 111, loss: -0.92756
# epoch: 112, loss: -0.92801
# epoch: 113, loss: -0.92798
# epoch: 114, loss: -0.92881
# epoch: 115, loss: -0.92863
# epoch: 116, loss: -0.92817
# epoch: 117, loss: -0.92860
# epoch: 118, loss: -0.92904
# epoch: 119, loss: -0.92936
# epoch: 120, loss: -0.92867
# epoch: 121, loss: -0.92865
# epoch: 122, loss: -0.92880
# epoch: 123, loss: -0.92925
# epoch: 124, loss: -0.92905
# epoch: 125, loss: -0.92890
# epoch: 126, loss: -0.92903
# epoch: 127, loss: -0.92861
# epoch: 128, loss: -0.92969
# epoch: 129, loss: -0.92854
# epoch: 130, loss: -0.93009
# epoch: 131, loss: -0.92913
# epoch: 132, loss: -0.92916
# epoch: 133, loss: -0.92948
# epoch: 134, loss: -0.92963
# epoch: 135, loss: -0.93037
# epoch: 136, loss: -0.92957
# epoch: 137, loss: -0.93017
# epoch: 138, loss: -0.93063
# epoch: 139, loss: -0.93065
# epoch: 140, loss: -0.93016
# epoch: 141, loss: -0.93001
# epoch: 142, loss: -0.93087
# epoch: 143, loss: -0.93113
# epoch: 144, loss: -0.93164
# epoch: 145, loss: -0.93127
# epoch: 146, loss: -0.93192
# epoch: 147, loss: -0.93075
# epoch: 148, loss: -0.93160
# epoch: 149, loss: -0.93128
# epoch: 150, loss: -0.93114
# epoch: 151, loss: -0.93110
# epoch: 152, loss: -0.93127
# epoch: 153, loss: -0.93126
# epoch: 154, loss: -0.93141
# epoch: 155, loss: -0.93104
# epoch: 156, loss: -0.93150
# epoch: 157, loss: -0.93137
# epoch: 158, loss: -0.93153
# epoch: 159, loss: -0.93190
# epoch: 160, loss: -0.93182
# epoch: 161, loss: -0.93214
# epoch: 162, loss: -0.93158
# epoch: 163, loss: -0.93131
# epoch: 164, loss: -0.93169
# epoch: 165, loss: -0.93153
# epoch: 166, loss: -0.93240
# epoch: 167, loss: -0.93217
# epoch: 168, loss: -0.93222
# epoch: 169, loss: -0.93242
# epoch: 170, loss: -0.93277
# epoch: 171, loss: -0.93230
# epoch: 172, loss: -0.93268
# epoch: 173, loss: -0.93241
# epoch: 174, loss: -0.93371
# epoch: 175, loss: -0.93318
# epoch: 176, loss: -0.93248
# epoch: 177, loss: -0.93293
# epoch: 178, loss: -0.93283
# epoch: 179, loss: -0.93259
# epoch: 180, loss: -0.93213
# epoch: 181, loss: -0.93218
# epoch: 182, loss: -0.93246
# epoch: 183, loss: -0.93226
# epoch: 184, loss: -0.93248
# epoch: 185, loss: -0.93279
# epoch: 186, loss: -0.93275
# epoch: 187, loss: -0.93255
# epoch: 188, loss: -0.93192
# epoch: 189, loss: -0.93253
# epoch: 190, loss: -0.93306
# epoch: 191, loss: -0.93242
# epoch: 192, loss: -0.93296
# epoch: 193, loss: -0.93265
# epoch: 194, loss: -0.93281
# epoch: 195, loss: -0.93308
# epoch: 196, loss: -0.93341
# epoch: 197, loss: -0.93281
# epoch: 198, loss: -0.93298
# epoch: 199, loss: -0.93269
# epoch: 200, loss: -0.93356
# epoch: 201, loss: -0.93317
# epoch: 202, loss: -0.93309
# epoch: 203, loss: -0.93368
# epoch: 204, loss: -0.93306
# epoch: 205, loss: -0.93283
# epoch: 206, loss: -0.93321
# epoch: 207, loss: -0.93346
# epoch: 208, loss: -0.93207
# epoch: 209, loss: -0.93247
# epoch: 210, loss: -0.93349
# epoch: 211, loss: -0.93252
# epoch: 212, loss: -0.93367
# epoch: 213, loss: -0.93298
# epoch: 214, loss: -0.93292
# epoch: 215, loss: -0.93279
# epoch: 216, loss: -0.93305
# epoch: 217, loss: -0.93299
# epoch: 218, loss: -0.93301
# epoch: 219, loss: -0.93293
# epoch: 220, loss: -0.93422
# epoch: 221, loss: -0.93341
# epoch: 222, loss: -0.93356
# epoch: 223, loss: -0.93344
# epoch: 224, loss: -0.93359
# epoch: 225, loss: -0.93458
# epoch: 226, loss: -0.93415
# epoch: 227, loss: -0.93416
# epoch: 228, loss: -0.93406
# epoch: 229, loss: -0.93413
# epoch: 230, loss: -0.93313
# epoch: 231, loss: -0.93393
# epoch: 232, loss: -0.93397
# epoch: 233, loss: -0.93407
# epoch: 234, loss: -0.93420
# epoch: 235, loss: -0.93479
# epoch: 236, loss: -0.93382
# epoch: 237, loss: -0.93329
# epoch: 238, loss: -0.93324
# epoch: 239, loss: -0.93304
# epoch: 240, loss: -0.93400
# epoch: 241, loss: -0.93431
# epoch: 242, loss: -0.93346
# epoch: 243, loss: -0.93389
# epoch: 244, loss: -0.93307
# epoch: 245, loss: -0.93446
# epoch: 246, loss: -0.93416
# epoch: 247, loss: -0.93351
# epoch: 248, loss: -0.93425
# epoch: 249, loss: -0.93476
# epoch: 250, loss: -0.93522
# epoch: 251, loss: -0.93443
# epoch: 252, loss: -0.93547
# epoch: 253, loss: -0.93517
# epoch: 254, loss: -0.93477
# epoch: 255, loss: -0.93527
# epoch: 256, loss: -0.93502
# epoch: 257, loss: -0.93499
# epoch: 258, loss: -0.93480
# epoch: 259, loss: -0.93452
# epoch: 260, loss: -0.93453
# epoch: 261, loss: -0.93499
# epoch: 262, loss: -0.93451
# epoch: 263, loss: -0.93505
# epoch: 264, loss: -0.93446
# epoch: 265, loss: -0.93505
# epoch: 266, loss: -0.93438
# epoch: 267, loss: -0.93457
# epoch: 268, loss: -0.93436
# epoch: 269, loss: -0.93436
# epoch: 270, loss: -0.93458
# epoch: 271, loss: -0.93433
# epoch: 272, loss: -0.93405
# epoch: 273, loss: -0.93494
# epoch: 274, loss: -0.93465
# epoch: 275, loss: -0.93519
# epoch: 276, loss: -0.93485
# epoch: 277, loss: -0.93535
# epoch: 278, loss: -0.93552
# epoch: 279, loss: -0.93504
# epoch: 280, loss: -0.93525
# epoch: 281, loss: -0.93556
# epoch: 282, loss: -0.93631
# epoch: 283, loss: -0.93554
# epoch: 284, loss: -0.93512
# epoch: 285, loss: -0.93578
# epoch: 286, loss: -0.93543
# epoch: 287, loss: -0.93526
# epoch: 288, loss: -0.93606
# epoch: 289, loss: -0.93488
# epoch: 290, loss: -0.93601
# epoch: 291, loss: -0.93426
# epoch: 292, loss: -0.93502
# epoch: 293, loss: -0.93579
# epoch: 294, loss: -0.93588
# epoch: 295, loss: -0.93497
# epoch: 296, loss: -0.93574
# epoch: 297, loss: -0.93593
# epoch: 298, loss: -0.93534
# epoch: 299, loss: -0.93575
# epoch: 300, loss: -0.93526
# epoch: 301, loss: -0.93635
# epoch: 302, loss: -0.93696
# epoch: 303, loss: -0.93612
# epoch: 304, loss: -0.93633
# epoch: 305, loss: -0.93559
# epoch: 306, loss: -0.93653
# epoch: 307, loss: -0.93653
# epoch: 308, loss: -0.93646
# epoch: 309, loss: -0.93670
# epoch: 310, loss: -0.93684
# epoch: 311, loss: -0.93605
# epoch: 312, loss: -0.93708
# epoch: 313, loss: -0.93713
# epoch: 314, loss: -0.93688
# epoch: 315, loss: -0.93694
# epoch: 316, loss: -0.93646
# epoch: 317, loss: -0.93676
# epoch: 318, loss: -0.93576
# epoch: 319, loss: -0.93651
# epoch: 320, loss: -0.93692
# epoch: 321, loss: -0.93634
# epoch: 322, loss: -0.93588
# epoch: 323, loss: -0.93648
# epoch: 324, loss: -0.93631
# epoch: 325, loss: -0.93633
# epoch: 326, loss: -0.93680
# epoch: 327, loss: -0.93765
# epoch: 328, loss: -0.93757
# epoch: 329, loss: -0.93747
# epoch: 330, loss: -0.93789
# epoch: 331, loss: -0.93686
# epoch: 332, loss: -0.93755
# epoch: 333, loss: -0.93799
# epoch: 334, loss: -0.93756
# epoch: 335, loss: -0.93724
# epoch: 336, loss: -0.93746
# epoch: 337, loss: -0.93746
# epoch: 338, loss: -0.93779
# epoch: 339, loss: -0.93782
# epoch: 340, loss: -0.93765
# epoch: 341, loss: -0.93819
# epoch: 342, loss: -0.93728
# epoch: 343, loss: -0.93806
# epoch: 344, loss: -0.93737
# epoch: 345, loss: -0.93742
# epoch: 346, loss: -0.93721
# epoch: 347, loss: -0.93727
# epoch: 348, loss: -0.93748
# epoch: 349, loss: -0.93652
# epoch: 350, loss: -0.93787
# epoch: 351, loss: -0.93747
# epoch: 352, loss: -0.93800
# epoch: 353, loss: -0.93795
# epoch: 354, loss: -0.93722
# epoch: 355, loss: -0.93770
# epoch: 356, loss: -0.93663
# epoch: 357, loss: -0.93764
# epoch: 358, loss: -0.93745
# epoch: 359, loss: -0.93850
# epoch: 360, loss: -0.93857
# epoch: 361, loss: -0.93888
# epoch: 362, loss: -0.93891
# epoch: 363, loss: -0.93841
# epoch: 364, loss: -0.93902
# epoch: 365, loss: -0.93804
# epoch: 366, loss: -0.93875
# epoch: 367, loss: -0.93828
# epoch: 368, loss: -0.93787
# epoch: 369, loss: -0.93826
# epoch: 370, loss: -0.93807
# epoch: 371, loss: -0.93811
# epoch: 372, loss: -0.93705
# epoch: 373, loss: -0.93775
# epoch: 374, loss: -0.93749
# epoch: 375, loss: -0.93719
# epoch: 376, loss: -0.93766
# epoch: 377, loss: -0.93800
# epoch: 378, loss: -0.93801
# epoch: 379, loss: -0.93774
# epoch: 380, loss: -0.93837
# epoch: 381, loss: -0.93756
# epoch: 382, loss: -0.93788
# epoch: 383, loss: -0.93864
# epoch: 384, loss: -0.93837
# epoch: 385, loss: -0.93895
# epoch: 386, loss: -0.93831
# epoch: 387, loss: -0.93862
# epoch: 388, loss: -0.93848
# epoch: 389, loss: -0.93896
# epoch: 390, loss: -0.93889
# epoch: 391, loss: -0.93845
# epoch: 392, loss: -0.93912
# epoch: 393, loss: -0.93936
# epoch: 394, loss: -0.93914
# epoch: 395, loss: -0.93836
# epoch: 396, loss: -0.93916
# epoch: 397, loss: -0.93847
# epoch: 398, loss: -0.93866
# epoch: 399, loss: -0.93902
# epoch: 400, loss: -0.93808
# epoch: 401, loss: -0.93786
# epoch: 402, loss: -0.93861
# epoch: 403, loss: -0.93837
# epoch: 404, loss: -0.93810
# epoch: 405, loss: -0.93859
# epoch: 406, loss: -0.93853
# epoch: 407, loss: -0.93933
# epoch: 408, loss: -0.93901
# epoch: 409, loss: -0.93911
# epoch: 410, loss: -0.93963
# epoch: 411, loss: -0.93957
# epoch: 412, loss: -0.93955
# epoch: 413, loss: -0.93887
# epoch: 414, loss: -0.93950
# epoch: 415, loss: -0.93986
# epoch: 416, loss: -0.93966
# epoch: 417, loss: -0.93992
# epoch: 418, loss: -0.93939
# epoch: 419, loss: -0.93937
# epoch: 420, loss: -0.93968
# epoch: 421, loss: -0.93908
# epoch: 422, loss: -0.93978
# epoch: 423, loss: -0.93973
# epoch: 424, loss: -0.93962
# epoch: 425, loss: -0.93969
# epoch: 426, loss: -0.93932
# epoch: 427, loss: -0.93975
# epoch: 428, loss: -0.93924
# epoch: 429, loss: -0.93967
# epoch: 430, loss: -0.93964
# epoch: 431, loss: -0.93965
# epoch: 432, loss: -0.93893
# epoch: 433, loss: -0.93934
# epoch: 434, loss: -0.93960
# epoch: 435, loss: -0.93910
# epoch: 436, loss: -0.93991
# epoch: 437, loss: -0.93974
# epoch: 438, loss: -0.94077
# epoch: 439, loss: -0.93967
# epoch: 440, loss: -0.94050
# epoch: 441, loss: -0.93974
# epoch: 442, loss: -0.94063
# epoch: 443, loss: -0.94012
# epoch: 444, loss: -0.93963
# epoch: 445, loss: -0.93991
# epoch: 446, loss: -0.94005
# epoch: 447, loss: -0.93988
# epoch: 448, loss: -0.94032
# epoch: 449, loss: -0.93974
# epoch: 450, loss: -0.93898
# epoch: 451, loss: -0.93997
# epoch: 452, loss: -0.93973
# epoch: 453, loss: -0.94001
# epoch: 454, loss: -0.93955
# epoch: 455, loss: -0.93986
# epoch: 456, loss: -0.93945
# epoch: 457, loss: -0.93955
# epoch: 458, loss: -0.93932
# epoch: 459, loss: -0.94016
# epoch: 460, loss: -0.93968
# epoch: 461, loss: -0.93889
# epoch: 462, loss: -0.93947
# epoch: 463, loss: -0.93946
# epoch: 464, loss: -0.93972
# epoch: 465, loss: -0.94001
# epoch: 466, loss: -0.93944
# epoch: 467, loss: -0.94028
# epoch: 468, loss: -0.93977
# epoch: 469, loss: -0.94053
# epoch: 470, loss: -0.94021
# epoch: 471, loss: -0.94045
# epoch: 472, loss: -0.94058
# epoch: 473, loss: -0.94131
# epoch: 474, loss: -0.94044
# epoch: 475, loss: -0.94076
# epoch: 476, loss: -0.94034
# epoch: 477, loss: -0.94059
# epoch: 478, loss: -0.93977
# epoch: 479, loss: -0.94067
# epoch: 480, loss: -0.94026
# epoch: 481, loss: -0.93922
# epoch: 482, loss: -0.93969
# epoch: 483, loss: -0.93998
# epoch: 484, loss: -0.93992
# epoch: 485, loss: -0.93949
# epoch: 486, loss: -0.93947
# epoch: 487, loss: -0.94037
# epoch: 488, loss: -0.93959
# epoch: 489, loss: -0.94015
# epoch: 490, loss: -0.93967
# epoch: 491, loss: -0.94039
# epoch: 492, loss: -0.93999
# epoch: 493, loss: -0.93969
# epoch: 494, loss: -0.93987
# epoch: 495, loss: -0.93988
# epoch: 496, loss: -0.94026
# epoch: 497, loss: -0.94005
# epoch: 498, loss: -0.94015
# epoch: 499, loss: -0.94053

# %% [markdown]
# ##Check the Training Result

# %%
ds_cl= MyDataSet(X_ds, X_ds)
dl_cl = DataLoader(ds_cl, batch_size=256)

# %%
embeddings = []

# disable gradients for faster calculations
model.eval()
with torch.no_grad():
    for dl_cl1, dl_cl2 in dl_cl:

        dl_cl1 = dl_cl1.to(device)
        f, z, p = model(dl_cl1)
        
        # store the embeddings in lists
        embeddings.append(f)

# concatenate the embeddings, targets and convert to numpy
embeddings = torch.cat(embeddings, dim=0)
embeddings = embeddings.cpu().numpy()

# %%
test = (embeddings - embeddings.mean(axis=0)) / (embeddings.std(axis=0))

# %%
#KMeans in latent space
kmeans_backbone = KMeans(n_clusters=10).fit(test)
kmeans_labels_backbone = kmeans_backbone.labels_

# %%
normalized_mutual_info_score(kmeans_labels_backbone, y_ds)
# Out:
# 0.7259331865179988

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(embeddings)
data_X_tsne = np.vstack((X_tsne.T, kmeans_labels_backbone)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#NMI increases from 0.61 to 0.72
