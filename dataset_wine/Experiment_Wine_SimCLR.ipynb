# %% [markdown]
# ## Conifuration

# %%
#import the lib for contrastive learning framework
# !pip install lightly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lightly
#   Downloading lightly-1.2.20-py3-none-any.whl (451 kB)
#      |████████████████████████████████| 451 kB 8.5 MB/s
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.7/dist-packages (from lightly) (4.64.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.7/dist-packages (from lightly) (2022.6.15)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.8.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from lightly) (0.12.0+cu113)
# Collecting hydra-core>=1.0.0
#   Downloading hydra_core-1.2.0-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 31.3 MB/s
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (57.4.0)
# Collecting lightly-utils~=0.0.0
#   Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.15.0)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.23.0)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.24.3)
# Collecting pytorch-lightning>=1.0.4
#   Downloading pytorch_lightning-1.6.4-py3-none-any.whl (585 kB)
#      |████████████████████████████████| 585 kB 28.5 MB/s
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (21.3)
# Collecting omegaconf~=2.2
#   Downloading omegaconf-2.2.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 8.1 MB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (5.7.1)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      |████████████████████████████████| 117 kB 60.8 MB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from lightly-utils~=0.0.0->lightly) (7.1.2)
# Collecting PyYAML>=5.1.0
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 39.8 MB/s
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (4.1.1)
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.9.1-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 26.9 MB/s
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 44.1 MB/s
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (3.17.3)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2.8.0)
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (1.11.0+cu113)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 47.0 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->hydra-core>=1.0.0->lightly) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (2.10)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.37.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.46.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.3.7)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.1.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.8.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.2.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.9 MB/s
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 38.6 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (2.0.12)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (21.4.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 48.0 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=341e9d9555db4516a85a0e7d25fd9f315927c3606478f19eff2dcdfb21b639af
#   Stored in directory: /root/.cache/pip/wheels/8b/8d/53/2af8772d9aec614e3fc65e53d4a993ad73c61daa8bbd85a873
# Successfully built antlr4-python3-runtime
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, PyYAML, fsspec, antlr4-python3-runtime, aiohttp, torchmetrics, pyDeprecate, omegaconf, pytorch-lightning, lightly-utils, hydra-core, lightly
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-6.0 aiohttp-3.8.1 aiosignal-1.2.0 antlr4-python3-runtime-4.9.3 async-timeout-4.0.2 asynctest-0.13.0 frozenlist-1.3.0 fsspec-2022.5.0 hydra-core-1.2.0 lightly-1.2.20 lightly-utils-0.0.2 multidict-6.0.2 omegaconf-2.2.2 pyDeprecate-0.3.2 pytorch-lightning-1.6.4 torchmetrics-0.9.1 yarl-1.7.2

# %%
import lightly
from lightly.models.modules.heads import SimSiamPredictionHead
from lightly.models.modules.heads import SimSiamProjectionHead

from lightly.data import LightlyDataset
from lightly.data import ImageCollateFunction
from lightly.models.modules import BarlowTwinsProjectionHead
from lightly.loss import BarlowTwinsLoss

from lightly.data import LightlyDataset
from lightly.data import SimCLRCollateFunction
from lightly.loss import NTXentLoss
from lightly.loss import NegativeCosineSimilarity
from lightly.models.modules import SimCLRProjectionHead

# %%
import math
import torch
import torch.nn as nn
import torchvision
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from torch.utils.data import Dataset, DataLoader
import torch.optim as torch_optim
import torch.optim.lr_scheduler as lr_scheduler
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
from datetime import datetime

from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from matplotlib import pyplot
import seaborn as sns

from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_mutual_info_score
from sklearn.metrics import silhouette_score
from sklearn import mixture
from sklearn.cluster import DBSCAN
from sklearn.cluster import OPTICS
from sklearn.cluster import AgglomerativeClustering

import tensorboard
from tensorboard import notebook
from torch.utils.tensorboard import SummaryWriter

import matplotlib 
import matplotlib.pyplot as plt
#import plotly.express as px

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons
from sklearn.utils import shuffle

import torchvision.transforms as transforms
import torchvision.datasets as datasets
from sklearn.metrics.pairwise import cosine_similarity

import random
from torch.nn.modules.loss import MSELoss
from sklearn.neighbors import KDTree
#from kmodes.kprototypes import KPrototypes

from scipy.io.arff import loadarff
from sklearn.preprocessing import MinMaxScaler 
from sklearn.datasets import make_classification

# %% [markdown]
# ## Load Dataset Wine and Check Clustering Result with the Baseline Method Kmeans

# %%
data0 = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/winequality_red.csv')
data1 = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/winequality_white.csv')

# %%
data0['color'] = 0
data1['color'] = 1

# %%
data=pd.concat([data0,data1],axis=0)
data.shape
# Out:
# (6497, 13)

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# color                   0
# dtype: int64

# %%
X = data.drop(['color'], axis=1)
y = data['color']

#normalize and scale the data to prevent gradient vanishing
X_ds = pd.DataFrame(X).to_numpy()
norm_X_ds = 100 * (X_ds - np.mean(X_ds, axis=0)) / np.std(X_ds, axis=0) + 256

# %%
#KMeans with one-hot-encoding for categorical features
kmeans_ori = KMeans(n_clusters=2).fit(norm_X_ds)
kmeans_labels_ori = kmeans_ori.labels_

normalized_mutual_info_score(kmeans_labels_ori, y)
# Out:
# 0.8482669252973938

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(norm_X_ds)
data_X_tsne = np.vstack((X_tsne.T, y)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ####MixUp

# %%
def mixup(data):
  view = data.copy()
  for i in range(len(view)):
    random_row_index = random.randint(0, len(view)-1)
    view[i] = view[i]*0.5  + view[random_row_index]*0.5
  return view

# %% [markdown]
# ####MixCut

# %%
def mixcut(data):
  data_copy = data.copy()
  view = data.copy()
  mask_len = 100

  for i in range(len(data_copy)):
    random_row_id = random.randint(0, len(data_copy)-1)
    random_column_id = random.randint(0, data_copy.shape[1]-mask_len)
    view[i,random_column_id:(random_column_id+mask_len)] = data_copy[random_row_id,random_column_id:(random_column_id+mask_len)]
  return view

# %% [markdown]
# #### Masking with mean

# %%
def get_random_indices(data, portion_of_mask):
  return np.random.choice(data.shape[1], size=np.floor(data.shape[1]*portion_of_mask).astype(int), replace=False)

# %%
def masking_with_mean(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = column_mu[j]
              
  return view

# %% [markdown]
# ####Masking with random value in domain range

# %%
def masking_with_random(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)
  column_min = np.minimum(data)
  column_max = np.maximum(data)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = random.randint(column_min[j], column_max[j])
              
  return view

# %% [markdown]
# ####Masking with margin distribution

# %%
def masking_with_margin_distribution(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = np.random.normal(column_mu[j], column_std[j])
              
  return view

# %% [markdown]
# ####Upsampling (SMOTE like)

# %%
#put all data points in kd-tree for fast searching
kdtree = KDTree(norm_X_ds, leaf_size=2)

# %%
#get random point in the k nearest neighbors
def get_idx_random_knn(x,k):
   _, ids = kdtree.query(x.reshape(1, -1), k=k)
   ids = ids.flatten()
   ids = ids[1:-1]
   random_id = np.random.choice(ids, 1)
   return random_id

# %%
#mix up with a random near neighbor 
def mixup_random_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = 0.5*data[i] + 0.5*data[random_neighbor_id]
  return view

# %%
#a random neighbor as augmentation
def random_near_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = data[random_neighbor_id]
  return view

# %% [markdown]
# ##Create Model and Train with Augmented Data

# %%
class MyDataSet(Dataset):
  def __init__(self, view1, view2):
 
    X_view1 = view1.copy()
    X_view2 = view2.copy()
    self.X_view1 = X_view1.copy().astype(np.float32)
    self.X_view2 = X_view2.copy().astype(np.float32)
  
  def __len__(self):
    return len(self.X_view1)
  
  def __getitem__(self, idx):
    return self.X_view1[idx], self.X_view2[idx]

# %%
# define the NN architecture
class convBackbone(nn.Module):
    def __init__(self):
        super(convBackbone, self).__init__()

        #turn on dropout for testing the 'cropping' data augmentation
        #self.dropout = nn.Dropout(p=0.1)
        
        self.fc1 = nn.Linear(12, 12, bias=False)
        self.bn1 = nn.BatchNorm1d(12)

        self.fc2 = nn.Linear(12, 12, bias=False)
        self.bn2 = nn.BatchNorm1d(12)

        self.fc3 = nn.Linear(12, 12, bias=False)
        self.bn3 = nn.BatchNorm1d(12)


    def forward(self, x):

        #turn on dropout for testing the 'cropping' data augmentation
        #x = self.dropout(x)

        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.bn3(self.fc3(x))
                
        return x

# %%
class SimCLR(nn.Module):
    def __init__(self, backbone):
        super().__init__()
        self.backbone = backbone
        self.projection_head = SimCLRProjectionHead(12, 8, 12)

    def forward(self, x):
        x = self.backbone(x).flatten(start_dim=1)
        z = self.projection_head(x)
        return x,z

backbone = convBackbone()
model = SimCLR(backbone)

# %%
criterion = NTXentLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.05, momentum=0.9,weight_decay=1e-4)

#cosine annealing lr
scheduler = lr_scheduler.CosineAnnealingLR(optimizer,T_max=500, eta_min=0)

# %%
view1 = random_near_neighbor(norm_X_ds, 20)
view2 = random_near_neighbor(norm_X_ds, 25)

#turn on the following to test other augmentations

#view1 = mixup_random_neighbor(X_ds, 15)
#view2 = mixup_random_neighbor(X_ds, 15)

#view1 = mixup(X_ds)
#view2 = mixup(X_ds)

#view1 = mixcut(X_ds)
#view2 = mixcut(X_ds)

#view1 = masking_with_mean(X_ds, 0.4)
#view2 = masking_with_mean(X_ds, 0.4)

#view1 = masking_with_random(X_ds, 0.4)
#view2 = masking_with_random(X_ds, 0.4)

#view1 = masking_with_margin_distribution(X_ds, 0.4)
#view2 = masking_with_margin_distribution(X_ds, 0.4)

train_ds = MyDataSet(view1, view2)
train_dl = DataLoader(train_ds, batch_size=256, shuffle=True)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

for epoch in range(500):
    total_loss = 0
    for x0, x1 in train_dl:

        x0 = x0.to(device)
        x1 = x1.to(device)
        _,z0 = model(x0)
        _,z1 = model(x1)

        z0 = (z0 - torch.mean(z0,0)) / torch.std(z0,0)
        z1 = (z1 - torch.mean(z1,0)) / torch.std(z1,0)

        loss = criterion(z0, z1)
        total_loss += loss.detach()
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    avg_loss = total_loss / len(train_dl)
    print(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
# Out:
# epoch: 00, loss: 5.06489
# epoch: 01, loss: 4.89287
# epoch: 02, loss: 4.84957
# epoch: 03, loss: 4.83406
# epoch: 04, loss: 4.82176
# epoch: 05, loss: 4.81049
# epoch: 06, loss: 4.80196
# epoch: 07, loss: 4.79682
# epoch: 08, loss: 4.79347
# epoch: 09, loss: 4.79093
# epoch: 10, loss: 4.78748
# epoch: 11, loss: 4.78702
# epoch: 12, loss: 4.78467
# epoch: 13, loss: 4.78622
# epoch: 14, loss: 4.78096
# epoch: 15, loss: 4.78177
# epoch: 16, loss: 4.78072
# epoch: 17, loss: 4.77879
# epoch: 18, loss: 4.77925
# epoch: 19, loss: 4.77766
# epoch: 20, loss: 4.77683
# epoch: 21, loss: 4.77379
# epoch: 22, loss: 4.77643
# epoch: 23, loss: 4.77474
# epoch: 24, loss: 4.77293
# epoch: 25, loss: 4.77154
# epoch: 26, loss: 4.77212
# epoch: 27, loss: 4.77267
# epoch: 28, loss: 4.76991
# epoch: 29, loss: 4.76871
# epoch: 30, loss: 4.76935
# epoch: 31, loss: 4.77099
# epoch: 32, loss: 4.76835
# epoch: 33, loss: 4.76959
# epoch: 34, loss: 4.77014
# epoch: 35, loss: 4.76562
# epoch: 36, loss: 4.76651
# epoch: 37, loss: 4.77061
# epoch: 38, loss: 4.76864
# epoch: 39, loss: 4.76757
# epoch: 40, loss: 4.76637
# epoch: 41, loss: 4.76530
# epoch: 42, loss: 4.76813
# epoch: 43, loss: 4.76326
# epoch: 44, loss: 4.76592
# epoch: 45, loss: 4.76399
# epoch: 46, loss: 4.76442
# epoch: 47, loss: 4.76504
# epoch: 48, loss: 4.76454
# epoch: 49, loss: 4.76358
# epoch: 50, loss: 4.76369
# epoch: 51, loss: 4.76338
# epoch: 52, loss: 4.76359
# epoch: 53, loss: 4.76374
# epoch: 54, loss: 4.76313
# epoch: 55, loss: 4.76224
# epoch: 56, loss: 4.76345
# epoch: 57, loss: 4.76229
# epoch: 58, loss: 4.76139
# epoch: 59, loss: 4.75933
# epoch: 60, loss: 4.76220
# epoch: 61, loss: 4.76136
# epoch: 62, loss: 4.76137
# epoch: 63, loss: 4.76129
# epoch: 64, loss: 4.76161
# epoch: 65, loss: 4.76290
# epoch: 66, loss: 4.76111
# epoch: 67, loss: 4.76311
# epoch: 68, loss: 4.76347
# epoch: 69, loss: 4.76198
# epoch: 70, loss: 4.76080
# epoch: 71, loss: 4.75866
# epoch: 72, loss: 4.76062
# epoch: 73, loss: 4.76174
# epoch: 74, loss: 4.76163
# epoch: 75, loss: 4.75913
# epoch: 76, loss: 4.76153
# epoch: 77, loss: 4.75890
# epoch: 78, loss: 4.76255
# epoch: 79, loss: 4.75955
# epoch: 80, loss: 4.75932
# epoch: 81, loss: 4.75839
# epoch: 82, loss: 4.76010
# epoch: 83, loss: 4.75762
# epoch: 84, loss: 4.76000
# epoch: 85, loss: 4.76083
# epoch: 86, loss: 4.76157
# epoch: 87, loss: 4.75991
# epoch: 88, loss: 4.75971
# epoch: 89, loss: 4.76012
# epoch: 90, loss: 4.75987
# epoch: 91, loss: 4.75982
# epoch: 92, loss: 4.75907
# epoch: 93, loss: 4.75606
# epoch: 94, loss: 4.75767
# epoch: 95, loss: 4.75776
# epoch: 96, loss: 4.75856
# epoch: 97, loss: 4.75800
# epoch: 98, loss: 4.75805
# epoch: 99, loss: 4.75929
# epoch: 100, loss: 4.75771
# epoch: 101, loss: 4.75629
# epoch: 102, loss: 4.75621
# epoch: 103, loss: 4.75386
# epoch: 104, loss: 4.75784
# epoch: 105, loss: 4.75650
# epoch: 106, loss: 4.75561
# epoch: 107, loss: 4.75740
# epoch: 108, loss: 4.75932
# epoch: 109, loss: 4.75525
# epoch: 110, loss: 4.75673
# epoch: 111, loss: 4.75692
# epoch: 112, loss: 4.75477
# epoch: 113, loss: 4.75715
# epoch: 114, loss: 4.75686
# epoch: 115, loss: 4.75501
# epoch: 116, loss: 4.75574
# epoch: 117, loss: 4.75628
# epoch: 118, loss: 4.75562
# epoch: 119, loss: 4.75695
# epoch: 120, loss: 4.75705
# epoch: 121, loss: 4.75473
# epoch: 122, loss: 4.75435
# epoch: 123, loss: 4.76003
# epoch: 124, loss: 4.75643
# epoch: 125, loss: 4.75735
# epoch: 126, loss: 4.75668
# epoch: 127, loss: 4.75588
# epoch: 128, loss: 4.75653
# epoch: 129, loss: 4.75450
# epoch: 130, loss: 4.75689
# epoch: 131, loss: 4.75262
# epoch: 132, loss: 4.75295
# epoch: 133, loss: 4.75266
# epoch: 134, loss: 4.75178
# epoch: 135, loss: 4.75533
# epoch: 136, loss: 4.75294
# epoch: 137, loss: 4.75506
# epoch: 138, loss: 4.75333
# epoch: 139, loss: 4.75285
# epoch: 140, loss: 4.75457
# epoch: 141, loss: 4.75441
# epoch: 142, loss: 4.75412
# epoch: 143, loss: 4.75549
# epoch: 144, loss: 4.75509
# epoch: 145, loss: 4.75401
# epoch: 146, loss: 4.75211
# epoch: 147, loss: 4.75513
# epoch: 148, loss: 4.75285
# epoch: 149, loss: 4.75496
# epoch: 150, loss: 4.75234
# epoch: 151, loss: 4.75343
# epoch: 152, loss: 4.75303
# epoch: 153, loss: 4.75083
# epoch: 154, loss: 4.75277
# epoch: 155, loss: 4.75491
# epoch: 156, loss: 4.75187
# epoch: 157, loss: 4.75284
# epoch: 158, loss: 4.75222
# epoch: 159, loss: 4.75279
# epoch: 160, loss: 4.75284
# epoch: 161, loss: 4.75139
# epoch: 162, loss: 4.75270
# epoch: 163, loss: 4.75360
# epoch: 164, loss: 4.75210
# epoch: 165, loss: 4.75238
# epoch: 166, loss: 4.75297
# epoch: 167, loss: 4.75408
# epoch: 168, loss: 4.75662
# epoch: 169, loss: 4.75101
# epoch: 170, loss: 4.75220
# epoch: 171, loss: 4.75399
# epoch: 172, loss: 4.75334
# epoch: 173, loss: 4.75085
# epoch: 174, loss: 4.75160
# epoch: 175, loss: 4.75529
# epoch: 176, loss: 4.75263
# epoch: 177, loss: 4.75268
# epoch: 178, loss: 4.75162
# epoch: 179, loss: 4.75153
# epoch: 180, loss: 4.75242
# epoch: 181, loss: 4.75119
# epoch: 182, loss: 4.75245
# epoch: 183, loss: 4.75427
# epoch: 184, loss: 4.74961
# epoch: 185, loss: 4.75297
# epoch: 186, loss: 4.75451
# epoch: 187, loss: 4.75531
# epoch: 188, loss: 4.75528
# epoch: 189, loss: 4.75123
# epoch: 190, loss: 4.75226
# epoch: 191, loss: 4.75368
# epoch: 192, loss: 4.75271
# epoch: 193, loss: 4.75031
# epoch: 194, loss: 4.75316
# epoch: 195, loss: 4.75211
# epoch: 196, loss: 4.75312
# epoch: 197, loss: 4.75384
# epoch: 198, loss: 4.75052
# epoch: 199, loss: 4.75005
# epoch: 200, loss: 4.74845
# epoch: 201, loss: 4.75429
# epoch: 202, loss: 4.75230
# epoch: 203, loss: 4.75542
# epoch: 204, loss: 4.75085
# epoch: 205, loss: 4.75030
# epoch: 206, loss: 4.75151
# epoch: 207, loss: 4.75275
# epoch: 208, loss: 4.74956
# epoch: 209, loss: 4.75123
# epoch: 210, loss: 4.74897
# epoch: 211, loss: 4.75092
# epoch: 212, loss: 4.74899
# epoch: 213, loss: 4.74912
# epoch: 214, loss: 4.75041
# epoch: 215, loss: 4.75311
# epoch: 216, loss: 4.74984
# epoch: 217, loss: 4.75115
# epoch: 218, loss: 4.75052
# epoch: 219, loss: 4.74974
# epoch: 220, loss: 4.75372
# epoch: 221, loss: 4.75087
# epoch: 222, loss: 4.74977
# epoch: 223, loss: 4.75373
# epoch: 224, loss: 4.75013
# epoch: 225, loss: 4.75168
# epoch: 226, loss: 4.75388
# epoch: 227, loss: 4.75364
# epoch: 228, loss: 4.75003
# epoch: 229, loss: 4.75154
# epoch: 230, loss: 4.75187
# epoch: 231, loss: 4.74836
# epoch: 232, loss: 4.74890
# epoch: 233, loss: 4.75039
# epoch: 234, loss: 4.74713
# epoch: 235, loss: 4.74862
# epoch: 236, loss: 4.75007
# epoch: 237, loss: 4.75019
# epoch: 238, loss: 4.75296
# epoch: 239, loss: 4.75118
# epoch: 240, loss: 4.74885
# epoch: 241, loss: 4.74925
# epoch: 242, loss: 4.75126
# epoch: 243, loss: 4.74798
# epoch: 244, loss: 4.74953
# epoch: 245, loss: 4.74824
# epoch: 246, loss: 4.75094
# epoch: 247, loss: 4.75059
# epoch: 248, loss: 4.74583
# epoch: 249, loss: 4.74885
# epoch: 250, loss: 4.74827
# epoch: 251, loss: 4.74885
# epoch: 252, loss: 4.74929
# epoch: 253, loss: 4.75054
# epoch: 254, loss: 4.75023
# epoch: 255, loss: 4.74676
# epoch: 256, loss: 4.75128
# epoch: 257, loss: 4.74894
# epoch: 258, loss: 4.75334
# epoch: 259, loss: 4.75085
# epoch: 260, loss: 4.74844
# epoch: 261, loss: 4.75112
# epoch: 262, loss: 4.75023
# epoch: 263, loss: 4.74787
# epoch: 264, loss: 4.74763
# epoch: 265, loss: 4.74868
# epoch: 266, loss: 4.74886
# epoch: 267, loss: 4.74950
# epoch: 268, loss: 4.74816
# epoch: 269, loss: 4.75202
# epoch: 270, loss: 4.74937
# epoch: 271, loss: 4.74716
# epoch: 272, loss: 4.75029
# epoch: 273, loss: 4.74836
# epoch: 274, loss: 4.74918
# epoch: 275, loss: 4.74804
# epoch: 276, loss: 4.74866
# epoch: 277, loss: 4.74848
# epoch: 278, loss: 4.74799
# epoch: 279, loss: 4.75085
# epoch: 280, loss: 4.74813
# epoch: 281, loss: 4.74927
# epoch: 282, loss: 4.75161
# epoch: 283, loss: 4.74996
# epoch: 284, loss: 4.74854
# epoch: 285, loss: 4.74620
# epoch: 286, loss: 4.74999
# epoch: 287, loss: 4.74911
# epoch: 288, loss: 4.74705
# epoch: 289, loss: 4.74649
# epoch: 290, loss: 4.74827
# epoch: 291, loss: 4.75149
# epoch: 292, loss: 4.74867
# epoch: 293, loss: 4.74886
# epoch: 294, loss: 4.74969
# epoch: 295, loss: 4.74925
# epoch: 296, loss: 4.74708
# epoch: 297, loss: 4.74691
# epoch: 298, loss: 4.74896
# epoch: 299, loss: 4.74748
# epoch: 300, loss: 4.74693
# epoch: 301, loss: 4.74842
# epoch: 302, loss: 4.75072
# epoch: 303, loss: 4.74982
# epoch: 304, loss: 4.74905
# epoch: 305, loss: 4.74740
# epoch: 306, loss: 4.74639
# epoch: 307, loss: 4.74826
# epoch: 308, loss: 4.74695
# epoch: 309, loss: 4.74883
# epoch: 310, loss: 4.74891
# epoch: 311, loss: 4.75008
# epoch: 312, loss: 4.75073
# epoch: 313, loss: 4.74517
# epoch: 314, loss: 4.74518
# epoch: 315, loss: 4.74807
# epoch: 316, loss: 4.74818
# epoch: 317, loss: 4.74845
# epoch: 318, loss: 4.74717
# epoch: 319, loss: 4.75088
# epoch: 320, loss: 4.74985
# epoch: 321, loss: 4.74830
# epoch: 322, loss: 4.74844
# epoch: 323, loss: 4.74961
# epoch: 324, loss: 4.74879
# epoch: 325, loss: 4.74877
# epoch: 326, loss: 4.74597
# epoch: 327, loss: 4.74650
# epoch: 328, loss: 4.74917
# epoch: 329, loss: 4.74606
# epoch: 330, loss: 4.74824
# epoch: 331, loss: 4.74863
# epoch: 332, loss: 4.74678
# epoch: 333, loss: 4.74901
# epoch: 334, loss: 4.74966
# epoch: 335, loss: 4.74525
# epoch: 336, loss: 4.74681
# epoch: 337, loss: 4.74754
# epoch: 338, loss: 4.74801
# epoch: 339, loss: 4.75149
# epoch: 340, loss: 4.74645
# epoch: 341, loss: 4.74805
# epoch: 342, loss: 4.74945
# epoch: 343, loss: 4.74845
# epoch: 344, loss: 4.74829
# epoch: 345, loss: 4.74848
# epoch: 346, loss: 4.74674
# epoch: 347, loss: 4.74922
# epoch: 348, loss: 4.74877
# epoch: 349, loss: 4.74975
# epoch: 350, loss: 4.74745
# epoch: 351, loss: 4.74746
# epoch: 352, loss: 4.74763
# epoch: 353, loss: 4.74878
# epoch: 354, loss: 4.74958
# epoch: 355, loss: 4.74939
# epoch: 356, loss: 4.75197
# epoch: 357, loss: 4.74626
# epoch: 358, loss: 4.74680
# epoch: 359, loss: 4.74304
# epoch: 360, loss: 4.74592
# epoch: 361, loss: 4.74861
# epoch: 362, loss: 4.75021
# epoch: 363, loss: 4.74466
# epoch: 364, loss: 4.74954
# epoch: 365, loss: 4.74837
# epoch: 366, loss: 4.74824
# epoch: 367, loss: 4.74735
# epoch: 368, loss: 4.74690
# epoch: 369, loss: 4.74843
# epoch: 370, loss: 4.74771
# epoch: 371, loss: 4.74750
# epoch: 372, loss: 4.74708
# epoch: 373, loss: 4.74914
# epoch: 374, loss: 4.74716
# epoch: 375, loss: 4.74563
# epoch: 376, loss: 4.74477
# epoch: 377, loss: 4.74531
# epoch: 378, loss: 4.74782
# epoch: 379, loss: 4.74891
# epoch: 380, loss: 4.74722
# epoch: 381, loss: 4.74791
# epoch: 382, loss: 4.74523
# epoch: 383, loss: 4.74627
# epoch: 384, loss: 4.74748
# epoch: 385, loss: 4.74563
# epoch: 386, loss: 4.74657
# epoch: 387, loss: 4.74733
# epoch: 388, loss: 4.74504
# epoch: 389, loss: 4.74556
# epoch: 390, loss: 4.74575
# epoch: 391, loss: 4.74782
# epoch: 392, loss: 4.74532
# epoch: 393, loss: 4.74509
# epoch: 394, loss: 4.74853
# epoch: 395, loss: 4.74953
# epoch: 396, loss: 4.74774
# epoch: 397, loss: 4.74724
# epoch: 398, loss: 4.74818
# epoch: 399, loss: 4.74695
# epoch: 400, loss: 4.74617
# epoch: 401, loss: 4.74776
# epoch: 402, loss: 4.74693
# epoch: 403, loss: 4.74590
# epoch: 404, loss: 4.74642
# epoch: 405, loss: 4.74843
# epoch: 406, loss: 4.74349
# epoch: 407, loss: 4.74806
# epoch: 408, loss: 4.74531
# epoch: 409, loss: 4.74478
# epoch: 410, loss: 4.74651
# epoch: 411, loss: 4.74465
# epoch: 412, loss: 4.74580
# epoch: 413, loss: 4.74823
# epoch: 414, loss: 4.74884
# epoch: 415, loss: 4.74832
# epoch: 416, loss: 4.74858
# epoch: 417, loss: 4.74797
# epoch: 418, loss: 4.74726
# epoch: 419, loss: 4.74883
# epoch: 420, loss: 4.74481
# epoch: 421, loss: 4.74671
# epoch: 422, loss: 4.74675
# epoch: 423, loss: 4.74612
# epoch: 424, loss: 4.74541
# epoch: 425, loss: 4.74886
# epoch: 426, loss: 4.74535
# epoch: 427, loss: 4.74496
# epoch: 428, loss: 4.74875
# epoch: 429, loss: 4.74843
# epoch: 430, loss: 4.74454
# epoch: 431, loss: 4.74746
# epoch: 432, loss: 4.74586
# epoch: 433, loss: 4.74673
# epoch: 434, loss: 4.74782
# epoch: 435, loss: 4.74483
# epoch: 436, loss: 4.74446
# epoch: 437, loss: 4.74789
# epoch: 438, loss: 4.74652
# epoch: 439, loss: 4.74875
# epoch: 440, loss: 4.75074
# epoch: 441, loss: 4.74466
# epoch: 442, loss: 4.74861
# epoch: 443, loss: 4.74563
# epoch: 444, loss: 4.74740
# epoch: 445, loss: 4.74618
# epoch: 446, loss: 4.74560
# epoch: 447, loss: 4.74683
# epoch: 448, loss: 4.74613
# epoch: 449, loss: 4.74563
# epoch: 450, loss: 4.74569
# epoch: 451, loss: 4.74523
# epoch: 452, loss: 4.74637
# epoch: 453, loss: 4.74600
# epoch: 454, loss: 4.74770
# epoch: 455, loss: 4.74724
# epoch: 456, loss: 4.74885
# epoch: 457, loss: 4.74634
# epoch: 458, loss: 4.74599
# epoch: 459, loss: 4.74518
# epoch: 460, loss: 4.74618
# epoch: 461, loss: 4.74390
# epoch: 462, loss: 4.74719
# epoch: 463, loss: 4.74874
# epoch: 464, loss: 4.74457
# epoch: 465, loss: 4.74522
# epoch: 466, loss: 4.74457
# epoch: 467, loss: 4.74552
# epoch: 468, loss: 4.74503
# epoch: 469, loss: 4.74647
# epoch: 470, loss: 4.74683
# epoch: 471, loss: 4.74789
# epoch: 472, loss: 4.74564
# epoch: 473, loss: 4.74507
# epoch: 474, loss: 4.74586
# epoch: 475, loss: 4.74377
# epoch: 476, loss: 4.74748
# epoch: 477, loss: 4.74885
# epoch: 478, loss: 4.74747
# epoch: 479, loss: 4.74878
# epoch: 480, loss: 4.74690
# epoch: 481, loss: 4.74301
# epoch: 482, loss: 4.74518
# epoch: 483, loss: 4.74496
# epoch: 484, loss: 4.74455
# epoch: 485, loss: 4.74645
# epoch: 486, loss: 4.74866
# epoch: 487, loss: 4.74611
# epoch: 488, loss: 4.74309
# epoch: 489, loss: 4.74628
# epoch: 490, loss: 4.74530
# epoch: 491, loss: 4.74810
# epoch: 492, loss: 4.74643
# epoch: 493, loss: 4.74849
# epoch: 494, loss: 4.74887
# epoch: 495, loss: 4.74363
# epoch: 496, loss: 4.74703
# epoch: 497, loss: 4.74686
# epoch: 498, loss: 4.74710
# epoch: 499, loss: 4.74558

# %% [markdown]
# ##Check the Training Result

# %%
ds_cl= MyDataSet(norm_X_ds, norm_X_ds)
dl_cl = DataLoader(ds_cl, batch_size=256)

# %%
embeddings = []

# disable gradients for faster calculations
model.eval()
with torch.no_grad():
    for dl_cl1, dl_cl2 in dl_cl:

        dl_cl1 = dl_cl1.to(device)
        x,_ = model(dl_cl1)
        
        # store the embeddings in lists
        embeddings.append(x)

# concatenate the embeddings, targets and convert to numpy
embeddings = torch.cat(embeddings, dim=0)
embeddings = embeddings.cpu().numpy()

# %%
test = (embeddings - embeddings.mean(axis=0)) / (embeddings.std(axis=0))

# %%
#KMeans in latent space
kmeans_backbone = KMeans(n_clusters=2).fit(test)
kmeans_labels_backbone = kmeans_backbone.labels_

# %%
normalized_mutual_info_score(kmeans_labels_backbone, y)
# Out:
# 0.8868530582332784

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(test)
data_X_tsne = np.vstack((X_tsne.T, y)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#NMI increases from 0.84 to 0.88
