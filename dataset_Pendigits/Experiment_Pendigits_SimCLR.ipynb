# %% [markdown]
# ## Conifuration

# %%
#import the lib for contrastive learning framework
# !pip install lightly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lightly
#   Downloading lightly-1.2.20-py3-none-any.whl (451 kB)
#      |████████████████████████████████| 451 kB 4.4 MB/s
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.15.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.21.6)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.23.0)
# Collecting hydra-core>=1.0.0
#   Downloading hydra_core-1.2.0-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 11.2 MB/s
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.24.3)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from lightly) (0.12.0+cu113)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.8.2)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (57.4.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.7/dist-packages (from lightly) (2022.6.15)
# Collecting pytorch-lightning>=1.0.4
#   Downloading pytorch_lightning-1.6.4-py3-none-any.whl (585 kB)
#      |████████████████████████████████| 585 kB 11.7 MB/s
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.7/dist-packages (from lightly) (4.64.0)
# Collecting lightly-utils~=0.0.0
#   Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      |████████████████████████████████| 117 kB 23.6 MB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (5.7.1)
# Collecting omegaconf~=2.2
#   Downloading omegaconf-2.2.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 6.3 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (21.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from lightly-utils~=0.0.0->lightly) (7.1.2)
# Collecting PyYAML>=5.1.0
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 23.3 MB/s
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (4.1.1)
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.9.1-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 32.0 MB/s
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2.8.0)
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (3.17.3)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 16.6 MB/s
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 23.4 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->hydra-core>=1.0.0->lightly) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (2.10)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.3.7)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.1.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.6.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.46.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.37.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.0.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (21.4.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 4.2 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 37.1 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 37.7 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (2.0.12)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=2754775bcc2d1f80c58331ee327712d85502d598397b91b4918294bf1ef8555a
#   Stored in directory: /root/.cache/pip/wheels/8b/8d/53/2af8772d9aec614e3fc65e53d4a993ad73c61daa8bbd85a873
# Successfully built antlr4-python3-runtime
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, PyYAML, fsspec, antlr4-python3-runtime, aiohttp, torchmetrics, pyDeprecate, omegaconf, pytorch-lightning, lightly-utils, hydra-core, lightly
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-6.0 aiohttp-3.8.1 aiosignal-1.2.0 antlr4-python3-runtime-4.9.3 async-timeout-4.0.2 asynctest-0.13.0 frozenlist-1.3.0 fsspec-2022.5.0 hydra-core-1.2.0 lightly-1.2.20 lightly-utils-0.0.2 multidict-6.0.2 omegaconf-2.2.2 pyDeprecate-0.3.2 pytorch-lightning-1.6.4 torchmetrics-0.9.1 yarl-1.7.2

# %%
import lightly
from lightly.models.modules.heads import SimSiamPredictionHead
from lightly.models.modules.heads import SimSiamProjectionHead

from lightly.data import LightlyDataset
from lightly.data import ImageCollateFunction
from lightly.models.modules import BarlowTwinsProjectionHead
from lightly.loss import BarlowTwinsLoss

from lightly.data import LightlyDataset
from lightly.data import SimCLRCollateFunction
from lightly.loss import NTXentLoss
from lightly.loss import NegativeCosineSimilarity
from lightly.models.modules import SimCLRProjectionHead

# %%
import math
import torch
import torch.nn as nn
import torchvision
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from torch.utils.data import Dataset, DataLoader
import torch.optim as torch_optim
import torch.optim.lr_scheduler as lr_scheduler
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
from datetime import datetime

from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from matplotlib import pyplot
import seaborn as sns

from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_mutual_info_score
from sklearn.metrics import silhouette_score
from sklearn import mixture
from sklearn.cluster import DBSCAN
from sklearn.cluster import OPTICS
from sklearn.cluster import AgglomerativeClustering

import tensorboard
from tensorboard import notebook
from torch.utils.tensorboard import SummaryWriter

import matplotlib 
import matplotlib.pyplot as plt
#import plotly.express as px

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons
from sklearn.utils import shuffle

import torchvision.transforms as transforms
import torchvision.datasets as datasets
from sklearn.metrics.pairwise import cosine_similarity

import random
from torch.nn.modules.loss import MSELoss
from sklearn.neighbors import KDTree
#from kmodes.kprototypes import KPrototypes

from scipy.io.arff import loadarff
from sklearn.preprocessing import MinMaxScaler 
from sklearn.datasets import make_classification

# %% [markdown]
# ## Load Dataset Pendigits and Check Clustering Result with the Baseline Method Kmeans

# %%
# set the path to the dataset
path_to_data = '/content/drive/MyDrive/Colab_Notebooks/pendigits.csv'

# %%
data = pd.read_csv(path_to_data)

X_ds = data.copy()
X_ds = X_ds.drop(['class'], axis=1)
X_ds = pd.DataFrame(X_ds).to_numpy()

y_ds = data.copy()
y_ds = y_ds['class']

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X_ds)
data_X_tsne = np.vstack((X_tsne.T, y_ds)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#check the clustering result with Kmeans
kmeans_ori = KMeans(n_clusters=10).fit(X_ds)
kmeans_labels_ori = kmeans_ori.labels_

normalized_mutual_info_score(kmeans_labels_ori, y_ds)
# Out:
# 0.6930072473203124

# %%
#tsne = TSNE(n_components=2)
#X_tsne = tsne.fit_transform(X_ds)
data_X_tsne = np.vstack((X_tsne.T, kmeans_labels_ori)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ####MixUp

# %%
def mixup(data):
  view = data.copy()
  for i in range(len(view)):
    random_row_index = random.randint(0, len(view)-1)
    view[i] = view[i]*0.5  + view[random_row_index]*0.5
  return view

# %% [markdown]
# ####MixCut

# %%
def mixcut(data):
  data_copy = data.copy()
  view = data.copy()
  mask_len = 100

  for i in range(len(data_copy)):
    random_row_id = random.randint(0, len(data_copy)-1)
    random_column_id = random.randint(0, data_copy.shape[1]-mask_len)
    view[i,random_column_id:(random_column_id+mask_len)] = data_copy[random_row_id,random_column_id:(random_column_id+mask_len)]
  return view

# %% [markdown]
# #### Masking with mean

# %%
def get_random_indices(data, portion_of_mask):
  return np.random.choice(data.shape[1], size=np.floor(data.shape[1]*portion_of_mask).astype(int), replace=False)

# %%
def masking_with_mean(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = column_mu[j]
              
  return view

# %% [markdown]
# ####Masking with random value in domain range

# %%
def masking_with_random(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)
  column_min = np.minimum(data)
  column_max = np.maximum(data)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = random.randint(column_min[j], column_max[j])
              
  return view

# %% [markdown]
# ####Masking with margin distribution

# %%
def masking_with_margin_distribution(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = np.random.normal(column_mu[j], column_std[j])
              
  return view

# %% [markdown]
# ####Upsampling (SMOTE like)

# %%
#put all data points in kd-tree for fast searching
kdtree = KDTree(X_ds, leaf_size=2)

# %%
#get random point in the k nearest neighbors
def get_idx_random_knn(x,k):
   _, ids = kdtree.query(x.reshape(1, -1), k=k)
   ids = ids.flatten()
   ids = ids[1:-1]
   random_id = np.random.choice(ids, 1)
   return random_id

# %%
#mix up with a random near neighbor 
def mixup_random_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = 0.5*data[i] + 0.5*data[random_neighbor_id]
  return view

# %%
#a random neighbor as augmentation
def random_near_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = data[random_neighbor_id]
  return view

# %% [markdown]
# ##Create Model and Train with Augmented Data

# %%
class MyDataSet(Dataset):
  def __init__(self, view1, view2):
 
    X_view1 = view1.copy()
    X_view2 = view2.copy()
    self.X_view1 = X_view1.copy().astype(np.float32)
    self.X_view2 = X_view2.copy().astype(np.float32)
  
  def __len__(self):
    return len(self.X_view1)
  
  def __getitem__(self, idx):
    return self.X_view1[idx], self.X_view2[idx]

# %%
# define the NN architecture
class convBackbone(nn.Module):
    def __init__(self):
        super(convBackbone, self).__init__()

        #turn on dropout for testing the 'cropping' data augmentation 
        #self.dropout = nn.Dropout(p=0.1)
        
        self.fc1 = nn.Linear(16, 16, bias=False)
        self.bn1 = nn.BatchNorm1d(16)

        self.fc2 = nn.Linear(16, 16, bias=False)
        self.bn2 = nn.BatchNorm1d(16)

        self.fc3 = nn.Linear(16, 8, bias=False)
        self.bn3 = nn.BatchNorm1d(8)


    def forward(self, x):

        #turn on dropout for testing the 'cropping' data augmentation 
        #x = self.dropout(x)
        
        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.bn3(self.fc3(x))
                
        return x

# %%
class SimCLR(nn.Module):
    def __init__(self, backbone):
        super().__init__()
        self.backbone = backbone
        self.projection_head = SimCLRProjectionHead(8, 4, 8)

    def forward(self, x):
        x = self.backbone(x).flatten(start_dim=1)
        z = self.projection_head(x)
        return x,z

backbone = convBackbone()
model = SimCLR(backbone)

# %%
criterion = NTXentLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.05, momentum=0.9,weight_decay=1e-4)

#cosine annealing lr
scheduler = lr_scheduler.CosineAnnealingLR(optimizer,T_max=800, eta_min=0)

# %%
view1 = random_near_neighbor(X_ds, 18)
view2 = random_near_neighbor(X_ds, 19)

#turn on the following to test other augmentations

#view1 = mixup_random_neighbor(X_ds, 15)
#view2 = mixup_random_neighbor(X_ds, 15)

#view1 = mixup(X_ds)
#view2 = mixup(X_ds)

#view1 = mixcut(X_ds)
#view2 = mixcut(X_ds)

#view1 = masking_with_mean(X_ds, 0.4)
#view2 = masking_with_mean(X_ds, 0.4)

#view1 = masking_with_random(X_ds, 0.4)
#view2 = masking_with_random(X_ds, 0.4)

#view1 = masking_with_margin_distribution(X_ds, 0.4)
#view2 = masking_with_margin_distribution(X_ds, 0.4)

train_ds = MyDataSet(view1, view2)
train_dl = DataLoader(train_ds, batch_size=256, shuffle=True)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

for epoch in range(500):
    total_loss = 0
    for x0, x1 in train_dl:

        x0 = x0.to(device)
        x1 = x1.to(device)
        _,z0 = model(x0)
        _,z1 = model(x1)

        loss = criterion(z0, z1)
        total_loss += loss.detach()
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        scheduler.step()

    avg_loss = total_loss / len(train_dl)
    print(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
# Out:
# epoch: 00, loss: 6.00204
# epoch: 01, loss: 5.59302
# epoch: 02, loss: 5.50770
# epoch: 03, loss: 5.46121
# epoch: 04, loss: 5.44572
# epoch: 05, loss: 5.43963
# epoch: 06, loss: 5.43309
# epoch: 07, loss: 5.42970
# epoch: 08, loss: 5.42678
# epoch: 09, loss: 5.42320
# epoch: 10, loss: 5.42071
# epoch: 11, loss: 5.41926
# epoch: 12, loss: 5.41830
# epoch: 13, loss: 5.41727
# epoch: 14, loss: 5.41671
# epoch: 15, loss: 5.41559
# epoch: 16, loss: 5.41513
# epoch: 17, loss: 5.41415
# epoch: 18, loss: 5.41446
# epoch: 19, loss: 5.41335
# epoch: 20, loss: 5.41453
# epoch: 21, loss: 5.41362
# epoch: 22, loss: 5.41377
# epoch: 23, loss: 5.41316
# epoch: 24, loss: 5.41305
# epoch: 25, loss: 5.41344
# epoch: 26, loss: 5.41357
# epoch: 27, loss: 5.41420
# epoch: 28, loss: 5.41330
# epoch: 29, loss: 5.41422
# epoch: 30, loss: 5.41305
# epoch: 31, loss: 5.41298
# epoch: 32, loss: 5.41305
# epoch: 33, loss: 5.41182
# epoch: 34, loss: 5.41063
# epoch: 35, loss: 5.41172
# epoch: 36, loss: 5.41074
# epoch: 37, loss: 5.40971
# epoch: 38, loss: 5.41037
# epoch: 39, loss: 5.40944
# epoch: 40, loss: 5.40787
# epoch: 41, loss: 5.40835
# epoch: 42, loss: 5.40746
# epoch: 43, loss: 5.40709
# epoch: 44, loss: 5.40813
# epoch: 45, loss: 5.40730
# epoch: 46, loss: 5.40628
# epoch: 47, loss: 5.40581
# epoch: 48, loss: 5.40580
# epoch: 49, loss: 5.40462
# epoch: 50, loss: 5.40443
# epoch: 51, loss: 5.40316
# epoch: 52, loss: 5.40338
# epoch: 53, loss: 5.40310
# epoch: 54, loss: 5.40314
# epoch: 55, loss: 5.40227
# epoch: 56, loss: 5.40157
# epoch: 57, loss: 5.40205
# epoch: 58, loss: 5.40241
# epoch: 59, loss: 5.40122
# epoch: 60, loss: 5.40081
# epoch: 61, loss: 5.40202
# epoch: 62, loss: 5.40107
# epoch: 63, loss: 5.39994
# epoch: 64, loss: 5.40018
# epoch: 65, loss: 5.40051
# epoch: 66, loss: 5.40026
# epoch: 67, loss: 5.40064
# epoch: 68, loss: 5.40018
# epoch: 69, loss: 5.40016
# epoch: 70, loss: 5.39996
# epoch: 71, loss: 5.40029
# epoch: 72, loss: 5.40075
# epoch: 73, loss: 5.40053
# epoch: 74, loss: 5.40081
# epoch: 75, loss: 5.40101
# epoch: 76, loss: 5.40119
# epoch: 77, loss: 5.40150
# epoch: 78, loss: 5.40085
# epoch: 79, loss: 5.40102
# epoch: 80, loss: 5.39971
# epoch: 81, loss: 5.40130
# epoch: 82, loss: 5.40106
# epoch: 83, loss: 5.40090
# epoch: 84, loss: 5.40067
# epoch: 85, loss: 5.40079
# epoch: 86, loss: 5.40077
# epoch: 87, loss: 5.40132
# epoch: 88, loss: 5.40035
# epoch: 89, loss: 5.40091
# epoch: 90, loss: 5.39944
# epoch: 91, loss: 5.39935
# epoch: 92, loss: 5.39978
# epoch: 93, loss: 5.40126
# epoch: 94, loss: 5.39916
# epoch: 95, loss: 5.39903
# epoch: 96, loss: 5.39836
# epoch: 97, loss: 5.39871
# epoch: 98, loss: 5.39811
# epoch: 99, loss: 5.39747
# epoch: 100, loss: 5.39763
# epoch: 101, loss: 5.39727
# epoch: 102, loss: 5.39827
# epoch: 103, loss: 5.39686
# epoch: 104, loss: 5.39715
# epoch: 105, loss: 5.39664
# epoch: 106, loss: 5.39751
# epoch: 107, loss: 5.39745
# epoch: 108, loss: 5.39707
# epoch: 109, loss: 5.39689
# epoch: 110, loss: 5.39639
# epoch: 111, loss: 5.39638
# epoch: 112, loss: 5.39626
# epoch: 113, loss: 5.39712
# epoch: 114, loss: 5.39722
# epoch: 115, loss: 5.39687
# epoch: 116, loss: 5.39696
# epoch: 117, loss: 5.39715
# epoch: 118, loss: 5.39699
# epoch: 119, loss: 5.39663
# epoch: 120, loss: 5.39738
# epoch: 121, loss: 5.39651
# epoch: 122, loss: 5.39658
# epoch: 123, loss: 5.39788
# epoch: 124, loss: 5.39691
# epoch: 125, loss: 5.39658
# epoch: 126, loss: 5.39733
# epoch: 127, loss: 5.39677
# epoch: 128, loss: 5.39868
# epoch: 129, loss: 5.39912
# epoch: 130, loss: 5.39729
# epoch: 131, loss: 5.39763
# epoch: 132, loss: 5.39788
# epoch: 133, loss: 5.39810
# epoch: 134, loss: 5.39809
# epoch: 135, loss: 5.39877
# epoch: 136, loss: 5.39746
# epoch: 137, loss: 5.39846
# epoch: 138, loss: 5.39678
# epoch: 139, loss: 5.39745
# epoch: 140, loss: 5.39774
# epoch: 141, loss: 5.39693
# epoch: 142, loss: 5.39710
# epoch: 143, loss: 5.39652
# epoch: 144, loss: 5.39669
# epoch: 145, loss: 5.39621
# epoch: 146, loss: 5.39596
# epoch: 147, loss: 5.39631
# epoch: 148, loss: 5.39625
# epoch: 149, loss: 5.39531
# epoch: 150, loss: 5.39522
# epoch: 151, loss: 5.39527
# epoch: 152, loss: 5.39613
# epoch: 153, loss: 5.39477
# epoch: 154, loss: 5.39540
# epoch: 155, loss: 5.39510
# epoch: 156, loss: 5.39463
# epoch: 157, loss: 5.39498
# epoch: 158, loss: 5.39457
# epoch: 159, loss: 5.39492
# epoch: 160, loss: 5.39472
# epoch: 161, loss: 5.39480
# epoch: 162, loss: 5.39513
# epoch: 163, loss: 5.39519
# epoch: 164, loss: 5.39506
# epoch: 165, loss: 5.39507
# epoch: 166, loss: 5.39571
# epoch: 167, loss: 5.39557
# epoch: 168, loss: 5.39491
# epoch: 169, loss: 5.39502
# epoch: 170, loss: 5.39611
# epoch: 171, loss: 5.39566
# epoch: 172, loss: 5.39595
# epoch: 173, loss: 5.39615
# epoch: 174, loss: 5.39676
# epoch: 175, loss: 5.39632
# epoch: 176, loss: 5.39588
# epoch: 177, loss: 5.39690
# epoch: 178, loss: 5.39581
# epoch: 179, loss: 5.39672
# epoch: 180, loss: 5.39668
# epoch: 181, loss: 5.39588
# epoch: 182, loss: 5.39698
# epoch: 183, loss: 5.39599
# epoch: 184, loss: 5.39529
# epoch: 185, loss: 5.39648
# epoch: 186, loss: 5.39589
# epoch: 187, loss: 5.39588
# epoch: 188, loss: 5.39538
# epoch: 189, loss: 5.39654
# epoch: 190, loss: 5.39582
# epoch: 191, loss: 5.39574
# epoch: 192, loss: 5.39543
# epoch: 193, loss: 5.39383
# epoch: 194, loss: 5.39511
# epoch: 195, loss: 5.39545
# epoch: 196, loss: 5.39467
# epoch: 197, loss: 5.39445
# epoch: 198, loss: 5.39420
# epoch: 199, loss: 5.39369
# epoch: 200, loss: 5.39379
# epoch: 201, loss: 5.39400
# epoch: 202, loss: 5.39423
# epoch: 203, loss: 5.39385
# epoch: 204, loss: 5.39404
# epoch: 205, loss: 5.39313
# epoch: 206, loss: 5.39382
# epoch: 207, loss: 5.39329
# epoch: 208, loss: 5.39391
# epoch: 209, loss: 5.39341
# epoch: 210, loss: 5.39393
# epoch: 211, loss: 5.39379
# epoch: 212, loss: 5.39442
# epoch: 213, loss: 5.39392
# epoch: 214, loss: 5.39510
# epoch: 215, loss: 5.39504
# epoch: 216, loss: 5.39440
# epoch: 217, loss: 5.39568
# epoch: 218, loss: 5.39519
# epoch: 219, loss: 5.39566
# epoch: 220, loss: 5.39543
# epoch: 221, loss: 5.39569
# epoch: 222, loss: 5.39557
# epoch: 223, loss: 5.39516
# epoch: 224, loss: 5.39496
# epoch: 225, loss: 5.39529
# epoch: 226, loss: 5.39479
# epoch: 227, loss: 5.39523
# epoch: 228, loss: 5.39646
# epoch: 229, loss: 5.39688
# epoch: 230, loss: 5.39597
# epoch: 231, loss: 5.39492
# epoch: 232, loss: 5.39563
# epoch: 233, loss: 5.39511
# epoch: 234, loss: 5.39419
# epoch: 235, loss: 5.39490
# epoch: 236, loss: 5.39480
# epoch: 237, loss: 5.39497
# epoch: 238, loss: 5.39439
# epoch: 239, loss: 5.39428
# epoch: 240, loss: 5.39435
# epoch: 241, loss: 5.39401
# epoch: 242, loss: 5.39348
# epoch: 243, loss: 5.39392
# epoch: 244, loss: 5.39308
# epoch: 245, loss: 5.39376
# epoch: 246, loss: 5.39293
# epoch: 247, loss: 5.39381
# epoch: 248, loss: 5.39351
# epoch: 249, loss: 5.39344
# epoch: 250, loss: 5.39346
# epoch: 251, loss: 5.39345
# epoch: 252, loss: 5.39314
# epoch: 253, loss: 5.39391
# epoch: 254, loss: 5.39381
# epoch: 255, loss: 5.39302
# epoch: 256, loss: 5.39336
# epoch: 257, loss: 5.39390
# epoch: 258, loss: 5.39381
# epoch: 259, loss: 5.39418
# epoch: 260, loss: 5.39413
# epoch: 261, loss: 5.39389
# epoch: 262, loss: 5.39450
# epoch: 263, loss: 5.39409
# epoch: 264, loss: 5.39485
# epoch: 265, loss: 5.39561
# epoch: 266, loss: 5.39534
# epoch: 267, loss: 5.39528
# epoch: 268, loss: 5.39470
# epoch: 269, loss: 5.39426
# epoch: 270, loss: 5.39535
# epoch: 271, loss: 5.39544
# epoch: 272, loss: 5.39449
# epoch: 273, loss: 5.39645
# epoch: 274, loss: 5.39408
# epoch: 275, loss: 5.39459
# epoch: 276, loss: 5.39407
# epoch: 277, loss: 5.39502
# epoch: 278, loss: 5.39550
# epoch: 279, loss: 5.39527
# epoch: 280, loss: 5.39420
# epoch: 281, loss: 5.39462
# epoch: 282, loss: 5.39468
# epoch: 283, loss: 5.39454
# epoch: 284, loss: 5.39404
# epoch: 285, loss: 5.39363
# epoch: 286, loss: 5.39316
# epoch: 287, loss: 5.39403
# epoch: 288, loss: 5.39334
# epoch: 289, loss: 5.39262
# epoch: 290, loss: 5.39325
# epoch: 291, loss: 5.39344
# epoch: 292, loss: 5.39357
# epoch: 293, loss: 5.39345
# epoch: 294, loss: 5.39278
# epoch: 295, loss: 5.39295
# epoch: 296, loss: 5.39369
# epoch: 297, loss: 5.39383
# epoch: 298, loss: 5.39284
# epoch: 299, loss: 5.39335
# epoch: 300, loss: 5.39295
# epoch: 301, loss: 5.39288
# epoch: 302, loss: 5.39245
# epoch: 303, loss: 5.39324
# epoch: 304, loss: 5.39313
# epoch: 305, loss: 5.39309
# epoch: 306, loss: 5.39403
# epoch: 307, loss: 5.39352
# epoch: 308, loss: 5.39488
# epoch: 309, loss: 5.39455
# epoch: 310, loss: 5.39519
# epoch: 311, loss: 5.39440
# epoch: 312, loss: 5.39409
# epoch: 313, loss: 5.39566
# epoch: 314, loss: 5.39465
# epoch: 315, loss: 5.39458
# epoch: 316, loss: 5.39539
# epoch: 317, loss: 5.39503
# epoch: 318, loss: 5.39485
# epoch: 319, loss: 5.39536
# epoch: 320, loss: 5.39447
# epoch: 321, loss: 5.39433
# epoch: 322, loss: 5.39452
# epoch: 323, loss: 5.39508
# epoch: 324, loss: 5.39406
# epoch: 325, loss: 5.39434
# epoch: 326, loss: 5.39334
# epoch: 327, loss: 5.39365
# epoch: 328, loss: 5.39408
# epoch: 329, loss: 5.39310
# epoch: 330, loss: 5.39285
# epoch: 331, loss: 5.39472
# epoch: 332, loss: 5.39304
# epoch: 333, loss: 5.39312
# epoch: 334, loss: 5.39323
# epoch: 335, loss: 5.39252
# epoch: 336, loss: 5.39305
# epoch: 337, loss: 5.39312
# epoch: 338, loss: 5.39251
# epoch: 339, loss: 5.39217
# epoch: 340, loss: 5.39219
# epoch: 341, loss: 5.39328
# epoch: 342, loss: 5.39260
# epoch: 343, loss: 5.39254
# epoch: 344, loss: 5.39231
# epoch: 345, loss: 5.39208
# epoch: 346, loss: 5.39258
# epoch: 347, loss: 5.39261
# epoch: 348, loss: 5.39196
# epoch: 349, loss: 5.39367
# epoch: 350, loss: 5.39351
# epoch: 351, loss: 5.39301
# epoch: 352, loss: 5.39336
# epoch: 353, loss: 5.39375
# epoch: 354, loss: 5.39365
# epoch: 355, loss: 5.39452
# epoch: 356, loss: 5.39423
# epoch: 357, loss: 5.39512
# epoch: 358, loss: 5.39488
# epoch: 359, loss: 5.39513
# epoch: 360, loss: 5.39473
# epoch: 361, loss: 5.39433
# epoch: 362, loss: 5.39348
# epoch: 363, loss: 5.39409
# epoch: 364, loss: 5.39291
# epoch: 365, loss: 5.39450
# epoch: 366, loss: 5.39456
# epoch: 367, loss: 5.39406
# epoch: 368, loss: 5.39522
# epoch: 369, loss: 5.39487
# epoch: 370, loss: 5.39388
# epoch: 371, loss: 5.39347
# epoch: 372, loss: 5.39443
# epoch: 373, loss: 5.39312
# epoch: 374, loss: 5.39290
# epoch: 375, loss: 5.39347
# epoch: 376, loss: 5.39332
# epoch: 377, loss: 5.39305
# epoch: 378, loss: 5.39217
# epoch: 379, loss: 5.39234
# epoch: 380, loss: 5.39342
# epoch: 381, loss: 5.39207
# epoch: 382, loss: 5.39259
# epoch: 383, loss: 5.39196
# epoch: 384, loss: 5.39230
# epoch: 385, loss: 5.39229
# epoch: 386, loss: 5.39206
# epoch: 387, loss: 5.39324
# epoch: 388, loss: 5.39255
# epoch: 389, loss: 5.39234
# epoch: 390, loss: 5.39246
# epoch: 391, loss: 5.39235
# epoch: 392, loss: 5.39253
# epoch: 393, loss: 5.39323
# epoch: 394, loss: 5.39327
# epoch: 395, loss: 5.39296
# epoch: 396, loss: 5.39264
# epoch: 397, loss: 5.39256
# epoch: 398, loss: 5.39338
# epoch: 399, loss: 5.39305
# epoch: 400, loss: 5.39370
# epoch: 401, loss: 5.39421
# epoch: 402, loss: 5.39379
# epoch: 403, loss: 5.39323
# epoch: 404, loss: 5.39369
# epoch: 405, loss: 5.39401
# epoch: 406, loss: 5.39386
# epoch: 407, loss: 5.39408
# epoch: 408, loss: 5.39403
# epoch: 409, loss: 5.39477
# epoch: 410, loss: 5.39476
# epoch: 411, loss: 5.39459
# epoch: 412, loss: 5.39346
# epoch: 413, loss: 5.39439
# epoch: 414, loss: 5.39477
# epoch: 415, loss: 5.39387
# epoch: 416, loss: 5.39328
# epoch: 417, loss: 5.39341
# epoch: 418, loss: 5.39399
# epoch: 419, loss: 5.39400
# epoch: 420, loss: 5.39309
# epoch: 421, loss: 5.39330
# epoch: 422, loss: 5.39257
# epoch: 423, loss: 5.39336
# epoch: 424, loss: 5.39280
# epoch: 425, loss: 5.39239
# epoch: 426, loss: 5.39173
# epoch: 427, loss: 5.39278
# epoch: 428, loss: 5.39221
# epoch: 429, loss: 5.39179
# epoch: 430, loss: 5.39247
# epoch: 431, loss: 5.39256
# epoch: 432, loss: 5.39174
# epoch: 433, loss: 5.39236
# epoch: 434, loss: 5.39214
# epoch: 435, loss: 5.39158
# epoch: 436, loss: 5.39208
# epoch: 437, loss: 5.39214
# epoch: 438, loss: 5.39255
# epoch: 439, loss: 5.39239
# epoch: 440, loss: 5.39314
# epoch: 441, loss: 5.39269
# epoch: 442, loss: 5.39300
# epoch: 443, loss: 5.39276
# epoch: 444, loss: 5.39333
# epoch: 445, loss: 5.39398
# epoch: 446, loss: 5.39320
# epoch: 447, loss: 5.39356
# epoch: 448, loss: 5.39357
# epoch: 449, loss: 5.39446
# epoch: 450, loss: 5.39421
# epoch: 451, loss: 5.39462
# epoch: 452, loss: 5.39410
# epoch: 453, loss: 5.39383
# epoch: 454, loss: 5.39424
# epoch: 455, loss: 5.39382
# epoch: 456, loss: 5.39490
# epoch: 457, loss: 5.39398
# epoch: 458, loss: 5.39506
# epoch: 459, loss: 5.39413
# epoch: 460, loss: 5.39375
# epoch: 461, loss: 5.39367
# epoch: 462, loss: 5.39307
# epoch: 463, loss: 5.39396
# epoch: 464, loss: 5.39323
# epoch: 465, loss: 5.39244
# epoch: 466, loss: 5.39186
# epoch: 467, loss: 5.39206
# epoch: 468, loss: 5.39237
# epoch: 469, loss: 5.39296
# epoch: 470, loss: 5.39267
# epoch: 471, loss: 5.39200
# epoch: 472, loss: 5.39215
# epoch: 473, loss: 5.39210
# epoch: 474, loss: 5.39157
# epoch: 475, loss: 5.39142
# epoch: 476, loss: 5.39221
# epoch: 477, loss: 5.39139
# epoch: 478, loss: 5.39249
# epoch: 479, loss: 5.39149
# epoch: 480, loss: 5.39205
# epoch: 481, loss: 5.39234
# epoch: 482, loss: 5.39266
# epoch: 483, loss: 5.39245
# epoch: 484, loss: 5.39280
# epoch: 485, loss: 5.39226
# epoch: 486, loss: 5.39215
# epoch: 487, loss: 5.39338
# epoch: 488, loss: 5.39317
# epoch: 489, loss: 5.39253
# epoch: 490, loss: 5.39325
# epoch: 491, loss: 5.39306
# epoch: 492, loss: 5.39269
# epoch: 493, loss: 5.39457
# epoch: 494, loss: 5.39416
# epoch: 495, loss: 5.39335
# epoch: 496, loss: 5.39387
# epoch: 497, loss: 5.39352
# epoch: 498, loss: 5.39310
# epoch: 499, loss: 5.39420

# %% [markdown]
# ##Check the Training Result

# %%
ds_cl= MyDataSet(X_ds, X_ds)
dl_cl = DataLoader(ds_cl, batch_size=256)

# %%
embeddings = []

# disable gradients for faster calculations
model.eval()
with torch.no_grad():
    for dl_cl1, dl_cl2 in dl_cl:

        dl_cl1 = dl_cl1.to(device)
        x,z = model(dl_cl1)
        
        # store the embeddings in lists
        embeddings.append(x)

# concatenate the embeddings, targets and convert to numpy
embeddings = torch.cat(embeddings, dim=0)
embeddings = embeddings.cpu().numpy()

# %%
test = (embeddings - embeddings.mean(axis=0)) / (embeddings.std(axis=0))

# %%
#KMeans in latent space
kmeans_backbone = KMeans(n_clusters=10).fit(test)
kmeans_labels_backbone = kmeans_backbone.labels_

# %%
normalized_mutual_info_score(kmeans_labels_backbone, y_ds)
# Out:
# 0.7721229574921573

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(embeddings)
data_X_tsne = np.vstack((X_tsne.T, kmeans_labels_backbone)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#NMI increases from 0.69 to 0.77
