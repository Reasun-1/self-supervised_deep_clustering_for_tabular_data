# %% [markdown]
# ## Conifuration

# %%
#import the lib for contrastive learning framework
# !pip install lightly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lightly
#   Downloading lightly-1.2.19-py3-none-any.whl (449 kB)
#      |████████████████████████████████| 449 kB 5.0 MB/s
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.8.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.23.0)
# Collecting hydra-core>=1.0.0
#   Downloading hydra_core-1.2.0-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 80.0 MB/s
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.7/dist-packages (from lightly) (2022.6.15)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.21.6)
# Collecting pytorch-lightning>=1.0.4
#   Downloading pytorch_lightning-1.6.4-py3-none-any.whl (585 kB)
#      |████████████████████████████████| 585 kB 70.7 MB/s
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.15.0)
# Collecting lightly-utils~=0.0.0
#   Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from lightly) (0.12.0+cu113)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (57.4.0)
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.7/dist-packages (from lightly) (4.64.0)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.24.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (21.3)
# Collecting omegaconf~=2.2
#   Downloading omegaconf-2.2.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 10.0 MB/s
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      |████████████████████████████████| 117 kB 60.4 MB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (5.7.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from lightly-utils~=0.0.0->lightly) (7.1.2)
# Collecting PyYAML>=5.1.0
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 49.9 MB/s
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2.8.0)
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (4.1.1)
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (3.17.3)
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.9.1-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 61.8 MB/s
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 95.0 MB/s
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 76.9 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->hydra-core>=1.0.0->lightly) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (2.10)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.35.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.8.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.46.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.3.7)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (21.4.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 61.0 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 63.8 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (2.0.12)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 4.8 MB/s
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=56e5911891803feb2152294abd26dd3c46715a22783d8182254fbb6a11ff19d9
#   Stored in directory: /root/.cache/pip/wheels/8b/8d/53/2af8772d9aec614e3fc65e53d4a993ad73c61daa8bbd85a873
# Successfully built antlr4-python3-runtime
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, PyYAML, fsspec, antlr4-python3-runtime, aiohttp, torchmetrics, pyDeprecate, omegaconf, pytorch-lightning, lightly-utils, hydra-core, lightly
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-6.0 aiohttp-3.8.1 aiosignal-1.2.0 antlr4-python3-runtime-4.9.3 async-timeout-4.0.2 asynctest-0.13.0 frozenlist-1.3.0 fsspec-2022.5.0 hydra-core-1.2.0 lightly-1.2.19 lightly-utils-0.0.2 multidict-6.0.2 omegaconf-2.2.2 pyDeprecate-0.3.2 pytorch-lightning-1.6.4 torchmetrics-0.9.1 yarl-1.7.2

# %%
import lightly
from lightly.models.modules.heads import SimSiamPredictionHead
from lightly.models.modules.heads import SimSiamProjectionHead

from lightly.data import LightlyDataset
from lightly.data import ImageCollateFunction
from lightly.models.modules import BarlowTwinsProjectionHead
from lightly.loss import BarlowTwinsLoss

from lightly.data import LightlyDataset
from lightly.data import SimCLRCollateFunction
from lightly.loss import NTXentLoss
from lightly.loss import NegativeCosineSimilarity
from lightly.models.modules import SimCLRProjectionHead

# %%
import math
import torch
import torch.nn as nn
import torchvision
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from torch.utils.data import Dataset, DataLoader
import torch.optim as torch_optim
import torch.optim.lr_scheduler as lr_scheduler
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
from datetime import datetime

from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from matplotlib import pyplot
import seaborn as sns

from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_mutual_info_score
from sklearn.metrics import silhouette_score
from sklearn import mixture
from sklearn.cluster import DBSCAN
from sklearn.cluster import OPTICS
from sklearn.cluster import AgglomerativeClustering

import tensorboard
from tensorboard import notebook
from torch.utils.tensorboard import SummaryWriter

import matplotlib 
import matplotlib.pyplot as plt
#import plotly.express as px

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons
from sklearn.utils import shuffle

import torchvision.transforms as transforms
import torchvision.datasets as datasets
from sklearn.metrics.pairwise import cosine_similarity

import random
from torch.nn.modules.loss import MSELoss
from sklearn.neighbors import KDTree
#from kmodes.kprototypes import KPrototypes

from scipy.io.arff import loadarff
from sklearn.preprocessing import MinMaxScaler 
from sklearn.datasets import make_classification

# %% [markdown]
# ## Load Dataset Pendigits and Check Clustering Result with the Baseline Method Kmeans

# %%
# set the path to the dataset
path_to_data = '/content/drive/MyDrive/Colab_Notebooks/pendigits.csv'

# %%
data = pd.read_csv(path_to_data)

X_ds = data.copy()
X_ds = X_ds.drop(['class'], axis=1)
X_ds = pd.DataFrame(X_ds).to_numpy()

y_ds = data.copy()
y_ds = y_ds['class']

# %%
#check the clustering result with Kmeans
kmeans_ori = KMeans(n_clusters=10).fit(X_ds)
kmeans_labels_ori = kmeans_ori.labels_

normalized_mutual_info_score(kmeans_labels_ori, y_ds)
# Out:
# 0.6912159965088228

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X_ds)
data_X_tsne = np.vstack((X_tsne.T, y_ds)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ####MixUp

# %%
def mixup(data):
  view = data.copy()
  for i in range(len(view)):
    random_row_index = random.randint(0, len(view)-1)
    view[i] = view[i]*0.5  + view[random_row_index]*0.5
  return view

# %% [markdown]
# ####MixCut

# %%
def mixcut(data):
  data_copy = data.copy()
  view = data.copy()
  mask_len = 100

  for i in range(len(data_copy)):
    random_row_id = random.randint(0, len(data_copy)-1)
    random_column_id = random.randint(0, data_copy.shape[1]-mask_len)
    view[i,random_column_id:(random_column_id+mask_len)] = data_copy[random_row_id,random_column_id:(random_column_id+mask_len)]
  return view

# %% [markdown]
# #### Masking with mean

# %%
def get_random_indices(data, portion_of_mask):
  return np.random.choice(data.shape[1], size=np.floor(data.shape[1]*portion_of_mask).astype(int), replace=False)

# %%
def masking_with_mean(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = column_mu[j]
              
  return view

# %% [markdown]
# ####Masking with random value in domain range

# %%
def masking_with_random(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)
  column_min = np.minimum(data)
  column_max = np.maximum(data)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = random.randint(column_min[j], column_max[j])
              
  return view

# %% [markdown]
# ####Masking with margin distribution

# %%
def masking_with_margin_distribution(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = np.random.normal(column_mu[j], column_std[j])
              
  return view

# %% [markdown]
# ####Upsampling (SMOTE like)

# %%
#put all data points in kd-tree for fast searching
kdtree = KDTree(X_ds, leaf_size=2)

# %%
#get random point in the k nearest neighbors
def get_idx_random_knn(x,k):
   _, ids = kdtree.query(x.reshape(1, -1), k=k)
   ids = ids.flatten()
   ids = ids[1:-1]
   random_id = np.random.choice(ids, 1)
   return random_id

# %%
#mix up with a random near neighbor 
def mixup_random_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = 0.5*data[i] + 0.5*data[random_neighbor_id]
  return view

# %%
#a random neighbor as augmentation
def random_near_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = data[random_neighbor_id]
  return view

# %% [markdown]
# ##Create Model and Train with Augmented Data

# %%
class MyDataSet(Dataset):
  def __init__(self, view1, view2):
 
    X_view1 = view1.copy()
    X_view2 = view2.copy()
    self.X_view1 = X_view1.copy().astype(np.float32)
    self.X_view2 = X_view2.copy().astype(np.float32)
  
  def __len__(self):
    return len(self.X_view1)
  
  def __getitem__(self, idx):
    return self.X_view1[idx], self.X_view2[idx]

# %%
# define the NN architecture
class convBackbone(nn.Module):
    def __init__(self):
        super(convBackbone, self).__init__()

        #turn on dropout for testing the 'cropping' data augmentation 
        #self.dropout = nn.Dropout(p=0.1)
        
        self.fc1 = nn.Linear(16, 16, bias=False)
        self.bn1 = nn.BatchNorm1d(16)

        self.fc2 = nn.Linear(16, 16, bias=False)
        self.bn2 = nn.BatchNorm1d(16)

        self.fc3 = nn.Linear(16, 8, bias=False)
        self.bn3 = nn.BatchNorm1d(8)


    def forward(self, x):

        #turn on dropout for testing the 'cropping' data augmentation 
        #x = self.dropout(x)
        
        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.bn3(self.fc3(x))
                
        return x

# %%
class SimSiam(nn.Module):
    def __init__(self, backbone):
        super().__init__()
        self.backbone = backbone
        self.projection_head = SimSiamProjectionHead(8, 8, 8)
        self.prediction_head = SimSiamPredictionHead(8, 4, 8)

    def forward(self, x):
        f = self.backbone(x)
        z = f.flatten(start_dim=1)
        z = self.projection_head(z)
        p = self.prediction_head(z)
        z = z.detach()
        return f, z, p

backbone = convBackbone()
model = SimSiam(backbone)

# %%
criterion = NegativeCosineSimilarity()
optimizer = torch.optim.SGD(model.parameters(), lr=0.06)

#cosine annealing lr
scheduler = lr_scheduler.CosineAnnealingLR(optimizer,T_max=800, eta_min=0)

# %%
view1 = random_near_neighbor(X_ds, 18)
view2 = random_near_neighbor(X_ds, 19)

#turn on the following to test other augmentations

#view1 = mixup_random_neighbor(X_ds, 15)
#view2 = mixup_random_neighbor(X_ds, 15)

#view1 = mixup(X_ds)
#view2 = mixup(X_ds)

#view1 = mixcut(X_ds)
#view2 = mixcut(X_ds)

#view1 = masking_with_mean(X_ds, 0.4)
#view2 = masking_with_mean(X_ds, 0.4)

#view1 = masking_with_random(X_ds, 0.4)
#view2 = masking_with_random(X_ds, 0.4)

#view1 = masking_with_margin_distribution(X_ds, 0.4)
#view2 = masking_with_margin_distribution(X_ds, 0.4)

train_ds = MyDataSet(view1, view2)
train_dl = DataLoader(train_ds, batch_size=256, shuffle=True)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

for epoch in range(800):
    total_loss = 0
    for x0,x1 in train_dl:
        x0 = x0.to(device)
        x1 = x1.to(device)
        _, z0, p0 = model(x0)
        _, z1, p1 = model(x1)

        loss = 0.5 * (criterion(z0, p1) + criterion(z1, p0))
        total_loss += loss.detach()
        loss.backward()

        optimizer.step()
        optimizer.zero_grad()
        scheduler.step()

    avg_loss = total_loss / len(train_dl)
    print(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
# Out:
# epoch: 00, loss: -0.41594
# epoch: 01, loss: -0.81066
# epoch: 02, loss: -0.89335
# epoch: 03, loss: -0.92294
# epoch: 04, loss: -0.93073
# epoch: 05, loss: -0.93543
# epoch: 06, loss: -0.94331
# epoch: 07, loss: -0.94267
# epoch: 08, loss: -0.94811
# epoch: 09, loss: -0.95430
# epoch: 10, loss: -0.95739
# epoch: 11, loss: -0.95956
# epoch: 12, loss: -0.96024
# epoch: 13, loss: -0.96029
# epoch: 14, loss: -0.96025
# epoch: 15, loss: -0.96253
# epoch: 16, loss: -0.96161
# epoch: 17, loss: -0.96180
# epoch: 18, loss: -0.96289
# epoch: 19, loss: -0.96108
# epoch: 20, loss: -0.96215
# epoch: 21, loss: -0.96159
# epoch: 22, loss: -0.96184
# epoch: 23, loss: -0.96285
# epoch: 24, loss: -0.96228
# epoch: 25, loss: -0.96352
# epoch: 26, loss: -0.96269
# epoch: 27, loss: -0.96380
# epoch: 28, loss: -0.96469
# epoch: 29, loss: -0.96591
# epoch: 30, loss: -0.96579
# epoch: 31, loss: -0.96551
# epoch: 32, loss: -0.96551
# epoch: 33, loss: -0.96686
# epoch: 34, loss: -0.96402
# epoch: 35, loss: -0.96592
# epoch: 36, loss: -0.96865
# epoch: 37, loss: -0.97091
# epoch: 38, loss: -0.97139
# epoch: 39, loss: -0.97291
# epoch: 40, loss: -0.97307
# epoch: 41, loss: -0.97442
# epoch: 42, loss: -0.97467
# epoch: 43, loss: -0.97434
# epoch: 44, loss: -0.97582
# epoch: 45, loss: -0.97596
# epoch: 46, loss: -0.97518
# epoch: 47, loss: -0.97548
# epoch: 48, loss: -0.97575
# epoch: 49, loss: -0.97516
# epoch: 50, loss: -0.97568
# epoch: 51, loss: -0.97589
# epoch: 52, loss: -0.97585
# epoch: 53, loss: -0.97609
# epoch: 54, loss: -0.97591
# epoch: 55, loss: -0.97537
# epoch: 56, loss: -0.97547
# epoch: 57, loss: -0.97533
# epoch: 58, loss: -0.97520
# epoch: 59, loss: -0.97550
# epoch: 60, loss: -0.97575
# epoch: 61, loss: -0.97622
# epoch: 62, loss: -0.97557
# epoch: 63, loss: -0.97603
# epoch: 64, loss: -0.97545
# epoch: 65, loss: -0.97588
# epoch: 66, loss: -0.97652
# epoch: 67, loss: -0.97618
# epoch: 68, loss: -0.97614
# epoch: 69, loss: -0.97545
# epoch: 70, loss: -0.97462
# epoch: 71, loss: -0.97572
# epoch: 72, loss: -0.97549
# epoch: 73, loss: -0.97436
# epoch: 74, loss: -0.97360
# epoch: 75, loss: -0.97386
# epoch: 76, loss: -0.97372
# epoch: 77, loss: -0.97259
# epoch: 78, loss: -0.97243
# epoch: 79, loss: -0.97285
# epoch: 80, loss: -0.97225
# epoch: 81, loss: -0.97306
# epoch: 82, loss: -0.97229
# epoch: 83, loss: -0.97108
# epoch: 84, loss: -0.97016
# epoch: 85, loss: -0.96786
# epoch: 86, loss: -0.96667
# epoch: 87, loss: -0.96485
# epoch: 88, loss: -0.96243
# epoch: 89, loss: -0.96134
# epoch: 90, loss: -0.96039
# epoch: 91, loss: -0.96045
# epoch: 92, loss: -0.96058
# epoch: 93, loss: -0.96000
# epoch: 94, loss: -0.96030
# epoch: 95, loss: -0.95956
# epoch: 96, loss: -0.95937
# epoch: 97, loss: -0.95868
# epoch: 98, loss: -0.95535
# epoch: 99, loss: -0.95237
# epoch: 100, loss: -0.94632
# epoch: 101, loss: -0.93330
# epoch: 102, loss: -0.92437
# epoch: 103, loss: -0.92259
# epoch: 104, loss: -0.93402
# epoch: 105, loss: -0.94229
# epoch: 106, loss: -0.95273
# epoch: 107, loss: -0.96055
# epoch: 108, loss: -0.96258
# epoch: 109, loss: -0.95600
# epoch: 110, loss: -0.96393
# epoch: 111, loss: -0.97069
# epoch: 112, loss: -0.97459
# epoch: 113, loss: -0.97628
# epoch: 114, loss: -0.97836
# epoch: 115, loss: -0.97890
# epoch: 116, loss: -0.97900
# epoch: 117, loss: -0.97932
# epoch: 118, loss: -0.98006
# epoch: 119, loss: -0.98011
# epoch: 120, loss: -0.98065
# epoch: 121, loss: -0.98020
# epoch: 122, loss: -0.98076
# epoch: 123, loss: -0.98060
# epoch: 124, loss: -0.98089
# epoch: 125, loss: -0.98076
# epoch: 126, loss: -0.98090
# epoch: 127, loss: -0.98094
# epoch: 128, loss: -0.98072
# epoch: 129, loss: -0.98088
# epoch: 130, loss: -0.98119
# epoch: 131, loss: -0.98093
# epoch: 132, loss: -0.98154
# epoch: 133, loss: -0.98091
# epoch: 134, loss: -0.98085
# epoch: 135, loss: -0.98079
# epoch: 136, loss: -0.98082
# epoch: 137, loss: -0.98085
# epoch: 138, loss: -0.98127
# epoch: 139, loss: -0.98113
# epoch: 140, loss: -0.98131
# epoch: 141, loss: -0.98096
# epoch: 142, loss: -0.98084
# epoch: 143, loss: -0.98158
# epoch: 144, loss: -0.98139
# epoch: 145, loss: -0.98097
# epoch: 146, loss: -0.98171
# epoch: 147, loss: -0.98210
# epoch: 148, loss: -0.98162
# epoch: 149, loss: -0.98148
# epoch: 150, loss: -0.98119
# epoch: 151, loss: -0.98141
# epoch: 152, loss: -0.98157
# epoch: 153, loss: -0.98179
# epoch: 154, loss: -0.98165
# epoch: 155, loss: -0.98172
# epoch: 156, loss: -0.98199
# epoch: 157, loss: -0.98223
# epoch: 158, loss: -0.98120
# epoch: 159, loss: -0.98168
# epoch: 160, loss: -0.98140
# epoch: 161, loss: -0.98215
# epoch: 162, loss: -0.98168
# epoch: 163, loss: -0.98194
# epoch: 164, loss: -0.98167
# epoch: 165, loss: -0.98172
# epoch: 166, loss: -0.98175
# epoch: 167, loss: -0.98190
# epoch: 168, loss: -0.98197
# epoch: 169, loss: -0.98223
# epoch: 170, loss: -0.98188
# epoch: 171, loss: -0.98128
# epoch: 172, loss: -0.98158
# epoch: 173, loss: -0.98171
# epoch: 174, loss: -0.98194
# epoch: 175, loss: -0.98109
# epoch: 176, loss: -0.98240
# epoch: 177, loss: -0.98227
# epoch: 178, loss: -0.98220
# epoch: 179, loss: -0.98206
# epoch: 180, loss: -0.98220
# epoch: 181, loss: -0.98189
# epoch: 182, loss: -0.98187
# epoch: 183, loss: -0.98188
# epoch: 184, loss: -0.98177
# epoch: 185, loss: -0.98250
# epoch: 186, loss: -0.98214
# epoch: 187, loss: -0.98268
# epoch: 188, loss: -0.98232
# epoch: 189, loss: -0.98268
# epoch: 190, loss: -0.98282
# epoch: 191, loss: -0.98264
# epoch: 192, loss: -0.98288
# epoch: 193, loss: -0.98334
# epoch: 194, loss: -0.98360
# epoch: 195, loss: -0.98347
# epoch: 196, loss: -0.98332
# epoch: 197, loss: -0.98315
# epoch: 198, loss: -0.98340
# epoch: 199, loss: -0.98363
# epoch: 200, loss: -0.98314
# epoch: 201, loss: -0.98374
# epoch: 202, loss: -0.98322
# epoch: 203, loss: -0.98370
# epoch: 204, loss: -0.98339
# epoch: 205, loss: -0.98282
# epoch: 206, loss: -0.98385
# epoch: 207, loss: -0.98335
# epoch: 208, loss: -0.98323
# epoch: 209, loss: -0.98388
# epoch: 210, loss: -0.98376
# epoch: 211, loss: -0.98356
# epoch: 212, loss: -0.98364
# epoch: 213, loss: -0.98349
# epoch: 214, loss: -0.98376
# epoch: 215, loss: -0.98392
# epoch: 216, loss: -0.98381
# epoch: 217, loss: -0.98387
# epoch: 218, loss: -0.98390
# epoch: 219, loss: -0.98442
# epoch: 220, loss: -0.98406
# epoch: 221, loss: -0.98423
# epoch: 222, loss: -0.98393
# epoch: 223, loss: -0.98413
# epoch: 224, loss: -0.98422
# epoch: 225, loss: -0.98438
# epoch: 226, loss: -0.98427
# epoch: 227, loss: -0.98424
# epoch: 228, loss: -0.98475
# epoch: 229, loss: -0.98483
# epoch: 230, loss: -0.98497
# epoch: 231, loss: -0.98516
# epoch: 232, loss: -0.98515
# epoch: 233, loss: -0.98510
# epoch: 234, loss: -0.98514
# epoch: 235, loss: -0.98525
# epoch: 236, loss: -0.98498
# epoch: 237, loss: -0.98506
# epoch: 238, loss: -0.98497
# epoch: 239, loss: -0.98526
# epoch: 240, loss: -0.98530
# epoch: 241, loss: -0.98522
# epoch: 242, loss: -0.98484
# epoch: 243, loss: -0.98467
# epoch: 244, loss: -0.98510
# epoch: 245, loss: -0.98475
# epoch: 246, loss: -0.98503
# epoch: 247, loss: -0.98476
# epoch: 248, loss: -0.98551
# epoch: 249, loss: -0.98463
# epoch: 250, loss: -0.98525
# epoch: 251, loss: -0.98534
# epoch: 252, loss: -0.98519
# epoch: 253, loss: -0.98550
# epoch: 254, loss: -0.98512
# epoch: 255, loss: -0.98517
# epoch: 256, loss: -0.98552
# epoch: 257, loss: -0.98515
# epoch: 258, loss: -0.98542
# epoch: 259, loss: -0.98553
# epoch: 260, loss: -0.98521
# epoch: 261, loss: -0.98596
# epoch: 262, loss: -0.98600
# epoch: 263, loss: -0.98618
# epoch: 264, loss: -0.98610
# epoch: 265, loss: -0.98598
# epoch: 266, loss: -0.98577
# epoch: 267, loss: -0.98533
# epoch: 268, loss: -0.98571
# epoch: 269, loss: -0.98582
# epoch: 270, loss: -0.98613
# epoch: 271, loss: -0.98584
# epoch: 272, loss: -0.98632
# epoch: 273, loss: -0.98634
# epoch: 274, loss: -0.98617
# epoch: 275, loss: -0.98633
# epoch: 276, loss: -0.98650
# epoch: 277, loss: -0.98648
# epoch: 278, loss: -0.98651
# epoch: 279, loss: -0.98684
# epoch: 280, loss: -0.98630
# epoch: 281, loss: -0.98617
# epoch: 282, loss: -0.98636
# epoch: 283, loss: -0.98619
# epoch: 284, loss: -0.98620
# epoch: 285, loss: -0.98574
# epoch: 286, loss: -0.98582
# epoch: 287, loss: -0.98657
# epoch: 288, loss: -0.98647
# epoch: 289, loss: -0.98602
# epoch: 290, loss: -0.98608
# epoch: 291, loss: -0.98619
# epoch: 292, loss: -0.98666
# epoch: 293, loss: -0.98658
# epoch: 294, loss: -0.98650
# epoch: 295, loss: -0.98632
# epoch: 296, loss: -0.98667
# epoch: 297, loss: -0.98654
# epoch: 298, loss: -0.98662
# epoch: 299, loss: -0.98734
# epoch: 300, loss: -0.98704
# epoch: 301, loss: -0.98709
# epoch: 302, loss: -0.98707
# epoch: 303, loss: -0.98751
# epoch: 304, loss: -0.98675
# epoch: 305, loss: -0.98701
# epoch: 306, loss: -0.98743
# epoch: 307, loss: -0.98753
# epoch: 308, loss: -0.98745
# epoch: 309, loss: -0.98735
# epoch: 310, loss: -0.98762
# epoch: 311, loss: -0.98726
# epoch: 312, loss: -0.98713
# epoch: 313, loss: -0.98770
# epoch: 314, loss: -0.98781
# epoch: 315, loss: -0.98748
# epoch: 316, loss: -0.98786
# epoch: 317, loss: -0.98742
# epoch: 318, loss: -0.98763
# epoch: 319, loss: -0.98663
# epoch: 320, loss: -0.98712
# epoch: 321, loss: -0.98749
# epoch: 322, loss: -0.98725
# epoch: 323, loss: -0.98705
# epoch: 324, loss: -0.98709
# epoch: 325, loss: -0.98692
# epoch: 326, loss: -0.98710
# epoch: 327, loss: -0.98688
# epoch: 328, loss: -0.98716
# epoch: 329, loss: -0.98703
# epoch: 330, loss: -0.98702
# epoch: 331, loss: -0.98710
# epoch: 332, loss: -0.98704
# epoch: 333, loss: -0.98702
# epoch: 334, loss: -0.98638
# epoch: 335, loss: -0.98679
# epoch: 336, loss: -0.98639
# epoch: 337, loss: -0.98590
# epoch: 338, loss: -0.98555
# epoch: 339, loss: -0.98348
# epoch: 340, loss: -0.98377
# epoch: 341, loss: -0.98448
# epoch: 342, loss: -0.98447
# epoch: 343, loss: -0.98410
# epoch: 344, loss: -0.98374
# epoch: 345, loss: -0.98453
# epoch: 346, loss: -0.98478
# epoch: 347, loss: -0.98456
# epoch: 348, loss: -0.98446
# epoch: 349, loss: -0.98415
# epoch: 350, loss: -0.98436
# epoch: 351, loss: -0.98423
# epoch: 352, loss: -0.98413
# epoch: 353, loss: -0.98434
# epoch: 354, loss: -0.98415
# epoch: 355, loss: -0.98447
# epoch: 356, loss: -0.98430
# epoch: 357, loss: -0.98456
# epoch: 358, loss: -0.98437
# epoch: 359, loss: -0.98494
# epoch: 360, loss: -0.98452
# epoch: 361, loss: -0.98430
# epoch: 362, loss: -0.98500
# epoch: 363, loss: -0.98388
# epoch: 364, loss: -0.98432
# epoch: 365, loss: -0.98417
# epoch: 366, loss: -0.98415
# epoch: 367, loss: -0.98419
# epoch: 368, loss: -0.98345
# epoch: 369, loss: -0.98433
# epoch: 370, loss: -0.98359
# epoch: 371, loss: -0.98379
# epoch: 372, loss: -0.98382
# epoch: 373, loss: -0.98435
# epoch: 374, loss: -0.98437
# epoch: 375, loss: -0.98438
# epoch: 376, loss: -0.98376
# epoch: 377, loss: -0.98410
# epoch: 378, loss: -0.98391
# epoch: 379, loss: -0.98394
# epoch: 380, loss: -0.98419
# epoch: 381, loss: -0.98405
# epoch: 382, loss: -0.98461
# epoch: 383, loss: -0.98489
# epoch: 384, loss: -0.98437
# epoch: 385, loss: -0.98463
# epoch: 386, loss: -0.98486
# epoch: 387, loss: -0.98491
# epoch: 388, loss: -0.98432
# epoch: 389, loss: -0.98495
# epoch: 390, loss: -0.98398
# epoch: 391, loss: -0.98435
# epoch: 392, loss: -0.98421
# epoch: 393, loss: -0.98401
# epoch: 394, loss: -0.98476
# epoch: 395, loss: -0.98416
# epoch: 396, loss: -0.98449
# epoch: 397, loss: -0.98447
# epoch: 398, loss: -0.98443
# epoch: 399, loss: -0.98426
# epoch: 400, loss: -0.98488
# epoch: 401, loss: -0.98409
# epoch: 402, loss: -0.98426
# epoch: 403, loss: -0.98425
# epoch: 404, loss: -0.98378
# epoch: 405, loss: -0.98152
# epoch: 406, loss: -0.98029
# epoch: 407, loss: -0.98400
# epoch: 408, loss: -0.98491
# epoch: 409, loss: -0.98572
# epoch: 410, loss: -0.98541
# epoch: 411, loss: -0.98496
# epoch: 412, loss: -0.98498
# epoch: 413, loss: -0.98503
# epoch: 414, loss: -0.98561
# epoch: 415, loss: -0.98547
# epoch: 416, loss: -0.98553
# epoch: 417, loss: -0.98590
# epoch: 418, loss: -0.98584
# epoch: 419, loss: -0.98635
# epoch: 420, loss: -0.98585
# epoch: 421, loss: -0.98625
# epoch: 422, loss: -0.98608
# epoch: 423, loss: -0.98548
# epoch: 424, loss: -0.98619
# epoch: 425, loss: -0.98574
# epoch: 426, loss: -0.98612
# epoch: 427, loss: -0.98599
# epoch: 428, loss: -0.98587
# epoch: 429, loss: -0.98582
# epoch: 430, loss: -0.98619
# epoch: 431, loss: -0.98608
# epoch: 432, loss: -0.98607
# epoch: 433, loss: -0.98574
# epoch: 434, loss: -0.98602
# epoch: 435, loss: -0.98600
# epoch: 436, loss: -0.98616
# epoch: 437, loss: -0.98583
# epoch: 438, loss: -0.98579
# epoch: 439, loss: -0.98606
# epoch: 440, loss: -0.98586
# epoch: 441, loss: -0.98608
# epoch: 442, loss: -0.98565
# epoch: 443, loss: -0.98604
# epoch: 444, loss: -0.98543
# epoch: 445, loss: -0.98575
# epoch: 446, loss: -0.98576
# epoch: 447, loss: -0.98539
# epoch: 448, loss: -0.98524
# epoch: 449, loss: -0.98544
# epoch: 450, loss: -0.98490
# epoch: 451, loss: -0.98425
# epoch: 452, loss: -0.98419
# epoch: 453, loss: -0.98461
# epoch: 454, loss: -0.98327
# epoch: 455, loss: -0.98334
# epoch: 456, loss: -0.98366
# epoch: 457, loss: -0.98314
# epoch: 458, loss: -0.98273
# epoch: 459, loss: -0.98296
# epoch: 460, loss: -0.98245
# epoch: 461, loss: -0.98140
# epoch: 462, loss: -0.98142
# epoch: 463, loss: -0.98172
# epoch: 464, loss: -0.98168
# epoch: 465, loss: -0.98190
# epoch: 466, loss: -0.98197
# epoch: 467, loss: -0.98180
# epoch: 468, loss: -0.98167
# epoch: 469, loss: -0.98190
# epoch: 470, loss: -0.98122
# epoch: 471, loss: -0.98043
# epoch: 472, loss: -0.97897
# epoch: 473, loss: -0.97699
# epoch: 474, loss: -0.97414
# epoch: 475, loss: -0.97115
# epoch: 476, loss: -0.96751
# epoch: 477, loss: -0.96380
# epoch: 478, loss: -0.96609
# epoch: 479, loss: -0.96841
# epoch: 480, loss: -0.96332
# epoch: 481, loss: -0.96188
# epoch: 482, loss: -0.96736
# epoch: 483, loss: -0.96933
# epoch: 484, loss: -0.97014
# epoch: 485, loss: -0.97048
# epoch: 486, loss: -0.96881
# epoch: 487, loss: -0.96936
# epoch: 488, loss: -0.96985
# epoch: 489, loss: -0.97083
# epoch: 490, loss: -0.97100
# epoch: 491, loss: -0.97022
# epoch: 492, loss: -0.97164
# epoch: 493, loss: -0.97060
# epoch: 494, loss: -0.97130
# epoch: 495, loss: -0.97146
# epoch: 496, loss: -0.97172
# epoch: 497, loss: -0.97117
# epoch: 498, loss: -0.97198
# epoch: 499, loss: -0.97124
# epoch: 500, loss: -0.97156
# epoch: 501, loss: -0.97194
# epoch: 502, loss: -0.97103
# epoch: 503, loss: -0.97092
# epoch: 504, loss: -0.97141
# epoch: 505, loss: -0.97137
# epoch: 506, loss: -0.97194
# epoch: 507, loss: -0.97196
# epoch: 508, loss: -0.97247
# epoch: 509, loss: -0.97182
# epoch: 510, loss: -0.97224
# epoch: 511, loss: -0.97241
# epoch: 512, loss: -0.97273
# epoch: 513, loss: -0.97247
# epoch: 514, loss: -0.97192
# epoch: 515, loss: -0.97132
# epoch: 516, loss: -0.97048
# epoch: 517, loss: -0.96973
# epoch: 518, loss: -0.96814
# epoch: 519, loss: -0.96727
# epoch: 520, loss: -0.96648
# epoch: 521, loss: -0.96736
# epoch: 522, loss: -0.96807
# epoch: 523, loss: -0.96825
# epoch: 524, loss: -0.96902
# epoch: 525, loss: -0.96965
# epoch: 526, loss: -0.97096
# epoch: 527, loss: -0.97002
# epoch: 528, loss: -0.97097
# epoch: 529, loss: -0.97129
# epoch: 530, loss: -0.97175
# epoch: 531, loss: -0.97170
# epoch: 532, loss: -0.97143
# epoch: 533, loss: -0.97193
# epoch: 534, loss: -0.97222
# epoch: 535, loss: -0.97245
# epoch: 536, loss: -0.97129
# epoch: 537, loss: -0.97238
# epoch: 538, loss: -0.97234
# epoch: 539, loss: -0.97216
# epoch: 540, loss: -0.97293
# epoch: 541, loss: -0.97226
# epoch: 542, loss: -0.97277
# epoch: 543, loss: -0.97267
# epoch: 544, loss: -0.97303
# epoch: 545, loss: -0.97262
# epoch: 546, loss: -0.97234
# epoch: 547, loss: -0.97279
# epoch: 548, loss: -0.97223
# epoch: 549, loss: -0.97263
# epoch: 550, loss: -0.97355
# epoch: 551, loss: -0.97329
# epoch: 552, loss: -0.97285
# epoch: 553, loss: -0.97285
# epoch: 554, loss: -0.97205
# epoch: 555, loss: -0.97108
# epoch: 556, loss: -0.96881
# epoch: 557, loss: -0.96721
# epoch: 558, loss: -0.96796
# epoch: 559, loss: -0.96827
# epoch: 560, loss: -0.96824
# epoch: 561, loss: -0.96733
# epoch: 562, loss: -0.96742
# epoch: 563, loss: -0.96606
# epoch: 564, loss: -0.96576
# epoch: 565, loss: -0.96653
# epoch: 566, loss: -0.96780
# epoch: 567, loss: -0.96897
# epoch: 568, loss: -0.96936
# epoch: 569, loss: -0.97040
# epoch: 570, loss: -0.97099
# epoch: 571, loss: -0.97159
# epoch: 572, loss: -0.97187
# epoch: 573, loss: -0.97226
# epoch: 574, loss: -0.97178
# epoch: 575, loss: -0.97193
# epoch: 576, loss: -0.97239
# epoch: 577, loss: -0.97228
# epoch: 578, loss: -0.97201
# epoch: 579, loss: -0.97255
# epoch: 580, loss: -0.97239
# epoch: 581, loss: -0.97157
# epoch: 582, loss: -0.97195
# epoch: 583, loss: -0.97242
# epoch: 584, loss: -0.97178
# epoch: 585, loss: -0.97102
# epoch: 586, loss: -0.97224
# epoch: 587, loss: -0.97183
# epoch: 588, loss: -0.97258
# epoch: 589, loss: -0.97304
# epoch: 590, loss: -0.97447
# epoch: 591, loss: -0.97484
# epoch: 592, loss: -0.97617
# epoch: 593, loss: -0.97728
# epoch: 594, loss: -0.97912
# epoch: 595, loss: -0.97939
# epoch: 596, loss: -0.98005
# epoch: 597, loss: -0.98063
# epoch: 598, loss: -0.98019
# epoch: 599, loss: -0.98043
# epoch: 600, loss: -0.98030
# epoch: 601, loss: -0.98035
# epoch: 602, loss: -0.98030
# epoch: 603, loss: -0.98043
# epoch: 604, loss: -0.98013
# epoch: 605, loss: -0.98014
# epoch: 606, loss: -0.97963
# epoch: 607, loss: -0.97984
# epoch: 608, loss: -0.97999
# epoch: 609, loss: -0.98071
# epoch: 610, loss: -0.98014
# epoch: 611, loss: -0.97986
# epoch: 612, loss: -0.98014
# epoch: 613, loss: -0.98031
# epoch: 614, loss: -0.98020
# epoch: 615, loss: -0.98011
# epoch: 616, loss: -0.97985
# epoch: 617, loss: -0.98024
# epoch: 618, loss: -0.97997
# epoch: 619, loss: -0.98008
# epoch: 620, loss: -0.97918
# epoch: 621, loss: -0.98002
# epoch: 622, loss: -0.97942
# epoch: 623, loss: -0.97889
# epoch: 624, loss: -0.97902
# epoch: 625, loss: -0.97847
# epoch: 626, loss: -0.97746
# epoch: 627, loss: -0.97498
# epoch: 628, loss: -0.97760
# epoch: 629, loss: -0.97657
# epoch: 630, loss: -0.97421
# epoch: 631, loss: -0.97275
# epoch: 632, loss: -0.97296
# epoch: 633, loss: -0.97473
# epoch: 634, loss: -0.97448
# epoch: 635, loss: -0.97457
# epoch: 636, loss: -0.97489
# epoch: 637, loss: -0.97544
# epoch: 638, loss: -0.97609
# epoch: 639, loss: -0.97584
# epoch: 640, loss: -0.97604
# epoch: 641, loss: -0.97711
# epoch: 642, loss: -0.97802
# epoch: 643, loss: -0.97829
# epoch: 644, loss: -0.97787
# epoch: 645, loss: -0.97816
# epoch: 646, loss: -0.97890
# epoch: 647, loss: -0.97890
# epoch: 648, loss: -0.97922
# epoch: 649, loss: -0.97933
# epoch: 650, loss: -0.97920
# epoch: 651, loss: -0.98008
# epoch: 652, loss: -0.97953
# epoch: 653, loss: -0.97887
# epoch: 654, loss: -0.97969
# epoch: 655, loss: -0.97901
# epoch: 656, loss: -0.97850
# epoch: 657, loss: -0.97816
# epoch: 658, loss: -0.97801
# epoch: 659, loss: -0.97785
# epoch: 660, loss: -0.97730
# epoch: 661, loss: -0.97655
# epoch: 662, loss: -0.97639
# epoch: 663, loss: -0.97592
# epoch: 664, loss: -0.97582
# epoch: 665, loss: -0.97523
# epoch: 666, loss: -0.97506
# epoch: 667, loss: -0.97540
# epoch: 668, loss: -0.97518
# epoch: 669, loss: -0.97590
# epoch: 670, loss: -0.97646
# epoch: 671, loss: -0.97545
# epoch: 672, loss: -0.97631
# epoch: 673, loss: -0.97621
# epoch: 674, loss: -0.97716
# epoch: 675, loss: -0.97776
# epoch: 676, loss: -0.97876
# epoch: 677, loss: -0.97913
# epoch: 678, loss: -0.97970
# epoch: 679, loss: -0.98033
# epoch: 680, loss: -0.98037
# epoch: 681, loss: -0.98148
# epoch: 682, loss: -0.98188
# epoch: 683, loss: -0.98274
# epoch: 684, loss: -0.98255
# epoch: 685, loss: -0.98254
# epoch: 686, loss: -0.98234
# epoch: 687, loss: -0.98303
# epoch: 688, loss: -0.98278
# epoch: 689, loss: -0.98237
# epoch: 690, loss: -0.98280
# epoch: 691, loss: -0.98312
# epoch: 692, loss: -0.98258
# epoch: 693, loss: -0.98222
# epoch: 694, loss: -0.98161
# epoch: 695, loss: -0.98089
# epoch: 696, loss: -0.98149
# epoch: 697, loss: -0.97994
# epoch: 698, loss: -0.97949
# epoch: 699, loss: -0.97900
# epoch: 700, loss: -0.97883
# epoch: 701, loss: -0.97945
# epoch: 702, loss: -0.97934
# epoch: 703, loss: -0.97908
# epoch: 704, loss: -0.98017
# epoch: 705, loss: -0.97978
# epoch: 706, loss: -0.97932
# epoch: 707, loss: -0.98001
# epoch: 708, loss: -0.98037
# epoch: 709, loss: -0.98019
# epoch: 710, loss: -0.98138
# epoch: 711, loss: -0.98093
# epoch: 712, loss: -0.98155
# epoch: 713, loss: -0.98194
# epoch: 714, loss: -0.98232
# epoch: 715, loss: -0.98224
# epoch: 716, loss: -0.98325
# epoch: 717, loss: -0.98293
# epoch: 718, loss: -0.98354
# epoch: 719, loss: -0.98370
# epoch: 720, loss: -0.98391
# epoch: 721, loss: -0.98442
# epoch: 722, loss: -0.98413
# epoch: 723, loss: -0.98485
# epoch: 724, loss: -0.98449
# epoch: 725, loss: -0.98470
# epoch: 726, loss: -0.98453
# epoch: 727, loss: -0.98474
# epoch: 728, loss: -0.98404
# epoch: 729, loss: -0.98445
# epoch: 730, loss: -0.98445
# epoch: 731, loss: -0.98389
# epoch: 732, loss: -0.98377
# epoch: 733, loss: -0.98318
# epoch: 734, loss: -0.98248
# epoch: 735, loss: -0.98248
# epoch: 736, loss: -0.98155
# epoch: 737, loss: -0.98181
# epoch: 738, loss: -0.98172
# epoch: 739, loss: -0.98183
# epoch: 740, loss: -0.98254
# epoch: 741, loss: -0.98110
# epoch: 742, loss: -0.98259
# epoch: 743, loss: -0.98150
# epoch: 744, loss: -0.98181
# epoch: 745, loss: -0.98241
# epoch: 746, loss: -0.98281
# epoch: 747, loss: -0.98243
# epoch: 748, loss: -0.98303
# epoch: 749, loss: -0.98373
# epoch: 750, loss: -0.98388
# epoch: 751, loss: -0.98437
# epoch: 752, loss: -0.98426
# epoch: 753, loss: -0.98423
# epoch: 754, loss: -0.98468
# epoch: 755, loss: -0.98466
# epoch: 756, loss: -0.98415
# epoch: 757, loss: -0.98512
# epoch: 758, loss: -0.98477
# epoch: 759, loss: -0.98525
# epoch: 760, loss: -0.98507
# epoch: 761, loss: -0.98529
# epoch: 762, loss: -0.98498
# epoch: 763, loss: -0.98513
# epoch: 764, loss: -0.98521
# epoch: 765, loss: -0.98465
# epoch: 766, loss: -0.98481
# epoch: 767, loss: -0.98515
# epoch: 768, loss: -0.98510
# epoch: 769, loss: -0.98482
# epoch: 770, loss: -0.98426
# epoch: 771, loss: -0.98444
# epoch: 772, loss: -0.98351
# epoch: 773, loss: -0.98362
# epoch: 774, loss: -0.98262
# epoch: 775, loss: -0.98327
# epoch: 776, loss: -0.98274
# epoch: 777, loss: -0.98350
# epoch: 778, loss: -0.98349
# epoch: 779, loss: -0.98313
# epoch: 780, loss: -0.98354
# epoch: 781, loss: -0.98316
# epoch: 782, loss: -0.98419
# epoch: 783, loss: -0.98437
# epoch: 784, loss: -0.98464
# epoch: 785, loss: -0.98441
# epoch: 786, loss: -0.98464
# epoch: 787, loss: -0.98461
# epoch: 788, loss: -0.98532
# epoch: 789, loss: -0.98531
# epoch: 790, loss: -0.98598
# epoch: 791, loss: -0.98600
# epoch: 792, loss: -0.98579
# epoch: 793, loss: -0.98612
# epoch: 794, loss: -0.98629
# epoch: 795, loss: -0.98616
# epoch: 796, loss: -0.98653
# epoch: 797, loss: -0.98645
# epoch: 798, loss: -0.98650
# epoch: 799, loss: -0.98631

# %% [markdown]
# ##Check the Training Result

# %%
ds_cl= MyDataSet(X_ds, X_ds)
dl_cl = DataLoader(ds_cl, batch_size=256)

# %%
embeddings = []

# disable gradients for faster calculations
model.eval()
with torch.no_grad():
    for dl_cl1, dl_cl2 in dl_cl:

        dl_cl1 = dl_cl1.to(device)
        f, z, p = model(dl_cl1)
        
        # store the embeddings in lists
        embeddings.append(f)

# concatenate the embeddings, targets and convert to numpy
embeddings = torch.cat(embeddings, dim=0)
embeddings = embeddings.cpu().numpy()

# %%
test = (embeddings - embeddings.mean(axis=0)) / (embeddings.std(axis=0))

# %%
#KMeans in latent space
kmeans_backbone = KMeans(n_clusters=10).fit(test)
kmeans_labels_backbone = kmeans_backbone.labels_

# %%
normalized_mutual_info_score(kmeans_labels_backbone, y_ds)
# Out:
# 0.7437658314514592

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(embeddings)
data_X_tsne = np.vstack((X_tsne.T, y_ds)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
df_tsne.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
#         dim1       dim2    y
# 0 -30.012217  76.616356  8.0
# 1 -21.683224  -4.453712  2.0
# 2  71.651115  -9.425030  1.0
# 3 -57.965805  36.935688  4.0
# 4  85.212578  -2.163475  1.0

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()

# %%
#NMI increases from 0.69 to 0.74
