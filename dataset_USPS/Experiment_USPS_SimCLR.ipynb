# %% [markdown]
# ## Conifuration

# %%
#import the lib for contrastive learning framework
# !pip install lightly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lightly
#   Downloading lightly-1.2.21-py3-none-any.whl (458 kB)
#      |████████████████████████████████| 458 kB 4.3 MB/s
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from lightly) (0.12.0+cu113)
# Collecting hydra-core>=1.0.0
#   Downloading hydra_core-1.2.0-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 10.6 MB/s
# Collecting lightly-utils~=0.0.0
#   Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Collecting pytorch-lightning>=1.0.4
#   Downloading pytorch_lightning-1.6.4-py3-none-any.whl (585 kB)
#      |████████████████████████████████| 585 kB 11.8 MB/s
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.15.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.7/dist-packages (from lightly) (2022.6.15)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (57.4.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.8.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.23.0)
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.7/dist-packages (from lightly) (4.64.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.21.6)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.24.3)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      |████████████████████████████████| 117 kB 27.6 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (21.3)
# Collecting omegaconf~=2.2
#   Downloading omegaconf-2.2.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 4.9 MB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (5.7.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from lightly-utils~=0.0.0->lightly) (7.1.2)
# Collecting PyYAML>=5.1.0
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 23.2 MB/s
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.9.2-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 27.0 MB/s
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 32.5 MB/s
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (3.17.3)
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (1.11.0+cu113)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2.8.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (4.1.1)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 21.9 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->hydra-core>=1.0.0->lightly) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (2.10)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.1.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.37.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.46.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.3.7)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.35.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.2.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 2.0 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 34.6 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (21.4.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (2.0.12)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 42.8 MB/s
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=67c6bf40d84976c46a16b03db3d867a1d0a04ad110058982ddfb337b381657c5
#   Stored in directory: /root/.cache/pip/wheels/8b/8d/53/2af8772d9aec614e3fc65e53d4a993ad73c61daa8bbd85a873
# Successfully built antlr4-python3-runtime
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, PyYAML, fsspec, antlr4-python3-runtime, aiohttp, torchmetrics, pyDeprecate, omegaconf, pytorch-lightning, lightly-utils, hydra-core, lightly
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-6.0 aiohttp-3.8.1 aiosignal-1.2.0 antlr4-python3-runtime-4.9.3 async-timeout-4.0.2 asynctest-0.13.0 frozenlist-1.3.0 fsspec-2022.5.0 hydra-core-1.2.0 lightly-1.2.21 lightly-utils-0.0.2 multidict-6.0.2 omegaconf-2.2.2 pyDeprecate-0.3.2 pytorch-lightning-1.6.4 torchmetrics-0.9.2 yarl-1.7.2

# %%
import lightly
from lightly.models.modules.heads import SimSiamPredictionHead
from lightly.models.modules.heads import SimSiamProjectionHead

from lightly.data import LightlyDataset
from lightly.data import ImageCollateFunction
from lightly.models.modules import BarlowTwinsProjectionHead
from lightly.loss import BarlowTwinsLoss

from lightly.data import LightlyDataset
from lightly.data import SimCLRCollateFunction
from lightly.loss import NTXentLoss
from lightly.loss import NegativeCosineSimilarity
from lightly.models.modules import SimCLRProjectionHead

# %%
import math
import torch
import torch.nn as nn
import torchvision
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from torch.utils.data import Dataset, DataLoader
import torch.optim as torch_optim
import torch.optim.lr_scheduler as lr_scheduler
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
from datetime import datetime

from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from matplotlib import pyplot
import seaborn as sns

from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_mutual_info_score
from sklearn.metrics import silhouette_score
from sklearn import mixture
from sklearn.cluster import DBSCAN
from sklearn.cluster import OPTICS
from sklearn.cluster import AgglomerativeClustering

import tensorboard
from tensorboard import notebook
from torch.utils.tensorboard import SummaryWriter

import matplotlib 
import matplotlib.pyplot as plt
#import plotly.express as px

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons
from sklearn.utils import shuffle

import torchvision.transforms as transforms
import torchvision.datasets as datasets
from sklearn.metrics.pairwise import cosine_similarity

import random
from torch.nn.modules.loss import MSELoss
from sklearn.neighbors import KDTree
#from kmodes.kprototypes import KPrototypes

from scipy.io.arff import loadarff
from sklearn.preprocessing import MinMaxScaler 
from sklearn.datasets import make_classification

# %% [markdown]
# ## Load Dataset Pendigits and Check Clustering Result with the Baseline Method Kmeans

# %%
# set the path to the dataset
path_to_data = '/content/drive/MyDrive/Colab_Notebooks/usps.arff'

# %%
raw_data = loadarff(path_to_data)
data = pd.DataFrame(raw_data[0])

# %%
X_ds = data.copy()
X_ds = X_ds.drop(['int0'], axis=1)
X_ds = pd.DataFrame(X_ds).to_numpy()

y_ds = data.copy()
y_ds = y_ds['int0']

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X_ds)
data_X_tsne = np.vstack((X_tsne.T, y_ds)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#check the clustering result with Kmeans
kmeans_ori = KMeans(n_clusters=10).fit(X_ds)
kmeans_labels_ori = kmeans_ori.labels_

normalized_mutual_info_score(kmeans_labels_ori, y_ds)
# Out:
# 0.6147356198138265

# %%
#tsne = TSNE(n_components=2)
#X_tsne = tsne.fit_transform(X_ds)
data_X_tsne = np.vstack((X_tsne.T, kmeans_labels_ori)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ####MixUp

# %%
def mixup(data):
  view = data.copy()
  for i in range(len(view)):
    random_row_index = random.randint(0, len(view)-1)
    view[i] = view[i]*0.7  + view[random_row_index]*0.3
  return view

# %% [markdown]
# ####MixCut

# %%
def mixcut(data):
  data_copy = data.copy()
  view = data.copy()
  mask_len = int(data_copy.shape[1]*0.25)

  for i in range(len(data_copy)):
    random_row_id = random.randint(0, len(data_copy)-1)
    random_column_id = random.randint(0, data_copy.shape[1]-mask_len)
    view[i,random_column_id:(random_column_id+mask_len)] = data_copy[random_row_id,random_column_id:(random_column_id+mask_len)]
  return view

# %% [markdown]
# #### Masking with mean

# %%
def get_random_indices(data, portion_of_mask):
  return np.random.choice(data.shape[1], size=np.floor(data.shape[1]*portion_of_mask).astype(int), replace=False)

# %%
def masking_with_mean(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = column_mu[j]
              
  return view

# %% [markdown]
# ####Masking with random value in domain range

# %%
def masking_with_random(data, portion_of_mask):
  mean = np.mean(data, axis=0)

  column_min = data.min(axis=0).astype(int)
  column_max = data.max(axis=0).astype(int)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = random.randint(column_min[j], column_max[j])
              
  return view

# %% [markdown]
# ####Masking with margin distribution

# %%
def masking_with_margin_distribution(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = np.random.normal(column_mu[j], column_std[j])
              
  return view

# %% [markdown]
# ####Upsampling (SMOTE like)

# %%
#put all data points in kd-tree for fast searching
kdtree = KDTree(X_ds, leaf_size=2)

# %%
#get random point in the k nearest neighbors
def get_idx_random_knn(x,k):
   _, ids = kdtree.query(x.reshape(1, -1), k=k)
   ids = ids.flatten()
   ids = ids[1:-1]
   random_id = np.random.choice(ids, 1)
   return random_id

# %%
#mix up with a random near neighbor 
def mixup_random_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = 0.5*data[i] + 0.5*data[random_neighbor_id]
  return view

# %%
#a random neighbor as augmentation
def random_near_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = data[random_neighbor_id]
  return view

# %% [markdown]
# ##Create Model and Train with Augmented Data

# %%
class MyDataSet(Dataset):
  def __init__(self, view1, view2):
 
    X_view1 = view1.copy()
    X_view2 = view2.copy()
    self.X_view1 = X_view1.copy().astype(np.float32)
    self.X_view2 = X_view2.copy().astype(np.float32)
  
  def __len__(self):
    return len(self.X_view1)
  
  def __getitem__(self, idx):
    return self.X_view1[idx], self.X_view2[idx]

# %%
# define the NN architecture
class convBackbone(nn.Module):
    def __init__(self):
        super(convBackbone, self).__init__()

        #turn on dropout for testing the 'cropping' data augmentation 
        #self.dropout = nn.Dropout(p=0.1)
        
        self.fc1 = nn.Linear(256, 256, bias=False)
        self.bn1 = nn.BatchNorm1d(256)

        self.fc2 = nn.Linear(256, 256, bias=False)
        self.bn2 = nn.BatchNorm1d(256)

        self.fc3 = nn.Linear(256, 128, bias=False)
        self.bn3 = nn.BatchNorm1d(128)


    def forward(self, x):

        #turn on dropout for testing the 'cropping' data augmentation 
        #x = self.dropout(x)
        
        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.bn3(self.fc3(x))
                
        return x

# %%
class SimCLR(nn.Module):
    def __init__(self, backbone):
        super().__init__()
        self.backbone = backbone
        self.projection_head = SimCLRProjectionHead(128, 64, 128)

    def forward(self, x):
        x = self.backbone(x).flatten(start_dim=1)
        z = self.projection_head(x)
        return x,z

backbone = convBackbone()
model = SimCLR(backbone)

# %%
criterion = NTXentLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.05, momentum=0.9,weight_decay=1e-4)

#cosine annealing lr
scheduler = lr_scheduler.CosineAnnealingLR(optimizer,T_max=800, eta_min=0)

# %%
view1 = random_near_neighbor(X_ds, 18)
view2 = random_near_neighbor(X_ds, 19)

#turn on the following to test other augmentations

#view1 = mixup_random_neighbor(X_ds, 15)
#view2 = mixup_random_neighbor(X_ds, 15)

#view1 = mixup(X_ds)
#view2 = mixup(X_ds)

#view1 = mixcut(X_ds)
#view2 = mixcut(X_ds)

#view1 = masking_with_mean(X_ds, 0.4)
#view2 = masking_with_mean(X_ds, 0.4)

#view1 = masking_with_random(X_ds, 0.4)
#view2 = masking_with_random(X_ds, 0.4)

#view1 = masking_with_margin_distribution(X_ds, 0.4)
#view2 = masking_with_margin_distribution(X_ds, 0.4)

train_ds = MyDataSet(view1, view2)
train_dl = DataLoader(train_ds, batch_size=256, shuffle=True)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

for epoch in range(500):
    total_loss = 0
    for x0, x1 in train_dl:

        x0 = x0.to(device)
        x1 = x1.to(device)
        _,z0 = model(x0)
        _,z1 = model(x1)

        loss = criterion(z0, z1)
        total_loss += loss.detach()
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        scheduler.step()

    avg_loss = total_loss / len(train_dl)
    print(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
# Out:
# epoch: 00, loss: 4.75658
# epoch: 01, loss: 4.60986
# epoch: 02, loss: 4.58736
# epoch: 03, loss: 4.57724
# epoch: 04, loss: 4.57069
# epoch: 05, loss: 4.56431
# epoch: 06, loss: 4.55914
# epoch: 07, loss: 4.55321
# epoch: 08, loss: 4.54899
# epoch: 09, loss: 4.54416
# epoch: 10, loss: 4.54254
# epoch: 11, loss: 4.53837
# epoch: 12, loss: 4.53687
# epoch: 13, loss: 4.53251
# epoch: 14, loss: 4.53164
# epoch: 15, loss: 4.52867
# epoch: 16, loss: 4.52677
# epoch: 17, loss: 4.52574
# epoch: 18, loss: 4.52403
# epoch: 19, loss: 4.52162
# epoch: 20, loss: 4.52523
# epoch: 21, loss: 4.52199
# epoch: 22, loss: 4.52142
# epoch: 23, loss: 4.52366
# epoch: 24, loss: 4.52548
# epoch: 25, loss: 4.52448
# epoch: 26, loss: 4.52294
# epoch: 27, loss: 4.52382
# epoch: 28, loss: 4.52317
# epoch: 29, loss: 4.52433
# epoch: 30, loss: 4.52489
# epoch: 31, loss: 4.52526
# epoch: 32, loss: 4.52488
# epoch: 33, loss: 4.52631
# epoch: 34, loss: 4.52477
# epoch: 35, loss: 4.52381
# epoch: 36, loss: 4.52513
# epoch: 37, loss: 4.52275
# epoch: 38, loss: 4.52128
# epoch: 39, loss: 4.51969
# epoch: 40, loss: 4.51937
# epoch: 41, loss: 4.51822
# epoch: 42, loss: 4.51774
# epoch: 43, loss: 4.51638
# epoch: 44, loss: 4.51263
# epoch: 45, loss: 4.51211
# epoch: 46, loss: 4.50799
# epoch: 47, loss: 4.50951
# epoch: 48, loss: 4.50182
# epoch: 49, loss: 4.50109
# epoch: 50, loss: 4.49811
# epoch: 51, loss: 4.49353
# epoch: 52, loss: 4.49233
# epoch: 53, loss: 4.48885
# epoch: 54, loss: 4.48634
# epoch: 55, loss: 4.48468
# epoch: 56, loss: 4.48138
# epoch: 57, loss: 4.47697
# epoch: 58, loss: 4.47620
# epoch: 59, loss: 4.47316
# epoch: 60, loss: 4.47352
# epoch: 61, loss: 4.47023
# epoch: 62, loss: 4.46899
# epoch: 63, loss: 4.46849
# epoch: 64, loss: 4.46712
# epoch: 65, loss: 4.46839
# epoch: 66, loss: 4.46866
# epoch: 67, loss: 4.46860
# epoch: 68, loss: 4.46916
# epoch: 69, loss: 4.46916
# epoch: 70, loss: 4.47265
# epoch: 71, loss: 4.47244
# epoch: 72, loss: 4.47384
# epoch: 73, loss: 4.47623
# epoch: 74, loss: 4.47753
# epoch: 75, loss: 4.48139
# epoch: 76, loss: 4.48192
# epoch: 77, loss: 4.48521
# epoch: 78, loss: 4.48792
# epoch: 79, loss: 4.48799
# epoch: 80, loss: 4.48889
# epoch: 81, loss: 4.49014
# epoch: 82, loss: 4.48878
# epoch: 83, loss: 4.48981
# epoch: 84, loss: 4.48932
# epoch: 85, loss: 4.48962
# epoch: 86, loss: 4.48840
# epoch: 87, loss: 4.48876
# epoch: 88, loss: 4.48695
# epoch: 89, loss: 4.48513
# epoch: 90, loss: 4.48166
# epoch: 91, loss: 4.47791
# epoch: 92, loss: 4.47665
# epoch: 93, loss: 4.47511
# epoch: 94, loss: 4.47212
# epoch: 95, loss: 4.47061
# epoch: 96, loss: 4.46623
# epoch: 97, loss: 4.46420
# epoch: 98, loss: 4.46266
# epoch: 99, loss: 4.45953
# epoch: 100, loss: 4.45611
# epoch: 101, loss: 4.45469
# epoch: 102, loss: 4.45104
# epoch: 103, loss: 4.44826
# epoch: 104, loss: 4.44719
# epoch: 105, loss: 4.44446
# epoch: 106, loss: 4.44530
# epoch: 107, loss: 4.44587
# epoch: 108, loss: 4.44543
# epoch: 109, loss: 4.44517
# epoch: 110, loss: 4.44491
# epoch: 111, loss: 4.44569
# epoch: 112, loss: 4.44913
# epoch: 113, loss: 4.44823
# epoch: 114, loss: 4.44981
# epoch: 115, loss: 4.45068
# epoch: 116, loss: 4.45444
# epoch: 117, loss: 4.45447
# epoch: 118, loss: 4.45941
# epoch: 119, loss: 4.46092
# epoch: 120, loss: 4.46333
# epoch: 121, loss: 4.46669
# epoch: 122, loss: 4.46929
# epoch: 123, loss: 4.47055
# epoch: 124, loss: 4.47203
# epoch: 125, loss: 4.47240
# epoch: 126, loss: 4.47550
# epoch: 127, loss: 4.47494
# epoch: 128, loss: 4.47437
# epoch: 129, loss: 4.47186
# epoch: 130, loss: 4.47375
# epoch: 131, loss: 4.47131
# epoch: 132, loss: 4.47125
# epoch: 133, loss: 4.46724
# epoch: 134, loss: 4.46911
# epoch: 135, loss: 4.46600
# epoch: 136, loss: 4.46180
# epoch: 137, loss: 4.45741
# epoch: 138, loss: 4.45491
# epoch: 139, loss: 4.45308
# epoch: 140, loss: 4.44914
# epoch: 141, loss: 4.44661
# epoch: 142, loss: 4.44382
# epoch: 143, loss: 4.44350
# epoch: 144, loss: 4.44091
# epoch: 145, loss: 4.43759
# epoch: 146, loss: 4.43610
# epoch: 147, loss: 4.43437
# epoch: 148, loss: 4.43344
# epoch: 149, loss: 4.43200
# epoch: 150, loss: 4.43084
# epoch: 151, loss: 4.43076
# epoch: 152, loss: 4.43199
# epoch: 153, loss: 4.43404
# epoch: 154, loss: 4.43352
# epoch: 155, loss: 4.43308
# epoch: 156, loss: 4.43613
# epoch: 157, loss: 4.43629
# epoch: 158, loss: 4.43674
# epoch: 159, loss: 4.43893
# epoch: 160, loss: 4.44375
# epoch: 161, loss: 4.44478
# epoch: 162, loss: 4.44823
# epoch: 163, loss: 4.45042
# epoch: 164, loss: 4.45436
# epoch: 165, loss: 4.45285
# epoch: 166, loss: 4.45583
# epoch: 167, loss: 4.46129
# epoch: 168, loss: 4.46225
# epoch: 169, loss: 4.46124
# epoch: 170, loss: 4.46233
# epoch: 171, loss: 4.46193
# epoch: 172, loss: 4.46289
# epoch: 173, loss: 4.45944
# epoch: 174, loss: 4.46345
# epoch: 175, loss: 4.45990
# epoch: 176, loss: 4.45749
# epoch: 177, loss: 4.45505
# epoch: 178, loss: 4.45591
# epoch: 179, loss: 4.45203
# epoch: 180, loss: 4.44854
# epoch: 181, loss: 4.44652
# epoch: 182, loss: 4.44494
# epoch: 183, loss: 4.44119
# epoch: 184, loss: 4.44023
# epoch: 185, loss: 4.43754
# epoch: 186, loss: 4.43400
# epoch: 187, loss: 4.43248
# epoch: 188, loss: 4.43109
# epoch: 189, loss: 4.42786
# epoch: 190, loss: 4.42664
# epoch: 191, loss: 4.42638
# epoch: 192, loss: 4.42337
# epoch: 193, loss: 4.42284
# epoch: 194, loss: 4.42417
# epoch: 195, loss: 4.42335
# epoch: 196, loss: 4.42349
# epoch: 197, loss: 4.42513
# epoch: 198, loss: 4.42535
# epoch: 199, loss: 4.42829
# epoch: 200, loss: 4.42654
# epoch: 201, loss: 4.42828
# epoch: 202, loss: 4.43061
# epoch: 203, loss: 4.43501
# epoch: 204, loss: 4.43630
# epoch: 205, loss: 4.43843
# epoch: 206, loss: 4.44026
# epoch: 207, loss: 4.44637
# epoch: 208, loss: 4.44518
# epoch: 209, loss: 4.45026
# epoch: 210, loss: 4.44961
# epoch: 211, loss: 4.45343
# epoch: 212, loss: 4.45101
# epoch: 213, loss: 4.45371
# epoch: 214, loss: 4.45507
# epoch: 215, loss: 4.45405
# epoch: 216, loss: 4.45350
# epoch: 217, loss: 4.45364
# epoch: 218, loss: 4.45178
# epoch: 219, loss: 4.45376
# epoch: 220, loss: 4.45192
# epoch: 221, loss: 4.44738
# epoch: 222, loss: 4.44694
# epoch: 223, loss: 4.44451
# epoch: 224, loss: 4.43982
# epoch: 225, loss: 4.43778
# epoch: 226, loss: 4.43507
# epoch: 227, loss: 4.43228
# epoch: 228, loss: 4.43102
# epoch: 229, loss: 4.42660
# epoch: 230, loss: 4.42553
# epoch: 231, loss: 4.42312
# epoch: 232, loss: 4.42196
# epoch: 233, loss: 4.42016
# epoch: 234, loss: 4.41839
# epoch: 235, loss: 4.41827
# epoch: 236, loss: 4.41822
# epoch: 237, loss: 4.41833
# epoch: 238, loss: 4.41844
# epoch: 239, loss: 4.41863
# epoch: 240, loss: 4.42028
# epoch: 241, loss: 4.41956
# epoch: 242, loss: 4.42161
# epoch: 243, loss: 4.42091
# epoch: 244, loss: 4.42173
# epoch: 245, loss: 4.42282
# epoch: 246, loss: 4.42717
# epoch: 247, loss: 4.42771
# epoch: 248, loss: 4.43199
# epoch: 249, loss: 4.43245
# epoch: 250, loss: 4.43687
# epoch: 251, loss: 4.44730
# epoch: 252, loss: 4.44299
# epoch: 253, loss: 4.44240
# epoch: 254, loss: 4.44518
# epoch: 255, loss: 4.44556
# epoch: 256, loss: 4.44784
# epoch: 257, loss: 4.44861
# epoch: 258, loss: 4.44606
# epoch: 259, loss: 4.44741
# epoch: 260, loss: 4.44989
# epoch: 261, loss: 4.44761
# epoch: 262, loss: 4.44729
# epoch: 263, loss: 4.44449
# epoch: 264, loss: 4.44260
# epoch: 265, loss: 4.44095
# epoch: 266, loss: 4.43550
# epoch: 267, loss: 4.43475
# epoch: 268, loss: 4.43301
# epoch: 269, loss: 4.42927
# epoch: 270, loss: 4.42621
# epoch: 271, loss: 4.42686
# epoch: 272, loss: 4.42376
# epoch: 273, loss: 4.42063
# epoch: 274, loss: 4.41780
# epoch: 275, loss: 4.41669
# epoch: 276, loss: 4.41529
# epoch: 277, loss: 4.41553
# epoch: 278, loss: 4.41270
# epoch: 279, loss: 4.41177
# epoch: 280, loss: 4.41103
# epoch: 281, loss: 4.41278
# epoch: 282, loss: 4.41200
# epoch: 283, loss: 4.41264
# epoch: 284, loss: 4.41167
# epoch: 285, loss: 4.41378
# epoch: 286, loss: 4.41572
# epoch: 287, loss: 4.41683
# epoch: 288, loss: 4.41603
# epoch: 289, loss: 4.41918
# epoch: 290, loss: 4.42233
# epoch: 291, loss: 4.42453
# epoch: 292, loss: 4.42721
# epoch: 293, loss: 4.42943
# epoch: 294, loss: 4.43149
# epoch: 295, loss: 4.43387
# epoch: 296, loss: 4.43944
# epoch: 297, loss: 4.43778
# epoch: 298, loss: 4.44017
# epoch: 299, loss: 4.44045
# epoch: 300, loss: 4.44088
# epoch: 301, loss: 4.44201
# epoch: 302, loss: 4.44533
# epoch: 303, loss: 4.44169
# epoch: 304, loss: 4.44220
# epoch: 305, loss: 4.44292
# epoch: 306, loss: 4.44187
# epoch: 307, loss: 4.44051
# epoch: 308, loss: 4.43683
# epoch: 309, loss: 4.43352
# epoch: 310, loss: 4.43202
# epoch: 311, loss: 4.42950
# epoch: 312, loss: 4.42665
# epoch: 313, loss: 4.42552
# epoch: 314, loss: 4.42488
# epoch: 315, loss: 4.42013
# epoch: 316, loss: 4.41678
# epoch: 317, loss: 4.41577
# epoch: 318, loss: 4.41329
# epoch: 319, loss: 4.41153
# epoch: 320, loss: 4.41038
# epoch: 321, loss: 4.41048
# epoch: 322, loss: 4.40933
# epoch: 323, loss: 4.40753
# epoch: 324, loss: 4.40867
# epoch: 325, loss: 4.40854
# epoch: 326, loss: 4.40773
# epoch: 327, loss: 4.40886
# epoch: 328, loss: 4.40935
# epoch: 329, loss: 4.41025
# epoch: 330, loss: 4.41223
# epoch: 331, loss: 4.41539
# epoch: 332, loss: 4.41596
# epoch: 333, loss: 4.41741
# epoch: 334, loss: 4.41891
# epoch: 335, loss: 4.42232
# epoch: 336, loss: 4.42614
# epoch: 337, loss: 4.42685
# epoch: 338, loss: 4.43340
# epoch: 339, loss: 4.43375
# epoch: 340, loss: 4.43267
# epoch: 341, loss: 4.43543
# epoch: 342, loss: 4.43809
# epoch: 343, loss: 4.43652
# epoch: 344, loss: 4.44156
# epoch: 345, loss: 4.43963
# epoch: 346, loss: 4.43689
# epoch: 347, loss: 4.43766
# epoch: 348, loss: 4.43530
# epoch: 349, loss: 4.43568
# epoch: 350, loss: 4.43167
# epoch: 351, loss: 4.43175
# epoch: 352, loss: 4.43085
# epoch: 353, loss: 4.42734
# epoch: 354, loss: 4.42544
# epoch: 355, loss: 4.42217
# epoch: 356, loss: 4.42020
# epoch: 357, loss: 4.41798
# epoch: 358, loss: 4.41652
# epoch: 359, loss: 4.41403
# epoch: 360, loss: 4.41149
# epoch: 361, loss: 4.40918
# epoch: 362, loss: 4.40633
# epoch: 363, loss: 4.40727
# epoch: 364, loss: 4.40678
# epoch: 365, loss: 4.40695
# epoch: 366, loss: 4.40423
# epoch: 367, loss: 4.40442
# epoch: 368, loss: 4.40635
# epoch: 369, loss: 4.40449
# epoch: 370, loss: 4.40546
# epoch: 371, loss: 4.40624
# epoch: 372, loss: 4.40666
# epoch: 373, loss: 4.40825
# epoch: 374, loss: 4.41005
# epoch: 375, loss: 4.41145
# epoch: 376, loss: 4.41267
# epoch: 377, loss: 4.41458
# epoch: 378, loss: 4.41716
# epoch: 379, loss: 4.42045
# epoch: 380, loss: 4.42268
# epoch: 381, loss: 4.42587
# epoch: 382, loss: 4.42765
# epoch: 383, loss: 4.42976
# epoch: 384, loss: 4.43163
# epoch: 385, loss: 4.43464
# epoch: 386, loss: 4.43451
# epoch: 387, loss: 4.43367
# epoch: 388, loss: 4.43620
# epoch: 389, loss: 4.43497
# epoch: 390, loss: 4.43292
# epoch: 391, loss: 4.43404
# epoch: 392, loss: 4.43408
# epoch: 393, loss: 4.43207
# epoch: 394, loss: 4.42963
# epoch: 395, loss: 4.42899
# epoch: 396, loss: 4.42613
# epoch: 397, loss: 4.42266
# epoch: 398, loss: 4.41964
# epoch: 399, loss: 4.41656
# epoch: 400, loss: 4.41441
# epoch: 401, loss: 4.41261
# epoch: 402, loss: 4.41133
# epoch: 403, loss: 4.40859
# epoch: 404, loss: 4.40668
# epoch: 405, loss: 4.40518
# epoch: 406, loss: 4.40332
# epoch: 407, loss: 4.40217
# epoch: 408, loss: 4.40183
# epoch: 409, loss: 4.39909
# epoch: 410, loss: 4.40025
# epoch: 411, loss: 4.40198
# epoch: 412, loss: 4.40059
# epoch: 413, loss: 4.40210
# epoch: 414, loss: 4.40137
# epoch: 415, loss: 4.40342
# epoch: 416, loss: 4.40460
# epoch: 417, loss: 4.40495
# epoch: 418, loss: 4.40835
# epoch: 419, loss: 4.40826
# epoch: 420, loss: 4.41106
# epoch: 421, loss: 4.41339
# epoch: 422, loss: 4.41626
# epoch: 423, loss: 4.41848
# epoch: 424, loss: 4.42091
# epoch: 425, loss: 4.42377
# epoch: 426, loss: 4.42445
# epoch: 427, loss: 4.42593
# epoch: 428, loss: 4.42881
# epoch: 429, loss: 4.43185
# epoch: 430, loss: 4.43164
# epoch: 431, loss: 4.43225
# epoch: 432, loss: 4.43121
# epoch: 433, loss: 4.43153
# epoch: 434, loss: 4.42989
# epoch: 435, loss: 4.42719
# epoch: 436, loss: 4.42851
# epoch: 437, loss: 4.42662
# epoch: 438, loss: 4.42665
# epoch: 439, loss: 4.42368
# epoch: 440, loss: 4.41947
# epoch: 441, loss: 4.41569
# epoch: 442, loss: 4.41573
# epoch: 443, loss: 4.41218
# epoch: 444, loss: 4.41135
# epoch: 445, loss: 4.40774
# epoch: 446, loss: 4.40614
# epoch: 447, loss: 4.40482
# epoch: 448, loss: 4.40264
# epoch: 449, loss: 4.40169
# epoch: 450, loss: 4.39956
# epoch: 451, loss: 4.39913
# epoch: 452, loss: 4.39808
# epoch: 453, loss: 4.39901
# epoch: 454, loss: 4.39859
# epoch: 455, loss: 4.39680
# epoch: 456, loss: 4.39765
# epoch: 457, loss: 4.39949
# epoch: 458, loss: 4.39953
# epoch: 459, loss: 4.40177
# epoch: 460, loss: 4.40266
# epoch: 461, loss: 4.40336
# epoch: 462, loss: 4.40466
# epoch: 463, loss: 4.40742
# epoch: 464, loss: 4.40984
# epoch: 465, loss: 4.41087
# epoch: 466, loss: 4.41439
# epoch: 467, loss: 4.41661
# epoch: 468, loss: 4.41767
# epoch: 469, loss: 4.42319
# epoch: 470, loss: 4.42469
# epoch: 471, loss: 4.42571
# epoch: 472, loss: 4.42586
# epoch: 473, loss: 4.42774
# epoch: 474, loss: 4.42898
# epoch: 475, loss: 4.43005
# epoch: 476, loss: 4.42949
# epoch: 477, loss: 4.42961
# epoch: 478, loss: 4.42846
# epoch: 479, loss: 4.42426
# epoch: 480, loss: 4.42315
# epoch: 481, loss: 4.42314
# epoch: 482, loss: 4.41970
# epoch: 483, loss: 4.41663
# epoch: 484, loss: 4.41505
# epoch: 485, loss: 4.41350
# epoch: 486, loss: 4.41002
# epoch: 487, loss: 4.40852
# epoch: 488, loss: 4.40466
# epoch: 489, loss: 4.40472
# epoch: 490, loss: 4.40227
# epoch: 491, loss: 4.39994
# epoch: 492, loss: 4.39797
# epoch: 493, loss: 4.39765
# epoch: 494, loss: 4.39824
# epoch: 495, loss: 4.39559
# epoch: 496, loss: 4.39510
# epoch: 497, loss: 4.39542
# epoch: 498, loss: 4.39400
# epoch: 499, loss: 4.39542

# %% [markdown]
# ##Check the Training Result

# %%
ds_cl= MyDataSet(X_ds, X_ds)
dl_cl = DataLoader(ds_cl, batch_size=256)

# %%
embeddings = []

# disable gradients for faster calculations
model.eval()
with torch.no_grad():
    for dl_cl1, dl_cl2 in dl_cl:

        dl_cl1 = dl_cl1.to(device)
        x,z = model(dl_cl1)
        
        # store the embeddings in lists
        embeddings.append(x)

# concatenate the embeddings, targets and convert to numpy
embeddings = torch.cat(embeddings, dim=0)
embeddings = embeddings.cpu().numpy()

# %%
test = (embeddings - embeddings.mean(axis=0)) / (embeddings.std(axis=0))

# %%
#KMeans in latent space
kmeans_backbone = KMeans(n_clusters=10).fit(test)
kmeans_labels_backbone = kmeans_backbone.labels_

# %%
normalized_mutual_info_score(kmeans_labels_backbone, y_ds)
# Out:
# 0.7480377868984744

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(embeddings)
data_X_tsne = np.vstack((X_tsne.T, kmeans_labels_backbone)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#NMI increases from 0.69 to 0.74
