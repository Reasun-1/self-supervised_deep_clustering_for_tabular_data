# %% [markdown]
# ## Conifuration

# %%
#import the lib for contrastive learning framework
# !pip install lightly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lightly in /usr/local/lib/python3.7/dist-packages (1.2.23)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.21.6)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (57.4.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.8.2)
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.7/dist-packages (from lightly) (4.64.0)
# Requirement already satisfied: pytorch-lightning>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.6.5)
# Requirement already satisfied: lightly-utils~=0.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (0.0.2)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.7/dist-packages (from lightly) (2022.6.15)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from lightly) (0.13.0+cu113)
# Requirement already satisfied: hydra-core>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.15.0)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.24.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.23.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (5.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (21.3)
# Requirement already satisfied: omegaconf~=2.2 in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (2.2.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (4.9.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from lightly-utils~=0.0.0->lightly) (7.1.2)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.7/dist-packages (from omegaconf~=2.2->hydra-core>=1.0.0->lightly) (6.0)
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (3.17.3)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2.8.0)
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (1.12.0+cu113)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (0.3.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (4.1.1)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2022.5.0)
# Requirement already satisfied: torchmetrics>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (0.9.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->hydra-core>=1.0.0->lightly) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (3.0.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.6)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.47.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.3.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (21.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (6.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (0.13.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (2.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (1.3.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (1.2.0)

# %%
import lightly
from lightly.models.modules.heads import SimSiamPredictionHead
from lightly.models.modules.heads import SimSiamProjectionHead

from lightly.data import LightlyDataset
from lightly.data import ImageCollateFunction
from lightly.models.modules import BarlowTwinsProjectionHead
from lightly.loss import BarlowTwinsLoss

from lightly.data import LightlyDataset
from lightly.data import SimCLRCollateFunction
from lightly.loss import NTXentLoss
from lightly.loss import NegativeCosineSimilarity
from lightly.models.modules import SimCLRProjectionHead

# %%
import math
import torch
import torch.nn as nn
import torchvision
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from torch.utils.data import Dataset, DataLoader
import torch.optim as torch_optim
import torch.optim.lr_scheduler as lr_scheduler
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
from datetime import datetime

from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from matplotlib import pyplot
import seaborn as sns

from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_mutual_info_score
from sklearn.metrics import silhouette_score
from sklearn import mixture
from sklearn.cluster import DBSCAN
from sklearn.cluster import OPTICS
from sklearn.cluster import AgglomerativeClustering

import tensorboard
from tensorboard import notebook
from torch.utils.tensorboard import SummaryWriter

import matplotlib 
import matplotlib.pyplot as plt
#import plotly.express as px

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons
from sklearn.utils import shuffle

import torchvision.transforms as transforms
import torchvision.datasets as datasets
from sklearn.metrics.pairwise import cosine_similarity

import random
from torch.nn.modules.loss import MSELoss
from sklearn.neighbors import KDTree
#from kmodes.kprototypes import KPrototypes

from scipy.io.arff import loadarff
from sklearn.preprocessing import MinMaxScaler 
from sklearn.datasets import make_classification
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline

# %% [markdown]
# ## Load Dataset mobile and Check Clustering Result with the Baseline Method Kmeans

# %%
# set the path to the dataset
path_to_data = '/content/drive/MyDrive/Colab_Notebooks/mobile.csv'

# %%
data = pd.read_csv(path_to_data)

# %%
#clean outliers of feature ram
range0_data = data.loc[data['price_range'] == 0]
range1_data = data.loc[data['price_range'] == 1]
range2_data = data.loc[data['price_range'] == 2]
range3_data = data.loc[data['price_range'] == 3]

mean_ram_range0 = range0_data.ram.mean()
mean_ram_range1 = range1_data.ram.mean()
mean_ram_range2 = range2_data.ram.mean()
mean_ram_range3 = range3_data.ram.mean()

std_ram_range0 = range0_data.ram.std()
std_ram_range1 = range1_data.ram.std()
std_ram_range2 = range2_data.ram.std()
std_ram_range3 = range3_data.ram.std()

range0_data = range0_data.drop(range0_data[(range0_data.ram < mean_ram_range0 - 0.85*std_ram_range0) | (range0_data.ram > mean_ram_range0 + 0.85*std_ram_range0)].index)
range1_data = range1_data.drop(range1_data[(range1_data.ram < mean_ram_range1 - 0.85*std_ram_range1) | (range1_data.ram > mean_ram_range1 + 0.85*std_ram_range1)].index)
range2_data = range2_data.drop(range2_data[(range2_data.ram < mean_ram_range2 - 0.85*std_ram_range2) | (range2_data.ram > mean_ram_range2 + 0.85*std_ram_range2)].index)
range3_data = range3_data.drop(range3_data[(range3_data.ram < mean_ram_range3 - 0.85*std_ram_range3) | (range3_data.ram > mean_ram_range3 + 0.85*std_ram_range3)].index)

clean_data = pd.concat([range0_data, range1_data, range2_data, range3_data], axis=0, ignore_index=True)

# %%
X = clean_data.copy()
X = X.drop(['price_range'], axis=1)
X_ds = pd.DataFrame(X).to_numpy()

# %%
y_ds = clean_data.copy()
y_ds = y_ds['price_range']
y_ds = LabelEncoder().fit_transform(y_ds)

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X_ds)
data_X_tsne = np.vstack((X_tsne.T, y_ds)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#check the clustering result with Kmeans
kmeans_ori = KMeans(n_clusters=4).fit(X_ds)
kmeans_labels_ori = kmeans_ori.labels_

normalized_mutual_info_score(kmeans_labels_ori, y_ds)
# Out:
# 0.5951744833143676

# %%
data_X_tsne = np.vstack((X_tsne.T, kmeans_labels_ori)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ####MixUp

# %%
def mixup(data):
  view = data.copy()
  for i in range(len(view)):
    random_row_index = random.randint(0, len(view)-1)
    view[i] = view[i]*0.7  + view[random_row_index]*0.3
  return view

# %% [markdown]
# ####MixCut

# %%
def mixcut(data):
  data_copy = data.copy()
  view = data.copy()
  mask_len = int(data_copy.shape[1]*0.25)

  for i in range(len(data_copy)):
    random_row_id = random.randint(0, len(data_copy)-1)
    random_column_id = random.randint(0, data_copy.shape[1]-mask_len)
    view[i,random_column_id:(random_column_id+mask_len)] = data_copy[random_row_id,random_column_id:(random_column_id+mask_len)]
  return view

# %% [markdown]
# #### Masking with mean

# %%
def get_random_indices(data, portion_of_mask):
  return np.random.choice(data.shape[1], size=np.floor(data.shape[1]*portion_of_mask).astype(int), replace=False)

# %%
def masking_with_mean(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = column_mu[j]
              
  return view

# %% [markdown]
# ####Masking with random value in domain range

# %%
def masking_with_random(data, portion_of_mask):
  mean = np.mean(data, axis=0)

  column_min = data.min(axis=0).astype(int)
  column_max = data.max(axis=0).astype(int)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = random.randint(column_min[j], column_max[j])
              
  return view

# %% [markdown]
# ####Masking with margin distribution

# %%
def masking_with_margin_distribution(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = np.random.normal(column_mu[j], column_std[j])
              
  return view

# %% [markdown]
# ####Upsampling (SMOTE like)

# %%
#put all data points in kd-tree for fast searching
kdtree = KDTree(X_ds, leaf_size=2)

# %%
#get random point in the k nearest neighbors
def get_idx_random_knn(x,k):
   _, ids = kdtree.query(x.reshape(1, -1), k=k)
   ids = ids.flatten()
   ids = ids[1:-1]
   random_id = np.random.choice(ids, 1)
   return random_id

# %%
#mix up with a random near neighbor 
def mixup_random_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = 0.5*data[i] + 0.5*data[random_neighbor_id]
  return view

# %%
#a random neighbor as augmentation
def random_near_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = data[random_neighbor_id]
  return view

# %% [markdown]
# ##Create Model and Train with Augmented Data

# %%
class MyDataSet(Dataset):
  def __init__(self, view1, view2):
 
    X_view1 = view1.copy()
    X_view2 = view2.copy()
    self.X_view1 = X_view1.copy().astype(np.float32)
    self.X_view2 = X_view2.copy().astype(np.float32)
  
  def __len__(self):
    return len(self.X_view1)
  
  def __getitem__(self, idx):
    return self.X_view1[idx], self.X_view2[idx]

# %%
# define the NN architecture
class convBackbone(nn.Module):
    def __init__(self):
        super(convBackbone, self).__init__()

        #turn on dropout for testing the 'cropping' data augmentation 
        #self.dropout = nn.Dropout(p=0.1)
        
        self.fc1 = nn.Linear(20, 20, bias=False)
        self.bn1 = nn.BatchNorm1d(20)

        self.fc2 = nn.Linear(20, 20, bias=False)
        self.bn2 = nn.BatchNorm1d(20)

        self.fc3 = nn.Linear(20, 20, bias=False)
        self.bn3 = nn.BatchNorm1d(20)


    def forward(self, x):

        #turn on dropout for testing the 'cropping' data augmentation 
        #x = self.dropout(x)
        
        #x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.bn3(self.fc3(x))
                
        return x

# %%
class BarlowTwins(nn.Module):
    def __init__(self, backbone):
        super().__init__()
        self.backbone = backbone
        self.projection_head = BarlowTwinsProjectionHead(20, 256, 256)

    def forward(self, x):
        x = self.backbone(x)
        y = x.flatten(start_dim=1)
        z = self.projection_head(y)
        return x,z

backbone = convBackbone()
model = BarlowTwins(backbone)

# %%
criterion = BarlowTwinsLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.05)

#cosine annealing lr
scheduler = lr_scheduler.CosineAnnealingLR(optimizer,T_max=500, eta_min=0)

# %%
view1 = random_near_neighbor(X_ds, 19)
view2 = random_near_neighbor(X_ds, 20)

#turn on the following to test other augmentations

#view1 = mixup_random_neighbor(X_ds, 15)
#view2 = mixup_random_neighbor(X_ds, 15)

#view1 = mixup(X_ds)
#view2 = mixup(X_ds)

#view1 = mixcut(X_ds)
#view2 = mixcut(X_ds)

#view1 = masking_with_mean(X_ds, 0.4)
#view2 = masking_with_mean(X_ds, 0.4)

#view1 = masking_with_random(X_ds, 0.4)
#view2 = masking_with_random(X_ds, 0.4)

#view1 = masking_with_margin_distribution(X_ds, 0.4)
#view2 = masking_with_margin_distribution(X_ds, 0.4)

train_ds = MyDataSet(view1, view2)
train_dl = DataLoader(train_ds, batch_size=256, shuffle=True)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

for epoch in range(500):
    total_loss = 0

    for x0,x1 in train_dl:
        x0 = x0.to(device)
        x1 = x1.to(device)
        _,z0 = model(x0)
        _,z1 = model(x1)

        loss = criterion(z0, z1)
        total_loss += loss.detach()
        loss.backward()

        optimizer.step()
        optimizer.zero_grad()
        scheduler.step()

    avg_loss = total_loss / len(train_dl)
    print(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
# Out:
# epoch: 00, loss: 52.64711
# epoch: 01, loss: 46.17356
# epoch: 02, loss: 34.74451
# epoch: 03, loss: 30.29055
# epoch: 04, loss: 28.54136
# epoch: 05, loss: 26.93241
# epoch: 06, loss: 26.44045
# epoch: 07, loss: 25.75979
# epoch: 08, loss: 24.93936
# epoch: 09, loss: 24.78372
# epoch: 10, loss: 24.46806
# epoch: 11, loss: 24.25616
# epoch: 12, loss: 24.15273
# epoch: 13, loss: 23.52147
# epoch: 14, loss: 23.49492
# epoch: 15, loss: 23.46949
# epoch: 16, loss: 23.44798
# epoch: 17, loss: 22.93968
# epoch: 18, loss: 22.69255
# epoch: 19, loss: 22.85555
# epoch: 20, loss: 22.70645
# epoch: 21, loss: 22.55212
# epoch: 22, loss: 22.37993
# epoch: 23, loss: 22.35474
# epoch: 24, loss: 22.78157
# epoch: 25, loss: 21.97239
# epoch: 26, loss: 21.94223
# epoch: 27, loss: 22.27945
# epoch: 28, loss: 22.01645
# epoch: 29, loss: 21.95701
# epoch: 30, loss: 22.05997
# epoch: 31, loss: 21.64709
# epoch: 32, loss: 21.68376
# epoch: 33, loss: 21.37614
# epoch: 34, loss: 21.88641
# epoch: 35, loss: 21.31472
# epoch: 36, loss: 21.28986
# epoch: 37, loss: 21.33657
# epoch: 38, loss: 21.16304
# epoch: 39, loss: 20.52217
# epoch: 40, loss: 20.90916
# epoch: 41, loss: 21.47586
# epoch: 42, loss: 20.86386
# epoch: 43, loss: 20.98001
# epoch: 44, loss: 20.79511
# epoch: 45, loss: 20.40946
# epoch: 46, loss: 20.80040
# epoch: 47, loss: 20.81181
# epoch: 48, loss: 20.99965
# epoch: 49, loss: 20.92277
# epoch: 50, loss: 20.57365
# epoch: 51, loss: 21.11823
# epoch: 52, loss: 20.83889
# epoch: 53, loss: 20.20852
# epoch: 54, loss: 19.98365
# epoch: 55, loss: 19.92751
# epoch: 56, loss: 20.18237
# epoch: 57, loss: 20.68235
# epoch: 58, loss: 20.60009
# epoch: 59, loss: 19.93571
# epoch: 60, loss: 20.06594
# epoch: 61, loss: 19.92941
# epoch: 62, loss: 19.86122
# epoch: 63, loss: 19.95050
# epoch: 64, loss: 19.92570
# epoch: 65, loss: 19.76992
# epoch: 66, loss: 19.99157
# epoch: 67, loss: 19.92023
# epoch: 68, loss: 19.95380
# epoch: 69, loss: 20.07234
# epoch: 70, loss: 19.39925
# epoch: 71, loss: 19.51571
# epoch: 72, loss: 19.48969
# epoch: 73, loss: 19.59200
# epoch: 74, loss: 20.00294
# epoch: 75, loss: 19.56495
# epoch: 76, loss: 19.67105
# epoch: 77, loss: 19.77765
# epoch: 78, loss: 19.48817
# epoch: 79, loss: 19.75373
# epoch: 80, loss: 19.54874
# epoch: 81, loss: 19.08581
# epoch: 82, loss: 19.55317
# epoch: 83, loss: 19.11963
# epoch: 84, loss: 19.41706
# epoch: 85, loss: 19.53028
# epoch: 86, loss: 19.18223
# epoch: 87, loss: 19.27437
# epoch: 88, loss: 19.32693
# epoch: 89, loss: 19.34682
# epoch: 90, loss: 19.36605
# epoch: 91, loss: 19.10049
# epoch: 92, loss: 19.26071
# epoch: 93, loss: 19.59090
# epoch: 94, loss: 19.26772
# epoch: 95, loss: 19.34090
# epoch: 96, loss: 19.30086
# epoch: 97, loss: 18.97220
# epoch: 98, loss: 19.47088
# epoch: 99, loss: 19.27120
# epoch: 100, loss: 19.54570
# epoch: 101, loss: 19.39240
# epoch: 102, loss: 19.41108
# epoch: 103, loss: 19.11624
# epoch: 104, loss: 19.32615
# epoch: 105, loss: 19.10275
# epoch: 106, loss: 19.82574
# epoch: 107, loss: 19.30640
# epoch: 108, loss: 19.52580
# epoch: 109, loss: 19.28170
# epoch: 110, loss: 19.34274
# epoch: 111, loss: 19.84424
# epoch: 112, loss: 19.75325
# epoch: 113, loss: 19.18734
# epoch: 114, loss: 19.69378
# epoch: 115, loss: 19.19343
# epoch: 116, loss: 19.41528
# epoch: 117, loss: 19.52752
# epoch: 118, loss: 19.07364
# epoch: 119, loss: 19.60629
# epoch: 120, loss: 19.57168
# epoch: 121, loss: 19.43941
# epoch: 122, loss: 19.31660
# epoch: 123, loss: 19.84904
# epoch: 124, loss: 19.31486
# epoch: 125, loss: 19.42176
# epoch: 126, loss: 19.38869
# epoch: 127, loss: 19.41048
# epoch: 128, loss: 19.90092
# epoch: 129, loss: 19.72873
# epoch: 130, loss: 19.33135
# epoch: 131, loss: 19.38554
# epoch: 132, loss: 19.84444
# epoch: 133, loss: 19.53241
# epoch: 134, loss: 19.40669
# epoch: 135, loss: 20.02571
# epoch: 136, loss: 19.65020
# epoch: 137, loss: 19.19016
# epoch: 138, loss: 19.51828
# epoch: 139, loss: 19.25784
# epoch: 140, loss: 19.61508
# epoch: 141, loss: 19.50689
# epoch: 142, loss: 19.17682
# epoch: 143, loss: 19.72169
# epoch: 144, loss: 20.03117
# epoch: 145, loss: 19.75738
# epoch: 146, loss: 19.45769
# epoch: 147, loss: 19.73235
# epoch: 148, loss: 20.07760
# epoch: 149, loss: 19.89590
# epoch: 150, loss: 19.92263
# epoch: 151, loss: 20.15270
# epoch: 152, loss: 20.18366
# epoch: 153, loss: 19.71946
# epoch: 154, loss: 19.39799
# epoch: 155, loss: 19.78667
# epoch: 156, loss: 19.99337
# epoch: 157, loss: 19.43000
# epoch: 158, loss: 19.52617
# epoch: 159, loss: 20.04866
# epoch: 160, loss: 20.75337
# epoch: 161, loss: 20.08585
# epoch: 162, loss: 20.54491
# epoch: 163, loss: 19.66071
# epoch: 164, loss: 19.65327
# epoch: 165, loss: 20.11988
# epoch: 166, loss: 19.87269
# epoch: 167, loss: 19.64260
# epoch: 168, loss: 19.88616
# epoch: 169, loss: 19.76626
# epoch: 170, loss: 20.62683
# epoch: 171, loss: 21.60257
# epoch: 172, loss: 20.37734
# epoch: 173, loss: 19.99757
# epoch: 174, loss: 20.57484
# epoch: 175, loss: 19.93312
# epoch: 176, loss: 20.52151
# epoch: 177, loss: 19.53416
# epoch: 178, loss: 19.94140
# epoch: 179, loss: 20.08811
# epoch: 180, loss: 20.00655
# epoch: 181, loss: 19.31618
# epoch: 182, loss: 20.06383
# epoch: 183, loss: 20.00974
# epoch: 184, loss: 20.22458
# epoch: 185, loss: 21.11579
# epoch: 186, loss: 20.92541
# epoch: 187, loss: 19.98436
# epoch: 188, loss: 19.74948
# epoch: 189, loss: 20.34736
# epoch: 190, loss: 19.24292
# epoch: 191, loss: 20.25209
# epoch: 192, loss: 20.35786
# epoch: 193, loss: 19.53360
# epoch: 194, loss: 20.04078
# epoch: 195, loss: 19.74364
# epoch: 196, loss: 20.06802
# epoch: 197, loss: 19.35244
# epoch: 198, loss: 20.68382
# epoch: 199, loss: 19.60843
# epoch: 200, loss: 19.04007
# epoch: 201, loss: 19.89333
# epoch: 202, loss: 19.57030
# epoch: 203, loss: 19.77851
# epoch: 204, loss: 20.20971
# epoch: 205, loss: 19.74618
# epoch: 206, loss: 19.23369
# epoch: 207, loss: 19.62370
# epoch: 208, loss: 18.73359
# epoch: 209, loss: 19.14225
# epoch: 210, loss: 20.53849
# epoch: 211, loss: 19.65921
# epoch: 212, loss: 19.85710
# epoch: 213, loss: 18.90229
# epoch: 214, loss: 19.02130
# epoch: 215, loss: 18.99642
# epoch: 216, loss: 18.99587
# epoch: 217, loss: 18.91243
# epoch: 218, loss: 19.30318
# epoch: 219, loss: 19.11287
# epoch: 220, loss: 18.78008
# epoch: 221, loss: 18.73925
# epoch: 222, loss: 18.88577
# epoch: 223, loss: 19.03640
# epoch: 224, loss: 19.00245
# epoch: 225, loss: 18.58098
# epoch: 226, loss: 19.48211
# epoch: 227, loss: 19.22602
# epoch: 228, loss: 19.03236
# epoch: 229, loss: 19.29596
# epoch: 230, loss: 19.05484
# epoch: 231, loss: 18.32330
# epoch: 232, loss: 18.13027
# epoch: 233, loss: 18.75784
# epoch: 234, loss: 18.33529
# epoch: 235, loss: 19.57622
# epoch: 236, loss: 19.64997
# epoch: 237, loss: 18.24360
# epoch: 238, loss: 17.90188
# epoch: 239, loss: 17.83095
# epoch: 240, loss: 18.31903
# epoch: 241, loss: 18.31784
# epoch: 242, loss: 18.42869
# epoch: 243, loss: 18.38262
# epoch: 244, loss: 17.61687
# epoch: 245, loss: 17.96038
# epoch: 246, loss: 19.39470
# epoch: 247, loss: 18.45751
# epoch: 248, loss: 18.16977
# epoch: 249, loss: 18.37384
# epoch: 250, loss: 17.92378
# epoch: 251, loss: 17.85200
# epoch: 252, loss: 17.96988
# epoch: 253, loss: 18.28603
# epoch: 254, loss: 17.67268
# epoch: 255, loss: 17.45663
# epoch: 256, loss: 17.43334
# epoch: 257, loss: 17.42939
# epoch: 258, loss: 17.19916
# epoch: 259, loss: 17.51841
# epoch: 260, loss: 17.39634
# epoch: 261, loss: 17.58894
# epoch: 262, loss: 17.33692
# epoch: 263, loss: 17.27723
# epoch: 264, loss: 17.50994
# epoch: 265, loss: 17.39974
# epoch: 266, loss: 17.52789
# epoch: 267, loss: 17.30735
# epoch: 268, loss: 17.75146
# epoch: 269, loss: 17.84506
# epoch: 270, loss: 17.06187
# epoch: 271, loss: 17.01922
# epoch: 272, loss: 17.29709
# epoch: 273, loss: 17.24109
# epoch: 274, loss: 17.35024
# epoch: 275, loss: 17.79608
# epoch: 276, loss: 17.22140
# epoch: 277, loss: 16.74805
# epoch: 278, loss: 16.80069
# epoch: 279, loss: 16.98530
# epoch: 280, loss: 17.70713
# epoch: 281, loss: 17.33763
# epoch: 282, loss: 16.74846
# epoch: 283, loss: 16.72697
# epoch: 284, loss: 16.83026
# epoch: 285, loss: 16.76970
# epoch: 286, loss: 16.78845
# epoch: 287, loss: 16.68399
# epoch: 288, loss: 16.98530
# epoch: 289, loss: 17.27756
# epoch: 290, loss: 16.63737
# epoch: 291, loss: 16.53949
# epoch: 292, loss: 16.75983
# epoch: 293, loss: 16.62684
# epoch: 294, loss: 16.41644
# epoch: 295, loss: 16.75134
# epoch: 296, loss: 16.83489
# epoch: 297, loss: 16.96546
# epoch: 298, loss: 16.79538
# epoch: 299, loss: 16.68801
# epoch: 300, loss: 16.72576
# epoch: 301, loss: 16.58832
# epoch: 302, loss: 17.03120
# epoch: 303, loss: 17.20737
# epoch: 304, loss: 16.79533
# epoch: 305, loss: 16.52548
# epoch: 306, loss: 17.31235
# epoch: 307, loss: 17.01531
# epoch: 308, loss: 16.88460
# epoch: 309, loss: 16.86932
# epoch: 310, loss: 16.95602
# epoch: 311, loss: 16.70709
# epoch: 312, loss: 16.76132
# epoch: 313, loss: 16.57183
# epoch: 314, loss: 16.98552
# epoch: 315, loss: 16.64403
# epoch: 316, loss: 16.81480
# epoch: 317, loss: 17.13010
# epoch: 318, loss: 16.78997
# epoch: 319, loss: 17.09823
# epoch: 320, loss: 17.39989
# epoch: 321, loss: 17.12589
# epoch: 322, loss: 16.57755
# epoch: 323, loss: 16.77054
# epoch: 324, loss: 16.45613
# epoch: 325, loss: 17.24784
# epoch: 326, loss: 16.75769
# epoch: 327, loss: 16.96728
# epoch: 328, loss: 17.29053
# epoch: 329, loss: 17.37181
# epoch: 330, loss: 16.97605
# epoch: 331, loss: 16.88004
# epoch: 332, loss: 16.78490
# epoch: 333, loss: 17.02295
# epoch: 334, loss: 16.56373
# epoch: 335, loss: 17.52000
# epoch: 336, loss: 17.17590
# epoch: 337, loss: 16.75184
# epoch: 338, loss: 17.67966
# epoch: 339, loss: 17.44132
# epoch: 340, loss: 16.81184
# epoch: 341, loss: 17.35657
# epoch: 342, loss: 17.35517
# epoch: 343, loss: 17.17242
# epoch: 344, loss: 17.20967
# epoch: 345, loss: 17.58827
# epoch: 346, loss: 17.45872
# epoch: 347, loss: 17.38982
# epoch: 348, loss: 17.49572
# epoch: 349, loss: 16.97641
# epoch: 350, loss: 16.84869
# epoch: 351, loss: 17.29471
# epoch: 352, loss: 17.36258
# epoch: 353, loss: 17.26154
# epoch: 354, loss: 17.24550
# epoch: 355, loss: 17.50426
# epoch: 356, loss: 17.32293
# epoch: 357, loss: 18.49423
# epoch: 358, loss: 17.89954
# epoch: 359, loss: 17.85884
# epoch: 360, loss: 19.03855
# epoch: 361, loss: 18.06144
# epoch: 362, loss: 17.80865
# epoch: 363, loss: 17.68527
# epoch: 364, loss: 18.47053
# epoch: 365, loss: 18.34572
# epoch: 366, loss: 18.38448
# epoch: 367, loss: 18.55295
# epoch: 368, loss: 17.82126
# epoch: 369, loss: 18.24155
# epoch: 370, loss: 19.16300
# epoch: 371, loss: 18.12653
# epoch: 372, loss: 18.02851
# epoch: 373, loss: 18.03175
# epoch: 374, loss: 18.55974
# epoch: 375, loss: 18.28025
# epoch: 376, loss: 17.48820
# epoch: 377, loss: 18.30790
# epoch: 378, loss: 19.40718
# epoch: 379, loss: 19.47624
# epoch: 380, loss: 18.22095
# epoch: 381, loss: 19.43590
# epoch: 382, loss: 18.16536
# epoch: 383, loss: 18.40115
# epoch: 384, loss: 18.61903
# epoch: 385, loss: 18.40119
# epoch: 386, loss: 18.51685
# epoch: 387, loss: 18.47260
# epoch: 388, loss: 17.51443
# epoch: 389, loss: 17.92232
# epoch: 390, loss: 17.62633
# epoch: 391, loss: 18.83496
# epoch: 392, loss: 18.89756
# epoch: 393, loss: 18.05831
# epoch: 394, loss: 17.59594
# epoch: 395, loss: 17.67044
# epoch: 396, loss: 18.11367
# epoch: 397, loss: 17.51294
# epoch: 398, loss: 17.68193
# epoch: 399, loss: 18.12447
# epoch: 400, loss: 17.80157
# epoch: 401, loss: 17.91393
# epoch: 402, loss: 18.04566
# epoch: 403, loss: 17.66589
# epoch: 404, loss: 20.03499
# epoch: 405, loss: 19.17864
# epoch: 406, loss: 17.58957
# epoch: 407, loss: 17.79161
# epoch: 408, loss: 17.43339
# epoch: 409, loss: 17.89128
# epoch: 410, loss: 17.77578
# epoch: 411, loss: 18.35249
# epoch: 412, loss: 17.75023
# epoch: 413, loss: 19.26643
# epoch: 414, loss: 17.32976
# epoch: 415, loss: 17.52586
# epoch: 416, loss: 18.72474
# epoch: 417, loss: 17.03126
# epoch: 418, loss: 17.92746
# epoch: 419, loss: 16.75391
# epoch: 420, loss: 17.53226
# epoch: 421, loss: 17.72593
# epoch: 422, loss: 17.55722
# epoch: 423, loss: 17.20680
# epoch: 424, loss: 16.66393
# epoch: 425, loss: 17.40577
# epoch: 426, loss: 18.04785
# epoch: 427, loss: 17.09893
# epoch: 428, loss: 18.64068
# epoch: 429, loss: 17.49746
# epoch: 430, loss: 17.32410
# epoch: 431, loss: 17.01954
# epoch: 432, loss: 17.14775
# epoch: 433, loss: 16.86817
# epoch: 434, loss: 16.61143
# epoch: 435, loss: 17.36131
# epoch: 436, loss: 16.95705
# epoch: 437, loss: 18.03566
# epoch: 438, loss: 17.92403
# epoch: 439, loss: 17.01908
# epoch: 440, loss: 16.41650
# epoch: 441, loss: 16.56952
# epoch: 442, loss: 16.61415
# epoch: 443, loss: 17.33528
# epoch: 444, loss: 16.39314
# epoch: 445, loss: 16.23372
# epoch: 446, loss: 16.27840
# epoch: 447, loss: 16.36703
# epoch: 448, loss: 16.73391
# epoch: 449, loss: 16.07787
# epoch: 450, loss: 15.80353
# epoch: 451, loss: 16.43259
# epoch: 452, loss: 15.66414
# epoch: 453, loss: 16.99819
# epoch: 454, loss: 16.51097
# epoch: 455, loss: 15.95118
# epoch: 456, loss: 16.22152
# epoch: 457, loss: 15.80922
# epoch: 458, loss: 16.34248
# epoch: 459, loss: 15.77379
# epoch: 460, loss: 16.28853
# epoch: 461, loss: 16.35099
# epoch: 462, loss: 16.10507
# epoch: 463, loss: 15.63246
# epoch: 464, loss: 15.53463
# epoch: 465, loss: 15.55194
# epoch: 466, loss: 15.66710
# epoch: 467, loss: 16.11002
# epoch: 468, loss: 15.72787
# epoch: 469, loss: 15.28443
# epoch: 470, loss: 16.25929
# epoch: 471, loss: 16.35761
# epoch: 472, loss: 15.34134
# epoch: 473, loss: 15.44403
# epoch: 474, loss: 15.51974
# epoch: 475, loss: 15.47821
# epoch: 476, loss: 15.59956
# epoch: 477, loss: 15.44315
# epoch: 478, loss: 15.57264
# epoch: 479, loss: 15.22013
# epoch: 480, loss: 15.47243
# epoch: 481, loss: 15.35549
# epoch: 482, loss: 15.76702
# epoch: 483, loss: 15.73716
# epoch: 484, loss: 15.04736
# epoch: 485, loss: 15.77359
# epoch: 486, loss: 15.14917
# epoch: 487, loss: 15.53937
# epoch: 488, loss: 15.32655
# epoch: 489, loss: 15.90001
# epoch: 490, loss: 15.39266
# epoch: 491, loss: 15.96582
# epoch: 492, loss: 15.26332
# epoch: 493, loss: 15.56886
# epoch: 494, loss: 15.12540
# epoch: 495, loss: 15.25249
# epoch: 496, loss: 14.94952
# epoch: 497, loss: 15.62344
# epoch: 498, loss: 14.89141
# epoch: 499, loss: 15.01353

# %% [markdown]
# ##Check the Training Result

# %%
ds_cl= MyDataSet(X_ds, X_ds)
dl_cl = DataLoader(ds_cl, batch_size=256)

# %%
embeddings = []

# disable gradients for faster calculations
model.eval()
with torch.no_grad():
    for dl_cl1, dl_cl2 in dl_cl:

        dl_cl1 = dl_cl1.to(device)
        x,z = model(dl_cl1)
        
        # store the embeddings in lists
        embeddings.append(x)

# concatenate the embeddings, targets and convert to numpy
embeddings = torch.cat(embeddings, dim=0)
embeddings = embeddings.cpu().numpy()

# %%
test = (embeddings - embeddings.mean(axis=0)) / (embeddings.std(axis=0))

# %%
#KMeans in latent space
kmeans_backbone = KMeans(n_clusters=4).fit(test)
kmeans_labels_backbone = kmeans_backbone.labels_

# %%
normalized_mutual_info_score(kmeans_labels_backbone, y_ds)
# Out:
# 0.6478421811031774

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(embeddings)
data_X_tsne = np.vstack((X_tsne.T, kmeans_labels_backbone)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
data_X_tsne = np.vstack((X_tsne.T, y_ds)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()

# %%
#NMI increases from 0.59 to 0.65
