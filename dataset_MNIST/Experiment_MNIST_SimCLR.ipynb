# %% [markdown]
# ## Conifuration

# %%
#import the lib for contrastive learning framework
# !pip install lightly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lightly
#   Downloading lightly-1.2.19-py3-none-any.whl (449 kB)
#      |████████████████████████████████| 449 kB 28.4 MB/s
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.7/dist-packages (from lightly) (4.64.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.21.6)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (57.4.0)
# Collecting lightly-utils~=0.0.0
#   Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.8.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.23.0)
# Collecting hydra-core>=1.0.0
#   Downloading hydra_core-1.2.0-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 63.0 MB/s
# Collecting pytorch-lightning>=1.0.4
#   Downloading pytorch_lightning-1.6.4-py3-none-any.whl (585 kB)
#      |████████████████████████████████| 585 kB 50.7 MB/s
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.7/dist-packages (from lightly) (2022.6.15)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from lightly) (0.12.0+cu113)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.24.3)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.15.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (5.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (21.3)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      |████████████████████████████████| 117 kB 72.7 MB/s
# Collecting omegaconf~=2.2
#   Downloading omegaconf-2.2.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 6.8 MB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from lightly-utils~=0.0.0->lightly) (7.1.2)
# Collecting PyYAML>=5.1.0
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 50.3 MB/s
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (1.11.0+cu113)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2.8.0)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 56.4 MB/s
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (4.1.1)
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.9.1-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 55.1 MB/s
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (3.17.3)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 41.6 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->hydra-core>=1.0.0->lightly) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (3.0.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.3.7)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.1.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.46.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.2.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 69.5 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 66.9 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (21.4.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (2.0.12)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 4.0 MB/s
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=0ec2aef84bbe7f444689f02db546bb3517cfce2f4402714f66988e3db5c7a604
#   Stored in directory: /root/.cache/pip/wheels/8b/8d/53/2af8772d9aec614e3fc65e53d4a993ad73c61daa8bbd85a873
# Successfully built antlr4-python3-runtime
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, PyYAML, fsspec, antlr4-python3-runtime, aiohttp, torchmetrics, pyDeprecate, omegaconf, pytorch-lightning, lightly-utils, hydra-core, lightly
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-6.0 aiohttp-3.8.1 aiosignal-1.2.0 antlr4-python3-runtime-4.9.3 async-timeout-4.0.2 asynctest-0.13.0 frozenlist-1.3.0 fsspec-2022.5.0 hydra-core-1.2.0 lightly-1.2.19 lightly-utils-0.0.2 multidict-6.0.2 omegaconf-2.2.2 pyDeprecate-0.3.2 pytorch-lightning-1.6.4 torchmetrics-0.9.1 yarl-1.7.2

# %%
import lightly
from lightly.models.modules.heads import SimSiamPredictionHead
from lightly.models.modules.heads import SimSiamProjectionHead

from lightly.data import LightlyDataset
from lightly.data import ImageCollateFunction
from lightly.models.modules import BarlowTwinsProjectionHead
from lightly.loss import BarlowTwinsLoss

from lightly.data import LightlyDataset
from lightly.data import SimCLRCollateFunction
from lightly.loss import NTXentLoss
from lightly.loss import NegativeCosineSimilarity
from lightly.models.modules import SimCLRProjectionHead

# %%
import math
import torch
import torch.nn as nn
import torchvision
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from torch.utils.data import Dataset, DataLoader
import torch.optim as torch_optim
import torch.optim.lr_scheduler as lr_scheduler
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
from datetime import datetime

from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from matplotlib import pyplot
import seaborn as sns

from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_mutual_info_score
from sklearn.metrics import silhouette_score
from sklearn import mixture
from sklearn.cluster import DBSCAN
from sklearn.cluster import OPTICS
from sklearn.cluster import AgglomerativeClustering

import tensorboard
from tensorboard import notebook
from torch.utils.tensorboard import SummaryWriter

import matplotlib 
import matplotlib.pyplot as plt
#import plotly.express as px

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons
from sklearn.utils import shuffle

import torchvision.transforms as transforms
import torchvision.datasets as datasets
from sklearn.metrics.pairwise import cosine_similarity

import random
from torch.nn.modules.loss import MSELoss
from sklearn.neighbors import KDTree
#from kmodes.kprototypes import KPrototypes

from scipy.io.arff import loadarff
from sklearn.preprocessing import MinMaxScaler 
from sklearn.datasets import make_classification

# %% [markdown]
# ## Load Dataset MNIST and Check Clustering Result with the Baseline Method Kmeans

# %%
# set the path to the dataset
path_to_data = '/content/drive/MyDrive/Colab_Notebooks/mnist_train.csv'

# %%
data = pd.read_csv(path_to_data)

X_ds = data.copy()
X_ds = X_ds.drop(['label'], axis=1)

y_ds = data.copy()
y_ds = y_ds['label']

# %%
X_ds = X_ds.copy()
X_ds = pd.DataFrame(X_ds).to_numpy()

# %%
#check the clustering result with Kmeans
kmeans_ori = KMeans(n_clusters=10).fit(X_ds)
kmeans_labels_ori = kmeans_ori.labels_

normalized_mutual_info_score(kmeans_labels_ori, y_ds)
# Out:
# 0.4906313683037329

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X_ds)
data_X_tsne = np.vstack((X_tsne.T, y_ds)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ####MixUp

# %%
def mixup(data):
  view = data.copy()
  for i in range(len(view)):
    random_row_index = random.randint(0, len(view)-1)
    view[i] = view[i]*0.5  + view[random_row_index]*0.5
  return view

# %% [markdown]
# ####MixCut

# %%
def mixcut(data):
  data_copy = data.copy()
  view = data.copy()
  mask_len = 100

  for i in range(len(data_copy)):
    random_row_id = random.randint(0, len(data_copy)-1)
    random_column_id = random.randint(0, data_copy.shape[1]-mask_len)
    view[i,random_column_id:(random_column_id+mask_len)] = data_copy[random_row_id,random_column_id:(random_column_id+mask_len)]
  return view

# %% [markdown]
# #### Masking with mean

# %%
def get_random_indices(data, portion_of_mask):
  return np.random.choice(data.shape[1], size=np.floor(data.shape[1]*portion_of_mask).astype(int), replace=False)

# %%
def masking_with_mean(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = column_mu[j]
              
  return view

# %% [markdown]
# ####Masking with random value in domain range

# %%
def masking_with_random(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)
  column_min = np.minimum(data)
  column_max = np.maximum(data)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = random.randint(column_min[j], column_max[j])
              
  return view

# %% [markdown]
# ####Masking with margin distribution

# %%
def masking_with_margin_distribution(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = np.random.normal(column_mu[j], column_std[j])
              
  return view

# %% [markdown]
# ####Upsampling (SMOTE like)

# %%
#put all data points in kd-tree for fast searching
kdtree = KDTree(X_ds, leaf_size=2)

# %%
#get random point in the k nearest neighbors
def get_idx_random_knn(x,k):
   _, ids = kdtree.query(x.reshape(1, -1), k=k)
   ids = ids.flatten()
   ids = ids[1:-1]
   random_id = np.random.choice(ids, 1)
   return random_id

# %%
#mix up with a random near neighbor 
def mixup_random_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = 0.5*data[i] + 0.5*data[random_neighbor_id]
  return view

# %%
#a random neighbor as augmentation
def random_near_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = data[random_neighbor_id]
  return view

# %% [markdown]
# ##Create Model and Train with Augmented Data

# %%
class MyDataSet(Dataset):
  def __init__(self, view1, view2):
 
    X_view1 = view1.copy()
    X_view2 = view2.copy()
    self.X_view1 = X_view1.copy().astype(np.float32)
    self.X_view2 = X_view2.copy().astype(np.float32)
  
  def __len__(self):
    return len(self.X_view1)
  
  def __getitem__(self, idx):
    return self.X_view1[idx], self.X_view2[idx]

# %%
# define the NN architecture
class convBackbone(nn.Module):
    def __init__(self):
        super(convBackbone, self).__init__()

        #turn on dropout for testing the 'cropping' data augmentation 
        #self.dropout = nn.Dropout(p=0.2)
        
        self.fc1 = nn.Linear(784, 256, bias=False)
        self.bn1 = nn.BatchNorm1d(256)

        self.fc2 = nn.Linear(256, 256, bias=False)
        self.bn2 = nn.BatchNorm1d(256)

        self.fc3 = nn.Linear(256, 256, bias=False)
        self.bn3 = nn.BatchNorm1d(256)


    def forward(self, x):

        #turn on dropout for testing the 'cropping' data augmentation
        #x = self.dropout(x)
        
        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.bn3(self.fc3(x))
                
        return x

# %%
class SimCLR(nn.Module):
    def __init__(self, backbone):
        super().__init__()
        self.backbone = backbone
        self.projection_head = SimCLRProjectionHead(256, 128, 256)

    def forward(self, x):
        x = self.backbone(x).flatten(start_dim=1)
        z = self.projection_head(x)
        return x,z

backbone = convBackbone()
model = SimCLR(backbone)

# %%
criterion = NTXentLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.05, momentum=0.9,weight_decay=1e-4)

#cosine annealing lr
scheduler = lr_scheduler.CosineAnnealingLR(optimizer,T_max=500, eta_min=0)

# %%
view1 = random_near_neighbor(X_ds, 15)
view2 = random_near_neighbor(X_ds, 15)

#turn on the following to test other augmentations

#view1 = mixup_random_neighbor(X_ds, 15)
#view2 = mixup_random_neighbor(X_ds, 15)

#view1 = mixup(X_ds)
#view2 = mixup(X_ds)

#view1 = mixcut(X_ds)
#view2 = mixcut(X_ds)

#view1 = masking_with_mean(X_ds, 0.4)
#view2 = masking_with_mean(X_ds, 0.4)

#view1 = masking_with_random(X_ds, 0.4)
#view2 = masking_with_random(X_ds, 0.4)

#view1 = masking_with_margin_distribution(X_ds, 0.4)
#view2 = masking_with_margin_distribution(X_ds, 0.4)

train_ds = MyDataSet(view1, view2)
train_dl = DataLoader(train_ds, batch_size=256, shuffle=True)

# %%
train_ds = MyDataSet(view1, view2)
train_dl = DataLoader(train_ds, batch_size=2048, shuffle=True)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

for epoch in range(500):
    total_loss = 0
    for x0, x1 in train_dl:

        x0 = x0.to(device)
        x1 = x1.to(device)
        _,z0 = model(x0)
        _,z1 = model(x1)

        z0 = (z0 - torch.mean(z0,0)) / torch.std(z0,0)
        z1 = (z1 - torch.mean(z1,0)) / torch.std(z1,0)

        loss = criterion(z0, z1)
        total_loss += loss.detach()
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    avg_loss = total_loss / len(train_dl)
    print(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
# Out:
# epoch: 00, loss: 6.94160
# epoch: 01, loss: 6.71446
# epoch: 02, loss: 6.68672
# epoch: 03, loss: 6.67198
# epoch: 04, loss: 6.66255
# epoch: 05, loss: 6.65349
# epoch: 06, loss: 6.64769
# epoch: 07, loss: 6.64314
# epoch: 08, loss: 6.63916
# epoch: 09, loss: 6.63538
# epoch: 10, loss: 6.63241
# epoch: 11, loss: 6.62919
# epoch: 12, loss: 6.62651
# epoch: 13, loss: 6.62427
# epoch: 14, loss: 6.62247
# epoch: 15, loss: 6.62052
# epoch: 16, loss: 6.61805
# epoch: 17, loss: 6.61662
# epoch: 18, loss: 6.61395
# epoch: 19, loss: 6.61294
# epoch: 20, loss: 6.61247
# epoch: 21, loss: 6.61035
# epoch: 22, loss: 6.60850
# epoch: 23, loss: 6.60799
# epoch: 24, loss: 6.60705
# epoch: 25, loss: 6.60637
# epoch: 26, loss: 6.60634
# epoch: 27, loss: 6.60379
# epoch: 28, loss: 6.60323
# epoch: 29, loss: 6.60187
# epoch: 30, loss: 6.60115
# epoch: 31, loss: 6.60089
# epoch: 32, loss: 6.59983
# epoch: 33, loss: 6.59924
# epoch: 34, loss: 6.59879
# epoch: 35, loss: 6.59760
# epoch: 36, loss: 6.59678
# epoch: 37, loss: 6.59607
# epoch: 38, loss: 6.59594
# epoch: 39, loss: 6.59508
# epoch: 40, loss: 6.59440
# epoch: 41, loss: 6.59359
# epoch: 42, loss: 6.59322
# epoch: 43, loss: 6.59235
# epoch: 44, loss: 6.59228
# epoch: 45, loss: 6.59153
# epoch: 46, loss: 6.59077
# epoch: 47, loss: 6.59027
# epoch: 48, loss: 6.59017
# epoch: 49, loss: 6.58877
# epoch: 50, loss: 6.58882
# epoch: 51, loss: 6.58839
# epoch: 52, loss: 6.58790
# epoch: 53, loss: 6.58767
# epoch: 54, loss: 6.58615
# epoch: 55, loss: 6.58611
# epoch: 56, loss: 6.58636
# epoch: 57, loss: 6.58570
# epoch: 58, loss: 6.58566
# epoch: 59, loss: 6.58446
# epoch: 60, loss: 6.58467
# epoch: 61, loss: 6.58363
# epoch: 62, loss: 6.58292
# epoch: 63, loss: 6.58380
# epoch: 64, loss: 6.58269
# epoch: 65, loss: 6.58235
# epoch: 66, loss: 6.58224
# epoch: 67, loss: 6.58167
# epoch: 68, loss: 6.58087
# epoch: 69, loss: 6.58088
# epoch: 70, loss: 6.58064
# epoch: 71, loss: 6.58003
# epoch: 72, loss: 6.57978
# epoch: 73, loss: 6.57903
# epoch: 74, loss: 6.57957
# epoch: 75, loss: 6.57856
# epoch: 76, loss: 6.57743
# epoch: 77, loss: 6.57782
# epoch: 78, loss: 6.57753
# epoch: 79, loss: 6.57763
# epoch: 80, loss: 6.57720
# epoch: 81, loss: 6.57620
# epoch: 82, loss: 6.57718
# epoch: 83, loss: 6.57579
# epoch: 84, loss: 6.57559
# epoch: 85, loss: 6.57560
# epoch: 86, loss: 6.57531
# epoch: 87, loss: 6.57483
# epoch: 88, loss: 6.57464
# epoch: 89, loss: 6.57399
# epoch: 90, loss: 6.57415
# epoch: 91, loss: 6.57396
# epoch: 92, loss: 6.57324
# epoch: 93, loss: 6.57302
# epoch: 94, loss: 6.57276
# epoch: 95, loss: 6.57237
# epoch: 96, loss: 6.57221
# epoch: 97, loss: 6.57221
# epoch: 98, loss: 6.57067
# epoch: 99, loss: 6.57130
# epoch: 100, loss: 6.57111
# epoch: 101, loss: 6.57025
# epoch: 102, loss: 6.57027
# epoch: 103, loss: 6.57061
# epoch: 104, loss: 6.56986
# epoch: 105, loss: 6.56964
# epoch: 106, loss: 6.56892
# epoch: 107, loss: 6.56886
# epoch: 108, loss: 6.56901
# epoch: 109, loss: 6.56809
# epoch: 110, loss: 6.56740
# epoch: 111, loss: 6.56828
# epoch: 112, loss: 6.56776
# epoch: 113, loss: 6.56781
# epoch: 114, loss: 6.56725
# epoch: 115, loss: 6.56706
# epoch: 116, loss: 6.56654
# epoch: 117, loss: 6.56638
# epoch: 118, loss: 6.56622
# epoch: 119, loss: 6.56595
# epoch: 120, loss: 6.56607
# epoch: 121, loss: 6.56595
# epoch: 122, loss: 6.56483
# epoch: 123, loss: 6.56511
# epoch: 124, loss: 6.56472
# epoch: 125, loss: 6.56457
# epoch: 126, loss: 6.56409
# epoch: 127, loss: 6.56372
# epoch: 128, loss: 6.56330
# epoch: 129, loss: 6.56405
# epoch: 130, loss: 6.56290
# epoch: 131, loss: 6.56296
# epoch: 132, loss: 6.56270
# epoch: 133, loss: 6.56289
# epoch: 134, loss: 6.56245
# epoch: 135, loss: 6.56222
# epoch: 136, loss: 6.56271
# epoch: 137, loss: 6.56177
# epoch: 138, loss: 6.56092
# epoch: 139, loss: 6.56104
# epoch: 140, loss: 6.56059
# epoch: 141, loss: 6.56047
# epoch: 142, loss: 6.56049
# epoch: 143, loss: 6.56023
# epoch: 144, loss: 6.55983
# epoch: 145, loss: 6.55991
# epoch: 146, loss: 6.56032
# epoch: 147, loss: 6.55919
# epoch: 148, loss: 6.55897
# epoch: 149, loss: 6.55954
# epoch: 150, loss: 6.55874
# epoch: 151, loss: 6.55894
# epoch: 152, loss: 6.55854
# epoch: 153, loss: 6.55846
# epoch: 154, loss: 6.55805
# epoch: 155, loss: 6.55825
# epoch: 156, loss: 6.55794
# epoch: 157, loss: 6.55764
# epoch: 158, loss: 6.55741
# epoch: 159, loss: 6.55709
# epoch: 160, loss: 6.55727
# epoch: 161, loss: 6.55668
# epoch: 162, loss: 6.55668
# epoch: 163, loss: 6.55567
# epoch: 164, loss: 6.55666
# epoch: 165, loss: 6.55628
# epoch: 166, loss: 6.55646
# epoch: 167, loss: 6.55620
# epoch: 168, loss: 6.55552
# epoch: 169, loss: 6.55487
# epoch: 170, loss: 6.55467
# epoch: 171, loss: 6.55398
# epoch: 172, loss: 6.55481
# epoch: 173, loss: 6.55460
# epoch: 174, loss: 6.55483
# epoch: 175, loss: 6.55511
# epoch: 176, loss: 6.55419
# epoch: 177, loss: 6.55353
# epoch: 178, loss: 6.55314
# epoch: 179, loss: 6.55347
# epoch: 180, loss: 6.55404
# epoch: 181, loss: 6.55319
# epoch: 182, loss: 6.55301
# epoch: 183, loss: 6.55364
# epoch: 184, loss: 6.55328
# epoch: 185, loss: 6.55342
# epoch: 186, loss: 6.55259
# epoch: 187, loss: 6.55169
# epoch: 188, loss: 6.55233
# epoch: 189, loss: 6.55250
# epoch: 190, loss: 6.55189
# epoch: 191, loss: 6.55257
# epoch: 192, loss: 6.55111
# epoch: 193, loss: 6.55206
# epoch: 194, loss: 6.55043
# epoch: 195, loss: 6.55117
# epoch: 196, loss: 6.55180
# epoch: 197, loss: 6.55121
# epoch: 198, loss: 6.55070
# epoch: 199, loss: 6.55029
# epoch: 200, loss: 6.54995
# epoch: 201, loss: 6.54965
# epoch: 202, loss: 6.54938
# epoch: 203, loss: 6.55002
# epoch: 204, loss: 6.54918
# epoch: 205, loss: 6.54932
# epoch: 206, loss: 6.54881
# epoch: 207, loss: 6.54976
# epoch: 208, loss: 6.54961
# epoch: 209, loss: 6.54905
# epoch: 210, loss: 6.54846
# epoch: 211, loss: 6.54807
# epoch: 212, loss: 6.54858
# epoch: 213, loss: 6.54811
# epoch: 214, loss: 6.54782
# epoch: 215, loss: 6.54766
# epoch: 216, loss: 6.54836
# epoch: 217, loss: 6.54725
# epoch: 218, loss: 6.54774
# epoch: 219, loss: 6.54705
# epoch: 220, loss: 6.54669
# epoch: 221, loss: 6.54670
# epoch: 222, loss: 6.54676
# epoch: 223, loss: 6.54733
# epoch: 224, loss: 6.54634
# epoch: 225, loss: 6.54661
# epoch: 226, loss: 6.54693
# epoch: 227, loss: 6.54637
# epoch: 228, loss: 6.54639
# epoch: 229, loss: 6.54618
# epoch: 230, loss: 6.54693
# epoch: 231, loss: 6.54625
# epoch: 232, loss: 6.54583
# epoch: 233, loss: 6.54475
# epoch: 234, loss: 6.54500
# epoch: 235, loss: 6.54514
# epoch: 236, loss: 6.54526
# epoch: 237, loss: 6.54525
# epoch: 238, loss: 6.54450
# epoch: 239, loss: 6.54485
# epoch: 240, loss: 6.54459
# epoch: 241, loss: 6.54407
# epoch: 242, loss: 6.54451
# epoch: 243, loss: 6.54449
# epoch: 244, loss: 6.54524
# epoch: 245, loss: 6.54455
# epoch: 246, loss: 6.54369
# epoch: 247, loss: 6.54349
# epoch: 248, loss: 6.54286
# epoch: 249, loss: 6.54380
# epoch: 250, loss: 6.54371
# epoch: 251, loss: 6.54329
# epoch: 252, loss: 6.54324
# epoch: 253, loss: 6.54263
# epoch: 254, loss: 6.54307
# epoch: 255, loss: 6.54217
# epoch: 256, loss: 6.54306
# epoch: 257, loss: 6.54307
# epoch: 258, loss: 6.54328
# epoch: 259, loss: 6.54212
# epoch: 260, loss: 6.54196
# epoch: 261, loss: 6.54230
# epoch: 262, loss: 6.54238
# epoch: 263, loss: 6.54170
# epoch: 264, loss: 6.54199
# epoch: 265, loss: 6.54140
# epoch: 266, loss: 6.54131
# epoch: 267, loss: 6.54150
# epoch: 268, loss: 6.54136
# epoch: 269, loss: 6.54072
# epoch: 270, loss: 6.54182
# epoch: 271, loss: 6.54138
# epoch: 272, loss: 6.54173
# epoch: 273, loss: 6.54075
# epoch: 274, loss: 6.54054
# epoch: 275, loss: 6.54098
# epoch: 276, loss: 6.54148
# epoch: 277, loss: 6.54071
# epoch: 278, loss: 6.53933
# epoch: 279, loss: 6.53966
# epoch: 280, loss: 6.54005
# epoch: 281, loss: 6.53940
# epoch: 282, loss: 6.54021
# epoch: 283, loss: 6.53990
# epoch: 284, loss: 6.53933
# epoch: 285, loss: 6.53926
# epoch: 286, loss: 6.53966
# epoch: 287, loss: 6.53995
# epoch: 288, loss: 6.53882
# epoch: 289, loss: 6.53893
# epoch: 290, loss: 6.53978
# epoch: 291, loss: 6.53894
# epoch: 292, loss: 6.53819
# epoch: 293, loss: 6.53777
# epoch: 294, loss: 6.53863
# epoch: 295, loss: 6.53880
# epoch: 296, loss: 6.53833
# epoch: 297, loss: 6.53860
# epoch: 298, loss: 6.53763
# epoch: 299, loss: 6.53756
# epoch: 300, loss: 6.53749
# epoch: 301, loss: 6.53866
# epoch: 302, loss: 6.53801
# epoch: 303, loss: 6.53779
# epoch: 304, loss: 6.53687
# epoch: 305, loss: 6.53773
# epoch: 306, loss: 6.53676
# epoch: 307, loss: 6.53783
# epoch: 308, loss: 6.53701
# epoch: 309, loss: 6.53713
# epoch: 310, loss: 6.53793
# epoch: 311, loss: 6.53724
# epoch: 312, loss: 6.53686
# epoch: 313, loss: 6.53741
# epoch: 314, loss: 6.53667
# epoch: 315, loss: 6.53741
# epoch: 316, loss: 6.53644
# epoch: 317, loss: 6.53580
# epoch: 318, loss: 6.53610
# epoch: 319, loss: 6.53723
# epoch: 320, loss: 6.53657
# epoch: 321, loss: 6.53582
# epoch: 322, loss: 6.53555
# epoch: 323, loss: 6.53554
# epoch: 324, loss: 6.53573
# epoch: 325, loss: 6.53588
# epoch: 326, loss: 6.53595
# epoch: 327, loss: 6.53553
# epoch: 328, loss: 6.53533
# epoch: 329, loss: 6.53614
# epoch: 330, loss: 6.53595
# epoch: 331, loss: 6.53574
# epoch: 332, loss: 6.53528
# epoch: 333, loss: 6.53520
# epoch: 334, loss: 6.53565
# epoch: 335, loss: 6.53474
# epoch: 336, loss: 6.53550
# epoch: 337, loss: 6.53546
# epoch: 338, loss: 6.53472
# epoch: 339, loss: 6.53475
# epoch: 340, loss: 6.53496
# epoch: 341, loss: 6.53475
# epoch: 342, loss: 6.53489
# epoch: 343, loss: 6.53467
# epoch: 344, loss: 6.53527
# epoch: 345, loss: 6.53401
# epoch: 346, loss: 6.53420
# epoch: 347, loss: 6.53352
# epoch: 348, loss: 6.53419
# epoch: 349, loss: 6.53303
# epoch: 350, loss: 6.53414
# epoch: 351, loss: 6.53451
# epoch: 352, loss: 6.53305
# epoch: 353, loss: 6.53382
# epoch: 354, loss: 6.53348
# epoch: 355, loss: 6.53329
# epoch: 356, loss: 6.53335
# epoch: 357, loss: 6.53290
# epoch: 358, loss: 6.53405
# epoch: 359, loss: 6.53385
# epoch: 360, loss: 6.53281
# epoch: 361, loss: 6.53268
# epoch: 362, loss: 6.53309
# epoch: 363, loss: 6.53320
# epoch: 364, loss: 6.53236
# epoch: 365, loss: 6.53210
# epoch: 366, loss: 6.53315
# epoch: 367, loss: 6.53253
# epoch: 368, loss: 6.53293
# epoch: 369, loss: 6.53222
# epoch: 370, loss: 6.53289
# epoch: 371, loss: 6.53184
# epoch: 372, loss: 6.53291
# epoch: 373, loss: 6.53179
# epoch: 374, loss: 6.53193
# epoch: 375, loss: 6.53186
# epoch: 376, loss: 6.53274
# epoch: 377, loss: 6.53206
# epoch: 378, loss: 6.53220
# epoch: 379, loss: 6.53209
# epoch: 380, loss: 6.53145
# epoch: 381, loss: 6.53170
# epoch: 382, loss: 6.53179
# epoch: 383, loss: 6.53121
# epoch: 384, loss: 6.53143
# epoch: 385, loss: 6.53181
# epoch: 386, loss: 6.53212
# epoch: 387, loss: 6.53157
# epoch: 388, loss: 6.53174
# epoch: 389, loss: 6.53043
# epoch: 390, loss: 6.53126
# epoch: 391, loss: 6.53109
# epoch: 392, loss: 6.53214
# epoch: 393, loss: 6.53093
# epoch: 394, loss: 6.53096
# epoch: 395, loss: 6.53029
# epoch: 396, loss: 6.53006
# epoch: 397, loss: 6.53116
# epoch: 398, loss: 6.52992
# epoch: 399, loss: 6.53012
# epoch: 400, loss: 6.53053
# epoch: 401, loss: 6.53087
# epoch: 402, loss: 6.53027
# epoch: 403, loss: 6.53028
# epoch: 404, loss: 6.53049
# epoch: 405, loss: 6.52992
# epoch: 406, loss: 6.53011
# epoch: 407, loss: 6.52990
# epoch: 408, loss: 6.53011
# epoch: 409, loss: 6.53022
# epoch: 410, loss: 6.53012
# epoch: 411, loss: 6.52972
# epoch: 412, loss: 6.53036
# epoch: 413, loss: 6.52945
# epoch: 414, loss: 6.52890
# epoch: 415, loss: 6.53049
# epoch: 416, loss: 6.52989
# epoch: 417, loss: 6.52971
# epoch: 418, loss: 6.52928
# epoch: 419, loss: 6.52975
# epoch: 420, loss: 6.52857
# epoch: 421, loss: 6.53027
# epoch: 422, loss: 6.52913
# epoch: 423, loss: 6.52989
# epoch: 424, loss: 6.52881
# epoch: 425, loss: 6.52871
# epoch: 426, loss: 6.52979
# epoch: 427, loss: 6.52966
# epoch: 428, loss: 6.52995
# epoch: 429, loss: 6.52954
# epoch: 430, loss: 6.52888
# epoch: 431, loss: 6.52847
# epoch: 432, loss: 6.52901
# epoch: 433, loss: 6.52801
# epoch: 434, loss: 6.52904
# epoch: 435, loss: 6.52911
# epoch: 436, loss: 6.52840
# epoch: 437, loss: 6.52809
# epoch: 438, loss: 6.52912
# epoch: 439, loss: 6.52824
# epoch: 440, loss: 6.52830
# epoch: 441, loss: 6.52825
# epoch: 442, loss: 6.52822
# epoch: 443, loss: 6.52870
# epoch: 444, loss: 6.52763
# epoch: 445, loss: 6.52836
# epoch: 446, loss: 6.52741
# epoch: 447, loss: 6.52791
# epoch: 448, loss: 6.52717
# epoch: 449, loss: 6.52838
# epoch: 450, loss: 6.52760
# epoch: 451, loss: 6.52801
# epoch: 452, loss: 6.52753
# epoch: 453, loss: 6.52731
# epoch: 454, loss: 6.52756
# epoch: 455, loss: 6.52789
# epoch: 456, loss: 6.52805
# epoch: 457, loss: 6.52732
# epoch: 458, loss: 6.52709
# epoch: 459, loss: 6.52760
# epoch: 460, loss: 6.52712
# epoch: 461, loss: 6.52724
# epoch: 462, loss: 6.52750
# epoch: 463, loss: 6.52678
# epoch: 464, loss: 6.52672
# epoch: 465, loss: 6.52741
# epoch: 466, loss: 6.52642
# epoch: 467, loss: 6.52718
# epoch: 468, loss: 6.52704
# epoch: 469, loss: 6.52690
# epoch: 470, loss: 6.52720
# epoch: 471, loss: 6.52634
# epoch: 472, loss: 6.52682
# epoch: 473, loss: 6.52738
# epoch: 474, loss: 6.52632
# epoch: 475, loss: 6.52745
# epoch: 476, loss: 6.52665
# epoch: 477, loss: 6.52676
# epoch: 478, loss: 6.52716
# epoch: 479, loss: 6.52667
# epoch: 480, loss: 6.52641
# epoch: 481, loss: 6.52581
# epoch: 482, loss: 6.52696
# epoch: 483, loss: 6.52664
# epoch: 484, loss: 6.52722
# epoch: 485, loss: 6.52721
# epoch: 486, loss: 6.52598
# epoch: 487, loss: 6.52690
# epoch: 488, loss: 6.52615
# epoch: 489, loss: 6.52540
# epoch: 490, loss: 6.52651
# epoch: 491, loss: 6.52605
# epoch: 492, loss: 6.52525
# epoch: 493, loss: 6.52552
# epoch: 494, loss: 6.52610
# epoch: 495, loss: 6.52458
# epoch: 496, loss: 6.52521
# epoch: 497, loss: 6.52565
# epoch: 498, loss: 6.52563
# epoch: 499, loss: 6.52551

# %% [markdown]
# ##Check the Training Result

# %%
ds_cl= MyDataSet(X_ds, X_ds)
dl_cl = DataLoader(ds_cl, batch_size=2048)

# %%
embeddings = []

# disable gradients for faster calculations
model.eval()
with torch.no_grad():
    for dl_cl1, dl_cl2 in dl_cl:

        dl_cl1 = dl_cl1.to(device)
        x,z = model(dl_cl1)
        
        # store the embeddings in lists
        embeddings.append(x)

# concatenate the embeddings, targets and convert to numpy
embeddings = torch.cat(embeddings, dim=0)
embeddings = embeddings.cpu().numpy()

# %%
test = (embeddings - embeddings.mean(axis=0)) / (embeddings.std(axis=0))

# %%
#KMeans in latent space
kmeans_backbone = KMeans(n_clusters=10).fit(test)
kmeans_labels_backbone = kmeans_backbone.labels_

# %%
normalized_mutual_info_score(kmeans_labels_backbone, y_ds)
# Out:
# 0.6953341965779135

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(embeddings)
data_X_tsne = np.vstack((X_tsne.T, y_ds)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#NMI increases from 0.49 to 0.69
