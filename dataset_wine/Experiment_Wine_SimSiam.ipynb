# %% [markdown]
# ## Conifuration

# %%
#import the lib for contrastive learning framework
# !pip install lightly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lightly
#   Downloading lightly-1.2.20-py3-none-any.whl (451 kB)
#      |████████████████████████████████| 451 kB 8.5 MB/s
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.7/dist-packages (from lightly) (4.64.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.7/dist-packages (from lightly) (2022.6.15)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.8.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from lightly) (0.12.0+cu113)
# Collecting hydra-core>=1.0.0
#   Downloading hydra_core-1.2.0-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 31.3 MB/s
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (57.4.0)
# Collecting lightly-utils~=0.0.0
#   Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.15.0)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.23.0)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.24.3)
# Collecting pytorch-lightning>=1.0.4
#   Downloading pytorch_lightning-1.6.4-py3-none-any.whl (585 kB)
#      |████████████████████████████████| 585 kB 28.5 MB/s
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (21.3)
# Collecting omegaconf~=2.2
#   Downloading omegaconf-2.2.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 8.1 MB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (5.7.1)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      |████████████████████████████████| 117 kB 60.8 MB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from lightly-utils~=0.0.0->lightly) (7.1.2)
# Collecting PyYAML>=5.1.0
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 39.8 MB/s
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (4.1.1)
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.9.1-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 26.9 MB/s
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 44.1 MB/s
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (3.17.3)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2.8.0)
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (1.11.0+cu113)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 47.0 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->hydra-core>=1.0.0->lightly) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (2.10)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.37.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.46.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.3.7)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.1.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.8.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.2.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.9 MB/s
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 38.6 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (2.0.12)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (21.4.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 48.0 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=341e9d9555db4516a85a0e7d25fd9f315927c3606478f19eff2dcdfb21b639af
#   Stored in directory: /root/.cache/pip/wheels/8b/8d/53/2af8772d9aec614e3fc65e53d4a993ad73c61daa8bbd85a873
# Successfully built antlr4-python3-runtime
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, PyYAML, fsspec, antlr4-python3-runtime, aiohttp, torchmetrics, pyDeprecate, omegaconf, pytorch-lightning, lightly-utils, hydra-core, lightly
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-6.0 aiohttp-3.8.1 aiosignal-1.2.0 antlr4-python3-runtime-4.9.3 async-timeout-4.0.2 asynctest-0.13.0 frozenlist-1.3.0 fsspec-2022.5.0 hydra-core-1.2.0 lightly-1.2.20 lightly-utils-0.0.2 multidict-6.0.2 omegaconf-2.2.2 pyDeprecate-0.3.2 pytorch-lightning-1.6.4 torchmetrics-0.9.1 yarl-1.7.2

# %%
import lightly
from lightly.models.modules.heads import SimSiamPredictionHead
from lightly.models.modules.heads import SimSiamProjectionHead

from lightly.data import LightlyDataset
from lightly.data import ImageCollateFunction
from lightly.models.modules import BarlowTwinsProjectionHead
from lightly.loss import BarlowTwinsLoss

from lightly.data import LightlyDataset
from lightly.data import SimCLRCollateFunction
from lightly.loss import NTXentLoss
from lightly.loss import NegativeCosineSimilarity
from lightly.models.modules import SimCLRProjectionHead

# %%
import math
import torch
import torch.nn as nn
import torchvision
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from torch.utils.data import Dataset, DataLoader
import torch.optim as torch_optim
import torch.optim.lr_scheduler as lr_scheduler
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
from datetime import datetime

from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from matplotlib import pyplot
import seaborn as sns

from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_mutual_info_score
from sklearn.metrics import silhouette_score
from sklearn import mixture
from sklearn.cluster import DBSCAN
from sklearn.cluster import OPTICS
from sklearn.cluster import AgglomerativeClustering

import tensorboard
from tensorboard import notebook
from torch.utils.tensorboard import SummaryWriter

import matplotlib 
import matplotlib.pyplot as plt
#import plotly.express as px

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons
from sklearn.utils import shuffle

import torchvision.transforms as transforms
import torchvision.datasets as datasets
from sklearn.metrics.pairwise import cosine_similarity

import random
from torch.nn.modules.loss import MSELoss
from sklearn.neighbors import KDTree
#from kmodes.kprototypes import KPrototypes

from scipy.io.arff import loadarff
from sklearn.preprocessing import MinMaxScaler 
from sklearn.datasets import make_classification

# %% [markdown]
# ## Load Dataset Wine and Check Clustering Result with the Baseline Method Kmeans

# %%
data0 = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/winequality_red.csv')
data1 = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/winequality_white.csv')

# %%
data0['color'] = 0
data1['color'] = 1

# %%
data=pd.concat([data0,data1],axis=0)
data.shape
# Out:
# (6497, 13)

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# color                   0
# dtype: int64

# %%
X = data.drop(['color'], axis=1)
y = data['color']

#normalize and scale the data to prevent gradient vanishing
X_ds = pd.DataFrame(X).to_numpy()
norm_X_ds = 100 * (X_ds - np.mean(X_ds, axis=0)) / np.std(X_ds, axis=0) + 256

# %%
#KMeans with one-hot-encoding for categorical features
kmeans_ori = KMeans(n_clusters=2).fit(norm_X_ds)
kmeans_labels_ori = kmeans_ori.labels_

normalized_mutual_info_score(kmeans_labels_ori, y)
# Out:
# 0.8482669252973938

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(norm_X_ds)
data_X_tsne = np.vstack((X_tsne.T, y)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ####MixUp

# %%
def mixup(data):
  view = data.copy()
  for i in range(len(view)):
    random_row_index = random.randint(0, len(view)-1)
    view[i] = view[i]*0.7  + view[random_row_index]*0.3
  return view

# %% [markdown]
# ####MixCut

# %%
def mixcut(data):
  data_copy = data.copy()
  view = data.copy()
  mask_len = int(data_copy.shape[1]*0.25)

  for i in range(len(data_copy)):
    random_row_id = random.randint(0, len(data_copy)-1)
    random_column_id = random.randint(0, data_copy.shape[1]-mask_len)
    view[i,random_column_id:(random_column_id+mask_len)] = data_copy[random_row_id,random_column_id:(random_column_id+mask_len)]
  return view

# %% [markdown]
# #### Masking with mean

# %%
def get_random_indices(data, portion_of_mask):
  return np.random.choice(data.shape[1], size=np.floor(data.shape[1]*portion_of_mask).astype(int), replace=False)

# %%
def masking_with_mean(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = column_mu[j]
              
  return view

# %% [markdown]
# ####Masking with random value in domain range

# %%
def masking_with_random(data, portion_of_mask):
  mean = np.mean(data, axis=0)

  column_min = data.min(axis=0).astype(int)
  column_max = data.max(axis=0).astype(int)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = random.randint(column_min[j], column_max[j])
              
  return view

# %% [markdown]
# ####Masking with margin distribution

# %%
def masking_with_margin_distribution(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = np.random.normal(column_mu[j], column_std[j])
              
  return view

# %% [markdown]
# ####Upsampling (SMOTE like)

# %%
#put all data points in kd-tree for fast searching
kdtree = KDTree(norm_X_ds, leaf_size=2)

# %%
#get random point in the k nearest neighbors
def get_idx_random_knn(x,k):
   _, ids = kdtree.query(x.reshape(1, -1), k=k)
   ids = ids.flatten()
   ids = ids[1:-1]
   random_id = np.random.choice(ids, 1)
   return random_id

# %%
#mix up with a random near neighbor 
def mixup_random_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = 0.5*data[i] + 0.5*data[random_neighbor_id]
  return view

# %%
#a random neighbor as augmentation
def random_near_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = data[random_neighbor_id]
  return view

# %% [markdown]
# ##Create Model and Train with Augmented Data

# %%
class MyDataSet(Dataset):
  def __init__(self, view1, view2):
 
    X_view1 = view1.copy()
    X_view2 = view2.copy()
    self.X_view1 = X_view1.copy().astype(np.float32)
    self.X_view2 = X_view2.copy().astype(np.float32)
  
  def __len__(self):
    return len(self.X_view1)
  
  def __getitem__(self, idx):
    return self.X_view1[idx], self.X_view2[idx]

# %%
# define the NN architecture
class convBackbone(nn.Module):
    def __init__(self):
        super(convBackbone, self).__init__()

        #turn on dropout for testing the 'cropping' data augmentation
        #self.dropout = nn.Dropout(p=0.1)
        
        self.fc1 = nn.Linear(12, 12, bias=False)
        self.bn1 = nn.BatchNorm1d(12)

        self.fc2 = nn.Linear(12, 12, bias=False)
        self.bn2 = nn.BatchNorm1d(12)

        self.fc3 = nn.Linear(12, 12, bias=False)
        self.bn3 = nn.BatchNorm1d(12)


    def forward(self, x):

        #turn on dropout for testing the 'cropping' data augmentation
        #x = self.dropout(x)

        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.bn3(self.fc3(x))
                
        return x

# %%
class SimSiam(nn.Module):
    def __init__(self, backbone):
        super().__init__()
        self.backbone = backbone
        self.projection_head = SimSiamProjectionHead(12, 12, 12)
        self.prediction_head = SimSiamPredictionHead(12, 8, 12)

    def forward(self, x):
        f = self.backbone(x)
        z = f.flatten(start_dim=1)
        z = self.projection_head(z)
        p = self.prediction_head(z)
        z = z.detach()
        return f, z, p

backbone = convBackbone()
model = SimSiam(backbone)

# %%
criterion = NegativeCosineSimilarity()
optimizer = torch.optim.SGD(model.parameters(), lr=0.02)

#cosine annealing lr
scheduler = lr_scheduler.CosineAnnealingLR(optimizer,T_max=1200, eta_min=0)

# %%
view1 = random_near_neighbor(norm_X_ds, 20)
view2 = random_near_neighbor(norm_X_ds, 25)

#turn on the following to test other augmentations

#view1 = mixup_random_neighbor(X_ds, 15)
#view2 = mixup_random_neighbor(X_ds, 15)

#view1 = mixup(X_ds)
#view2 = mixup(X_ds)

#view1 = mixcut(X_ds)
#view2 = mixcut(X_ds)

#view1 = masking_with_mean(X_ds, 0.4)
#view2 = masking_with_mean(X_ds, 0.4)

#view1 = masking_with_random(X_ds, 0.4)
#view2 = masking_with_random(X_ds, 0.4)

#view1 = masking_with_margin_distribution(X_ds, 0.4)
#view2 = masking_with_margin_distribution(X_ds, 0.4)

train_ds = MyDataSet(view1, view2)
train_dl = DataLoader(train_ds, batch_size=256, shuffle=True)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

for epoch in range(1200):
    total_loss = 0
    for x0,x1 in train_dl:
        x0 = x0.to(device)
        x1 = x1.to(device)
        _, z0, p0 = model(x0)
        _, z1, p1 = model(x1)

        loss = 0.5 * (criterion(z0, p1) + criterion(z1, p0))
        total_loss += loss.detach()
        loss.backward()

        optimizer.step()
        optimizer.zero_grad()
        scheduler.step()

    avg_loss = total_loss / len(train_dl)
    print(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
# Out:
# epoch: 00, loss: -0.07367
# epoch: 01, loss: -0.19733
# epoch: 02, loss: -0.27844
# epoch: 03, loss: -0.33261
# epoch: 04, loss: -0.38828
# epoch: 05, loss: -0.44663
# epoch: 06, loss: -0.49240
# epoch: 07, loss: -0.53080
# epoch: 08, loss: -0.56516
# epoch: 09, loss: -0.58539
# epoch: 10, loss: -0.60172
# epoch: 11, loss: -0.61462
# epoch: 12, loss: -0.62544
# epoch: 13, loss: -0.64144
# epoch: 14, loss: -0.65807
# epoch: 15, loss: -0.67588
# epoch: 16, loss: -0.69199
# epoch: 17, loss: -0.70611
# epoch: 18, loss: -0.71674
# epoch: 19, loss: -0.73087
# epoch: 20, loss: -0.74268
# epoch: 21, loss: -0.75392
# epoch: 22, loss: -0.76365
# epoch: 23, loss: -0.77371
# epoch: 24, loss: -0.78008
# epoch: 25, loss: -0.78509
# epoch: 26, loss: -0.78820
# epoch: 27, loss: -0.79186
# epoch: 28, loss: -0.79575
# epoch: 29, loss: -0.79943
# epoch: 30, loss: -0.80197
# epoch: 31, loss: -0.80311
# epoch: 32, loss: -0.80585
# epoch: 33, loss: -0.80851
# epoch: 34, loss: -0.81138
# epoch: 35, loss: -0.81085
# epoch: 36, loss: -0.81148
# epoch: 37, loss: -0.81367
# epoch: 38, loss: -0.81396
# epoch: 39, loss: -0.81447
# epoch: 40, loss: -0.81382
# epoch: 41, loss: -0.81100
# epoch: 42, loss: -0.81454
# epoch: 43, loss: -0.81382
# epoch: 44, loss: -0.81254
# epoch: 45, loss: -0.81090
# epoch: 46, loss: -0.81695
# epoch: 47, loss: -0.81564
# epoch: 48, loss: -0.81688
# epoch: 49, loss: -0.81600
# epoch: 50, loss: -0.81486
# epoch: 51, loss: -0.81502
# epoch: 52, loss: -0.81610
# epoch: 53, loss: -0.81563
# epoch: 54, loss: -0.81751
# epoch: 55, loss: -0.81493
# epoch: 56, loss: -0.81778
# epoch: 57, loss: -0.81679
# epoch: 58, loss: -0.81905
# epoch: 59, loss: -0.82301
# epoch: 60, loss: -0.82220
# epoch: 61, loss: -0.82408
# epoch: 62, loss: -0.82381
# epoch: 63, loss: -0.82419
# epoch: 64, loss: -0.82881
# epoch: 65, loss: -0.83145
# epoch: 66, loss: -0.83222
# epoch: 67, loss: -0.83343
# epoch: 68, loss: -0.83737
# epoch: 69, loss: -0.83615
# epoch: 70, loss: -0.83888
# epoch: 71, loss: -0.84275
# epoch: 72, loss: -0.84149
# epoch: 73, loss: -0.84589
# epoch: 74, loss: -0.84559
# epoch: 75, loss: -0.85022
# epoch: 76, loss: -0.85019
# epoch: 77, loss: -0.85291
# epoch: 78, loss: -0.85335
# epoch: 79, loss: -0.85720
# epoch: 80, loss: -0.85776
# epoch: 81, loss: -0.85900
# epoch: 82, loss: -0.86372
# epoch: 83, loss: -0.86318
# epoch: 84, loss: -0.86364
# epoch: 85, loss: -0.86337
# epoch: 86, loss: -0.86651
# epoch: 87, loss: -0.86939
# epoch: 88, loss: -0.87000
# epoch: 89, loss: -0.87218
# epoch: 90, loss: -0.86967
# epoch: 91, loss: -0.87299
# epoch: 92, loss: -0.87406
# epoch: 93, loss: -0.87402
# epoch: 94, loss: -0.87719
# epoch: 95, loss: -0.87577
# epoch: 96, loss: -0.87567
# epoch: 97, loss: -0.87696
# epoch: 98, loss: -0.87821
# epoch: 99, loss: -0.87930
# epoch: 100, loss: -0.87708
# epoch: 101, loss: -0.88015
# epoch: 102, loss: -0.88284
# epoch: 103, loss: -0.88022
# epoch: 104, loss: -0.88271
# epoch: 105, loss: -0.88277
# epoch: 106, loss: -0.88164
# epoch: 107, loss: -0.88498
# epoch: 108, loss: -0.88488
# epoch: 109, loss: -0.88354
# epoch: 110, loss: -0.88384
# epoch: 111, loss: -0.88383
# epoch: 112, loss: -0.88529
# epoch: 113, loss: -0.88655
# epoch: 114, loss: -0.88580
# epoch: 115, loss: -0.88556
# epoch: 116, loss: -0.88603
# epoch: 117, loss: -0.88635
# epoch: 118, loss: -0.88558
# epoch: 119, loss: -0.88638
# epoch: 120, loss: -0.88540
# epoch: 121, loss: -0.88727
# epoch: 122, loss: -0.88688
# epoch: 123, loss: -0.88665
# epoch: 124, loss: -0.88698
# epoch: 125, loss: -0.88663
# epoch: 126, loss: -0.88841
# epoch: 127, loss: -0.88577
# epoch: 128, loss: -0.88847
# epoch: 129, loss: -0.88675
# epoch: 130, loss: -0.88542
# epoch: 131, loss: -0.88719
# epoch: 132, loss: -0.88662
# epoch: 133, loss: -0.88685
# epoch: 134, loss: -0.88883
# epoch: 135, loss: -0.88837
# epoch: 136, loss: -0.88632
# epoch: 137, loss: -0.88796
# epoch: 138, loss: -0.88719
# epoch: 139, loss: -0.88878
# epoch: 140, loss: -0.88654
# epoch: 141, loss: -0.88820
# epoch: 142, loss: -0.88692
# epoch: 143, loss: -0.88847
# epoch: 144, loss: -0.88596
# epoch: 145, loss: -0.88833
# epoch: 146, loss: -0.88803
# epoch: 147, loss: -0.88792
# epoch: 148, loss: -0.88904
# epoch: 149, loss: -0.88849
# epoch: 150, loss: -0.88672
# epoch: 151, loss: -0.88799
# epoch: 152, loss: -0.88811
# epoch: 153, loss: -0.88997
# epoch: 154, loss: -0.88853
# epoch: 155, loss: -0.88624
# epoch: 156, loss: -0.88909
# epoch: 157, loss: -0.88886
# epoch: 158, loss: -0.88777
# epoch: 159, loss: -0.88891
# epoch: 160, loss: -0.89083
# epoch: 161, loss: -0.89121
# epoch: 162, loss: -0.88834
# epoch: 163, loss: -0.89072
# epoch: 164, loss: -0.89018
# epoch: 165, loss: -0.89051
# epoch: 166, loss: -0.88927
# epoch: 167, loss: -0.88907
# epoch: 168, loss: -0.89041
# epoch: 169, loss: -0.89045
# epoch: 170, loss: -0.89092
# epoch: 171, loss: -0.89099
# epoch: 172, loss: -0.88975
# epoch: 173, loss: -0.89293
# epoch: 174, loss: -0.89213
# epoch: 175, loss: -0.89333
# epoch: 176, loss: -0.89185
# epoch: 177, loss: -0.89328
# epoch: 178, loss: -0.89438
# epoch: 179, loss: -0.89251
# epoch: 180, loss: -0.89259
# epoch: 181, loss: -0.89447
# epoch: 182, loss: -0.89360
# epoch: 183, loss: -0.89344
# epoch: 184, loss: -0.89284
# epoch: 185, loss: -0.89495
# epoch: 186, loss: -0.89368
# epoch: 187, loss: -0.89490
# epoch: 188, loss: -0.89491
# epoch: 189, loss: -0.89601
# epoch: 190, loss: -0.89673
# epoch: 191, loss: -0.89698
# epoch: 192, loss: -0.89634
# epoch: 193, loss: -0.89735
# epoch: 194, loss: -0.89815
# epoch: 195, loss: -0.89597
# epoch: 196, loss: -0.89981
# epoch: 197, loss: -0.89833
# epoch: 198, loss: -0.90040
# epoch: 199, loss: -0.89850
# epoch: 200, loss: -0.89920
# epoch: 201, loss: -0.90000
# epoch: 202, loss: -0.89990
# epoch: 203, loss: -0.90045
# epoch: 204, loss: -0.90086
# epoch: 205, loss: -0.90029
# epoch: 206, loss: -0.90062
# epoch: 207, loss: -0.89974
# epoch: 208, loss: -0.90072
# epoch: 209, loss: -0.89961
# epoch: 210, loss: -0.90102
# epoch: 211, loss: -0.89942
# epoch: 212, loss: -0.90113
# epoch: 213, loss: -0.89906
# epoch: 214, loss: -0.90373
# epoch: 215, loss: -0.90320
# epoch: 216, loss: -0.90286
# epoch: 217, loss: -0.90255
# epoch: 218, loss: -0.90085
# epoch: 219, loss: -0.90127
# epoch: 220, loss: -0.90161
# epoch: 221, loss: -0.90019
# epoch: 222, loss: -0.90340
# epoch: 223, loss: -0.90148
# epoch: 224, loss: -0.90123
# epoch: 225, loss: -0.90184
# epoch: 226, loss: -0.90267
# epoch: 227, loss: -0.90066
# epoch: 228, loss: -0.90128
# epoch: 229, loss: -0.90044
# epoch: 230, loss: -0.90277
# epoch: 231, loss: -0.90139
# epoch: 232, loss: -0.90056
# epoch: 233, loss: -0.90125
# epoch: 234, loss: -0.90324
# epoch: 235, loss: -0.90066
# epoch: 236, loss: -0.90205
# epoch: 237, loss: -0.90056
# epoch: 238, loss: -0.90258
# epoch: 239, loss: -0.90079
# epoch: 240, loss: -0.90091
# epoch: 241, loss: -0.90189
# epoch: 242, loss: -0.90230
# epoch: 243, loss: -0.90169
# epoch: 244, loss: -0.90101
# epoch: 245, loss: -0.90310
# epoch: 246, loss: -0.90143
# epoch: 247, loss: -0.89882
# epoch: 248, loss: -0.90264
# epoch: 249, loss: -0.90033
# epoch: 250, loss: -0.90173
# epoch: 251, loss: -0.90136
# epoch: 252, loss: -0.90149
# epoch: 253, loss: -0.90350
# epoch: 254, loss: -0.90252
# epoch: 255, loss: -0.90141
# epoch: 256, loss: -0.90220
# epoch: 257, loss: -0.90261
# epoch: 258, loss: -0.90301
# epoch: 259, loss: -0.90307
# epoch: 260, loss: -0.90233
# epoch: 261, loss: -0.90254
# epoch: 262, loss: -0.90284
# epoch: 263, loss: -0.90317
# epoch: 264, loss: -0.90148
# epoch: 265, loss: -0.90154
# epoch: 266, loss: -0.90167
# epoch: 267, loss: -0.90159
# epoch: 268, loss: -0.90160
# epoch: 269, loss: -0.90192
# epoch: 270, loss: -0.90161
# epoch: 271, loss: -0.90171
# epoch: 272, loss: -0.90313
# epoch: 273, loss: -0.90172
# epoch: 274, loss: -0.89955
# epoch: 275, loss: -0.90063
# epoch: 276, loss: -0.90103
# epoch: 277, loss: -0.90242
# epoch: 278, loss: -0.90121
# epoch: 279, loss: -0.90188
# epoch: 280, loss: -0.90076
# epoch: 281, loss: -0.89746
# epoch: 282, loss: -0.90058
# epoch: 283, loss: -0.90164
# epoch: 284, loss: -0.90157
# epoch: 285, loss: -0.90170
# epoch: 286, loss: -0.90223
# epoch: 287, loss: -0.90032
# epoch: 288, loss: -0.90266
# epoch: 289, loss: -0.90242
# epoch: 290, loss: -0.90039
# epoch: 291, loss: -0.90224
# epoch: 292, loss: -0.90165
# epoch: 293, loss: -0.90281
# epoch: 294, loss: -0.90159
# epoch: 295, loss: -0.90188
# epoch: 296, loss: -0.90001
# epoch: 297, loss: -0.90235
# epoch: 298, loss: -0.90082
# epoch: 299, loss: -0.90027
# epoch: 300, loss: -0.90048
# epoch: 301, loss: -0.90189
# epoch: 302, loss: -0.90223
# epoch: 303, loss: -0.90316
# epoch: 304, loss: -0.90257
# epoch: 305, loss: -0.90201
# epoch: 306, loss: -0.90386
# epoch: 307, loss: -0.90231
# epoch: 308, loss: -0.90220
# epoch: 309, loss: -0.90309
# epoch: 310, loss: -0.90237
# epoch: 311, loss: -0.90014
# epoch: 312, loss: -0.90189
# epoch: 313, loss: -0.90379
# epoch: 314, loss: -0.90324
# epoch: 315, loss: -0.90287
# epoch: 316, loss: -0.90299
# epoch: 317, loss: -0.90226
# epoch: 318, loss: -0.90181
# epoch: 319, loss: -0.90165
# epoch: 320, loss: -0.90275
# epoch: 321, loss: -0.90107
# epoch: 322, loss: -0.90269
# epoch: 323, loss: -0.90360
# epoch: 324, loss: -0.90145
# epoch: 325, loss: -0.90211
# epoch: 326, loss: -0.90346
# epoch: 327, loss: -0.90254
# epoch: 328, loss: -0.90273
# epoch: 329, loss: -0.90127
# epoch: 330, loss: -0.90266
# epoch: 331, loss: -0.89965
# epoch: 332, loss: -0.90237
# epoch: 333, loss: -0.90179
# epoch: 334, loss: -0.90433
# epoch: 335, loss: -0.90334
# epoch: 336, loss: -0.90296
# epoch: 337, loss: -0.90214
# epoch: 338, loss: -0.90190
# epoch: 339, loss: -0.90260
# epoch: 340, loss: -0.90249
# epoch: 341, loss: -0.90357
# epoch: 342, loss: -0.90258
# epoch: 343, loss: -0.90201
# epoch: 344, loss: -0.90286
# epoch: 345, loss: -0.90276
# epoch: 346, loss: -0.90199
# epoch: 347, loss: -0.90093
# epoch: 348, loss: -0.90285
# epoch: 349, loss: -0.90478
# epoch: 350, loss: -0.90295
# epoch: 351, loss: -0.90205
# epoch: 352, loss: -0.90270
# epoch: 353, loss: -0.90380
# epoch: 354, loss: -0.90480
# epoch: 355, loss: -0.90342
# epoch: 356, loss: -0.90308
# epoch: 357, loss: -0.90477
# epoch: 358, loss: -0.90375
# epoch: 359, loss: -0.90387
# epoch: 360, loss: -0.90347
# epoch: 361, loss: -0.90360
# epoch: 362, loss: -0.90420
# epoch: 363, loss: -0.90520
# epoch: 364, loss: -0.90430
# epoch: 365, loss: -0.90480
# epoch: 366, loss: -0.90638
# epoch: 367, loss: -0.90427
# epoch: 368, loss: -0.90543
# epoch: 369, loss: -0.90429
# epoch: 370, loss: -0.90466
# epoch: 371, loss: -0.90663
# epoch: 372, loss: -0.90558
# epoch: 373, loss: -0.90526
# epoch: 374, loss: -0.90570
# epoch: 375, loss: -0.90464
# epoch: 376, loss: -0.90607
# epoch: 377, loss: -0.90622
# epoch: 378, loss: -0.90622
# epoch: 379, loss: -0.90535
# epoch: 380, loss: -0.90403
# epoch: 381, loss: -0.90456
# epoch: 382, loss: -0.90602
# epoch: 383, loss: -0.90553
# epoch: 384, loss: -0.90572
# epoch: 385, loss: -0.90403
# epoch: 386, loss: -0.90461
# epoch: 387, loss: -0.90359
# epoch: 388, loss: -0.90615
# epoch: 389, loss: -0.90589
# epoch: 390, loss: -0.90600
# epoch: 391, loss: -0.90439
# epoch: 392, loss: -0.90548
# epoch: 393, loss: -0.90511
# epoch: 394, loss: -0.90664
# epoch: 395, loss: -0.90518
# epoch: 396, loss: -0.90478
# epoch: 397, loss: -0.90438
# epoch: 398, loss: -0.90629
# epoch: 399, loss: -0.90564
# epoch: 400, loss: -0.90643
# epoch: 401, loss: -0.90455
# epoch: 402, loss: -0.90625
# epoch: 403, loss: -0.90716
# epoch: 404, loss: -0.90635
# epoch: 405, loss: -0.90614
# epoch: 406, loss: -0.90557
# epoch: 407, loss: -0.90743
# epoch: 408, loss: -0.90673
# epoch: 409, loss: -0.90695
# epoch: 410, loss: -0.90544
# epoch: 411, loss: -0.90600
# epoch: 412, loss: -0.90629
# epoch: 413, loss: -0.90525
# epoch: 414, loss: -0.90572
# epoch: 415, loss: -0.90403
# epoch: 416, loss: -0.90475
# epoch: 417, loss: -0.90543
# epoch: 418, loss: -0.90453
# epoch: 419, loss: -0.90582
# epoch: 420, loss: -0.90379
# epoch: 421, loss: -0.90615
# epoch: 422, loss: -0.90635
# epoch: 423, loss: -0.90372
# epoch: 424, loss: -0.90417
# epoch: 425, loss: -0.90678
# epoch: 426, loss: -0.90520
# epoch: 427, loss: -0.90703
# epoch: 428, loss: -0.90486
# epoch: 429, loss: -0.90636
# epoch: 430, loss: -0.90463
# epoch: 431, loss: -0.90671
# epoch: 432, loss: -0.90469
# epoch: 433, loss: -0.90707
# epoch: 434, loss: -0.90427
# epoch: 435, loss: -0.90615
# epoch: 436, loss: -0.90639
# epoch: 437, loss: -0.90641
# epoch: 438, loss: -0.90496
# epoch: 439, loss: -0.90596
# epoch: 440, loss: -0.90640
# epoch: 441, loss: -0.90537
# epoch: 442, loss: -0.90634
# epoch: 443, loss: -0.90532
# epoch: 444, loss: -0.90479
# epoch: 445, loss: -0.90529
# epoch: 446, loss: -0.90487
# epoch: 447, loss: -0.90535
# epoch: 448, loss: -0.90278
# epoch: 449, loss: -0.90486
# epoch: 450, loss: -0.90406
# epoch: 451, loss: -0.90474
# epoch: 452, loss: -0.90513
# epoch: 453, loss: -0.90305
# epoch: 454, loss: -0.90174
# epoch: 455, loss: -0.90460
# epoch: 456, loss: -0.90292
# epoch: 457, loss: -0.90396
# epoch: 458, loss: -0.90424
# epoch: 459, loss: -0.90441
# epoch: 460, loss: -0.90452
# epoch: 461, loss: -0.90390
# epoch: 462, loss: -0.90352
# epoch: 463, loss: -0.90104
# epoch: 464, loss: -0.90248
# epoch: 465, loss: -0.90320
# epoch: 466, loss: -0.90360
# epoch: 467, loss: -0.90207
# epoch: 468, loss: -0.90173
# epoch: 469, loss: -0.90300
# epoch: 470, loss: -0.90287
# epoch: 471, loss: -0.90362
# epoch: 472, loss: -0.90190
# epoch: 473, loss: -0.90219
# epoch: 474, loss: -0.90178
# epoch: 475, loss: -0.90197
# epoch: 476, loss: -0.90178
# epoch: 477, loss: -0.90095
# epoch: 478, loss: -0.90236
# epoch: 479, loss: -0.90093
# epoch: 480, loss: -0.90064
# epoch: 481, loss: -0.90095
# epoch: 482, loss: -0.90107
# epoch: 483, loss: -0.90167
# epoch: 484, loss: -0.89910
# epoch: 485, loss: -0.90058
# epoch: 486, loss: -0.90064
# epoch: 487, loss: -0.90072
# epoch: 488, loss: -0.90152
# epoch: 489, loss: -0.90220
# epoch: 490, loss: -0.90106
# epoch: 491, loss: -0.90142
# epoch: 492, loss: -0.90106
# epoch: 493, loss: -0.90078
# epoch: 494, loss: -0.90093
# epoch: 495, loss: -0.89952
# epoch: 496, loss: -0.90129
# epoch: 497, loss: -0.90098
# epoch: 498, loss: -0.90110
# epoch: 499, loss: -0.90037
# epoch: 500, loss: -0.89878
# epoch: 501, loss: -0.90238
# epoch: 502, loss: -0.90116
# epoch: 503, loss: -0.90280
# epoch: 504, loss: -0.90090
# epoch: 505, loss: -0.90145
# epoch: 506, loss: -0.90061
# epoch: 507, loss: -0.90120
# epoch: 508, loss: -0.90044
# epoch: 509, loss: -0.89966
# epoch: 510, loss: -0.90163
# epoch: 511, loss: -0.90202
# epoch: 512, loss: -0.90099
# epoch: 513, loss: -0.89874
# epoch: 514, loss: -0.90216
# epoch: 515, loss: -0.89966
# epoch: 516, loss: -0.89988
# epoch: 517, loss: -0.90120
# epoch: 518, loss: -0.89899
# epoch: 519, loss: -0.90172
# epoch: 520, loss: -0.90092
# epoch: 521, loss: -0.90089
# epoch: 522, loss: -0.90079
# epoch: 523, loss: -0.90078
# epoch: 524, loss: -0.89942
# epoch: 525, loss: -0.89911
# epoch: 526, loss: -0.90170
# epoch: 527, loss: -0.89900
# epoch: 528, loss: -0.90110
# epoch: 529, loss: -0.89928
# epoch: 530, loss: -0.90021
# epoch: 531, loss: -0.90172
# epoch: 532, loss: -0.90186
# epoch: 533, loss: -0.89951
# epoch: 534, loss: -0.90068
# epoch: 535, loss: -0.90046
# epoch: 536, loss: -0.90060
# epoch: 537, loss: -0.90185
# epoch: 538, loss: -0.90101
# epoch: 539, loss: -0.90052
# epoch: 540, loss: -0.90093
# epoch: 541, loss: -0.89929
# epoch: 542, loss: -0.90077
# epoch: 543, loss: -0.89911
# epoch: 544, loss: -0.90069
# epoch: 545, loss: -0.90144
# epoch: 546, loss: -0.90099
# epoch: 547, loss: -0.90087
# epoch: 548, loss: -0.89937
# epoch: 549, loss: -0.89985
# epoch: 550, loss: -0.89918
# epoch: 551, loss: -0.89857
# epoch: 552, loss: -0.90036
# epoch: 553, loss: -0.89816
# epoch: 554, loss: -0.89985
# epoch: 555, loss: -0.89995
# epoch: 556, loss: -0.89958
# epoch: 557, loss: -0.90097
# epoch: 558, loss: -0.90151
# epoch: 559, loss: -0.90055
# epoch: 560, loss: -0.90033
# epoch: 561, loss: -0.90171
# epoch: 562, loss: -0.90051
# epoch: 563, loss: -0.89880
# epoch: 564, loss: -0.90002
# epoch: 565, loss: -0.89943
# epoch: 566, loss: -0.89711
# epoch: 567, loss: -0.89945
# epoch: 568, loss: -0.89967
# epoch: 569, loss: -0.90097
# epoch: 570, loss: -0.90023
# epoch: 571, loss: -0.90007
# epoch: 572, loss: -0.90096
# epoch: 573, loss: -0.89957
# epoch: 574, loss: -0.90002
# epoch: 575, loss: -0.89731
# epoch: 576, loss: -0.90089
# epoch: 577, loss: -0.89936
# epoch: 578, loss: -0.90007
# epoch: 579, loss: -0.89918
# epoch: 580, loss: -0.90014
# epoch: 581, loss: -0.89771
# epoch: 582, loss: -0.89967
# epoch: 583, loss: -0.90048
# epoch: 584, loss: -0.89930
# epoch: 585, loss: -0.90023
# epoch: 586, loss: -0.90003
# epoch: 587, loss: -0.89882
# epoch: 588, loss: -0.90180
# epoch: 589, loss: -0.89849
# epoch: 590, loss: -0.90022
# epoch: 591, loss: -0.89907
# epoch: 592, loss: -0.90046
# epoch: 593, loss: -0.89938
# epoch: 594, loss: -0.89966
# epoch: 595, loss: -0.89985
# epoch: 596, loss: -0.90087
# epoch: 597, loss: -0.89911
# epoch: 598, loss: -0.89990
# epoch: 599, loss: -0.90005
# epoch: 600, loss: -0.89916
# epoch: 601, loss: -0.90066
# epoch: 602, loss: -0.90064
# epoch: 603, loss: -0.89938
# epoch: 604, loss: -0.89898
# epoch: 605, loss: -0.90012
# epoch: 606, loss: -0.90000
# epoch: 607, loss: -0.89926
# epoch: 608, loss: -0.89965
# epoch: 609, loss: -0.90145
# epoch: 610, loss: -0.90111
# epoch: 611, loss: -0.90070
# epoch: 612, loss: -0.90007
# epoch: 613, loss: -0.90144
# epoch: 614, loss: -0.89996
# epoch: 615, loss: -0.89986
# epoch: 616, loss: -0.89908
# epoch: 617, loss: -0.89963
# epoch: 618, loss: -0.90051
# epoch: 619, loss: -0.89996
# epoch: 620, loss: -0.90153
# epoch: 621, loss: -0.89967
# epoch: 622, loss: -0.89877
# epoch: 623, loss: -0.89944
# epoch: 624, loss: -0.90051
# epoch: 625, loss: -0.90033
# epoch: 626, loss: -0.89838
# epoch: 627, loss: -0.89865
# epoch: 628, loss: -0.89971
# epoch: 629, loss: -0.89848
# epoch: 630, loss: -0.89989
# epoch: 631, loss: -0.89935
# epoch: 632, loss: -0.89999
# epoch: 633, loss: -0.89933
# epoch: 634, loss: -0.90068
# epoch: 635, loss: -0.90095
# epoch: 636, loss: -0.89919
# epoch: 637, loss: -0.89963
# epoch: 638, loss: -0.89877
# epoch: 639, loss: -0.89996
# epoch: 640, loss: -0.89947
# epoch: 641, loss: -0.90024
# epoch: 642, loss: -0.89938
# epoch: 643, loss: -0.89725
# epoch: 644, loss: -0.89947
# epoch: 645, loss: -0.89852
# epoch: 646, loss: -0.90002
# epoch: 647, loss: -0.89910
# epoch: 648, loss: -0.89985
# epoch: 649, loss: -0.89754
# epoch: 650, loss: -0.90012
# epoch: 651, loss: -0.90098
# epoch: 652, loss: -0.89814
# epoch: 653, loss: -0.89886
# epoch: 654, loss: -0.89724
# epoch: 655, loss: -0.89849
# epoch: 656, loss: -0.89991
# epoch: 657, loss: -0.89974
# epoch: 658, loss: -0.89849
# epoch: 659, loss: -0.89806
# epoch: 660, loss: -0.89849
# epoch: 661, loss: -0.89756
# epoch: 662, loss: -0.89898
# epoch: 663, loss: -0.89866
# epoch: 664, loss: -0.89860
# epoch: 665, loss: -0.89764
# epoch: 666, loss: -0.89698
# epoch: 667, loss: -0.89697
# epoch: 668, loss: -0.89864
# epoch: 669, loss: -0.89673
# epoch: 670, loss: -0.89949
# epoch: 671, loss: -0.89756
# epoch: 672, loss: -0.89887
# epoch: 673, loss: -0.89692
# epoch: 674, loss: -0.89690
# epoch: 675, loss: -0.89826
# epoch: 676, loss: -0.89758
# epoch: 677, loss: -0.89809
# epoch: 678, loss: -0.89739
# epoch: 679, loss: -0.89880
# epoch: 680, loss: -0.89948
# epoch: 681, loss: -0.89703
# epoch: 682, loss: -0.89721
# epoch: 683, loss: -0.89658
# epoch: 684, loss: -0.89644
# epoch: 685, loss: -0.89870
# epoch: 686, loss: -0.89671
# epoch: 687, loss: -0.89630
# epoch: 688, loss: -0.89873
# epoch: 689, loss: -0.89729
# epoch: 690, loss: -0.89789
# epoch: 691, loss: -0.89737
# epoch: 692, loss: -0.89913
# epoch: 693, loss: -0.89754
# epoch: 694, loss: -0.89693
# epoch: 695, loss: -0.89680
# epoch: 696, loss: -0.89892
# epoch: 697, loss: -0.89693
# epoch: 698, loss: -0.89726
# epoch: 699, loss: -0.89764
# epoch: 700, loss: -0.89796
# epoch: 701, loss: -0.89661
# epoch: 702, loss: -0.89816
# epoch: 703, loss: -0.89582
# epoch: 704, loss: -0.89676
# epoch: 705, loss: -0.89717
# epoch: 706, loss: -0.89591
# epoch: 707, loss: -0.89672
# epoch: 708, loss: -0.89667
# epoch: 709, loss: -0.89788
# epoch: 710, loss: -0.89609
# epoch: 711, loss: -0.89790
# epoch: 712, loss: -0.89710
# epoch: 713, loss: -0.89682
# epoch: 714, loss: -0.89800
# epoch: 715, loss: -0.89701
# epoch: 716, loss: -0.89770
# epoch: 717, loss: -0.89781
# epoch: 718, loss: -0.89765
# epoch: 719, loss: -0.89649
# epoch: 720, loss: -0.89510
# epoch: 721, loss: -0.89608
# epoch: 722, loss: -0.89698
# epoch: 723, loss: -0.89603
# epoch: 724, loss: -0.89362
# epoch: 725, loss: -0.89723
# epoch: 726, loss: -0.89575
# epoch: 727, loss: -0.89655
# epoch: 728, loss: -0.89756
# epoch: 729, loss: -0.89691
# epoch: 730, loss: -0.89753
# epoch: 731, loss: -0.89570
# epoch: 732, loss: -0.89657
# epoch: 733, loss: -0.89588
# epoch: 734, loss: -0.89643
# epoch: 735, loss: -0.89705
# epoch: 736, loss: -0.89598
# epoch: 737, loss: -0.89520
# epoch: 738, loss: -0.89459
# epoch: 739, loss: -0.89549
# epoch: 740, loss: -0.89470
# epoch: 741, loss: -0.89547
# epoch: 742, loss: -0.89619
# epoch: 743, loss: -0.89423
# epoch: 744, loss: -0.89724
# epoch: 745, loss: -0.89701
# epoch: 746, loss: -0.89550
# epoch: 747, loss: -0.89363
# epoch: 748, loss: -0.89406
# epoch: 749, loss: -0.89566
# epoch: 750, loss: -0.89379
# epoch: 751, loss: -0.89426
# epoch: 752, loss: -0.89428
# epoch: 753, loss: -0.89483
# epoch: 754, loss: -0.89436
# epoch: 755, loss: -0.89225
# epoch: 756, loss: -0.89497
# epoch: 757, loss: -0.89570
# epoch: 758, loss: -0.89531
# epoch: 759, loss: -0.89353
# epoch: 760, loss: -0.89494
# epoch: 761, loss: -0.89352
# epoch: 762, loss: -0.89499
# epoch: 763, loss: -0.89484
# epoch: 764, loss: -0.89482
# epoch: 765, loss: -0.89430
# epoch: 766, loss: -0.89438
# epoch: 767, loss: -0.89608
# epoch: 768, loss: -0.89349
# epoch: 769, loss: -0.89428
# epoch: 770, loss: -0.89427
# epoch: 771, loss: -0.89327
# epoch: 772, loss: -0.89533
# epoch: 773, loss: -0.89443
# epoch: 774, loss: -0.89287
# epoch: 775, loss: -0.89275
# epoch: 776, loss: -0.89398
# epoch: 777, loss: -0.89342
# epoch: 778, loss: -0.89214
# epoch: 779, loss: -0.89555
# epoch: 780, loss: -0.89545
# epoch: 781, loss: -0.89385
# epoch: 782, loss: -0.89325
# epoch: 783, loss: -0.89462
# epoch: 784, loss: -0.89399
# epoch: 785, loss: -0.89537
# epoch: 786, loss: -0.89425
# epoch: 787, loss: -0.89330
# epoch: 788, loss: -0.89354
# epoch: 789, loss: -0.89570
# epoch: 790, loss: -0.89540
# epoch: 791, loss: -0.89548
# epoch: 792, loss: -0.89534
# epoch: 793, loss: -0.89270
# epoch: 794, loss: -0.89542
# epoch: 795, loss: -0.89309
# epoch: 796, loss: -0.89282
# epoch: 797, loss: -0.89348
# epoch: 798, loss: -0.89435
# epoch: 799, loss: -0.89311
# epoch: 800, loss: -0.89450
# epoch: 801, loss: -0.89372
# epoch: 802, loss: -0.89464
# epoch: 803, loss: -0.89440
# epoch: 804, loss: -0.89410
# epoch: 805, loss: -0.89358
# epoch: 806, loss: -0.89375
# epoch: 807, loss: -0.89426
# epoch: 808, loss: -0.89207
# epoch: 809, loss: -0.89262
# epoch: 810, loss: -0.89513
# epoch: 811, loss: -0.89533
# epoch: 812, loss: -0.89338
# epoch: 813, loss: -0.89460
# epoch: 814, loss: -0.89355
# epoch: 815, loss: -0.89192
# epoch: 816, loss: -0.89404
# epoch: 817, loss: -0.89424
# epoch: 818, loss: -0.89288
# epoch: 819, loss: -0.89311
# epoch: 820, loss: -0.89264
# epoch: 821, loss: -0.89310
# epoch: 822, loss: -0.89326
# epoch: 823, loss: -0.89108
# epoch: 824, loss: -0.89302
# epoch: 825, loss: -0.89320
# epoch: 826, loss: -0.89307
# epoch: 827, loss: -0.89239
# epoch: 828, loss: -0.89269
# epoch: 829, loss: -0.89331
# epoch: 830, loss: -0.89280
# epoch: 831, loss: -0.89159
# epoch: 832, loss: -0.89207
# epoch: 833, loss: -0.89269
# epoch: 834, loss: -0.89284
# epoch: 835, loss: -0.89362
# epoch: 836, loss: -0.89270
# epoch: 837, loss: -0.89543
# epoch: 838, loss: -0.89356
# epoch: 839, loss: -0.89514
# epoch: 840, loss: -0.89217
# epoch: 841, loss: -0.89415
# epoch: 842, loss: -0.89460
# epoch: 843, loss: -0.89644
# epoch: 844, loss: -0.89462
# epoch: 845, loss: -0.89330
# epoch: 846, loss: -0.89489
# epoch: 847, loss: -0.89486
# epoch: 848, loss: -0.89348
# epoch: 849, loss: -0.89565
# epoch: 850, loss: -0.89551
# epoch: 851, loss: -0.89471
# epoch: 852, loss: -0.89486
# epoch: 853, loss: -0.89718
# epoch: 854, loss: -0.89463
# epoch: 855, loss: -0.89427
# epoch: 856, loss: -0.89548
# epoch: 857, loss: -0.89667
# epoch: 858, loss: -0.89631
# epoch: 859, loss: -0.89486
# epoch: 860, loss: -0.89577
# epoch: 861, loss: -0.89691
# epoch: 862, loss: -0.89601
# epoch: 863, loss: -0.89670
# epoch: 864, loss: -0.89495
# epoch: 865, loss: -0.89661
# epoch: 866, loss: -0.89660
# epoch: 867, loss: -0.89742
# epoch: 868, loss: -0.89733
# epoch: 869, loss: -0.89557
# epoch: 870, loss: -0.89674
# epoch: 871, loss: -0.89672
# epoch: 872, loss: -0.89607
# epoch: 873, loss: -0.89605
# epoch: 874, loss: -0.89427
# epoch: 875, loss: -0.89697
# epoch: 876, loss: -0.89763
# epoch: 877, loss: -0.89688
# epoch: 878, loss: -0.89598
# epoch: 879, loss: -0.89473
# epoch: 880, loss: -0.89530
# epoch: 881, loss: -0.89671
# epoch: 882, loss: -0.89627
# epoch: 883, loss: -0.89626
# epoch: 884, loss: -0.89736
# epoch: 885, loss: -0.89655
# epoch: 886, loss: -0.89661
# epoch: 887, loss: -0.89677
# epoch: 888, loss: -0.89509
# epoch: 889, loss: -0.89618
# epoch: 890, loss: -0.89544
# epoch: 891, loss: -0.89756
# epoch: 892, loss: -0.89677
# epoch: 893, loss: -0.89494
# epoch: 894, loss: -0.89757
# epoch: 895, loss: -0.89659
# epoch: 896, loss: -0.89590
# epoch: 897, loss: -0.89769
# epoch: 898, loss: -0.89729
# epoch: 899, loss: -0.89701
# epoch: 900, loss: -0.89660
# epoch: 901, loss: -0.89666
# epoch: 902, loss: -0.89726
# epoch: 903, loss: -0.89671
# epoch: 904, loss: -0.89771
# epoch: 905, loss: -0.89673
# epoch: 906, loss: -0.89717
# epoch: 907, loss: -0.89689
# epoch: 908, loss: -0.89798
# epoch: 909, loss: -0.89697
# epoch: 910, loss: -0.89763
# epoch: 911, loss: -0.89583
# epoch: 912, loss: -0.89732
# epoch: 913, loss: -0.89897
# epoch: 914, loss: -0.89864
# epoch: 915, loss: -0.89733
# epoch: 916, loss: -0.89695
# epoch: 917, loss: -0.89718
# epoch: 918, loss: -0.89768
# epoch: 919, loss: -0.89756
# epoch: 920, loss: -0.89704
# epoch: 921, loss: -0.89787
# epoch: 922, loss: -0.89825
# epoch: 923, loss: -0.89905
# epoch: 924, loss: -0.89978
# epoch: 925, loss: -0.89737
# epoch: 926, loss: -0.89938
# epoch: 927, loss: -0.89780
# epoch: 928, loss: -0.89881
# epoch: 929, loss: -0.89937
# epoch: 930, loss: -0.89787
# epoch: 931, loss: -0.89933
# epoch: 932, loss: -0.89960
# epoch: 933, loss: -0.90038
# epoch: 934, loss: -0.89857
# epoch: 935, loss: -0.89879
# epoch: 936, loss: -0.89779
# epoch: 937, loss: -0.89775
# epoch: 938, loss: -0.89811
# epoch: 939, loss: -0.89841
# epoch: 940, loss: -0.89670
# epoch: 941, loss: -0.89900
# epoch: 942, loss: -0.89938
# epoch: 943, loss: -0.89912
# epoch: 944, loss: -0.89881
# epoch: 945, loss: -0.89977
# epoch: 946, loss: -0.89644
# epoch: 947, loss: -0.90025
# epoch: 948, loss: -0.89807
# epoch: 949, loss: -0.90015
# epoch: 950, loss: -0.89940
# epoch: 951, loss: -0.89879
# epoch: 952, loss: -0.89962
# epoch: 953, loss: -0.89926
# epoch: 954, loss: -0.89964
# epoch: 955, loss: -0.89886
# epoch: 956, loss: -0.89968
# epoch: 957, loss: -0.89754
# epoch: 958, loss: -0.89937
# epoch: 959, loss: -0.89948
# epoch: 960, loss: -0.89856
# epoch: 961, loss: -0.89947
# epoch: 962, loss: -0.89796
# epoch: 963, loss: -0.89854
# epoch: 964, loss: -0.89960
# epoch: 965, loss: -0.89955
# epoch: 966, loss: -0.89936
# epoch: 967, loss: -0.90044
# epoch: 968, loss: -0.89708
# epoch: 969, loss: -0.89921
# epoch: 970, loss: -0.89777
# epoch: 971, loss: -0.89960
# epoch: 972, loss: -0.89822
# epoch: 973, loss: -0.89758
# epoch: 974, loss: -0.89841
# epoch: 975, loss: -0.89968
# epoch: 976, loss: -0.89851
# epoch: 977, loss: -0.90047
# epoch: 978, loss: -0.90012
# epoch: 979, loss: -0.89871
# epoch: 980, loss: -0.89979
# epoch: 981, loss: -0.89958
# epoch: 982, loss: -0.89977
# epoch: 983, loss: -0.90080
# epoch: 984, loss: -0.90028
# epoch: 985, loss: -0.89980
# epoch: 986, loss: -0.90086
# epoch: 987, loss: -0.90105
# epoch: 988, loss: -0.89954
# epoch: 989, loss: -0.89742
# epoch: 990, loss: -0.89713
# epoch: 991, loss: -0.90000
# epoch: 992, loss: -0.89921
# epoch: 993, loss: -0.89991
# epoch: 994, loss: -0.89973
# epoch: 995, loss: -0.89871
# epoch: 996, loss: -0.89796
# epoch: 997, loss: -0.89993
# epoch: 998, loss: -0.90095
# epoch: 999, loss: -0.90058
# epoch: 1000, loss: -0.90001
# epoch: 1001, loss: -0.90088
# epoch: 1002, loss: -0.89896
# epoch: 1003, loss: -0.89796
# epoch: 1004, loss: -0.90013
# epoch: 1005, loss: -0.90007
# epoch: 1006, loss: -0.89942
# epoch: 1007, loss: -0.90087
# epoch: 1008, loss: -0.90021
# epoch: 1009, loss: -0.90015
# epoch: 1010, loss: -0.89960
# epoch: 1011, loss: -0.89860
# epoch: 1012, loss: -0.90017
# epoch: 1013, loss: -0.90073
# epoch: 1014, loss: -0.89934
# epoch: 1015, loss: -0.90113
# epoch: 1016, loss: -0.89855
# epoch: 1017, loss: -0.89892
# epoch: 1018, loss: -0.89905
# epoch: 1019, loss: -0.90089
# epoch: 1020, loss: -0.89865
# epoch: 1021, loss: -0.90036
# epoch: 1022, loss: -0.89949
# epoch: 1023, loss: -0.89989
# epoch: 1024, loss: -0.89802
# epoch: 1025, loss: -0.90146
# epoch: 1026, loss: -0.89775
# epoch: 1027, loss: -0.90098
# epoch: 1028, loss: -0.90126
# epoch: 1029, loss: -0.89890
# epoch: 1030, loss: -0.90128
# epoch: 1031, loss: -0.89906
# epoch: 1032, loss: -0.89990
# epoch: 1033, loss: -0.90083
# epoch: 1034, loss: -0.90028
# epoch: 1035, loss: -0.90014
# epoch: 1036, loss: -0.89998
# epoch: 1037, loss: -0.89991
# epoch: 1038, loss: -0.90121
# epoch: 1039, loss: -0.89995
# epoch: 1040, loss: -0.89965
# epoch: 1041, loss: -0.89963
# epoch: 1042, loss: -0.90096
# epoch: 1043, loss: -0.90006
# epoch: 1044, loss: -0.90000
# epoch: 1045, loss: -0.90011
# epoch: 1046, loss: -0.90170
# epoch: 1047, loss: -0.89966
# epoch: 1048, loss: -0.90103
# epoch: 1049, loss: -0.89966
# epoch: 1050, loss: -0.90056
# epoch: 1051, loss: -0.90112
# epoch: 1052, loss: -0.89968
# epoch: 1053, loss: -0.89892
# epoch: 1054, loss: -0.90172
# epoch: 1055, loss: -0.89841
# epoch: 1056, loss: -0.90041
# epoch: 1057, loss: -0.89944
# epoch: 1058, loss: -0.89963
# epoch: 1059, loss: -0.90120
# epoch: 1060, loss: -0.89912
# epoch: 1061, loss: -0.90124
# epoch: 1062, loss: -0.89941
# epoch: 1063, loss: -0.90083
# epoch: 1064, loss: -0.90121
# epoch: 1065, loss: -0.89992
# epoch: 1066, loss: -0.90172
# epoch: 1067, loss: -0.90080
# epoch: 1068, loss: -0.89918
# epoch: 1069, loss: -0.90133
# epoch: 1070, loss: -0.90170
# epoch: 1071, loss: -0.90111
# epoch: 1072, loss: -0.90085
# epoch: 1073, loss: -0.90054
# epoch: 1074, loss: -0.90068
# epoch: 1075, loss: -0.90104
# epoch: 1076, loss: -0.90081
# epoch: 1077, loss: -0.90061
# epoch: 1078, loss: -0.90102
# epoch: 1079, loss: -0.89951
# epoch: 1080, loss: -0.90056
# epoch: 1081, loss: -0.90043
# epoch: 1082, loss: -0.90114
# epoch: 1083, loss: -0.90032
# epoch: 1084, loss: -0.90161
# epoch: 1085, loss: -0.90137
# epoch: 1086, loss: -0.89976
# epoch: 1087, loss: -0.89870
# epoch: 1088, loss: -0.89868
# epoch: 1089, loss: -0.90062
# epoch: 1090, loss: -0.90084
# epoch: 1091, loss: -0.89953
# epoch: 1092, loss: -0.89904
# epoch: 1093, loss: -0.90116
# epoch: 1094, loss: -0.90183
# epoch: 1095, loss: -0.89900
# epoch: 1096, loss: -0.90141
# epoch: 1097, loss: -0.90085
# epoch: 1098, loss: -0.90066
# epoch: 1099, loss: -0.89989
# epoch: 1100, loss: -0.89966
# epoch: 1101, loss: -0.90003
# epoch: 1102, loss: -0.90085
# epoch: 1103, loss: -0.90047
# epoch: 1104, loss: -0.90057
# epoch: 1105, loss: -0.89927
# epoch: 1106, loss: -0.90052
# epoch: 1107, loss: -0.90000
# epoch: 1108, loss: -0.90039
# epoch: 1109, loss: -0.90008
# epoch: 1110, loss: -0.89944
# epoch: 1111, loss: -0.90024
# epoch: 1112, loss: -0.90034
# epoch: 1113, loss: -0.90172
# epoch: 1114, loss: -0.89943
# epoch: 1115, loss: -0.90049
# epoch: 1116, loss: -0.89863
# epoch: 1117, loss: -0.90163
# epoch: 1118, loss: -0.90105
# epoch: 1119, loss: -0.89953
# epoch: 1120, loss: -0.90122
# epoch: 1121, loss: -0.90002
# epoch: 1122, loss: -0.89912
# epoch: 1123, loss: -0.90055
# epoch: 1124, loss: -0.89965
# epoch: 1125, loss: -0.90122
# epoch: 1126, loss: -0.90202
# epoch: 1127, loss: -0.90098
# epoch: 1128, loss: -0.90231
# epoch: 1129, loss: -0.90225
# epoch: 1130, loss: -0.90085
# epoch: 1131, loss: -0.90161
# epoch: 1132, loss: -0.90035
# epoch: 1133, loss: -0.90022
# epoch: 1134, loss: -0.89906
# epoch: 1135, loss: -0.90037
# epoch: 1136, loss: -0.90083
# epoch: 1137, loss: -0.90028
# epoch: 1138, loss: -0.89907
# epoch: 1139, loss: -0.90092
# epoch: 1140, loss: -0.90068
# epoch: 1141, loss: -0.90106
# epoch: 1142, loss: -0.90299
# epoch: 1143, loss: -0.89993
# epoch: 1144, loss: -0.90039
# epoch: 1145, loss: -0.90168
# epoch: 1146, loss: -0.89919
# epoch: 1147, loss: -0.90150
# epoch: 1148, loss: -0.90151
# epoch: 1149, loss: -0.90180
# epoch: 1150, loss: -0.90174
# epoch: 1151, loss: -0.90053
# epoch: 1152, loss: -0.90186
# epoch: 1153, loss: -0.90017
# epoch: 1154, loss: -0.90154
# epoch: 1155, loss: -0.90184
# epoch: 1156, loss: -0.90120
# epoch: 1157, loss: -0.90052
# epoch: 1158, loss: -0.90196
# epoch: 1159, loss: -0.90141
# epoch: 1160, loss: -0.90151
# epoch: 1161, loss: -0.89960
# epoch: 1162, loss: -0.90163
# epoch: 1163, loss: -0.90271
# epoch: 1164, loss: -0.89968
# epoch: 1165, loss: -0.90202
# epoch: 1166, loss: -0.90094
# epoch: 1167, loss: -0.90123
# epoch: 1168, loss: -0.90187
# epoch: 1169, loss: -0.90213
# epoch: 1170, loss: -0.89889
# epoch: 1171, loss: -0.90075
# epoch: 1172, loss: -0.90072
# epoch: 1173, loss: -0.90128
# epoch: 1174, loss: -0.90096
# epoch: 1175, loss: -0.90165
# epoch: 1176, loss: -0.90027
# epoch: 1177, loss: -0.90190
# epoch: 1178, loss: -0.89998
# epoch: 1179, loss: -0.90029
# epoch: 1180, loss: -0.90063
# epoch: 1181, loss: -0.90268
# epoch: 1182, loss: -0.90111
# epoch: 1183, loss: -0.90178
# epoch: 1184, loss: -0.90110
# epoch: 1185, loss: -0.90006
# epoch: 1186, loss: -0.90142
# epoch: 1187, loss: -0.90216
# epoch: 1188, loss: -0.89985
# epoch: 1189, loss: -0.90023
# epoch: 1190, loss: -0.90028
# epoch: 1191, loss: -0.90109
# epoch: 1192, loss: -0.90274
# epoch: 1193, loss: -0.90236
# epoch: 1194, loss: -0.89982
# epoch: 1195, loss: -0.90241
# epoch: 1196, loss: -0.90085
# epoch: 1197, loss: -0.89942
# epoch: 1198, loss: -0.90130
# epoch: 1199, loss: -0.90179

# %% [markdown]
# ##Check the Training Result

# %%
ds_cl= MyDataSet(norm_X_ds, norm_X_ds)
dl_cl = DataLoader(ds_cl, batch_size=256)

# %%
embeddings = []

# disable gradients for faster calculations
model.eval()
with torch.no_grad():
    for dl_cl1, dl_cl2 in dl_cl:

        dl_cl1 = dl_cl1.to(device)
        f, z, p = model(dl_cl1)
        
        # store the embeddings in lists
        embeddings.append(f)

# concatenate the embeddings, targets and convert to numpy
embeddings = torch.cat(embeddings, dim=0)
embeddings = embeddings.cpu().numpy()

# %%
test = (embeddings - embeddings.mean(axis=0)) / (embeddings.std(axis=0))

# %%
#KMeans in latent space
kmeans_backbone = KMeans(n_clusters=2).fit(test)
kmeans_labels_backbone = kmeans_backbone.labels_

# %%
normalized_mutual_info_score(kmeans_labels_backbone, y)
# Out:
# 0.8810262189005555

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(test)
data_X_tsne = np.vstack((X_tsne.T, y)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#NMI increases from 0.84 to 0.88
