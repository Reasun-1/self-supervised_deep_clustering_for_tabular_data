# %% [markdown]
# ## Conifuration

# %%
#import the lib for contrastive learning framework
# !pip install lightly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lightly in /usr/local/lib/python3.7/dist-packages (1.2.17)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.21.6)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.7/dist-packages (from lightly) (2022.5.18.1)
# Requirement already satisfied: lightly-utils~=0.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (0.0.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.15.0)
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.7/dist-packages (from lightly) (4.64.0)
# Requirement already satisfied: pytorch-lightning>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.6.4)
# Requirement already satisfied: hydra-core>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.2.0)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.23.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.8.2)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (57.4.0)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.24.3)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from lightly) (0.12.0+cu113)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (4.9.3)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (5.7.1)
# Requirement already satisfied: omegaconf~=2.2 in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (2.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (21.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from lightly-utils~=0.0.0->lightly) (7.1.2)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.7/dist-packages (from omegaconf~=2.2->hydra-core>=1.0.0->lightly) (6.0)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2.8.0)
# Requirement already satisfied: torchmetrics>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (0.9.0)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (0.3.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (4.2.0)
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (1.11.0+cu113)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2022.5.0)
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (3.17.3)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->hydra-core>=1.0.0->lightly) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (3.0.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.3.7)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.46.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.0.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.37.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (1.7.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (6.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (1.3.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (0.13.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (21.4.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (2.0.12)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (4.0.2)

# %%
import lightly
from lightly.models.modules.heads import SimSiamPredictionHead
from lightly.models.modules.heads import SimSiamProjectionHead

from lightly.data import LightlyDataset
from lightly.data import ImageCollateFunction
from lightly.models.modules import BarlowTwinsProjectionHead
from lightly.loss import BarlowTwinsLoss

from lightly.data import LightlyDataset
from lightly.data import SimCLRCollateFunction
from lightly.loss import NTXentLoss
from lightly.loss import NegativeCosineSimilarity
from lightly.models.modules import SimCLRProjectionHead
# Out:
# /usr/local/lib/python3.7/dist-packages/lightly/cli/train_cli.py:145: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="config", config_name="config")
# /usr/local/lib/python3.7/dist-packages/lightly/cli/embed_cli.py:97: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path='config', config_name='config')
# /usr/local/lib/python3.7/dist-packages/lightly/cli/upload_cli.py:167: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path='config', config_name='config')
# /usr/local/lib/python3.7/dist-packages/lightly/cli/lightly_cli.py:70: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="config", config_name="config")
# /usr/local/lib/python3.7/dist-packages/lightly/cli/download_cli.py:78: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path='config', config_name='config')
# /usr/local/lib/python3.7/dist-packages/lightly/cli/crop_cli.py:66: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="config", config_name="config")

# %%
import math
import torch
import torch.nn as nn
import torchvision
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from torch.utils.data import Dataset, DataLoader
import torch.optim as torch_optim
import torch.optim.lr_scheduler as lr_scheduler
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
from datetime import datetime

from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from matplotlib import pyplot
import seaborn as sns

from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_mutual_info_score
from sklearn.metrics import silhouette_score
from sklearn import mixture
from sklearn.cluster import DBSCAN
from sklearn.cluster import OPTICS
from sklearn.cluster import AgglomerativeClustering

import tensorboard
from tensorboard import notebook
from torch.utils.tensorboard import SummaryWriter

import matplotlib 
import matplotlib.pyplot as plt
#import plotly.express as px

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons
from sklearn.utils import shuffle

import torchvision.transforms as transforms
import torchvision.datasets as datasets
from sklearn.metrics.pairwise import cosine_similarity

import random
from torch.nn.modules.loss import MSELoss
from sklearn.neighbors import KDTree
#from kmodes.kprototypes import KPrototypes

from scipy.io.arff import loadarff
from sklearn.preprocessing import MinMaxScaler 
from sklearn.datasets import make_classification

# %% [markdown]
# ## Create Synthetic Dataset and Check Clustering Result with the Baseline Method Kmeans

# %%
X, y = make_classification(n_samples=10000, n_features=200, n_redundant=0, n_informative=25, n_clusters_per_class=1, n_classes=3, class_sep=1.5)

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X)
data_X_tsne = np.vstack((X_tsne.T, y)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#check the clustering result with Kmeans
kmeans_ori = KMeans(n_clusters=3).fit(X)
kmeans_labels_ori = kmeans_ori.labels_

normalized_mutual_info_score(kmeans_labels_ori, y)
# Out:
# 0.7234961091073938

# %%
data_X_tsne = np.vstack((X_tsne.T, kmeans_labels_ori)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()

# %% [markdown]
# ## Data Augmentation

# %%
#scale data to prevent gradient vanishing
X_ds = 100*X+250

# %%
X_ds
# Out:
# array([[-398.82086019,  315.84135693,  130.34570121, ...,  242.03114681,
#          378.82745536,  169.29074118],
#        [ 215.82071291,  413.84602743,  184.85955446, ...,  199.95749421,
#          363.59762758,  153.24189938],
#        [ -78.87925489,  410.95216031,  479.43246734, ...,  291.61859016,
#          290.69632849,  326.63551054],
#        ...,
#        [ 363.33404158,  202.10263975,  208.42914835, ...,  382.70218029,
#          235.92695962,  284.14402061],
#        [-117.5793853 ,  121.08727904,  275.68995592, ...,  195.09261657,
#          376.49350483,  420.65797779],
#        [ 335.73783277,  286.82594277,   51.14679901, ...,  240.16455219,
#          304.36134516,   66.11509327]])

# %% [markdown]
# ####MixUp

# %%
def mixup(data):
  view = data.copy()
  for i in range(len(view)):
    random_row_index = random.randint(0, len(view)-1)
    view[i] = view[i]*0.5  + view[random_row_index]*0.5
  return view

# %% [markdown]
# ####MixCut

# %%
def mixcut(data):
  data_copy = data.copy()
  view = data.copy()
  mask_len = 100

  for i in range(len(data_copy)):
    random_row_id = random.randint(0, len(data_copy)-1)
    random_column_id = random.randint(0, data_copy.shape[1]-mask_len)
    view[i,random_column_id:(random_column_id+mask_len)] = data_copy[random_row_id,random_column_id:(random_column_id+mask_len)]
  return view

# %% [markdown]
# #### Masking with mean

# %%
def get_random_indices(data, portion_of_mask):
  return np.random.choice(data.shape[1], size=np.floor(data.shape[1]*portion_of_mask).astype(int), replace=False)

# %%
def masking_with_mean(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = column_mu[j]
              
  return view

# %% [markdown]
# ####Masking with random value in domain range

# %%
def masking_with_random(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)
  column_min = np.minimum(data)
  column_max = np.maximum(data)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = random.randint(column_min[j], column_max[j])
              
  return view

# %% [markdown]
# ####Masking with margin distribution

# %%
def masking_with_margin_distribution(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = np.random.normal(column_mu[j], column_std[j])
              
  return view

# %% [markdown]
# ####Upsampling (SMOTE like)

# %%
#put all data points in kd-tree for fast searching
kdtree = KDTree(X_ds, leaf_size=2)

# %%
#get random point in the k nearest neighbors
def get_idx_random_knn(x,k):
   _, ids = kdtree.query(x.reshape(1, -1), k=k)
   ids = ids.flatten()
   ids = ids[1:-1]
   random_id = np.random.choice(ids, 1)
   return random_id

# %%
#mix up with a random near neighbor 
def mixup_random_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = 0.5*data[i] + 0.5*data[random_neighbor_id]
  return view

# %%
#a random neighbor as augmentation
def random_near_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = data[random_neighbor_id]
  return view

# %% [markdown]
# ##Create Model and Train with Augmented Data

# %%
class MyDataSet(Dataset):
  def __init__(self, view1, view2):
 
    X_view1 = view1.copy()
    X_view2 = view2.copy()
    self.X_view1 = X_view1.copy().astype(np.float32)
    self.X_view2 = X_view2.copy().astype(np.float32)
  
  def __len__(self):
    return len(self.X_view1)
  
  def __getitem__(self, idx):
    return self.X_view1[idx], self.X_view2[idx]

# %%
# define the NN architecture
class convBackbone(nn.Module):
    def __init__(self):
        super(convBackbone, self).__init__()

        #turn on dropout for testing the 'cropping' data augmentation
        #self.dropout = nn.Dropout(p=0.1)
        
        self.fc1 = nn.Linear(200, 156, bias=False)
        self.bn1 = nn.BatchNorm1d(156)

        self.fc2 = nn.Linear(156, 128, bias=False)
        self.bn2 = nn.BatchNorm1d(128)

        self.fc3 = nn.Linear(128, 128, bias=False)
        self.bn3 = nn.BatchNorm1d(128)


    def forward(self, x):

        #turn on dropout for testing the 'cropping' data augmentation
        #x = self.dropout(x)
        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.bn3(self.fc3(x))
                
        return x

# %%
class SimCLR(nn.Module):
    def __init__(self, backbone):
        super().__init__()
        self.backbone = backbone
        self.projection_head = SimCLRProjectionHead(128, 64, 128)

    def forward(self, x):
        x = self.backbone(x).flatten(start_dim=1)
        z = self.projection_head(x)
        return x,z

backbone = convBackbone()
model = SimCLR(backbone)

# %%
criterion = NTXentLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9,weight_decay=1e-4)

#cosine annealing lr
scheduler = lr_scheduler.CosineAnnealingLR(optimizer,T_max=500, eta_min=0)

# %%
view1 = random_near_neighbor(X_ds, 15)
view2 = random_near_neighbor(X_ds, 15)

#turn on the following to test other augmentations

#view1 = mixup_random_neighbor(X_ds, 15)
#view2 = mixup_random_neighbor(X_ds, 15)

#view1 = mixup(X_ds)
#view2 = mixup(X_ds)

#view1 = mixcut(X_ds)
#view2 = mixcut(X_ds)

#view1 = masking_with_mean(X_ds, 0.4)
#view2 = masking_with_mean(X_ds, 0.4)

#view1 = masking_with_random(X_ds, 0.4)
#view2 = masking_with_random(X_ds, 0.4)

#view1 = masking_with_margin_distribution(X_ds, 0.4)
#view2 = masking_with_margin_distribution(X_ds, 0.4)

train_ds = MyDataSet(view1, view2)
train_dl = DataLoader(train_ds, batch_size=256, shuffle=True)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

for epoch in range(500):
    total_loss = 0
    for x0, x1 in train_dl:

        x0 = x0.to(device)
        x1 = x1.to(device)
        _,z0 = model(x0)
        _,z1 = model(x1)

        z0 = (z0 - torch.mean(z0,0)) / torch.std(z0,0)
        z1 = (z1 - torch.mean(z1,0)) / torch.std(z1,0)

        loss = criterion(z0, z1)
        total_loss += loss.detach()
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    avg_loss = total_loss / len(train_dl)
    print(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
# Out:
# epoch: 00, loss: 5.42158
# epoch: 01, loss: 5.11263
# epoch: 02, loss: 5.06463
# epoch: 03, loss: 5.03312
# epoch: 04, loss: 5.01630
# epoch: 05, loss: 5.00017
# epoch: 06, loss: 4.99412
# epoch: 07, loss: 4.98130
# epoch: 08, loss: 4.97623
# epoch: 09, loss: 4.96871
# epoch: 10, loss: 4.94961
# epoch: 11, loss: 4.94920
# epoch: 12, loss: 4.94167
# epoch: 13, loss: 4.93275
# epoch: 14, loss: 4.93383
# epoch: 15, loss: 4.92245
# epoch: 16, loss: 4.91499
# epoch: 17, loss: 4.90755
# epoch: 18, loss: 4.90049
# epoch: 19, loss: 4.89923
# epoch: 20, loss: 4.89454
# epoch: 21, loss: 4.88901
# epoch: 22, loss: 4.87786
# epoch: 23, loss: 4.88359
# epoch: 24, loss: 4.87656
# epoch: 25, loss: 4.86921
# epoch: 26, loss: 4.86749
# epoch: 27, loss: 4.86210
# epoch: 28, loss: 4.85249
# epoch: 29, loss: 4.85321
# epoch: 30, loss: 4.85667
# epoch: 31, loss: 4.84944
# epoch: 32, loss: 4.85093
# epoch: 33, loss: 4.84377
# epoch: 34, loss: 4.83749
# epoch: 35, loss: 4.83365
# epoch: 36, loss: 4.83444
# epoch: 37, loss: 4.83716
# epoch: 38, loss: 4.82490
# epoch: 39, loss: 4.82353
# epoch: 40, loss: 4.82587
# epoch: 41, loss: 4.82535
# epoch: 42, loss: 4.81125
# epoch: 43, loss: 4.81207
# epoch: 44, loss: 4.80275
# epoch: 45, loss: 4.80214
# epoch: 46, loss: 4.79518
# epoch: 47, loss: 4.79815
# epoch: 48, loss: 4.79941
# epoch: 49, loss: 4.79803
# epoch: 50, loss: 4.79681
# epoch: 51, loss: 4.79296
# epoch: 52, loss: 4.79512
# epoch: 53, loss: 4.79654
# epoch: 54, loss: 4.79818
# epoch: 55, loss: 4.79370
# epoch: 56, loss: 4.79301
# epoch: 57, loss: 4.78253
# epoch: 58, loss: 4.77964
# epoch: 59, loss: 4.78439
# epoch: 60, loss: 4.77722
# epoch: 61, loss: 4.77543
# epoch: 62, loss: 4.77724
# epoch: 63, loss: 4.77728
# epoch: 64, loss: 4.77347
# epoch: 65, loss: 4.76938
# epoch: 66, loss: 4.76982
# epoch: 67, loss: 4.77070
# epoch: 68, loss: 4.76706
# epoch: 69, loss: 4.76192
# epoch: 70, loss: 4.75950
# epoch: 71, loss: 4.75946
# epoch: 72, loss: 4.75855
# epoch: 73, loss: 4.75719
# epoch: 74, loss: 4.75181
# epoch: 75, loss: 4.75633
# epoch: 76, loss: 4.75420
# epoch: 77, loss: 4.75392
# epoch: 78, loss: 4.75270
# epoch: 79, loss: 4.75177
# epoch: 80, loss: 4.74510
# epoch: 81, loss: 4.74689
# epoch: 82, loss: 4.74778
# epoch: 83, loss: 4.74863
# epoch: 84, loss: 4.74064
# epoch: 85, loss: 4.74203
# epoch: 86, loss: 4.74585
# epoch: 87, loss: 4.73613
# epoch: 88, loss: 4.73650
# epoch: 89, loss: 4.73841
# epoch: 90, loss: 4.74688
# epoch: 91, loss: 4.75184
# epoch: 92, loss: 4.74567
# epoch: 93, loss: 4.73891
# epoch: 94, loss: 4.73400
# epoch: 95, loss: 4.73210
# epoch: 96, loss: 4.72896
# epoch: 97, loss: 4.73175
# epoch: 98, loss: 4.73617
# epoch: 99, loss: 4.73194
# epoch: 100, loss: 4.72576
# epoch: 101, loss: 4.73153
# epoch: 102, loss: 4.72491
# epoch: 103, loss: 4.72568
# epoch: 104, loss: 4.73060
# epoch: 105, loss: 4.72590
# epoch: 106, loss: 4.72119
# epoch: 107, loss: 4.72369
# epoch: 108, loss: 4.72725
# epoch: 109, loss: 4.72359
# epoch: 110, loss: 4.72557
# epoch: 111, loss: 4.72385
# epoch: 112, loss: 4.71782
# epoch: 113, loss: 4.71459
# epoch: 114, loss: 4.71562
# epoch: 115, loss: 4.72611
# epoch: 116, loss: 4.72104
# epoch: 117, loss: 4.71836
# epoch: 118, loss: 4.71591
# epoch: 119, loss: 4.71763
# epoch: 120, loss: 4.71909
# epoch: 121, loss: 4.71959
# epoch: 122, loss: 4.71597
# epoch: 123, loss: 4.71502
# epoch: 124, loss: 4.71091
# epoch: 125, loss: 4.71442
# epoch: 126, loss: 4.72250
# epoch: 127, loss: 4.72027
# epoch: 128, loss: 4.71538
# epoch: 129, loss: 4.71295
# epoch: 130, loss: 4.70505
# epoch: 131, loss: 4.70283
# epoch: 132, loss: 4.70907
# epoch: 133, loss: 4.70798
# epoch: 134, loss: 4.70719
# epoch: 135, loss: 4.70426
# epoch: 136, loss: 4.70004
# epoch: 137, loss: 4.70428
# epoch: 138, loss: 4.70662
# epoch: 139, loss: 4.70566
# epoch: 140, loss: 4.71060
# epoch: 141, loss: 4.70317
# epoch: 142, loss: 4.70536
# epoch: 143, loss: 4.69979
# epoch: 144, loss: 4.70088
# epoch: 145, loss: 4.70661
# epoch: 146, loss: 4.71199
# epoch: 147, loss: 4.70567
# epoch: 148, loss: 4.70448
# epoch: 149, loss: 4.70318
# epoch: 150, loss: 4.70180
# epoch: 151, loss: 4.69642
# epoch: 152, loss: 4.69508
# epoch: 153, loss: 4.69830
# epoch: 154, loss: 4.70006
# epoch: 155, loss: 4.70674
# epoch: 156, loss: 4.70463
# epoch: 157, loss: 4.69788
# epoch: 158, loss: 4.69373
# epoch: 159, loss: 4.70206
# epoch: 160, loss: 4.69526
# epoch: 161, loss: 4.69028
# epoch: 162, loss: 4.69312
# epoch: 163, loss: 4.69745
# epoch: 164, loss: 4.69416
# epoch: 165, loss: 4.70144
# epoch: 166, loss: 4.70883
# epoch: 167, loss: 4.69989
# epoch: 168, loss: 4.69413
# epoch: 169, loss: 4.69692
# epoch: 170, loss: 4.69227
# epoch: 171, loss: 4.69495
# epoch: 172, loss: 4.69403
# epoch: 173, loss: 4.69342
# epoch: 174, loss: 4.68962
# epoch: 175, loss: 4.68151
# epoch: 176, loss: 4.68613
# epoch: 177, loss: 4.69101
# epoch: 178, loss: 4.69215
# epoch: 179, loss: 4.68807
# epoch: 180, loss: 4.68363
# epoch: 181, loss: 4.69006
# epoch: 182, loss: 4.68560
# epoch: 183, loss: 4.68028
# epoch: 184, loss: 4.68221
# epoch: 185, loss: 4.68309
# epoch: 186, loss: 4.68430
# epoch: 187, loss: 4.68561
# epoch: 188, loss: 4.68159
# epoch: 189, loss: 4.68331
# epoch: 190, loss: 4.67818
# epoch: 191, loss: 4.68768
# epoch: 192, loss: 4.68167
# epoch: 193, loss: 4.68312
# epoch: 194, loss: 4.69081
# epoch: 195, loss: 4.68170
# epoch: 196, loss: 4.68596
# epoch: 197, loss: 4.68880
# epoch: 198, loss: 4.68659
# epoch: 199, loss: 4.68655
# epoch: 200, loss: 4.68511
# epoch: 201, loss: 4.67850
# epoch: 202, loss: 4.67921
# epoch: 203, loss: 4.67548
# epoch: 204, loss: 4.67468
# epoch: 205, loss: 4.67127
# epoch: 206, loss: 4.67567
# epoch: 207, loss: 4.68191
# epoch: 208, loss: 4.68156
# epoch: 209, loss: 4.67609
# epoch: 210, loss: 4.67602
# epoch: 211, loss: 4.67320
# epoch: 212, loss: 4.67073
# epoch: 213, loss: 4.67364
# epoch: 214, loss: 4.67869
# epoch: 215, loss: 4.67618
# epoch: 216, loss: 4.67270
# epoch: 217, loss: 4.67625
# epoch: 218, loss: 4.67574
# epoch: 219, loss: 4.67246
# epoch: 220, loss: 4.67398
# epoch: 221, loss: 4.66970
# epoch: 222, loss: 4.67858
# epoch: 223, loss: 4.67453
# epoch: 224, loss: 4.67191
# epoch: 225, loss: 4.67572
# epoch: 226, loss: 4.68227
# epoch: 227, loss: 4.67622
# epoch: 228, loss: 4.67108
# epoch: 229, loss: 4.67506
# epoch: 230, loss: 4.67569
# epoch: 231, loss: 4.67443
# epoch: 232, loss: 4.67179
# epoch: 233, loss: 4.67347
# epoch: 234, loss: 4.67844
# epoch: 235, loss: 4.67822
# epoch: 236, loss: 4.66838
# epoch: 237, loss: 4.68211
# epoch: 238, loss: 4.67849
# epoch: 239, loss: 4.67563
# epoch: 240, loss: 4.66789
# epoch: 241, loss: 4.66655
# epoch: 242, loss: 4.66653
# epoch: 243, loss: 4.67545
# epoch: 244, loss: 4.67214
# epoch: 245, loss: 4.67094
# epoch: 246, loss: 4.67472
# epoch: 247, loss: 4.66810
# epoch: 248, loss: 4.66777
# epoch: 249, loss: 4.66948
# epoch: 250, loss: 4.66868
# epoch: 251, loss: 4.66597
# epoch: 252, loss: 4.66423
# epoch: 253, loss: 4.67010
# epoch: 254, loss: 4.66436
# epoch: 255, loss: 4.66016
# epoch: 256, loss: 4.66313
# epoch: 257, loss: 4.66468
# epoch: 258, loss: 4.66615
# epoch: 259, loss: 4.66438
# epoch: 260, loss: 4.66209
# epoch: 261, loss: 4.66260
# epoch: 262, loss: 4.66518
# epoch: 263, loss: 4.66394
# epoch: 264, loss: 4.66440
# epoch: 265, loss: 4.66781
# epoch: 266, loss: 4.66372
# epoch: 267, loss: 4.66539
# epoch: 268, loss: 4.66395
# epoch: 269, loss: 4.66500
# epoch: 270, loss: 4.66069
# epoch: 271, loss: 4.66683
# epoch: 272, loss: 4.66453
# epoch: 273, loss: 4.67287
# epoch: 274, loss: 4.66390
# epoch: 275, loss: 4.66147
# epoch: 276, loss: 4.66326
# epoch: 277, loss: 4.66313
# epoch: 278, loss: 4.66027
# epoch: 279, loss: 4.66638
# epoch: 280, loss: 4.66142
# epoch: 281, loss: 4.66310
# epoch: 282, loss: 4.66073
# epoch: 283, loss: 4.66674
# epoch: 284, loss: 4.65566
# epoch: 285, loss: 4.65596
# epoch: 286, loss: 4.66223
# epoch: 287, loss: 4.65687
# epoch: 288, loss: 4.65538
# epoch: 289, loss: 4.65601
# epoch: 290, loss: 4.66329
# epoch: 291, loss: 4.65692
# epoch: 292, loss: 4.65843
# epoch: 293, loss: 4.66686
# epoch: 294, loss: 4.66244
# epoch: 295, loss: 4.66235
# epoch: 296, loss: 4.66015
# epoch: 297, loss: 4.65729
# epoch: 298, loss: 4.66101
# epoch: 299, loss: 4.66804
# epoch: 300, loss: 4.66218
# epoch: 301, loss: 4.66301
# epoch: 302, loss: 4.65773
# epoch: 303, loss: 4.65704
# epoch: 304, loss: 4.65547
# epoch: 305, loss: 4.65966
# epoch: 306, loss: 4.65627
# epoch: 307, loss: 4.65187
# epoch: 308, loss: 4.65373
# epoch: 309, loss: 4.65582
# epoch: 310, loss: 4.65950
# epoch: 311, loss: 4.65892
# epoch: 312, loss: 4.67354
# epoch: 313, loss: 4.66434
# epoch: 314, loss: 4.65955
# epoch: 315, loss: 4.66095
# epoch: 316, loss: 4.65442
# epoch: 317, loss: 4.65508
# epoch: 318, loss: 4.65348
# epoch: 319, loss: 4.65915
# epoch: 320, loss: 4.66060
# epoch: 321, loss: 4.66025
# epoch: 322, loss: 4.65991
# epoch: 323, loss: 4.65711
# epoch: 324, loss: 4.64858
# epoch: 325, loss: 4.65107
# epoch: 326, loss: 4.65629
# epoch: 327, loss: 4.64983
# epoch: 328, loss: 4.64854
# epoch: 329, loss: 4.65854
# epoch: 330, loss: 4.67038
# epoch: 331, loss: 4.65846
# epoch: 332, loss: 4.66019
# epoch: 333, loss: 4.66342
# epoch: 334, loss: 4.66150
# epoch: 335, loss: 4.65845
# epoch: 336, loss: 4.65527
# epoch: 337, loss: 4.66289
# epoch: 338, loss: 4.66548
# epoch: 339, loss: 4.66447
# epoch: 340, loss: 4.65554
# epoch: 341, loss: 4.65347
# epoch: 342, loss: 4.65122
# epoch: 343, loss: 4.65129
# epoch: 344, loss: 4.64811
# epoch: 345, loss: 4.65145
# epoch: 346, loss: 4.65073
# epoch: 347, loss: 4.65151
# epoch: 348, loss: 4.64845
# epoch: 349, loss: 4.65629
# epoch: 350, loss: 4.65782
# epoch: 351, loss: 4.65390
# epoch: 352, loss: 4.65612
# epoch: 353, loss: 4.65072
# epoch: 354, loss: 4.65029
# epoch: 355, loss: 4.64905
# epoch: 356, loss: 4.65292
# epoch: 357, loss: 4.65087
# epoch: 358, loss: 4.65581
# epoch: 359, loss: 4.66279
# epoch: 360, loss: 4.65789
# epoch: 361, loss: 4.65264
# epoch: 362, loss: 4.65312
# epoch: 363, loss: 4.65690
# epoch: 364, loss: 4.65972
# epoch: 365, loss: 4.65802
# epoch: 366, loss: 4.65035
# epoch: 367, loss: 4.65237
# epoch: 368, loss: 4.65362
# epoch: 369, loss: 4.64809
# epoch: 370, loss: 4.64506
# epoch: 371, loss: 4.64457
# epoch: 372, loss: 4.64667
# epoch: 373, loss: 4.65030
# epoch: 374, loss: 4.65094
# epoch: 375, loss: 4.65634
# epoch: 376, loss: 4.65924
# epoch: 377, loss: 4.65913
# epoch: 378, loss: 4.65567
# epoch: 379, loss: 4.65613
# epoch: 380, loss: 4.65785
# epoch: 381, loss: 4.65235
# epoch: 382, loss: 4.64911
# epoch: 383, loss: 4.64495
# epoch: 384, loss: 4.64902
# epoch: 385, loss: 4.64803
# epoch: 386, loss: 4.64139
# epoch: 387, loss: 4.64823
# epoch: 388, loss: 4.65231
# epoch: 389, loss: 4.65456
# epoch: 390, loss: 4.65771
# epoch: 391, loss: 4.65415
# epoch: 392, loss: 4.65077
# epoch: 393, loss: 4.65463
# epoch: 394, loss: 4.64959
# epoch: 395, loss: 4.65246
# epoch: 396, loss: 4.64616
# epoch: 397, loss: 4.64876
# epoch: 398, loss: 4.64454
# epoch: 399, loss: 4.64354
# epoch: 400, loss: 4.63929
# epoch: 401, loss: 4.64379
# epoch: 402, loss: 4.64619
# epoch: 403, loss: 4.64576
# epoch: 404, loss: 4.64725
# epoch: 405, loss: 4.64663
# epoch: 406, loss: 4.64552
# epoch: 407, loss: 4.64735
# epoch: 408, loss: 4.65097
# epoch: 409, loss: 4.65077
# epoch: 410, loss: 4.65283
# epoch: 411, loss: 4.65329
# epoch: 412, loss: 4.64744
# epoch: 413, loss: 4.64670
# epoch: 414, loss: 4.64462
# epoch: 415, loss: 4.64572
# epoch: 416, loss: 4.64507
# epoch: 417, loss: 4.64032
# epoch: 418, loss: 4.64280
# epoch: 419, loss: 4.64949
# epoch: 420, loss: 4.65220
# epoch: 421, loss: 4.64819
# epoch: 422, loss: 4.64291
# epoch: 423, loss: 4.64175
# epoch: 424, loss: 4.64376
# epoch: 425, loss: 4.64743
# epoch: 426, loss: 4.64329
# epoch: 427, loss: 4.64519
# epoch: 428, loss: 4.64443
# epoch: 429, loss: 4.65215
# epoch: 430, loss: 4.64520
# epoch: 431, loss: 4.64691
# epoch: 432, loss: 4.64552
# epoch: 433, loss: 4.64404
# epoch: 434, loss: 4.64143
# epoch: 435, loss: 4.64470
# epoch: 436, loss: 4.64540
# epoch: 437, loss: 4.64439
# epoch: 438, loss: 4.64688
# epoch: 439, loss: 4.64405
# epoch: 440, loss: 4.64269
# epoch: 441, loss: 4.63563
# epoch: 442, loss: 4.64621
# epoch: 443, loss: 4.64836
# epoch: 444, loss: 4.64192
# epoch: 445, loss: 4.63953
# epoch: 446, loss: 4.64078
# epoch: 447, loss: 4.63936
# epoch: 448, loss: 4.63756
# epoch: 449, loss: 4.64136
# epoch: 450, loss: 4.63631
# epoch: 451, loss: 4.64528
# epoch: 452, loss: 4.64413
# epoch: 453, loss: 4.64986
# epoch: 454, loss: 4.63879
# epoch: 455, loss: 4.63724
# epoch: 456, loss: 4.63973
# epoch: 457, loss: 4.64324
# epoch: 458, loss: 4.64215
# epoch: 459, loss: 4.63744
# epoch: 460, loss: 4.64264
# epoch: 461, loss: 4.64427
# epoch: 462, loss: 4.64384
# epoch: 463, loss: 4.64040
# epoch: 464, loss: 4.64106
# epoch: 465, loss: 4.63750
# epoch: 466, loss: 4.64013
# epoch: 467, loss: 4.63664
# epoch: 468, loss: 4.63903
# epoch: 469, loss: 4.63887
# epoch: 470, loss: 4.64007
# epoch: 471, loss: 4.64118
# epoch: 472, loss: 4.64209
# epoch: 473, loss: 4.64088
# epoch: 474, loss: 4.64095
# epoch: 475, loss: 4.64712
# epoch: 476, loss: 4.65462
# epoch: 477, loss: 4.64803
# epoch: 478, loss: 4.64739
# epoch: 479, loss: 4.65332
# epoch: 480, loss: 4.64147
# epoch: 481, loss: 4.64420
# epoch: 482, loss: 4.64325
# epoch: 483, loss: 4.64785
# epoch: 484, loss: 4.64263
# epoch: 485, loss: 4.64287
# epoch: 486, loss: 4.64415
# epoch: 487, loss: 4.64182
# epoch: 488, loss: 4.64669
# epoch: 489, loss: 4.63920
# epoch: 490, loss: 4.64062
# epoch: 491, loss: 4.64010
# epoch: 492, loss: 4.63824
# epoch: 493, loss: 4.64724
# epoch: 494, loss: 4.64443
# epoch: 495, loss: 4.63912
# epoch: 496, loss: 4.63945
# epoch: 497, loss: 4.64164
# epoch: 498, loss: 4.64420
# epoch: 499, loss: 4.63801

# %% [markdown]
# ##Check the Training Result

# %%
ds_cl= MyDataSet(X_ds, X_ds)
dl_cl = DataLoader(ds_cl, batch_size=256)

# %%
embeddings = []

# disable gradients for faster calculations
model.eval()
with torch.no_grad():
    for dl_cl1, dl_cl2 in dl_cl:

        #dl_cl1 = (dl_cl1 - torch.mean(dl_cl1,0))/torch.std(dl_cl1,0)

        # move images to the gpu
        dl_cl1 = dl_cl1.to(device)

        # embed the images with the pre-trained backbone
        #y = model.backbone(images).flatten(start_dim=1)
        x,_ = model(dl_cl1)
        # store the embeddings in lists
        embeddings.append(x)

# concatenate the embeddings, targets and convert to numpy
embeddings = torch.cat(embeddings, dim=0)
embeddings = embeddings.cpu().numpy()

# %%
test = (embeddings - embeddings.mean(axis=0)) / (embeddings.std(axis=0))

# %%
#KMeans in latent space
kmeans_backbone = KMeans(n_clusters=3).fit(test)
kmeans_labels_backbone = kmeans_backbone.labels_

# %%
normalized_mutual_info_score(kmeans_labels_backbone, y)
# Out:
# 0.8216940591071787

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(test)
data_X_tsne = np.vstack((X_tsne.T, y)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#NMI increases from 0.72 to 0.82
