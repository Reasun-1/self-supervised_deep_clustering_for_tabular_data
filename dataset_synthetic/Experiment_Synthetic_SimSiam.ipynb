# %% [markdown]
# ## Conifuration

# %%
#import the lib for contrastive learning framework
# !pip install lightly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lightly
#   Downloading lightly-1.2.19-py3-none-any.whl (449 kB)
#      |████████████████████████████████| 449 kB 5.2 MB/s
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.21.6)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.23.0)
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.7/dist-packages (from lightly) (4.64.0)
# Collecting pytorch-lightning>=1.0.4
#   Downloading pytorch_lightning-1.6.4-py3-none-any.whl (585 kB)
#      |████████████████████████████████| 585 kB 58.5 MB/s
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (57.4.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.15.0)
# Collecting hydra-core>=1.0.0
#   Downloading hydra_core-1.2.0-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 49.2 MB/s
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from lightly) (0.12.0+cu113)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.8.2)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.24.3)
# Collecting lightly-utils~=0.0.0
#   Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.7/dist-packages (from lightly) (2022.6.15)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      |████████████████████████████████| 117 kB 49.7 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (21.3)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (5.7.1)
# Collecting omegaconf~=2.2
#   Downloading omegaconf-2.2.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 6.9 MB/s
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from lightly-utils~=0.0.0->lightly) (7.1.2)
# Collecting PyYAML>=5.1.0
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 48.3 MB/s
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (4.1.1)
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.9.1-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 67.3 MB/s
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 58.0 MB/s
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (3.17.3)
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (1.11.0+cu113)
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2.8.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 37.3 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->hydra-core>=1.0.0->lightly) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (3.0.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.3.7)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.6.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.46.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.35.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.37.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.2.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.2 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 51.2 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (2.0.12)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 57.2 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (21.4.0)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=b16434e7979d7a70b77a9c3c32c80fd9cb6cd11f22fed91dae7640e6abd5bdef
#   Stored in directory: /root/.cache/pip/wheels/8b/8d/53/2af8772d9aec614e3fc65e53d4a993ad73c61daa8bbd85a873
# Successfully built antlr4-python3-runtime
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, PyYAML, fsspec, antlr4-python3-runtime, aiohttp, torchmetrics, pyDeprecate, omegaconf, pytorch-lightning, lightly-utils, hydra-core, lightly
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-6.0 aiohttp-3.8.1 aiosignal-1.2.0 antlr4-python3-runtime-4.9.3 async-timeout-4.0.2 asynctest-0.13.0 frozenlist-1.3.0 fsspec-2022.5.0 hydra-core-1.2.0 lightly-1.2.19 lightly-utils-0.0.2 multidict-6.0.2 omegaconf-2.2.2 pyDeprecate-0.3.2 pytorch-lightning-1.6.4 torchmetrics-0.9.1 yarl-1.7.2

# %%
import lightly
from lightly.models.modules.heads import SimSiamPredictionHead
from lightly.models.modules.heads import SimSiamProjectionHead

from lightly.data import LightlyDataset
from lightly.data import ImageCollateFunction
from lightly.models.modules import BarlowTwinsProjectionHead
from lightly.loss import BarlowTwinsLoss

from lightly.data import LightlyDataset
from lightly.data import SimCLRCollateFunction
from lightly.loss import NTXentLoss
from lightly.loss import NegativeCosineSimilarity
from lightly.models.modules import SimCLRProjectionHead

# %%
import math
import torch
import torch.nn as nn
import torchvision
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from torch.utils.data import Dataset, DataLoader
import torch.optim as torch_optim
import torch.optim.lr_scheduler as lr_scheduler
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
from datetime import datetime

from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from matplotlib import pyplot
import seaborn as sns

from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_mutual_info_score
from sklearn.metrics import silhouette_score
from sklearn import mixture
from sklearn.cluster import DBSCAN
from sklearn.cluster import OPTICS
from sklearn.cluster import AgglomerativeClustering

import tensorboard
from tensorboard import notebook
from torch.utils.tensorboard import SummaryWriter

import matplotlib 
import matplotlib.pyplot as plt
#import plotly.express as px

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons
from sklearn.utils import shuffle

import torchvision.transforms as transforms
import torchvision.datasets as datasets
from sklearn.metrics.pairwise import cosine_similarity

import random
from torch.nn.modules.loss import MSELoss
from sklearn.neighbors import KDTree
#from kmodes.kprototypes import KPrototypes

from scipy.io.arff import loadarff
from sklearn.preprocessing import MinMaxScaler 
from sklearn.datasets import make_classification

# %% [markdown]
# ## Create Synthetic Dataset and Check Clustering Result with the Baseline Method Kmeans

# %%
X, y = make_classification(n_samples=10000, n_features=200, n_redundant=0, n_informative=25, n_clusters_per_class=1, n_classes=3, class_sep=1.5)

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X)
data_X_tsne = np.vstack((X_tsne.T, y)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#check the clustering result with Kmeans
kmeans_ori = KMeans(n_clusters=3).fit(X)
kmeans_labels_ori = kmeans_ori.labels_

normalized_mutual_info_score(kmeans_labels_ori, y)
# Out:
# 0.696672260615435

# %%
data_X_tsne = np.vstack((X_tsne.T, kmeans_labels_ori)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()

# %% [markdown]
# ## Data Augmentation

# %%
#scale data to prevent gradient vanishing
X_ds = 100*X+250

# %%
X_ds
# Out:
# array([[198.27495067, 246.10323788, 543.73371779, ..., 432.60277446,
#         257.87132242, 170.9050181 ],
#        [168.21707052, 266.02398279, 301.19363793, ..., 243.39655303,
#         298.9933054 , 226.33827994],
#        [217.14194081, 194.11994533, 172.12207166, ..., 115.08551458,
#         127.46629991, 123.04704522],
#        ...,
#        [192.96083618, 409.43865908, 196.93263379, ..., 330.29121429,
#         311.794008  , 100.32034724],
#        [239.23421654, 257.19425887, 240.94628533, ..., 106.25159253,
#         182.52686382, 342.63112198],
#        [191.57860999,  78.42543034, 167.82649434, ..., 266.3250645 ,
#         422.84914174, 141.61303202]])

# %% [markdown]
# ####MixUp

# %%
def mixup(data):
  view = data.copy()
  for i in range(len(view)):
    random_row_index = random.randint(0, len(view)-1)
    view[i] = view[i]*0.5  + view[random_row_index]*0.5
  return view

# %% [markdown]
# ####MixCut

# %%
def mixcut(data):
  data_copy = data.copy()
  view = data.copy()
  mask_len = 100

  for i in range(len(data_copy)):
    random_row_id = random.randint(0, len(data_copy)-1)
    random_column_id = random.randint(0, data_copy.shape[1]-mask_len)
    view[i,random_column_id:(random_column_id+mask_len)] = data_copy[random_row_id,random_column_id:(random_column_id+mask_len)]
  return view

# %% [markdown]
# #### Masking with mean

# %%
def get_random_indices(data, portion_of_mask):
  return np.random.choice(data.shape[1], size=np.floor(data.shape[1]*portion_of_mask).astype(int), replace=False)

# %%
def masking_with_mean(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = column_mu[j]
              
  return view

# %% [markdown]
# ####Masking with random value in domain range

# %%
def masking_with_random(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)
  column_min = np.minimum(data)
  column_max = np.maximum(data)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = random.randint(column_min[j], column_max[j])
              
  return view

# %% [markdown]
# ####Masking with margin distribution

# %%
def masking_with_margin_distribution(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = np.random.normal(column_mu[j], column_std[j])
              
  return view

# %% [markdown]
# ####Upsampling (SMOTE like)

# %%
#put all data points in kd-tree for fast searching
kdtree = KDTree(X_ds, leaf_size=2)

# %%
#get random point in the k nearest neighbors
def get_idx_random_knn(x,k):
   _, ids = kdtree.query(x.reshape(1, -1), k=k)
   ids = ids.flatten()
   ids = ids[1:-1]
   random_id = np.random.choice(ids, 1)
   return random_id

# %%
#mix up with a random near neighbor 
def mixup_random_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = 0.5*data[i] + 0.5*data[random_neighbor_id]
  return view

# %%
#a random neighbor as augmentation
def random_near_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = data[random_neighbor_id]
  return view

# %% [markdown]
# ##Create Model and Train with Augmented Data

# %%
class MyDataSet(Dataset):
  def __init__(self, view1, view2):
 
    X_view1 = view1.copy()
    X_view2 = view2.copy()
    self.X_view1 = X_view1.copy().astype(np.float32)
    self.X_view2 = X_view2.copy().astype(np.float32)
  
  def __len__(self):
    return len(self.X_view1)
  
  def __getitem__(self, idx):
    return self.X_view1[idx], self.X_view2[idx]

# %%
# define the NN architecture
class convBackbone(nn.Module):
    def __init__(self):
        super(convBackbone, self).__init__()

        #turn on dropout for testing the 'cropping' data augmentation
        #self.dropout = nn.Dropout(p=0.1)
        
        self.fc1 = nn.Linear(200, 156, bias=False)
        self.bn1 = nn.BatchNorm1d(156)

        self.fc2 = nn.Linear(156, 128, bias=False)
        self.bn2 = nn.BatchNorm1d(128)

        self.fc3 = nn.Linear(128, 128, bias=False)
        self.bn3 = nn.BatchNorm1d(128)


    def forward(self, x):

        #turn on dropout for testing the 'cropping' data augmentation
        #x = self.dropout(x)
        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.bn3(self.fc3(x))
                
        return x

# %%
class SimSiam(nn.Module):
    def __init__(self, backbone):
        super().__init__()
        self.backbone = backbone
        self.projection_head = SimSiamProjectionHead(128, 128, 128)
        self.prediction_head = SimSiamPredictionHead(128, 64, 128)

    def forward(self, x):
        f = self.backbone(x)
        z = f.flatten(start_dim=1)
        z = self.projection_head(z)
        p = self.prediction_head(z)
        z = z.detach()
        return f, z, p

backbone = convBackbone()
model = SimSiam(backbone)

# %%
criterion = NegativeCosineSimilarity()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

#cosine annealing lr
scheduler = lr_scheduler.CosineAnnealingLR(optimizer,T_max=500, eta_min=0)

# %%
view1 = random_near_neighbor(X_ds, 15)
view2 = random_near_neighbor(X_ds, 15)

#turn on the following to test other augmentations

#view1 = mixup_random_neighbor(X_ds, 15)
#view2 = mixup_random_neighbor(X_ds, 15)

#view1 = mixup(X_ds)
#view2 = mixup(X_ds)

#view1 = mixcut(X_ds)
#view2 = mixcut(X_ds)

#view1 = masking_with_mean(X_ds, 0.4)
#view2 = masking_with_mean(X_ds, 0.4)

#view1 = masking_with_random(X_ds, 0.4)
#view2 = masking_with_random(X_ds, 0.4)

#view1 = masking_with_margin_distribution(X_ds, 0.4)
#view2 = masking_with_margin_distribution(X_ds, 0.4)

train_ds = MyDataSet(view1, view2)
train_dl = DataLoader(train_ds, batch_size=256, shuffle=True)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

for epoch in range(500):
    total_loss = 0
    for x0,x1 in train_dl:
        x0 = x0.to(device)
        x1 = x1.to(device)
        _, z0, p0 = model(x0)
        _, z1, p1 = model(x1)

        loss = 0.5 * (criterion(z0, p1) + criterion(z1, p0))
        total_loss += loss.detach()
        loss.backward()

        optimizer.step()
        optimizer.zero_grad()
        scheduler.step()

    avg_loss = total_loss / len(train_dl)
    print(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
# Out:
# epoch: 00, loss: -0.00732
# epoch: 01, loss: -0.01289
# epoch: 02, loss: -0.01820
# epoch: 03, loss: -0.02358
# epoch: 04, loss: -0.02922
# epoch: 05, loss: -0.03434
# epoch: 06, loss: -0.03855
# epoch: 07, loss: -0.04130
# epoch: 08, loss: -0.04361
# epoch: 09, loss: -0.04630
# epoch: 10, loss: -0.04642
# epoch: 11, loss: -0.04829
# epoch: 12, loss: -0.04762
# epoch: 13, loss: -0.04776
# epoch: 14, loss: -0.04861
# epoch: 15, loss: -0.04863
# epoch: 16, loss: -0.04951
# epoch: 17, loss: -0.05269
# epoch: 18, loss: -0.05739
# epoch: 19, loss: -0.06331
# epoch: 20, loss: -0.07077
# epoch: 21, loss: -0.08102
# epoch: 22, loss: -0.09363
# epoch: 23, loss: -0.10772
# epoch: 24, loss: -0.12632
# epoch: 25, loss: -0.14572
# epoch: 26, loss: -0.16771
# epoch: 27, loss: -0.19085
# epoch: 28, loss: -0.21333
# epoch: 29, loss: -0.23641
# epoch: 30, loss: -0.25291
# epoch: 31, loss: -0.27278
# epoch: 32, loss: -0.28486
# epoch: 33, loss: -0.29315
# epoch: 34, loss: -0.29995
# epoch: 35, loss: -0.30464
# epoch: 36, loss: -0.30565
# epoch: 37, loss: -0.30496
# epoch: 38, loss: -0.30495
# epoch: 39, loss: -0.30481
# epoch: 40, loss: -0.30971
# epoch: 41, loss: -0.31618
# epoch: 42, loss: -0.32527
# epoch: 43, loss: -0.34012
# epoch: 44, loss: -0.35357
# epoch: 45, loss: -0.37942
# epoch: 46, loss: -0.40315
# epoch: 47, loss: -0.43278
# epoch: 48, loss: -0.46124
# epoch: 49, loss: -0.49463
# epoch: 50, loss: -0.52234
# epoch: 51, loss: -0.55374
# epoch: 52, loss: -0.57656
# epoch: 53, loss: -0.59646
# epoch: 54, loss: -0.60820
# epoch: 55, loss: -0.62313
# epoch: 56, loss: -0.63381
# epoch: 57, loss: -0.63818
# epoch: 58, loss: -0.64415
# epoch: 59, loss: -0.64876
# epoch: 60, loss: -0.65087
# epoch: 61, loss: -0.65157
# epoch: 62, loss: -0.65209
# epoch: 63, loss: -0.65033
# epoch: 64, loss: -0.65106
# epoch: 65, loss: -0.65155
# epoch: 66, loss: -0.65716
# epoch: 67, loss: -0.65909
# epoch: 68, loss: -0.66738
# epoch: 69, loss: -0.67085
# epoch: 70, loss: -0.67976
# epoch: 71, loss: -0.68777
# epoch: 72, loss: -0.69802
# epoch: 73, loss: -0.70604
# epoch: 74, loss: -0.71635
# epoch: 75, loss: -0.71996
# epoch: 76, loss: -0.73095
# epoch: 77, loss: -0.73530
# epoch: 78, loss: -0.73999
# epoch: 79, loss: -0.74304
# epoch: 80, loss: -0.74836
# epoch: 81, loss: -0.75151
# epoch: 82, loss: -0.75196
# epoch: 83, loss: -0.75167
# epoch: 84, loss: -0.75006
# epoch: 85, loss: -0.75297
# epoch: 86, loss: -0.74991
# epoch: 87, loss: -0.75528
# epoch: 88, loss: -0.75584
# epoch: 89, loss: -0.75543
# epoch: 90, loss: -0.75407
# epoch: 91, loss: -0.75059
# epoch: 92, loss: -0.75747
# epoch: 93, loss: -0.75421
# epoch: 94, loss: -0.75738
# epoch: 95, loss: -0.76100
# epoch: 96, loss: -0.76353
# epoch: 97, loss: -0.76726
# epoch: 98, loss: -0.76987
# epoch: 99, loss: -0.77088
# epoch: 100, loss: -0.77633
# epoch: 101, loss: -0.77527
# epoch: 102, loss: -0.77926
# epoch: 103, loss: -0.78181
# epoch: 104, loss: -0.78156
# epoch: 105, loss: -0.78125
# epoch: 106, loss: -0.78644
# epoch: 107, loss: -0.78579
# epoch: 108, loss: -0.78786
# epoch: 109, loss: -0.78538
# epoch: 110, loss: -0.78608
# epoch: 111, loss: -0.78743
# epoch: 112, loss: -0.78782
# epoch: 113, loss: -0.78941
# epoch: 114, loss: -0.78778
# epoch: 115, loss: -0.78648
# epoch: 116, loss: -0.78248
# epoch: 117, loss: -0.78824
# epoch: 118, loss: -0.79074
# epoch: 119, loss: -0.78799
# epoch: 120, loss: -0.78817
# epoch: 121, loss: -0.79160
# epoch: 122, loss: -0.79417
# epoch: 123, loss: -0.79076
# epoch: 124, loss: -0.79420
# epoch: 125, loss: -0.79320
# epoch: 126, loss: -0.79933
# epoch: 127, loss: -0.79647
# epoch: 128, loss: -0.79994
# epoch: 129, loss: -0.79835
# epoch: 130, loss: -0.79786
# epoch: 131, loss: -0.80234
# epoch: 132, loss: -0.79553
# epoch: 133, loss: -0.79990
# epoch: 134, loss: -0.80102
# epoch: 135, loss: -0.80485
# epoch: 136, loss: -0.80182
# epoch: 137, loss: -0.80343
# epoch: 138, loss: -0.80296
# epoch: 139, loss: -0.80113
# epoch: 140, loss: -0.80388
# epoch: 141, loss: -0.80109
# epoch: 142, loss: -0.79982
# epoch: 143, loss: -0.80563
# epoch: 144, loss: -0.80546
# epoch: 145, loss: -0.80587
# epoch: 146, loss: -0.80485
# epoch: 147, loss: -0.80449
# epoch: 148, loss: -0.80450
# epoch: 149, loss: -0.80652
# epoch: 150, loss: -0.80587
# epoch: 151, loss: -0.80918
# epoch: 152, loss: -0.80908
# epoch: 153, loss: -0.80531
# epoch: 154, loss: -0.81010
# epoch: 155, loss: -0.81142
# epoch: 156, loss: -0.81009
# epoch: 157, loss: -0.81091
# epoch: 158, loss: -0.80980
# epoch: 159, loss: -0.80848
# epoch: 160, loss: -0.80806
# epoch: 161, loss: -0.81209
# epoch: 162, loss: -0.81242
# epoch: 163, loss: -0.80757
# epoch: 164, loss: -0.81142
# epoch: 165, loss: -0.80830
# epoch: 166, loss: -0.81271
# epoch: 167, loss: -0.81220
# epoch: 168, loss: -0.81066
# epoch: 169, loss: -0.80795
# epoch: 170, loss: -0.81383
# epoch: 171, loss: -0.81418
# epoch: 172, loss: -0.81015
# epoch: 173, loss: -0.81552
# epoch: 174, loss: -0.81427
# epoch: 175, loss: -0.81670
# epoch: 176, loss: -0.81453
# epoch: 177, loss: -0.81336
# epoch: 178, loss: -0.81713
# epoch: 179, loss: -0.81173
# epoch: 180, loss: -0.81318
# epoch: 181, loss: -0.81447
# epoch: 182, loss: -0.81888
# epoch: 183, loss: -0.81683
# epoch: 184, loss: -0.81616
# epoch: 185, loss: -0.81646
# epoch: 186, loss: -0.81707
# epoch: 187, loss: -0.81722
# epoch: 188, loss: -0.81846
# epoch: 189, loss: -0.81263
# epoch: 190, loss: -0.81611
# epoch: 191, loss: -0.81751
# epoch: 192, loss: -0.81679
# epoch: 193, loss: -0.81687
# epoch: 194, loss: -0.81751
# epoch: 195, loss: -0.81975
# epoch: 196, loss: -0.81830
# epoch: 197, loss: -0.81882
# epoch: 198, loss: -0.81585
# epoch: 199, loss: -0.81503
# epoch: 200, loss: -0.81602
# epoch: 201, loss: -0.82165
# epoch: 202, loss: -0.82112
# epoch: 203, loss: -0.81548
# epoch: 204, loss: -0.81842
# epoch: 205, loss: -0.82039
# epoch: 206, loss: -0.82155
# epoch: 207, loss: -0.81597
# epoch: 208, loss: -0.82022
# epoch: 209, loss: -0.81833
# epoch: 210, loss: -0.82112
# epoch: 211, loss: -0.81892
# epoch: 212, loss: -0.82142
# epoch: 213, loss: -0.82185
# epoch: 214, loss: -0.82270
# epoch: 215, loss: -0.82075
# epoch: 216, loss: -0.81601
# epoch: 217, loss: -0.82235
# epoch: 218, loss: -0.82125
# epoch: 219, loss: -0.82284
# epoch: 220, loss: -0.82172
# epoch: 221, loss: -0.81864
# epoch: 222, loss: -0.82097
# epoch: 223, loss: -0.82327
# epoch: 224, loss: -0.82339
# epoch: 225, loss: -0.82119
# epoch: 226, loss: -0.82217
# epoch: 227, loss: -0.82172
# epoch: 228, loss: -0.82387
# epoch: 229, loss: -0.82092
# epoch: 230, loss: -0.82503
# epoch: 231, loss: -0.82360
# epoch: 232, loss: -0.82271
# epoch: 233, loss: -0.82168
# epoch: 234, loss: -0.82254
# epoch: 235, loss: -0.82597
# epoch: 236, loss: -0.82394
# epoch: 237, loss: -0.82255
# epoch: 238, loss: -0.82130
# epoch: 239, loss: -0.82482
# epoch: 240, loss: -0.82458
# epoch: 241, loss: -0.82385
# epoch: 242, loss: -0.81562
# epoch: 243, loss: -0.82603
# epoch: 244, loss: -0.82276
# epoch: 245, loss: -0.82417
# epoch: 246, loss: -0.82473
# epoch: 247, loss: -0.82409
# epoch: 248, loss: -0.82126
# epoch: 249, loss: -0.82697
# epoch: 250, loss: -0.82710
# epoch: 251, loss: -0.82331
# epoch: 252, loss: -0.82513
# epoch: 253, loss: -0.82541
# epoch: 254, loss: -0.82588
# epoch: 255, loss: -0.82687
# epoch: 256, loss: -0.82337
# epoch: 257, loss: -0.82432
# epoch: 258, loss: -0.81920
# epoch: 259, loss: -0.82463
# epoch: 260, loss: -0.82344
# epoch: 261, loss: -0.81974
# epoch: 262, loss: -0.82837
# epoch: 263, loss: -0.82624
# epoch: 264, loss: -0.82630
# epoch: 265, loss: -0.82121
# epoch: 266, loss: -0.82575
# epoch: 267, loss: -0.82119
# epoch: 268, loss: -0.82625
# epoch: 269, loss: -0.82205
# epoch: 270, loss: -0.82345
# epoch: 271, loss: -0.82412
# epoch: 272, loss: -0.82479
# epoch: 273, loss: -0.82780
# epoch: 274, loss: -0.82283
# epoch: 275, loss: -0.82737
# epoch: 276, loss: -0.82810
# epoch: 277, loss: -0.82798
# epoch: 278, loss: -0.82394
# epoch: 279, loss: -0.82758
# epoch: 280, loss: -0.82631
# epoch: 281, loss: -0.82604
# epoch: 282, loss: -0.82300
# epoch: 283, loss: -0.82825
# epoch: 284, loss: -0.82538
# epoch: 285, loss: -0.82372
# epoch: 286, loss: -0.82852
# epoch: 287, loss: -0.82831
# epoch: 288, loss: -0.82584
# epoch: 289, loss: -0.82776
# epoch: 290, loss: -0.82530
# epoch: 291, loss: -0.82407
# epoch: 292, loss: -0.82936
# epoch: 293, loss: -0.82988
# epoch: 294, loss: -0.83031
# epoch: 295, loss: -0.82579
# epoch: 296, loss: -0.82828
# epoch: 297, loss: -0.82843
# epoch: 298, loss: -0.82804
# epoch: 299, loss: -0.82647
# epoch: 300, loss: -0.82804
# epoch: 301, loss: -0.82582
# epoch: 302, loss: -0.83017
# epoch: 303, loss: -0.82588
# epoch: 304, loss: -0.82924
# epoch: 305, loss: -0.83020
# epoch: 306, loss: -0.82794
# epoch: 307, loss: -0.82651
# epoch: 308, loss: -0.82802
# epoch: 309, loss: -0.82873
# epoch: 310, loss: -0.82795
# epoch: 311, loss: -0.82852
# epoch: 312, loss: -0.82474
# epoch: 313, loss: -0.82706
# epoch: 314, loss: -0.82686
# epoch: 315, loss: -0.82713
# epoch: 316, loss: -0.83012
# epoch: 317, loss: -0.82939
# epoch: 318, loss: -0.82511
# epoch: 319, loss: -0.83073
# epoch: 320, loss: -0.82999
# epoch: 321, loss: -0.82502
# epoch: 322, loss: -0.82782
# epoch: 323, loss: -0.82750
# epoch: 324, loss: -0.83009
# epoch: 325, loss: -0.82707
# epoch: 326, loss: -0.82607
# epoch: 327, loss: -0.82228
# epoch: 328, loss: -0.82894
# epoch: 329, loss: -0.83084
# epoch: 330, loss: -0.82966
# epoch: 331, loss: -0.82857
# epoch: 332, loss: -0.83083
# epoch: 333, loss: -0.82964
# epoch: 334, loss: -0.82405
# epoch: 335, loss: -0.82961
# epoch: 336, loss: -0.82836
# epoch: 337, loss: -0.82705
# epoch: 338, loss: -0.82875
# epoch: 339, loss: -0.82903
# epoch: 340, loss: -0.82893
# epoch: 341, loss: -0.82922
# epoch: 342, loss: -0.82878
# epoch: 343, loss: -0.82881
# epoch: 344, loss: -0.83112
# epoch: 345, loss: -0.83031
# epoch: 346, loss: -0.82581
# epoch: 347, loss: -0.83023
# epoch: 348, loss: -0.82672
# epoch: 349, loss: -0.82886
# epoch: 350, loss: -0.83069
# epoch: 351, loss: -0.83033
# epoch: 352, loss: -0.83145
# epoch: 353, loss: -0.83063
# epoch: 354, loss: -0.83021
# epoch: 355, loss: -0.82877
# epoch: 356, loss: -0.82904
# epoch: 357, loss: -0.83153
# epoch: 358, loss: -0.82918
# epoch: 359, loss: -0.83081
# epoch: 360, loss: -0.83029
# epoch: 361, loss: -0.82566
# epoch: 362, loss: -0.83061
# epoch: 363, loss: -0.82923
# epoch: 364, loss: -0.82839
# epoch: 365, loss: -0.83135
# epoch: 366, loss: -0.82777
# epoch: 367, loss: -0.82900
# epoch: 368, loss: -0.83000
# epoch: 369, loss: -0.82992
# epoch: 370, loss: -0.82990
# epoch: 371, loss: -0.82516
# epoch: 372, loss: -0.82986
# epoch: 373, loss: -0.83169
# epoch: 374, loss: -0.83034
# epoch: 375, loss: -0.83176
# epoch: 376, loss: -0.82975
# epoch: 377, loss: -0.82497
# epoch: 378, loss: -0.83160
# epoch: 379, loss: -0.82695
# epoch: 380, loss: -0.83066
# epoch: 381, loss: -0.82588
# epoch: 382, loss: -0.83137
# epoch: 383, loss: -0.83037
# epoch: 384, loss: -0.82739
# epoch: 385, loss: -0.82718
# epoch: 386, loss: -0.82785
# epoch: 387, loss: -0.83104
# epoch: 388, loss: -0.83206
# epoch: 389, loss: -0.82950
# epoch: 390, loss: -0.83012
# epoch: 391, loss: -0.82274
# epoch: 392, loss: -0.83045
# epoch: 393, loss: -0.83093
# epoch: 394, loss: -0.83246
# epoch: 395, loss: -0.82913
# epoch: 396, loss: -0.83171
# epoch: 397, loss: -0.83257
# epoch: 398, loss: -0.82906
# epoch: 399, loss: -0.83253
# epoch: 400, loss: -0.83198
# epoch: 401, loss: -0.83134
# epoch: 402, loss: -0.82980
# epoch: 403, loss: -0.82625
# epoch: 404, loss: -0.82859
# epoch: 405, loss: -0.83276
# epoch: 406, loss: -0.82634
# epoch: 407, loss: -0.83213
# epoch: 408, loss: -0.83267
# epoch: 409, loss: -0.83110
# epoch: 410, loss: -0.83102
# epoch: 411, loss: -0.83055
# epoch: 412, loss: -0.83349
# epoch: 413, loss: -0.82897
# epoch: 414, loss: -0.83259
# epoch: 415, loss: -0.82945
# epoch: 416, loss: -0.83129
# epoch: 417, loss: -0.82730
# epoch: 418, loss: -0.82822
# epoch: 419, loss: -0.82944
# epoch: 420, loss: -0.83124
# epoch: 421, loss: -0.82749
# epoch: 422, loss: -0.83218
# epoch: 423, loss: -0.83064
# epoch: 424, loss: -0.83254
# epoch: 425, loss: -0.82911
# epoch: 426, loss: -0.83064
# epoch: 427, loss: -0.82876
# epoch: 428, loss: -0.83043
# epoch: 429, loss: -0.83109
# epoch: 430, loss: -0.83334
# epoch: 431, loss: -0.83209
# epoch: 432, loss: -0.83386
# epoch: 433, loss: -0.82957
# epoch: 434, loss: -0.83133
# epoch: 435, loss: -0.82998
# epoch: 436, loss: -0.83024
# epoch: 437, loss: -0.83028
# epoch: 438, loss: -0.83040
# epoch: 439, loss: -0.83001
# epoch: 440, loss: -0.82984
# epoch: 441, loss: -0.83272
# epoch: 442, loss: -0.82887
# epoch: 443, loss: -0.82912
# epoch: 444, loss: -0.83103
# epoch: 445, loss: -0.83027
# epoch: 446, loss: -0.83342
# epoch: 447, loss: -0.83199
# epoch: 448, loss: -0.82973
# epoch: 449, loss: -0.83189
# epoch: 450, loss: -0.83114
# epoch: 451, loss: -0.82460
# epoch: 452, loss: -0.83143
# epoch: 453, loss: -0.82936
# epoch: 454, loss: -0.82673
# epoch: 455, loss: -0.83225
# epoch: 456, loss: -0.83221
# epoch: 457, loss: -0.82914
# epoch: 458, loss: -0.83138
# epoch: 459, loss: -0.83033
# epoch: 460, loss: -0.83025
# epoch: 461, loss: -0.83414
# epoch: 462, loss: -0.83096
# epoch: 463, loss: -0.83253
# epoch: 464, loss: -0.83383
# epoch: 465, loss: -0.83130
# epoch: 466, loss: -0.83341
# epoch: 467, loss: -0.83309
# epoch: 468, loss: -0.83169
# epoch: 469, loss: -0.83355
# epoch: 470, loss: -0.83094
# epoch: 471, loss: -0.83197
# epoch: 472, loss: -0.82941
# epoch: 473, loss: -0.83187
# epoch: 474, loss: -0.83217
# epoch: 475, loss: -0.83411
# epoch: 476, loss: -0.83084
# epoch: 477, loss: -0.83180
# epoch: 478, loss: -0.83382
# epoch: 479, loss: -0.83307
# epoch: 480, loss: -0.82552
# epoch: 481, loss: -0.83227
# epoch: 482, loss: -0.83381
# epoch: 483, loss: -0.83442
# epoch: 484, loss: -0.83083
# epoch: 485, loss: -0.83256
# epoch: 486, loss: -0.83440
# epoch: 487, loss: -0.83346
# epoch: 488, loss: -0.83158
# epoch: 489, loss: -0.83216
# epoch: 490, loss: -0.83150
# epoch: 491, loss: -0.83105
# epoch: 492, loss: -0.82846
# epoch: 493, loss: -0.83455
# epoch: 494, loss: -0.83179
# epoch: 495, loss: -0.83205
# epoch: 496, loss: -0.83339
# epoch: 497, loss: -0.83230
# epoch: 498, loss: -0.83462
# epoch: 499, loss: -0.83450

# %% [markdown]
# ##Check the Training Result

# %%
ds_cl= MyDataSet(X_ds, X_ds)
dl_cl = DataLoader(ds_cl, batch_size=256)

# %%
embeddings = []

# disable gradients for faster calculations
model.eval()
with torch.no_grad():
    for dl_cl1, dl_cl2 in dl_cl:

        #dl_cl1 = (dl_cl1 - torch.mean(dl_cl1,0))/torch.std(dl_cl1,0)

        # move images to the gpu
        dl_cl1 = dl_cl1.to(device)

        # embed the images with the pre-trained backbone
        #y = model.backbone(images).flatten(start_dim=1)
        f, z, p = model(dl_cl1)
        # store the embeddings in lists
        embeddings.append(f)

# concatenate the embeddings, targets and convert to numpy
embeddings = torch.cat(embeddings, dim=0)
embeddings = embeddings.cpu().numpy()

# %%
test = (embeddings - embeddings.mean(axis=0)) / (embeddings.std(axis=0))

# %%
#KMeans in latent space
kmeans_backbone = KMeans(n_clusters=3).fit(test)
kmeans_labels_backbone = kmeans_backbone.labels_

# %%
normalized_mutual_info_score(kmeans_labels_backbone, y)
# Out:
# 0.8072131782243347

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(test)
data_X_tsne = np.vstack((X_tsne.T, y)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#NMI increases from 0.69 to 0.80
