# %% [markdown]
# ## Conifuration

# %%
#import the lib for contrastive learning framework
# !pip install lightly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lightly in /usr/local/lib/python3.7/dist-packages (1.2.21)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.15.0)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (57.4.0)
# Requirement already satisfied: lightly-utils~=0.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (0.0.2)
# Requirement already satisfied: pytorch-lightning>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.6.4)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.21.6)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.23.0)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.24.3)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.7/dist-packages (from lightly) (2022.6.15)
# Requirement already satisfied: hydra-core>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.2.0)
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.7/dist-packages (from lightly) (4.64.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from lightly) (0.12.0+cu113)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.8.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (5.7.1)
# Requirement already satisfied: omegaconf~=2.2 in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (2.2.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (21.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from lightly-utils~=0.0.0->lightly) (7.1.2)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.7/dist-packages (from omegaconf~=2.2->hydra-core>=1.0.0->lightly) (6.0)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2.8.0)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2022.5.0)
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (1.11.0+cu113)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (0.3.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (4.1.1)
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (3.17.3)
# Requirement already satisfied: torchmetrics>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (0.9.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->hydra-core>=1.0.0->lightly) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (3.0.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.1.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.35.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.3.7)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.37.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.6.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.46.3)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (4.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (0.13.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (21.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (1.3.0)

# %%
import lightly
from lightly.models.modules.heads import SimSiamPredictionHead
from lightly.models.modules.heads import SimSiamProjectionHead

from lightly.data import LightlyDataset
from lightly.data import ImageCollateFunction
from lightly.models.modules import BarlowTwinsProjectionHead
from lightly.loss import BarlowTwinsLoss

from lightly.data import LightlyDataset
from lightly.data import SimCLRCollateFunction
from lightly.loss import NTXentLoss
from lightly.loss import NegativeCosineSimilarity
from lightly.models.modules import SimCLRProjectionHead

# %%
import math
import torch
import torch.nn as nn
import torchvision
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from torch.utils.data import Dataset, DataLoader
import torch.optim as torch_optim
import torch.optim.lr_scheduler as lr_scheduler
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
from datetime import datetime

from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from matplotlib import pyplot
import seaborn as sns

from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_mutual_info_score
from sklearn.metrics import silhouette_score
from sklearn import mixture
from sklearn.cluster import DBSCAN
from sklearn.cluster import OPTICS
from sklearn.cluster import AgglomerativeClustering

import tensorboard
from tensorboard import notebook
from torch.utils.tensorboard import SummaryWriter

import matplotlib 
import matplotlib.pyplot as plt
#import plotly.express as px

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons
from sklearn.utils import shuffle

import torchvision.transforms as transforms
import torchvision.datasets as datasets
from sklearn.metrics.pairwise import cosine_similarity

import random
from torch.nn.modules.loss import MSELoss
from sklearn.neighbors import KDTree
#from kmodes.kprototypes import KPrototypes

from scipy.io.arff import loadarff
from sklearn.preprocessing import MinMaxScaler 
from sklearn.datasets import make_classification

# %% [markdown]
# ## Load Dataset Pendigits and Check Clustering Result with the Baseline Method Kmeans

# %%
# set the path to the dataset
path_to_data = '/content/drive/MyDrive/Colab_Notebooks/optdigits.csv'

# %%
data = pd.read_csv(path_to_data)

X_ds = data.copy()
X_ds = X_ds.drop(['class'], axis=1)
X_ds = pd.DataFrame(X_ds).to_numpy()

y_ds = data.copy()
y_ds = y_ds['class']

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X_ds)
data_X_tsne = np.vstack((X_tsne.T, y_ds)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#check the clustering result with Kmeans
kmeans_ori = KMeans(n_clusters=10).fit(X_ds)
kmeans_labels_ori = kmeans_ori.labels_

normalized_mutual_info_score(kmeans_labels_ori, y_ds)
# Out:
# 0.7575409900034168

# %%
#tsne = TSNE(n_components=2)
#X_tsne = tsne.fit_transform(X_ds)
data_X_tsne = np.vstack((X_tsne.T, kmeans_labels_ori)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ####MixUp

# %%
def mixup(data):
  view = data.copy()
  for i in range(len(view)):
    random_row_index = random.randint(0, len(view)-1)
    view[i] = view[i]*0.5  + view[random_row_index]*0.5
  return view

# %% [markdown]
# ####MixCut

# %%
def mixcut(data):
  data_copy = data.copy()
  view = data.copy()
  mask_len = 100

  for i in range(len(data_copy)):
    random_row_id = random.randint(0, len(data_copy)-1)
    random_column_id = random.randint(0, data_copy.shape[1]-mask_len)
    view[i,random_column_id:(random_column_id+mask_len)] = data_copy[random_row_id,random_column_id:(random_column_id+mask_len)]
  return view

# %% [markdown]
# #### Masking with mean

# %%
def get_random_indices(data, portion_of_mask):
  return np.random.choice(data.shape[1], size=np.floor(data.shape[1]*portion_of_mask).astype(int), replace=False)

# %%
def masking_with_mean(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = column_mu[j]
              
  return view

# %% [markdown]
# ####Masking with random value in domain range

# %%
def masking_with_random(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)
  column_min = np.minimum(data)
  column_max = np.maximum(data)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = random.randint(column_min[j], column_max[j])
              
  return view

# %% [markdown]
# ####Masking with margin distribution

# %%
def masking_with_margin_distribution(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = np.random.normal(column_mu[j], column_std[j])
              
  return view

# %% [markdown]
# ####Upsampling (SMOTE like)

# %%
#put all data points in kd-tree for fast searching
kdtree = KDTree(X_ds, leaf_size=2)

# %%
#get random point in the k nearest neighbors
def get_idx_random_knn(x,k):
   _, ids = kdtree.query(x.reshape(1, -1), k=k)
   ids = ids.flatten()
   ids = ids[1:-1]
   random_id = np.random.choice(ids, 1)
   return random_id

# %%
#mix up with a random near neighbor 
def mixup_random_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = 0.5*data[i] + 0.5*data[random_neighbor_id]
  return view

# %%
#a random neighbor as augmentation
def random_near_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = data[random_neighbor_id]
  return view

# %% [markdown]
# ##Create Model and Train with Augmented Data

# %%
class MyDataSet(Dataset):
  def __init__(self, view1, view2):
 
    X_view1 = view1.copy()
    X_view2 = view2.copy()
    self.X_view1 = X_view1.copy().astype(np.float32)
    self.X_view2 = X_view2.copy().astype(np.float32)
  
  def __len__(self):
    return len(self.X_view1)
  
  def __getitem__(self, idx):
    return self.X_view1[idx], self.X_view2[idx]

# %%
# define the NN architecture
class convBackbone(nn.Module):
    def __init__(self):
        super(convBackbone, self).__init__()

        #turn on dropout for testing the 'cropping' data augmentation 
        #self.dropout = nn.Dropout(p=0.1)
        
        self.fc1 = nn.Linear(64, 64, bias=False)
        self.bn1 = nn.BatchNorm1d(64)

        self.fc2 = nn.Linear(64, 64, bias=False)
        self.bn2 = nn.BatchNorm1d(64)

        self.fc3 = nn.Linear(64, 32, bias=False)
        self.bn3 = nn.BatchNorm1d(32)


    def forward(self, x):

        #turn on dropout for testing the 'cropping' data augmentation 
        #x = self.dropout(x)
        
        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.bn3(self.fc3(x))
                
        return x

# %%
class SimCLR(nn.Module):
    def __init__(self, backbone):
        super().__init__()
        self.backbone = backbone
        self.projection_head = SimCLRProjectionHead(32, 16, 32)

    def forward(self, x):
        x = self.backbone(x).flatten(start_dim=1)
        z = self.projection_head(x)
        return x,z

backbone = convBackbone()
model = SimCLR(backbone)

# %%
criterion = NTXentLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.05, momentum=0.9,weight_decay=1e-4)

#cosine annealing lr
scheduler = lr_scheduler.CosineAnnealingLR(optimizer,T_max=500, eta_min=0)

# %%
view1 = random_near_neighbor(X_ds, 22)
view2 = random_near_neighbor(X_ds, 18)

#turn on the following to test other augmentations

#view1 = mixup_random_neighbor(X_ds, 15)
#view2 = mixup_random_neighbor(X_ds, 15)

#view1 = mixup(X_ds)
#view2 = mixup(X_ds)

#view1 = mixcut(X_ds)
#view2 = mixcut(X_ds)

#view1 = masking_with_mean(X_ds, 0.4)
#view2 = masking_with_mean(X_ds, 0.4)

#view1 = masking_with_random(X_ds, 0.4)
#view2 = masking_with_random(X_ds, 0.4)

#view1 = masking_with_margin_distribution(X_ds, 0.4)
#view2 = masking_with_margin_distribution(X_ds, 0.4)

train_ds = MyDataSet(view1, view2)
train_dl = DataLoader(train_ds, batch_size=256, shuffle=True)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

for epoch in range(500):
    total_loss = 0
    for x0, x1 in train_dl:

        x0 = x0.to(device)
        x1 = x1.to(device)
        _,z0 = model(x0)
        _,z1 = model(x1)

        loss = criterion(z0, z1)
        total_loss += loss.detach()
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        scheduler.step()

    avg_loss = total_loss / len(train_dl)
    print(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
# Out:
# epoch: 00, loss: 4.99056
# epoch: 01, loss: 4.71010
# epoch: 02, loss: 4.66745
# epoch: 03, loss: 4.65219
# epoch: 04, loss: 4.64196
# epoch: 05, loss: 4.63618
# epoch: 06, loss: 4.63061
# epoch: 07, loss: 4.62785
# epoch: 08, loss: 4.62352
# epoch: 09, loss: 4.61810
# epoch: 10, loss: 4.61711
# epoch: 11, loss: 4.61480
# epoch: 12, loss: 4.61550
# epoch: 13, loss: 4.60975
# epoch: 14, loss: 4.60892
# epoch: 15, loss: 4.60708
# epoch: 16, loss: 4.60636
# epoch: 17, loss: 4.60698
# epoch: 18, loss: 4.60518
# epoch: 19, loss: 4.60512
# epoch: 20, loss: 4.60469
# epoch: 21, loss: 4.60397
# epoch: 22, loss: 4.60648
# epoch: 23, loss: 4.60402
# epoch: 24, loss: 4.60361
# epoch: 25, loss: 4.60568
# epoch: 26, loss: 4.60315
# epoch: 27, loss: 4.60529
# epoch: 28, loss: 4.60413
# epoch: 29, loss: 4.60604
# epoch: 30, loss: 4.60298
# epoch: 31, loss: 4.60243
# epoch: 32, loss: 4.60211
# epoch: 33, loss: 4.60065
# epoch: 34, loss: 4.60218
# epoch: 35, loss: 4.59974
# epoch: 36, loss: 4.59885
# epoch: 37, loss: 4.59824
# epoch: 38, loss: 4.59530
# epoch: 39, loss: 4.59426
# epoch: 40, loss: 4.59376
# epoch: 41, loss: 4.59248
# epoch: 42, loss: 4.59345
# epoch: 43, loss: 4.59056
# epoch: 44, loss: 4.59079
# epoch: 45, loss: 4.58717
# epoch: 46, loss: 4.58651
# epoch: 47, loss: 4.58530
# epoch: 48, loss: 4.58356
# epoch: 49, loss: 4.58274
# epoch: 50, loss: 4.58331
# epoch: 51, loss: 4.57957
# epoch: 52, loss: 4.57852
# epoch: 53, loss: 4.57602
# epoch: 54, loss: 4.57405
# epoch: 55, loss: 4.57291
# epoch: 56, loss: 4.57282
# epoch: 57, loss: 4.57114
# epoch: 58, loss: 4.56979
# epoch: 59, loss: 4.56618
# epoch: 60, loss: 4.56677
# epoch: 61, loss: 4.56647
# epoch: 62, loss: 4.56516
# epoch: 63, loss: 4.56749
# epoch: 64, loss: 4.56508
# epoch: 65, loss: 4.56359
# epoch: 66, loss: 4.56171
# epoch: 67, loss: 4.56408
# epoch: 68, loss: 4.56266
# epoch: 69, loss: 4.56250
# epoch: 70, loss: 4.56557
# epoch: 71, loss: 4.56351
# epoch: 72, loss: 4.56394
# epoch: 73, loss: 4.56389
# epoch: 74, loss: 4.56535
# epoch: 75, loss: 4.56657
# epoch: 76, loss: 4.56773
# epoch: 77, loss: 4.56502
# epoch: 78, loss: 4.56622
# epoch: 79, loss: 4.56709
# epoch: 80, loss: 4.56678
# epoch: 81, loss: 4.56886
# epoch: 82, loss: 4.56757
# epoch: 83, loss: 4.56751
# epoch: 84, loss: 4.56819
# epoch: 85, loss: 4.56626
# epoch: 86, loss: 4.56682
# epoch: 87, loss: 4.56633
# epoch: 88, loss: 4.56978
# epoch: 89, loss: 4.56701
# epoch: 90, loss: 4.56403
# epoch: 91, loss: 4.56670
# epoch: 92, loss: 4.56795
# epoch: 93, loss: 4.56309
# epoch: 94, loss: 4.56409
# epoch: 95, loss: 4.56526
# epoch: 96, loss: 4.56337
# epoch: 97, loss: 4.55957
# epoch: 98, loss: 4.56225
# epoch: 99, loss: 4.55535
# epoch: 100, loss: 4.55684
# epoch: 101, loss: 4.55362
# epoch: 102, loss: 4.55291
# epoch: 103, loss: 4.55234
# epoch: 104, loss: 4.55496
# epoch: 105, loss: 4.54901
# epoch: 106, loss: 4.55125
# epoch: 107, loss: 4.54915
# epoch: 108, loss: 4.54886
# epoch: 109, loss: 4.54587
# epoch: 110, loss: 4.54419
# epoch: 111, loss: 4.54751
# epoch: 112, loss: 4.54362
# epoch: 113, loss: 4.54471
# epoch: 114, loss: 4.54563
# epoch: 115, loss: 4.54580
# epoch: 116, loss: 4.54686
# epoch: 117, loss: 4.54680
# epoch: 118, loss: 4.54606
# epoch: 119, loss: 4.54741
# epoch: 120, loss: 4.54455
# epoch: 121, loss: 4.54667
# epoch: 122, loss: 4.54795
# epoch: 123, loss: 4.54878
# epoch: 124, loss: 4.55055
# epoch: 125, loss: 4.55032
# epoch: 126, loss: 4.55238
# epoch: 127, loss: 4.55305
# epoch: 128, loss: 4.55399
# epoch: 129, loss: 4.55188
# epoch: 130, loss: 4.55581
# epoch: 131, loss: 4.55529
# epoch: 132, loss: 4.55739
# epoch: 133, loss: 4.55578
# epoch: 134, loss: 4.55400
# epoch: 135, loss: 4.55347
# epoch: 136, loss: 4.55487
# epoch: 137, loss: 4.55611
# epoch: 138, loss: 4.55176
# epoch: 139, loss: 4.55400
# epoch: 140, loss: 4.55395
# epoch: 141, loss: 4.55053
# epoch: 142, loss: 4.55148
# epoch: 143, loss: 4.54802
# epoch: 144, loss: 4.54850
# epoch: 145, loss: 4.54895
# epoch: 146, loss: 4.54414
# epoch: 147, loss: 4.54522
# epoch: 148, loss: 4.54390
# epoch: 149, loss: 4.53949
# epoch: 150, loss: 4.54248
# epoch: 151, loss: 4.54108
# epoch: 152, loss: 4.53664
# epoch: 153, loss: 4.53767
# epoch: 154, loss: 4.53521
# epoch: 155, loss: 4.53437
# epoch: 156, loss: 4.53576
# epoch: 157, loss: 4.53295
# epoch: 158, loss: 4.53322
# epoch: 159, loss: 4.53635
# epoch: 160, loss: 4.53279
# epoch: 161, loss: 4.53456
# epoch: 162, loss: 4.53298
# epoch: 163, loss: 4.53564
# epoch: 164, loss: 4.53459
# epoch: 165, loss: 4.53716
# epoch: 166, loss: 4.53718
# epoch: 167, loss: 4.53709
# epoch: 168, loss: 4.53901
# epoch: 169, loss: 4.53861
# epoch: 170, loss: 4.54335
# epoch: 171, loss: 4.54238
# epoch: 172, loss: 4.54556
# epoch: 173, loss: 4.54609
# epoch: 174, loss: 4.54487
# epoch: 175, loss: 4.54754
# epoch: 176, loss: 4.54818
# epoch: 177, loss: 4.54865
# epoch: 178, loss: 4.54735
# epoch: 179, loss: 4.54706
# epoch: 180, loss: 4.54968
# epoch: 181, loss: 4.54810
# epoch: 182, loss: 4.54726
# epoch: 183, loss: 4.54611
# epoch: 184, loss: 4.54959
# epoch: 185, loss: 4.55294
# epoch: 186, loss: 4.54660
# epoch: 187, loss: 4.54548
# epoch: 188, loss: 4.54136
# epoch: 189, loss: 4.54116
# epoch: 190, loss: 4.54047
# epoch: 191, loss: 4.53756
# epoch: 192, loss: 4.53552
# epoch: 193, loss: 4.53650
# epoch: 194, loss: 4.53389
# epoch: 195, loss: 4.53087
# epoch: 196, loss: 4.53025
# epoch: 197, loss: 4.52825
# epoch: 198, loss: 4.53108
# epoch: 199, loss: 4.52829
# epoch: 200, loss: 4.52992
# epoch: 201, loss: 4.52663
# epoch: 202, loss: 4.52713
# epoch: 203, loss: 4.52542
# epoch: 204, loss: 4.52711
# epoch: 205, loss: 4.52624
# epoch: 206, loss: 4.52440
# epoch: 207, loss: 4.52502
# epoch: 208, loss: 4.52620
# epoch: 209, loss: 4.52635
# epoch: 210, loss: 4.52697
# epoch: 211, loss: 4.52799
# epoch: 212, loss: 4.53036
# epoch: 213, loss: 4.53344
# epoch: 214, loss: 4.53046
# epoch: 215, loss: 4.53066
# epoch: 216, loss: 4.53263
# epoch: 217, loss: 4.53594
# epoch: 218, loss: 4.53969
# epoch: 219, loss: 4.54029
# epoch: 220, loss: 4.54017
# epoch: 221, loss: 4.54118
# epoch: 222, loss: 4.53850
# epoch: 223, loss: 4.54423
# epoch: 224, loss: 4.54247
# epoch: 225, loss: 4.54120
# epoch: 226, loss: 4.54389
# epoch: 227, loss: 4.54510
# epoch: 228, loss: 4.54282
# epoch: 229, loss: 4.54243
# epoch: 230, loss: 4.53892
# epoch: 231, loss: 4.53975
# epoch: 232, loss: 4.53888
# epoch: 233, loss: 4.53930
# epoch: 234, loss: 4.53639
# epoch: 235, loss: 4.53636
# epoch: 236, loss: 4.53416
# epoch: 237, loss: 4.53241
# epoch: 238, loss: 4.53037
# epoch: 239, loss: 4.53057
# epoch: 240, loss: 4.52764
# epoch: 241, loss: 4.52667
# epoch: 242, loss: 4.52435
# epoch: 243, loss: 4.52351
# epoch: 244, loss: 4.52119
# epoch: 245, loss: 4.52093
# epoch: 246, loss: 4.52132
# epoch: 247, loss: 4.51991
# epoch: 248, loss: 4.52051
# epoch: 249, loss: 4.52161
# epoch: 250, loss: 4.51777
# epoch: 251, loss: 4.52033
# epoch: 252, loss: 4.52118
# epoch: 253, loss: 4.52087
# epoch: 254, loss: 4.52042
# epoch: 255, loss: 4.52198
# epoch: 256, loss: 4.52144
# epoch: 257, loss: 4.52406
# epoch: 258, loss: 4.52477
# epoch: 259, loss: 4.52470
# epoch: 260, loss: 4.52662
# epoch: 261, loss: 4.53089
# epoch: 262, loss: 4.53139
# epoch: 263, loss: 4.53314
# epoch: 264, loss: 4.53019
# epoch: 265, loss: 4.53583
# epoch: 266, loss: 4.53394
# epoch: 267, loss: 4.53467
# epoch: 268, loss: 4.53630
# epoch: 269, loss: 4.53788
# epoch: 270, loss: 4.53987
# epoch: 271, loss: 4.53895
# epoch: 272, loss: 4.53831
# epoch: 273, loss: 4.54139
# epoch: 274, loss: 4.53658
# epoch: 275, loss: 4.53717
# epoch: 276, loss: 4.53684
# epoch: 277, loss: 4.53407
# epoch: 278, loss: 4.53218
# epoch: 279, loss: 4.53114
# epoch: 280, loss: 4.53218
# epoch: 281, loss: 4.53250
# epoch: 282, loss: 4.52986
# epoch: 283, loss: 4.52604
# epoch: 284, loss: 4.52788
# epoch: 285, loss: 4.52319
# epoch: 286, loss: 4.52231
# epoch: 287, loss: 4.52431
# epoch: 288, loss: 4.51853
# epoch: 289, loss: 4.52038
# epoch: 290, loss: 4.51988
# epoch: 291, loss: 4.51804
# epoch: 292, loss: 4.51656
# epoch: 293, loss: 4.51679
# epoch: 294, loss: 4.51790
# epoch: 295, loss: 4.51521
# epoch: 296, loss: 4.51699
# epoch: 297, loss: 4.51774
# epoch: 298, loss: 4.51644
# epoch: 299, loss: 4.51640
# epoch: 300, loss: 4.51631
# epoch: 301, loss: 4.52057
# epoch: 302, loss: 4.51965
# epoch: 303, loss: 4.51973
# epoch: 304, loss: 4.52032
# epoch: 305, loss: 4.52443
# epoch: 306, loss: 4.52293
# epoch: 307, loss: 4.52656
# epoch: 308, loss: 4.52771
# epoch: 309, loss: 4.53075
# epoch: 310, loss: 4.52851
# epoch: 311, loss: 4.52997
# epoch: 312, loss: 4.53125
# epoch: 313, loss: 4.53330
# epoch: 314, loss: 4.53549
# epoch: 315, loss: 4.53429
# epoch: 316, loss: 4.53420
# epoch: 317, loss: 4.53606
# epoch: 318, loss: 4.53426
# epoch: 319, loss: 4.53977
# epoch: 320, loss: 4.53437
# epoch: 321, loss: 4.53581
# epoch: 322, loss: 4.53589
# epoch: 323, loss: 4.53184
# epoch: 324, loss: 4.52939
# epoch: 325, loss: 4.52870
# epoch: 326, loss: 4.52880
# epoch: 327, loss: 4.52612
# epoch: 328, loss: 4.52501
# epoch: 329, loss: 4.52413
# epoch: 330, loss: 4.52126
# epoch: 331, loss: 4.52085
# epoch: 332, loss: 4.51924
# epoch: 333, loss: 4.51705
# epoch: 334, loss: 4.51939
# epoch: 335, loss: 4.51422
# epoch: 336, loss: 4.51656
# epoch: 337, loss: 4.51199
# epoch: 338, loss: 4.51214
# epoch: 339, loss: 4.51409
# epoch: 340, loss: 4.51471
# epoch: 341, loss: 4.51405
# epoch: 342, loss: 4.51328
# epoch: 343, loss: 4.51528
# epoch: 344, loss: 4.51317
# epoch: 345, loss: 4.51434
# epoch: 346, loss: 4.51729
# epoch: 347, loss: 4.51741
# epoch: 348, loss: 4.51853
# epoch: 349, loss: 4.51863
# epoch: 350, loss: 4.51732
# epoch: 351, loss: 4.52124
# epoch: 352, loss: 4.52181
# epoch: 353, loss: 4.52359
# epoch: 354, loss: 4.52340
# epoch: 355, loss: 4.52598
# epoch: 356, loss: 4.53001
# epoch: 357, loss: 4.52883
# epoch: 358, loss: 4.52737
# epoch: 359, loss: 4.52790
# epoch: 360, loss: 4.53080
# epoch: 361, loss: 4.53275
# epoch: 362, loss: 4.53208
# epoch: 363, loss: 4.53086
# epoch: 364, loss: 4.52993
# epoch: 365, loss: 4.53073
# epoch: 366, loss: 4.52950
# epoch: 367, loss: 4.53055
# epoch: 368, loss: 4.53043
# epoch: 369, loss: 4.53039
# epoch: 370, loss: 4.52765
# epoch: 371, loss: 4.52362
# epoch: 372, loss: 4.52488
# epoch: 373, loss: 4.52235
# epoch: 374, loss: 4.52032
# epoch: 375, loss: 4.51941
# epoch: 376, loss: 4.52014
# epoch: 377, loss: 4.51746
# epoch: 378, loss: 4.51391
# epoch: 379, loss: 4.51558
# epoch: 380, loss: 4.51580
# epoch: 381, loss: 4.51241
# epoch: 382, loss: 4.51099
# epoch: 383, loss: 4.51252
# epoch: 384, loss: 4.51016
# epoch: 385, loss: 4.51276
# epoch: 386, loss: 4.51230
# epoch: 387, loss: 4.51275
# epoch: 388, loss: 4.51011
# epoch: 389, loss: 4.51022
# epoch: 390, loss: 4.50868
# epoch: 391, loss: 4.51271
# epoch: 392, loss: 4.51506
# epoch: 393, loss: 4.51407
# epoch: 394, loss: 4.51612
# epoch: 395, loss: 4.51670
# epoch: 396, loss: 4.51666
# epoch: 397, loss: 4.51777
# epoch: 398, loss: 4.51834
# epoch: 399, loss: 4.52080
# epoch: 400, loss: 4.52463
# epoch: 401, loss: 4.52502
# epoch: 402, loss: 4.52555
# epoch: 403, loss: 4.52659
# epoch: 404, loss: 4.52730
# epoch: 405, loss: 4.52938
# epoch: 406, loss: 4.53175
# epoch: 407, loss: 4.53181
# epoch: 408, loss: 4.53199
# epoch: 409, loss: 4.52783
# epoch: 410, loss: 4.53162
# epoch: 411, loss: 4.52934
# epoch: 412, loss: 4.53169
# epoch: 413, loss: 4.52803
# epoch: 414, loss: 4.52754
# epoch: 415, loss: 4.52591
# epoch: 416, loss: 4.52395
# epoch: 417, loss: 4.52337
# epoch: 418, loss: 4.52110
# epoch: 419, loss: 4.51742
# epoch: 420, loss: 4.51849
# epoch: 421, loss: 4.51513
# epoch: 422, loss: 4.51564
# epoch: 423, loss: 4.51333
# epoch: 424, loss: 4.51307
# epoch: 425, loss: 4.51439
# epoch: 426, loss: 4.50965
# epoch: 427, loss: 4.51044
# epoch: 428, loss: 4.51161
# epoch: 429, loss: 4.50944
# epoch: 430, loss: 4.50794
# epoch: 431, loss: 4.50812
# epoch: 432, loss: 4.50829
# epoch: 433, loss: 4.50879
# epoch: 434, loss: 4.51024
# epoch: 435, loss: 4.51061
# epoch: 436, loss: 4.51233
# epoch: 437, loss: 4.51021
# epoch: 438, loss: 4.51188
# epoch: 439, loss: 4.51377
# epoch: 440, loss: 4.51290
# epoch: 441, loss: 4.51473
# epoch: 442, loss: 4.51774
# epoch: 443, loss: 4.51572
# epoch: 444, loss: 4.51893
# epoch: 445, loss: 4.51815
# epoch: 446, loss: 4.52203
# epoch: 447, loss: 4.52483
# epoch: 448, loss: 4.52655
# epoch: 449, loss: 4.52418
# epoch: 450, loss: 4.52459
# epoch: 451, loss: 4.52680
# epoch: 452, loss: 4.52618
# epoch: 453, loss: 4.52941
# epoch: 454, loss: 4.52595
# epoch: 455, loss: 4.52986
# epoch: 456, loss: 4.52491
# epoch: 457, loss: 4.52509
# epoch: 458, loss: 4.52667
# epoch: 459, loss: 4.52261
# epoch: 460, loss: 4.52383
# epoch: 461, loss: 4.52276
# epoch: 462, loss: 4.52452
# epoch: 463, loss: 4.52167
# epoch: 464, loss: 4.51923
# epoch: 465, loss: 4.52032
# epoch: 466, loss: 4.51646
# epoch: 467, loss: 4.51570
# epoch: 468, loss: 4.51436
# epoch: 469, loss: 4.51413
# epoch: 470, loss: 4.51127
# epoch: 471, loss: 4.51092
# epoch: 472, loss: 4.50921
# epoch: 473, loss: 4.50892
# epoch: 474, loss: 4.50708
# epoch: 475, loss: 4.50953
# epoch: 476, loss: 4.50768
# epoch: 477, loss: 4.50739
# epoch: 478, loss: 4.50750
# epoch: 479, loss: 4.50699
# epoch: 480, loss: 4.50679
# epoch: 481, loss: 4.50950
# epoch: 482, loss: 4.50994
# epoch: 483, loss: 4.51028
# epoch: 484, loss: 4.51009
# epoch: 485, loss: 4.51302
# epoch: 486, loss: 4.51179
# epoch: 487, loss: 4.51356
# epoch: 488, loss: 4.51525
# epoch: 489, loss: 4.51898
# epoch: 490, loss: 4.51736
# epoch: 491, loss: 4.52050
# epoch: 492, loss: 4.51779
# epoch: 493, loss: 4.52007
# epoch: 494, loss: 4.52198
# epoch: 495, loss: 4.52319
# epoch: 496, loss: 4.52340
# epoch: 497, loss: 4.52255
# epoch: 498, loss: 4.52491
# epoch: 499, loss: 4.52831

# %% [markdown]
# ##Check the Training Result

# %%
ds_cl= MyDataSet(X_ds, X_ds)
dl_cl = DataLoader(ds_cl, batch_size=256)

# %%
embeddings = []

# disable gradients for faster calculations
model.eval()
with torch.no_grad():
    for dl_cl1, dl_cl2 in dl_cl:

        dl_cl1 = dl_cl1.to(device)
        x,z = model(dl_cl1)
        
        # store the embeddings in lists
        embeddings.append(x)

# concatenate the embeddings, targets and convert to numpy
embeddings = torch.cat(embeddings, dim=0)
embeddings = embeddings.cpu().numpy()

# %%
test = (embeddings - embeddings.mean(axis=0)) / (embeddings.std(axis=0))

# %%
#KMeans in latent space
kmeans_backbone = KMeans(n_clusters=10).fit(test)
kmeans_labels_backbone = kmeans_backbone.labels_

# %%
normalized_mutual_info_score(kmeans_labels_backbone, y_ds)
# Out:
# 0.8514025075879257

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(embeddings)
data_X_tsne = np.vstack((X_tsne.T, kmeans_labels_backbone)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#NMI increases from 0.75 to 0.85
