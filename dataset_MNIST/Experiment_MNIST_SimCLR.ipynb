# %% [markdown]
# ## Conifuration

# %%
#import the lib for contrastive learning framework
# !pip install lightly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lightly
#   Downloading lightly-1.2.20-py3-none-any.whl (451 kB)
#      |████████████████████████████████| 451 kB 4.3 MB/s
# Collecting hydra-core>=1.0.0
#   Downloading hydra_core-1.2.0-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 49.9 MB/s
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.24.3)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.7/dist-packages (from lightly) (2022.6.15)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (57.4.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.8.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from lightly) (0.12.0+cu113)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from lightly) (1.21.6)
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.7/dist-packages (from lightly) (4.64.0)
# Collecting lightly-utils~=0.0.0
#   Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Collecting pytorch-lightning>=1.0.4
#   Downloading pytorch_lightning-1.6.4-py3-none-any.whl (585 kB)
#      |████████████████████████████████| 585 kB 46.6 MB/s
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from lightly) (2.23.0)
# Collecting omegaconf~=2.2
#   Downloading omegaconf-2.2.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 6.4 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (21.3)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      |████████████████████████████████| 117 kB 11.8 MB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.0.0->lightly) (5.7.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from lightly-utils~=0.0.0->lightly) (7.1.2)
# Collecting PyYAML>=5.1.0
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 54.7 MB/s
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (2.8.0)
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (3.17.3)
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.0.4->lightly) (4.1.1)
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.9.1-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 61.2 MB/s
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 70.5 MB/s
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 51.3 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->hydra-core>=1.0.0->lightly) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->lightly) (3.0.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.35.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.3.7)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.1.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.46.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.0.4->lightly) (3.2.0)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 72.8 MB/s
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 2.9 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 71.0 MB/s
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (2.0.12)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.0.4->lightly) (21.4.0)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=b12288a152a3c0ad96f0aea6a4c7a249e136acb8f9f8e683c39977f47f882082
#   Stored in directory: /root/.cache/pip/wheels/8b/8d/53/2af8772d9aec614e3fc65e53d4a993ad73c61daa8bbd85a873
# Successfully built antlr4-python3-runtime
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, PyYAML, fsspec, antlr4-python3-runtime, aiohttp, torchmetrics, pyDeprecate, omegaconf, pytorch-lightning, lightly-utils, hydra-core, lightly
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-6.0 aiohttp-3.8.1 aiosignal-1.2.0 antlr4-python3-runtime-4.9.3 async-timeout-4.0.2 asynctest-0.13.0 frozenlist-1.3.0 fsspec-2022.5.0 hydra-core-1.2.0 lightly-1.2.20 lightly-utils-0.0.2 multidict-6.0.2 omegaconf-2.2.2 pyDeprecate-0.3.2 pytorch-lightning-1.6.4 torchmetrics-0.9.1 yarl-1.7.2

# %%
import lightly
from lightly.models.modules.heads import SimSiamPredictionHead
from lightly.models.modules.heads import SimSiamProjectionHead

from lightly.data import LightlyDataset
from lightly.data import ImageCollateFunction
from lightly.models.modules import BarlowTwinsProjectionHead
from lightly.loss import BarlowTwinsLoss

from lightly.data import LightlyDataset
from lightly.data import SimCLRCollateFunction
from lightly.loss import NTXentLoss
from lightly.loss import NegativeCosineSimilarity
from lightly.models.modules import SimCLRProjectionHead

# %%
import math
import torch
import torch.nn as nn
import torchvision
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from torch.utils.data import Dataset, DataLoader
import torch.optim as torch_optim
import torch.optim.lr_scheduler as lr_scheduler
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
from datetime import datetime

from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.cluster import SpectralClustering
from matplotlib import pyplot
import seaborn as sns

from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_mutual_info_score
from sklearn.metrics import silhouette_score
from sklearn import mixture
from sklearn.cluster import DBSCAN
from sklearn.cluster import OPTICS
from sklearn.cluster import AgglomerativeClustering

import tensorboard
from tensorboard import notebook
from torch.utils.tensorboard import SummaryWriter

import matplotlib 
import matplotlib.pyplot as plt
#import plotly.express as px

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons
from sklearn.utils import shuffle

import torchvision.transforms as transforms
import torchvision.datasets as datasets
from sklearn.metrics.pairwise import cosine_similarity

import random
from torch.nn.modules.loss import MSELoss
from sklearn.neighbors import KDTree
#from kmodes.kprototypes import KPrototypes

from scipy.io.arff import loadarff
from sklearn.preprocessing import MinMaxScaler 
from sklearn.datasets import make_classification

# %% [markdown]
# ## Load Dataset MNIST and Check Clustering Result with the Baseline Method Kmeans

# %%
# set the path to the dataset
path_to_data = '/content/drive/MyDrive/Colab_Notebooks/mnist_train.csv'

# %%
data = pd.read_csv(path_to_data)

X_ds = data.copy()
X_ds = X_ds.drop(['label'], axis=1)

y_ds = data.copy()
y_ds = y_ds['label']

# %%
X_ds = X_ds.copy()
X_ds = pd.DataFrame(X_ds).to_numpy()

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X_ds)
data_X_tsne = np.vstack((X_tsne.T, y_ds)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#check the clustering result with Kmeans
kmeans_ori = KMeans(n_clusters=10).fit(X_ds)
kmeans_labels_ori = kmeans_ori.labels_

normalized_mutual_info_score(kmeans_labels_ori, y_ds)
# Out:
# 0.4906903143433434

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X_ds)
data_X_tsne = np.vstack((X_tsne.T, kmeans_labels_ori)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# ####MixUp

# %%
def mixup(data):
  view = data.copy()
  for i in range(len(view)):
    random_row_index = random.randint(0, len(view)-1)
    view[i] = view[i]*0.7  + view[random_row_index]*0.3
  return view

# %% [markdown]
# ####MixCut

# %%
def mixcut(data):
  data_copy = data.copy()
  view = data.copy()
  mask_len = int(data_copy.shape[1]*0.25)

  for i in range(len(data_copy)):
    random_row_id = random.randint(0, len(data_copy)-1)
    random_column_id = random.randint(0, data_copy.shape[1]-mask_len)
    view[i,random_column_id:(random_column_id+mask_len)] = data_copy[random_row_id,random_column_id:(random_column_id+mask_len)]
  return view

# %% [markdown]
# #### Masking with mean

# %%
def get_random_indices(data, portion_of_mask):
  return np.random.choice(data.shape[1], size=np.floor(data.shape[1]*portion_of_mask).astype(int), replace=False)

# %%
def masking_with_mean(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = column_mu[j]
              
  return view

# %% [markdown]
# ####Masking with random value in domain range

# %%
def masking_with_random(data, portion_of_mask):
  mean = np.mean(data, axis=0)

  column_min = data.min(axis=0).astype(int)
  column_max = data.max(axis=0).astype(int)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = random.randint(column_min[j], column_max[j])
              
  return view

# %% [markdown]
# ####Masking with margin distribution

# %%
def masking_with_margin_distribution(data, portion_of_mask):
  mean = np.mean(data, axis=0)
  column_mu = np.mean(data, axis=0)
  column_std = np.std(data, axis=0)

  view = data.copy()

  for i in range(len(data)): 
    masked_indices = get_random_indices(data, portion_of_mask)
   
    for j in range(len(mean)):
      if j in masked_indices:
        view[i,j] = np.random.normal(column_mu[j], column_std[j])
              
  return view

# %% [markdown]
# ####Upsampling (SMOTE like)

# %%
#put all data points in kd-tree for fast searching
kdtree = KDTree(X_ds, leaf_size=2)

# %%
#get random point in the k nearest neighbors
def get_idx_random_knn(x,k):
   _, ids = kdtree.query(x.reshape(1, -1), k=k)
   ids = ids.flatten()
   ids = ids[1:-1]
   random_id = np.random.choice(ids, 1)
   return random_id

# %%
#mix up with a random near neighbor 
def mixup_random_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = 0.5*data[i] + 0.5*data[random_neighbor_id]
  return view

# %%
#a random neighbor as augmentation
def random_near_neighbor(data, k):
  view = data.copy()
  for i in range(len(view)):
    point = data[i]
    random_neighbor_id = get_idx_random_knn(x=point, k=k)
    view[i] = data[random_neighbor_id]
  return view

# %% [markdown]
# ##Create Model and Train with Augmented Data

# %%
class MyDataSet(Dataset):
  def __init__(self, view1, view2):
 
    X_view1 = view1.copy()
    X_view2 = view2.copy()
    self.X_view1 = X_view1.copy().astype(np.float32)
    self.X_view2 = X_view2.copy().astype(np.float32)
  
  def __len__(self):
    return len(self.X_view1)
  
  def __getitem__(self, idx):
    return self.X_view1[idx], self.X_view2[idx]

# %%
# define the NN architecture
class convBackbone(nn.Module):
    def __init__(self):
        super(convBackbone, self).__init__()

        #turn on dropout for testing the 'cropping' data augmentation 
        #self.dropout = nn.Dropout(p=0.2)
        
        self.fc1 = nn.Linear(784, 256, bias=False)
        self.bn1 = nn.BatchNorm1d(256)

        self.fc2 = nn.Linear(256, 256, bias=False)
        self.bn2 = nn.BatchNorm1d(256)

        self.fc3 = nn.Linear(256, 256, bias=False)
        self.bn3 = nn.BatchNorm1d(256)


    def forward(self, x):

        #turn on dropout for testing the 'cropping' data augmentation
        #x = self.dropout(x)
        
        x = F.relu(self.bn1(self.fc1(x)))
        x = F.relu(self.bn2(self.fc2(x)))
        x = self.bn3(self.fc3(x))
                
        return x

# %%
class SimCLR(nn.Module):
    def __init__(self, backbone):
        super().__init__()
        self.backbone = backbone
        self.projection_head = SimCLRProjectionHead(256, 128, 256)

    def forward(self, x):
        x = self.backbone(x).flatten(start_dim=1)
        z = self.projection_head(x)
        return x,z

backbone = convBackbone()
model = SimCLR(backbone)

# %%
criterion = NTXentLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.05, momentum=0.9,weight_decay=1e-4)

#cosine annealing lr
scheduler = lr_scheduler.CosineAnnealingLR(optimizer,T_max=500, eta_min=0)

# %%
view1 = random_near_neighbor(X_ds, 15)
view2 = random_near_neighbor(X_ds, 15)

#turn on the following to test other augmentations

#view1 = mixup_random_neighbor(X_ds, 15)
#view2 = mixup_random_neighbor(X_ds, 15)

#view1 = mixup(X_ds)
#view2 = mixup(X_ds)

#view1 = mixcut(X_ds)
#view2 = mixcut(X_ds)

#view1 = masking_with_mean(X_ds, 0.4)
#view2 = masking_with_mean(X_ds, 0.4)

#view1 = masking_with_random(X_ds, 0.4)
#view2 = masking_with_random(X_ds, 0.4)

#view1 = masking_with_margin_distribution(X_ds, 0.4)
#view2 = masking_with_margin_distribution(X_ds, 0.4)

train_ds = MyDataSet(view1, view2)
train_dl = DataLoader(train_ds, batch_size=256, shuffle=True)

# %%
train_ds = MyDataSet(view1, view2)
train_dl = DataLoader(train_ds, batch_size=256, shuffle=True)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

for epoch in range(500):
    total_loss = 0
    for x0, x1 in train_dl:

        x0 = x0.to(device)
        x1 = x1.to(device)
        _,z0 = model(x0)
        _,z1 = model(x1)

        #z0 = (z0 - torch.mean(z0,0)) / torch.std(z0,0)
        #z1 = (z1 - torch.mean(z1,0)) / torch.std(z1,0)

        loss = criterion(z0, z1)
        total_loss += loss.detach()
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        scheduler.step()
        
    avg_loss = total_loss / len(train_dl)
    print(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
# Out:
# epoch: 00, loss: 4.68169
# epoch: 01, loss: 4.60437
# epoch: 02, loss: 4.59961
# epoch: 03, loss: 4.59365
# epoch: 04, loss: 4.58372
# epoch: 05, loss: 4.57421
# epoch: 06, loss: 4.56778
# epoch: 07, loss: 4.57007
# epoch: 08, loss: 4.56944
# epoch: 09, loss: 4.56359
# epoch: 10, loss: 4.55728
# epoch: 11, loss: 4.55880
# epoch: 12, loss: 4.56125
# epoch: 13, loss: 4.55796
# epoch: 14, loss: 4.55218
# epoch: 15, loss: 4.55110
# epoch: 16, loss: 4.55507
# epoch: 17, loss: 4.55420
# epoch: 18, loss: 4.54798
# epoch: 19, loss: 4.54552
# epoch: 20, loss: 4.54932
# epoch: 21, loss: 4.55210
# epoch: 22, loss: 4.54544
# epoch: 23, loss: 4.54061
# epoch: 24, loss: 4.54404
# epoch: 25, loss: 4.54825
# epoch: 26, loss: 4.54474
# epoch: 27, loss: 4.53840
# epoch: 28, loss: 4.53964
# epoch: 29, loss: 4.54462
# epoch: 30, loss: 4.54365
# epoch: 31, loss: 4.53690
# epoch: 32, loss: 4.53586
# epoch: 33, loss: 4.54121
# epoch: 34, loss: 4.54212
# epoch: 35, loss: 4.53599
# epoch: 36, loss: 4.53252
# epoch: 37, loss: 4.53757
# epoch: 38, loss: 4.54108
# epoch: 39, loss: 4.53569
# epoch: 40, loss: 4.52960
# epoch: 41, loss: 4.53331
# epoch: 42, loss: 4.53863
# epoch: 43, loss: 4.53623
# epoch: 44, loss: 4.52924
# epoch: 45, loss: 4.53032
# epoch: 46, loss: 4.53646
# epoch: 47, loss: 4.53556
# epoch: 48, loss: 4.52867
# epoch: 49, loss: 4.52687
# epoch: 50, loss: 4.53380
# epoch: 51, loss: 4.53536
# epoch: 52, loss: 4.52888
# epoch: 53, loss: 4.52533
# epoch: 54, loss: 4.53097
# epoch: 55, loss: 4.53490
# epoch: 56, loss: 4.52955
# epoch: 57, loss: 4.52334
# epoch: 58, loss: 4.52604
# epoch: 59, loss: 4.53317
# epoch: 60, loss: 4.52966
# epoch: 61, loss: 4.52232
# epoch: 62, loss: 4.52292
# epoch: 63, loss: 4.53185
# epoch: 64, loss: 4.53139
# epoch: 65, loss: 4.52270
# epoch: 66, loss: 4.52119
# epoch: 67, loss: 4.52867
# epoch: 68, loss: 4.53140
# epoch: 69, loss: 4.52323
# epoch: 70, loss: 4.51891
# epoch: 71, loss: 4.52470
# epoch: 72, loss: 4.53075
# epoch: 73, loss: 4.52469
# epoch: 74, loss: 4.51733
# epoch: 75, loss: 4.52145
# epoch: 76, loss: 4.52927
# epoch: 77, loss: 4.52608
# epoch: 78, loss: 4.51698
# epoch: 79, loss: 4.51821
# epoch: 80, loss: 4.52690
# epoch: 81, loss: 4.52672
# epoch: 82, loss: 4.51744
# epoch: 83, loss: 4.51564
# epoch: 84, loss: 4.52346
# epoch: 85, loss: 4.52752
# epoch: 86, loss: 4.51926
# epoch: 87, loss: 4.51403
# epoch: 88, loss: 4.52056
# epoch: 89, loss: 4.52682
# epoch: 90, loss: 4.52098
# epoch: 91, loss: 4.51375
# epoch: 92, loss: 4.51685
# epoch: 93, loss: 4.52551
# epoch: 94, loss: 4.52265
# epoch: 95, loss: 4.51391
# epoch: 96, loss: 4.51381
# epoch: 97, loss: 4.52298
# epoch: 98, loss: 4.52296
# epoch: 99, loss: 4.51483
# epoch: 100, loss: 4.51129
# epoch: 101, loss: 4.52058
# epoch: 102, loss: 4.52374
# epoch: 103, loss: 4.51559
# epoch: 104, loss: 4.51063
# epoch: 105, loss: 4.51712
# epoch: 106, loss: 4.52387
# epoch: 107, loss: 4.51749
# epoch: 108, loss: 4.50981
# epoch: 109, loss: 4.51374
# epoch: 110, loss: 4.52295
# epoch: 111, loss: 4.51906
# epoch: 112, loss: 4.51012
# epoch: 113, loss: 4.51074
# epoch: 114, loss: 4.52028
# epoch: 115, loss: 4.52093
# epoch: 116, loss: 4.51151
# epoch: 117, loss: 4.50857
# epoch: 118, loss: 4.51709
# epoch: 119, loss: 4.52187
# epoch: 120, loss: 4.51307
# epoch: 121, loss: 4.50749
# epoch: 122, loss: 4.51323
# epoch: 123, loss: 4.52122
# epoch: 124, loss: 4.51503
# epoch: 125, loss: 4.50672
# epoch: 126, loss: 4.51059
# epoch: 127, loss: 4.52029
# epoch: 128, loss: 4.51705
# epoch: 129, loss: 4.50728
# epoch: 130, loss: 4.50786
# epoch: 131, loss: 4.51726
# epoch: 132, loss: 4.51915
# epoch: 133, loss: 4.50901
# epoch: 134, loss: 4.50522
# epoch: 135, loss: 4.51473
# epoch: 136, loss: 4.51925
# epoch: 137, loss: 4.51070
# epoch: 138, loss: 4.50412
# epoch: 139, loss: 4.51150
# epoch: 140, loss: 4.51915
# epoch: 141, loss: 4.51371
# epoch: 142, loss: 4.50505
# epoch: 143, loss: 4.50810
# epoch: 144, loss: 4.51768
# epoch: 145, loss: 4.51573
# epoch: 146, loss: 4.50600
# epoch: 147, loss: 4.50534
# epoch: 148, loss: 4.51524
# epoch: 149, loss: 4.51757
# epoch: 150, loss: 4.50755
# epoch: 151, loss: 4.50424
# epoch: 152, loss: 4.51227
# epoch: 153, loss: 4.51831
# epoch: 154, loss: 4.50919
# epoch: 155, loss: 4.50238
# epoch: 156, loss: 4.50870
# epoch: 157, loss: 4.51821
# epoch: 158, loss: 4.51058
# epoch: 159, loss: 4.50237
# epoch: 160, loss: 4.50550
# epoch: 161, loss: 4.51633
# epoch: 162, loss: 4.51376
# epoch: 163, loss: 4.50423
# epoch: 164, loss: 4.50338
# epoch: 165, loss: 4.51362
# epoch: 166, loss: 4.51568
# epoch: 167, loss: 4.50632
# epoch: 168, loss: 4.50162
# epoch: 169, loss: 4.51025
# epoch: 170, loss: 4.51600
# epoch: 171, loss: 4.50794
# epoch: 172, loss: 4.50040
# epoch: 173, loss: 4.50685
# epoch: 174, loss: 4.51645
# epoch: 175, loss: 4.50997
# epoch: 176, loss: 4.50108
# epoch: 177, loss: 4.50350
# epoch: 178, loss: 4.51390
# epoch: 179, loss: 4.51251
# epoch: 180, loss: 4.50118
# epoch: 181, loss: 4.50117
# epoch: 182, loss: 4.51202
# epoch: 183, loss: 4.51451
# epoch: 184, loss: 4.50446
# epoch: 185, loss: 4.49899
# epoch: 186, loss: 4.50844
# epoch: 187, loss: 4.51489
# epoch: 188, loss: 4.50584
# epoch: 189, loss: 4.49833
# epoch: 190, loss: 4.50486
# epoch: 191, loss: 4.51414
# epoch: 192, loss: 4.50908
# epoch: 193, loss: 4.49914
# epoch: 194, loss: 4.50236
# epoch: 195, loss: 4.51297
# epoch: 196, loss: 4.51194
# epoch: 197, loss: 4.50061
# epoch: 198, loss: 4.49999
# epoch: 199, loss: 4.50978
# epoch: 200, loss: 4.51330
# epoch: 201, loss: 4.50323
# epoch: 202, loss: 4.49797
# epoch: 203, loss: 4.50672
# epoch: 204, loss: 4.51437
# epoch: 205, loss: 4.50562
# epoch: 206, loss: 4.49765
# epoch: 207, loss: 4.50384
# epoch: 208, loss: 4.51352
# epoch: 209, loss: 4.50785
# epoch: 210, loss: 4.49856
# epoch: 211, loss: 4.50028
# epoch: 212, loss: 4.51191
# epoch: 213, loss: 4.51000
# epoch: 214, loss: 4.49968
# epoch: 215, loss: 4.49805
# epoch: 216, loss: 4.50932
# epoch: 217, loss: 4.51199
# epoch: 218, loss: 4.50149
# epoch: 219, loss: 4.49662
# epoch: 220, loss: 4.50493
# epoch: 221, loss: 4.51282
# epoch: 222, loss: 4.50448
# epoch: 223, loss: 4.49695
# epoch: 224, loss: 4.50205
# epoch: 225, loss: 4.51253
# epoch: 226, loss: 4.50792
# epoch: 227, loss: 4.49658
# epoch: 228, loss: 4.49874
# epoch: 229, loss: 4.51058
# epoch: 230, loss: 4.51024
# epoch: 231, loss: 4.49920
# epoch: 232, loss: 4.49734
# epoch: 233, loss: 4.50755
# epoch: 234, loss: 4.51139
# epoch: 235, loss: 4.50059
# epoch: 236, loss: 4.49553
# epoch: 237, loss: 4.50348
# epoch: 238, loss: 4.51156
# epoch: 239, loss: 4.50429
# epoch: 240, loss: 4.49594
# epoch: 241, loss: 4.50168
# epoch: 242, loss: 4.51091
# epoch: 243, loss: 4.50677
# epoch: 244, loss: 4.49662
# epoch: 245, loss: 4.49775
# epoch: 246, loss: 4.51015
# epoch: 247, loss: 4.50948
# epoch: 248, loss: 4.49813
# epoch: 249, loss: 4.49574
# epoch: 250, loss: 4.50652
# epoch: 251, loss: 4.51040
# epoch: 252, loss: 4.49994
# epoch: 253, loss: 4.49406
# epoch: 254, loss: 4.50266
# epoch: 255, loss: 4.51209
# epoch: 256, loss: 4.50322
# epoch: 257, loss: 4.49420
# epoch: 258, loss: 4.49954
# epoch: 259, loss: 4.51066
# epoch: 260, loss: 4.50624
# epoch: 261, loss: 4.49573
# epoch: 262, loss: 4.49696
# epoch: 263, loss: 4.50883
# epoch: 264, loss: 4.50878
# epoch: 265, loss: 4.49711
# epoch: 266, loss: 4.49554
# epoch: 267, loss: 4.50591
# epoch: 268, loss: 4.51045
# epoch: 269, loss: 4.49973
# epoch: 270, loss: 4.49369
# epoch: 271, loss: 4.50219
# epoch: 272, loss: 4.51065
# epoch: 273, loss: 4.50333
# epoch: 274, loss: 4.49392
# epoch: 275, loss: 4.49923
# epoch: 276, loss: 4.50891
# epoch: 277, loss: 4.50543
# epoch: 278, loss: 4.49489
# epoch: 279, loss: 4.49633
# epoch: 280, loss: 4.50667
# epoch: 281, loss: 4.50878
# epoch: 282, loss: 4.49701
# epoch: 283, loss: 4.49440
# epoch: 284, loss: 4.50410
# epoch: 285, loss: 4.50981
# epoch: 286, loss: 4.49914
# epoch: 287, loss: 4.49249
# epoch: 288, loss: 4.50133
# epoch: 289, loss: 4.51023
# epoch: 290, loss: 4.50229
# epoch: 291, loss: 4.49234
# epoch: 292, loss: 4.49753
# epoch: 293, loss: 4.50945
# epoch: 294, loss: 4.50532
# epoch: 295, loss: 4.49432
# epoch: 296, loss: 4.49564
# epoch: 297, loss: 4.50602
# epoch: 298, loss: 4.50816
# epoch: 299, loss: 4.49612
# epoch: 300, loss: 4.49288
# epoch: 301, loss: 4.50376
# epoch: 302, loss: 4.50994
# epoch: 303, loss: 4.49887
# epoch: 304, loss: 4.49192
# epoch: 305, loss: 4.50076
# epoch: 306, loss: 4.50842
# epoch: 307, loss: 4.50159
# epoch: 308, loss: 4.49215
# epoch: 309, loss: 4.49619
# epoch: 310, loss: 4.50785
# epoch: 311, loss: 4.50464
# epoch: 312, loss: 4.49343
# epoch: 313, loss: 4.49394
# epoch: 314, loss: 4.50695
# epoch: 315, loss: 4.50708
# epoch: 316, loss: 4.49627
# epoch: 317, loss: 4.49250
# epoch: 318, loss: 4.50333
# epoch: 319, loss: 4.50893
# epoch: 320, loss: 4.49880
# epoch: 321, loss: 4.49126
# epoch: 322, loss: 4.49888
# epoch: 323, loss: 4.50950
# epoch: 324, loss: 4.50213
# epoch: 325, loss: 4.49221
# epoch: 326, loss: 4.49704
# epoch: 327, loss: 4.50723
# epoch: 328, loss: 4.50465
# epoch: 329, loss: 4.49332
# epoch: 330, loss: 4.49327
# epoch: 331, loss: 4.50398
# epoch: 332, loss: 4.50691
# epoch: 333, loss: 4.49556
# epoch: 334, loss: 4.49160
# epoch: 335, loss: 4.50128
# epoch: 336, loss: 4.50742
# epoch: 337, loss: 4.49891
# epoch: 338, loss: 4.49031
# epoch: 339, loss: 4.49788
# epoch: 340, loss: 4.50814
# epoch: 341, loss: 4.50078
# epoch: 342, loss: 4.49082
# epoch: 343, loss: 4.49431
# epoch: 344, loss: 4.50647
# epoch: 345, loss: 4.50512
# epoch: 346, loss: 4.49226
# epoch: 347, loss: 4.49273
# epoch: 348, loss: 4.50434
# epoch: 349, loss: 4.50641
# epoch: 350, loss: 4.49543
# epoch: 351, loss: 4.49163
# epoch: 352, loss: 4.50026
# epoch: 353, loss: 4.50708
# epoch: 354, loss: 4.49802
# epoch: 355, loss: 4.49025
# epoch: 356, loss: 4.49723
# epoch: 357, loss: 4.50804
# epoch: 358, loss: 4.50065
# epoch: 359, loss: 4.49053
# epoch: 360, loss: 4.49452
# epoch: 361, loss: 4.50654
# epoch: 362, loss: 4.50355
# epoch: 363, loss: 4.49209
# epoch: 364, loss: 4.49181
# epoch: 365, loss: 4.50301
# epoch: 366, loss: 4.50556
# epoch: 367, loss: 4.49431
# epoch: 368, loss: 4.49108
# epoch: 369, loss: 4.49971
# epoch: 370, loss: 4.50787
# epoch: 371, loss: 4.49817
# epoch: 372, loss: 4.48924
# epoch: 373, loss: 4.49662
# epoch: 374, loss: 4.50736
# epoch: 375, loss: 4.50089
# epoch: 376, loss: 4.49018
# epoch: 377, loss: 4.49338
# epoch: 378, loss: 4.50470
# epoch: 379, loss: 4.50341
# epoch: 380, loss: 4.49137
# epoch: 381, loss: 4.49127
# epoch: 382, loss: 4.50292
# epoch: 383, loss: 4.50581
# epoch: 384, loss: 4.49382
# epoch: 385, loss: 4.48970
# epoch: 386, loss: 4.49880
# epoch: 387, loss: 4.50743
# epoch: 388, loss: 4.49846
# epoch: 389, loss: 4.49101
# epoch: 390, loss: 4.49623
# epoch: 391, loss: 4.50562
# epoch: 392, loss: 4.50043
# epoch: 393, loss: 4.48984
# epoch: 394, loss: 4.49270
# epoch: 395, loss: 4.50442
# epoch: 396, loss: 4.50495
# epoch: 397, loss: 4.49222
# epoch: 398, loss: 4.48978
# epoch: 399, loss: 4.50195
# epoch: 400, loss: 4.50581
# epoch: 401, loss: 4.49545
# epoch: 402, loss: 4.48891
# epoch: 403, loss: 4.49865
# epoch: 404, loss: 4.50666
# epoch: 405, loss: 4.49806
# epoch: 406, loss: 4.48880
# epoch: 407, loss: 4.49556
# epoch: 408, loss: 4.50673
# epoch: 409, loss: 4.49999
# epoch: 410, loss: 4.48952
# epoch: 411, loss: 4.49211
# epoch: 412, loss: 4.50423
# epoch: 413, loss: 4.50377
# epoch: 414, loss: 4.49139
# epoch: 415, loss: 4.48937
# epoch: 416, loss: 4.49997
# epoch: 417, loss: 4.50667
# epoch: 418, loss: 4.49497
# epoch: 419, loss: 4.48912
# epoch: 420, loss: 4.49772
# epoch: 421, loss: 4.50527
# epoch: 422, loss: 4.49770
# epoch: 423, loss: 4.48808
# epoch: 424, loss: 4.49455
# epoch: 425, loss: 4.50573
# epoch: 426, loss: 4.50183
# epoch: 427, loss: 4.48917
# epoch: 428, loss: 4.49128
# epoch: 429, loss: 4.50402
# epoch: 430, loss: 4.50347
# epoch: 431, loss: 4.49168
# epoch: 432, loss: 4.48901
# epoch: 433, loss: 4.50114
# epoch: 434, loss: 4.50460
# epoch: 435, loss: 4.49424
# epoch: 436, loss: 4.48768
# epoch: 437, loss: 4.49686
# epoch: 438, loss: 4.50569
# epoch: 439, loss: 4.49737
# epoch: 440, loss: 4.48787
# epoch: 441, loss: 4.49420
# epoch: 442, loss: 4.50526
# epoch: 443, loss: 4.49977
# epoch: 444, loss: 4.48927
# epoch: 445, loss: 4.49072
# epoch: 446, loss: 4.50341
# epoch: 447, loss: 4.50336
# epoch: 448, loss: 4.49120
# epoch: 449, loss: 4.48875
# epoch: 450, loss: 4.50039
# epoch: 451, loss: 4.50491
# epoch: 452, loss: 4.49413
# epoch: 453, loss: 4.48731
# epoch: 454, loss: 4.49697
# epoch: 455, loss: 4.50624
# epoch: 456, loss: 4.49705
# epoch: 457, loss: 4.48764
# epoch: 458, loss: 4.49342
# epoch: 459, loss: 4.50487
# epoch: 460, loss: 4.50030
# epoch: 461, loss: 4.48791
# epoch: 462, loss: 4.49065
# epoch: 463, loss: 4.50343
# epoch: 464, loss: 4.50245
# epoch: 465, loss: 4.49063
# epoch: 466, loss: 4.48861
# epoch: 467, loss: 4.50009
# epoch: 468, loss: 4.50543
# epoch: 469, loss: 4.49409
# epoch: 470, loss: 4.48731
# epoch: 471, loss: 4.49664
# epoch: 472, loss: 4.50533
# epoch: 473, loss: 4.49691
# epoch: 474, loss: 4.48783
# epoch: 475, loss: 4.49221
# epoch: 476, loss: 4.50519
# epoch: 477, loss: 4.50039
# epoch: 478, loss: 4.48890
# epoch: 479, loss: 4.48970
# epoch: 480, loss: 4.50226
# epoch: 481, loss: 4.50304
# epoch: 482, loss: 4.49163
# epoch: 483, loss: 4.48831
# epoch: 484, loss: 4.49913
# epoch: 485, loss: 4.50389
# epoch: 486, loss: 4.49449
# epoch: 487, loss: 4.48782
# epoch: 488, loss: 4.49487
# epoch: 489, loss: 4.50518
# epoch: 490, loss: 4.49733
# epoch: 491, loss: 4.48735
# epoch: 492, loss: 4.49258
# epoch: 493, loss: 4.50330
# epoch: 494, loss: 4.49986
# epoch: 495, loss: 4.48822
# epoch: 496, loss: 4.49026
# epoch: 497, loss: 4.50100
# epoch: 498, loss: 4.50237
# epoch: 499, loss: 4.49062

# %% [markdown]
# ##Check the Training Result

# %%
ds_cl= MyDataSet(X_ds, X_ds)
dl_cl = DataLoader(ds_cl, batch_size=256)

# %%
embeddings = []

# disable gradients for faster calculations
model.eval()
with torch.no_grad():
    for dl_cl1, dl_cl2 in dl_cl:

        dl_cl1 = dl_cl1.to(device)
        x,z = model(dl_cl1)
        
        # store the embeddings in lists
        embeddings.append(x)

# concatenate the embeddings, targets and convert to numpy
embeddings = torch.cat(embeddings, dim=0)
embeddings = embeddings.cpu().numpy()

# %%
test = (embeddings - embeddings.mean(axis=0)) / (embeddings.std(axis=0))

# %%
#KMeans in latent space
kmeans_backbone = KMeans(n_clusters=10).fit(test)
kmeans_labels_backbone = kmeans_backbone.labels_

# %%
normalized_mutual_info_score(kmeans_labels_backbone, y_ds)
# Out:
# 0.776473808469658

# %%
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(embeddings)
data_X_tsne = np.vstack((X_tsne.T, kmeans_labels_backbone)).T
df_tsne = pd.DataFrame(data_X_tsne, columns=['dim1', 'dim2', 'y'])
plt.figure(figsize=(8,8))
sns.scatterplot(data=df_tsne, hue='y', x='dim1', y='dim2', palette='pastel')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
#NMI increases from 0.49 to 0.77
